# %%
import pandas as pd
import json
input_df = pd.read_csv(r"D:\Nexensus_Projects\GST_TaxPayer\panDetails_ScrapedData.csv")
for i in range(len(input_df)):
    ls  = json.loads(input_df['GSTIN'][i])['gstinResList']
    # print(ls)
    if all(i['authStatus'].lower() == 'inactive' for i in ls):
        if len(ls) !=0:
            print(ls)
# Out:
# [{'gstin': '06AAICB0405D1ZE', 'authStatus': 'Inactive', 'stateCd': '06'}]
# [{'gstin': '07AAECT9458N1ZI', 'authStatus': 'Inactive', 'stateCd': '07'}]
# [{'gstin': '04AADCI8824Q3Z0', 'authStatus': 'Inactive', 'stateCd': '04'}, {'gstin': '03AADCI8824Q1Z4', 'authStatus': 'Inactive', 'stateCd': '03'}, {'gstin': '04AADCI8824Q1Z2', 'authStatus': 'Inactive', 'stateCd': '04'}, {'gstin': '04AADCI8824Q2Z1', 'authStatus': 'Inactive', 'stateCd': '04'}]
# [{'gstin': '23AAJCP4422B1ZY', 'authStatus': 'Inactive', 'stateCd': '23'}]
# [{'gstin': '36AADCT1588Q1ZL', 'authStatus': 'Inactive', 'stateCd': '36'}, {'gstin': '36AADCT1588Q2ZK', 'authStatus': 'Inactive', 'stateCd': '36'}, {'gstin': '37AADCT1588Q1ZJ', 'authStatus': 'Inactive', 'stateCd': '37'}]
# [{'gstin': '22AACCJ0532D1ZE', 'authStatus': 'Inactive', 'stateCd': '22'}, {'gstin': '08AACCJ0532D1Z4', 'authStatus': 'Inactive', 'stateCd': '08'}]
# [{'gstin': '21AABCT5430H2ZR', 'authStatus': 'Inactive', 'stateCd': '21'}, {'gstin': '21AABCT5430H1ZS', 'authStatus': 'Inactive', 'stateCd': '21'}]
# [{'gstin': '18AABCN3976A1ZK', 'authStatus': 'Inactive', 'stateCd': '18'}]
# [{'gstin': '06AAACA6036B1ZC', 'authStatus': 'Inactive', 'stateCd': '06'}, {'gstin': '02AAACA6036B1ZK', 'authStatus': 'Inactive', 'stateCd': '02'}, {'gstin': '07AAACA6036B1ZA', 'authStatus': 'Inactive', 'stateCd': '07'}, {'gstin': '06AAACA6036B2ZB', 'authStatus': 'Inactive', 'stateCd': '06'}]
# [{'gstin': '24AAJCP9066B1ZE', 'authStatus': 'Inactive', 'stateCd': '24'}]
# [{'gstin': '29AAJCC2140F1ZW', 'authStatus': 'Inactive', 'stateCd': '29'}]
# [{'gstin': '24AALCR1395M1ZV', 'authStatus': 'Inactive', 'stateCd': '24'}]
# [{'gstin': '09AAFCC1151L1ZO', 'authStatus': 'Inactive', 'stateCd': '09'}]
# [{'gstin': '09AACCT3842Q1ZQ', 'authStatus': 'Inactive', 'stateCd': '09'}, {'gstin': '07AACCT3842Q1ZU', 'authStatus': 'Inactive', 'stateCd': '07'}]
# [{'gstin': '29AAJCD4832H1ZG', 'authStatus': 'Inactive', 'stateCd': '29'}]
# [{'gstin': '29AAECJ1279R1ZR', 'authStatus': 'Inactive', 'stateCd': '29'}]
# [{'gstin': '29AAGCR8355J1ZQ', 'authStatus': 'Inactive', 'stateCd': '29'}, {'gstin': '36AAGCR8355J1ZV', 'authStatus': 'Inactive', 'stateCd': '36'}, {'gstin': '37AAGCR8355J1ZT', 'authStatus': 'Inactive', 'stateCd': '37'}]
# [{'gstin': '03AAFCV5111P1Z9', 'authStatus': 'Inactive', 'stateCd': '03'}, {'gstin': '07AAFCV5111P1Z1', 'authStatus': 'Inactive', 'stateCd': '07'}, {'gstin': '09AAFCV5111P1ZX', 'authStatus': 'Inactive', 'stateCd': '09'}]
# [{'gstin': '05AAHCK4239K1ZD', 'authStatus': 'Inactive', 'stateCd': '05'}]
# [{'gstin': '23AAACU6406F1ZQ', 'authStatus': 'Inactive', 'stateCd': '23'}]
# [{'gstin': '27AAACZ7344R1ZH', 'authStatus': 'Inactive', 'stateCd': '27'}, {'gstin': '24AAACZ7344R1ZN', 'authStatus': 'Inactive', 'stateCd': '24'}, {'gstin': '29AAACZ7344R1ZD', 'authStatus': 'Inactive', 'stateCd': '29'}, {'gstin': '24AAACZ7344R3ZL', 'authStatus': 'Inactive', 'stateCd': '24'}]
# [{'gstin': '19AAECA8850H1ZF', 'authStatus': 'Inactive', 'stateCd': '19'}]
# [{'gstin': '09AAICS7866H1ZO', 'authStatus': 'Inactive', 'stateCd': '09'}]
# [{'gstin': '27AAACD6236C1Z1', 'authStatus': 'Inactive', 'stateCd': '27'}]
# [{'gstin': '07AADCH1667A1ZZ', 'authStatus': 'Inactive', 'stateCd': '07'}]
# [{'gstin': '27AAECE4521D1Z2', 'authStatus': 'Inactive', 'stateCd': '27'}]
# [{'gstin': '07AAACJ2278G1ZN', 'authStatus': 'Inactive', 'stateCd': '07'}, {'gstin': '06AAACJ2278G1ZP', 'authStatus': 'Inactive', 'stateCd': '06'}, {'gstin': '07AAACJ2278G2ZM', 'authStatus': 'Inactive', 'stateCd': '07'}]
# [{'gstin': '29AAACH6382F2ZF', 'authStatus': 'Inactive', 'stateCd': '29'}, {'gstin': '29AAACH6382F1ZG', 'authStatus': 'Inactive', 'stateCd': '29'}]
# [{'gstin': '27AAFCD5707P1Z7', 'authStatus': 'Inactive', 'stateCd': '27'}]
# [{'gstin': '27AADCC0683R1Z5', 'authStatus': 'Inactive', 'stateCd': '27'}]
# [{'gstin': '04AABCC5226E3Z7', 'authStatus': 'Inactive', 'stateCd': '04'}, {'gstin': '04AABCC5226E2Z8', 'authStatus': 'Inactive', 'stateCd': '04'}, {'gstin': '04AABCC5226E5Z5', 'authStatus': 'Inactive', 'stateCd': '04'}, {'gstin': '04AABCC5226E1Z9', 'authStatus': 'Inactive', 'stateCd': '04'}]
# [{'gstin': '06AACCO6441J1ZE', 'authStatus': 'Inactive', 'stateCd': '06'}]
# [{'gstin': '08AAGCH2967N1ZY', 'authStatus': 'Inactive', 'stateCd': '08'}]
# [{'gstin': '24AAACM5669E1ZJ', 'authStatus': 'Inactive', 'stateCd': '24'}, {'gstin': '33AAACM5669E1ZK', 'authStatus': 'Inactive', 'stateCd': '33'}, {'gstin': '27AAACM5669E1ZD', 'authStatus': 'Inactive', 'stateCd': '27'}]
