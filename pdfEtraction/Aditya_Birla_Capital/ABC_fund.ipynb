# %%
############## Code to split pdf to keep only pages with Rating table in it #####################
import pdfplumber
from PyPDF2 import PdfWriter, PdfReader
from datetime import datetime

# month_name = datetime.now().strftime("%b")
month_name = "July"

input_pdf_path = "ABSLMF_Empower_July25.pdf"
output_pdf_path = "filtered_{}.pdf".format(input_pdf_path.split(".")[0])

reader = PdfReader(input_pdf_path)
writer = PdfWriter()
fund_list = []

with pdfplumber.open(input_pdf_path) as pdf:
    for page_num, page in enumerate(pdf.pages):
        # page_heading = page.extract_text_lines()[0]['text'].strip().replace(" ", "_")
        # tables = page.extract_tables()

        # if not tables:
        #     continue

        # for table in tables:
        #     header = table[0]
        page_lines = [obj['text'] for obj in page.extract_text_lines()]
        if any("Issuer % to Net Assets Rating" in item for item in page_lines) or any("Issuer Rating" in item for item in page_lines):
        # if "Issuer % to Net Assets Rating" in page_lines or "Issuer Rating" in page_lines:
            writer.add_page(reader.pages[page_num])
            continue  # add this page once, then move to next page



# Save the filtered PDF
with open(output_pdf_path, "wb") as f_out:
    writer.write(f_out)

print(f"✅ New PDF created: {output_pdf_path}")
# Out:
# ✅ New PDF created: filtered_ABSLMF_Empower_July25.pdf

# %%
fund_list = ["Large Cap Fund",
"Retirement Fund - The 30s Plan",
"Retirement Fund - The 30s Plan",
"Retirement Fund - The 40s Plan",
"Retirement Fund - The 40s Plan",
"Retirement Fund - The 50s Plan",
"Equity Hybrid '95 Fund",
"Equity Savings Fund",
"Regular Savings Fund",
"Multi Asset Allocation Fund",
"Balanced Advantage Fund",
"Overnight Fund",
"Liquid Fund",
"Liquid Fund",
"Money Manager Fund",
"Money Manager Fund",
"Low Duration Fund",
"Low Duration Fund",
"Savings Fund",
"Savings Fund",
"Floating Rate Fund",
"Floating Rate Fund",
"Floating Rate Fund",
"Corporate Bond Fund",
"Corporate Bond Fund",
"Corporate Bond Fund",
"Short Term Fund",
"Short Term Fund",
"Banking & PSU Debt Fund",
"Banking & PSU Debt Fund",
"Medium Term Plan",
"Medium Term Plan",
"Credit Risk Fund",
"Dynamic Bond Fund",
"Income Fund",
"Government Securities Fund",
"Retirement Fund 'The 50s Plus - Debt Plan'",
"Long Duration Fund",
"NIFTY SDL Plus PSU Bond Sep 2026 60colon40 Index Fund",
"NIFTY SDL Plus PSU Bond Sep 2026 60colon40 Index Fund",
"Nifty SDL Apr 2027 Index Fund",
"Nifty SDL Apr 2027 Index Fund",
"CRISIL IBX 60colon40 SDL + AAA PSU - Apr 2027 Index Fund",
"Nifty SDL Sep 2025 Index Fund",
"CRISIL IBX Gilt - April 2026 Index Fund",
"CRISIL IBX 50colon50 Gilt Plus SDL Apr 2028 Index Fund",
"CRISIL IBX Gilt Apr 2029 Index Fund",
"Nifty SDL Sep 2027 Index Fund",
"CRISIL IBX Gilt Apr 2028 Index Fund",
"CRISIL IBX SDL Jun 2032 Index Fund",
"CRISIL IBX 60colon40 SDL + AAA PSU Apr 2026 Index Fund",
"CRISIL IBX Gilt April 2033 Index Fund",
"CRISIL IBX Gilt June 2027 Index Fund",
"CRISIL-IBX AAA NBFC-HFC Index - Dec 2025 Fund",
"CRISIL-IBX AAA NBFC-HFC Index - Sep 2026 Fund",
"CRISIL-IBX AAA Financial Services Index - Sep 2027 Fund",
"CRISIL-IBX Financial Services 3 to 6 Months Debt Index Fund",
"CRISIL-IBX Financial Services 9-12 Months Debt Index Fund",
"Gold ETF",
"CRISIL Liquid Overnight ETF",
"CRISIL Broad Based Gilt ETF",
"CRISIL 10 Year Gilt ETF"
]

# %%
import os
import cv2
import numpy as np
from pdf2image import convert_from_path

# === Input PDF path ===
pdf_path = output_pdf_path
left_folder = r"D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots"
right_folder = r"D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots"

os.makedirs(left_folder, exist_ok=True)
os.makedirs(right_folder, exist_ok=True)

# === Optional: If you have fund names per page ===
# fund_list = ["Fund1", "Fund2", "Fund3"]  # Replace with your actual list

# === Step 1: Convert PDF pages to images ===
images = convert_from_path(pdf_path, dpi=300)  # High DPI = good clarity

# === Step 2: Process each page ===
for idx, pil_image in enumerate(images):
    # Convert PIL to OpenCV (BGR)
    image = np.array(pil_image)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    # Get dimensions
    height, width, _ = image.shape

    # === Split vertically ===
    mid_x = width // 2

    # Left half
    left_half = image[:, :mid_x]

    # Right half
    right_half = image[:, mid_x:]

    # Use fund name if available, else fallback
    fund_name = fund_list[idx] if idx < len(fund_list) else f"page_{idx+1}"
    # fund_name = "ABC"

    # === Save images ===
    left_path = os.path.join(left_folder, f"{fund_name}_page_{idx+1}_left.png")
    right_path = os.path.join(right_folder, f"{fund_name}_page_{idx+1}_right.png")

    cv2.imwrite(left_path, left_half)
    cv2.imwrite(right_path, right_half)

    print(f"✅ Split Page {idx+1}:")
    print(f"   Left  → {left_path}")
    print(f"   Right → {right_path}")

print("\n🎯 All pages processed and saved successfully!")
# Out:
# ✅ Split Page 1:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Large Cap Fund_page_1_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Large Cap Fund_page_1_right.png
# ✅ Split Page 2:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Retirement Fund - The 30s Plan_page_2_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Retirement Fund - The 30s Plan_page_2_right.png
# ✅ Split Page 3:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Retirement Fund - The 30s Plan_page_3_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Retirement Fund - The 30s Plan_page_3_right.png
# ✅ Split Page 4:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Retirement Fund - The 40s Plan_page_4_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Retirement Fund - The 40s Plan_page_4_right.png
# ✅ Split Page 5:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Retirement Fund - The 40s Plan_page_5_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Retirement Fund - The 40s Plan_page_5_right.png
# ✅ Split Page 6:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Retirement Fund - The 50s Plan_page_6_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Retirement Fund - The 50s Plan_page_6_right.png
# ✅ Split Page 7:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Equity Hybrid '95 Fund_page_7_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Equity Hybrid '95 Fund_page_7_right.png
# ✅ Split Page 8:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Equity Savings Fund_page_8_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Equity Savings Fund_page_8_right.png
# ✅ Split Page 9:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Regular Savings Fund_page_9_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Regular Savings Fund_page_9_right.png
# ✅ Split Page 10:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Multi Asset Allocation Fund_page_10_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Multi Asset Allocation Fund_page_10_right.png
# ✅ Split Page 11:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Balanced Advantage Fund_page_11_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Balanced Advantage Fund_page_11_right.png
# ✅ Split Page 12:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Overnight Fund_page_12_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Overnight Fund_page_12_right.png
# ✅ Split Page 13:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Liquid Fund_page_13_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Liquid Fund_page_13_right.png
# ✅ Split Page 14:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Liquid Fund_page_14_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Liquid Fund_page_14_right.png
# ✅ Split Page 15:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Money Manager Fund_page_15_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Money Manager Fund_page_15_right.png
# ✅ Split Page 16:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Money Manager Fund_page_16_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Money Manager Fund_page_16_right.png
# ✅ Split Page 17:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Low Duration Fund_page_17_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Low Duration Fund_page_17_right.png
# ✅ Split Page 18:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Low Duration Fund_page_18_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Low Duration Fund_page_18_right.png
# ✅ Split Page 19:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Savings Fund_page_19_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Savings Fund_page_19_right.png
# ✅ Split Page 20:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Savings Fund_page_20_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Savings Fund_page_20_right.png
# ✅ Split Page 21:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Floating Rate Fund_page_21_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Floating Rate Fund_page_21_right.png
# ✅ Split Page 22:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Floating Rate Fund_page_22_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Floating Rate Fund_page_22_right.png
# ✅ Split Page 23:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Floating Rate Fund_page_23_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Floating Rate Fund_page_23_right.png
# ✅ Split Page 24:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Corporate Bond Fund_page_24_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Corporate Bond Fund_page_24_right.png
# ✅ Split Page 25:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Corporate Bond Fund_page_25_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Corporate Bond Fund_page_25_right.png
# ✅ Split Page 26:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Corporate Bond Fund_page_26_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Corporate Bond Fund_page_26_right.png
# ✅ Split Page 27:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Short Term Fund_page_27_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Short Term Fund_page_27_right.png
# ✅ Split Page 28:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Short Term Fund_page_28_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Short Term Fund_page_28_right.png
# ✅ Split Page 29:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Banking & PSU Debt Fund_page_29_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Banking & PSU Debt Fund_page_29_right.png
# ✅ Split Page 30:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Banking & PSU Debt Fund_page_30_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Banking & PSU Debt Fund_page_30_right.png
# ✅ Split Page 31:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Medium Term Plan_page_31_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Medium Term Plan_page_31_right.png
# ✅ Split Page 32:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Medium Term Plan_page_32_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Medium Term Plan_page_32_right.png
# ✅ Split Page 33:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Credit Risk Fund_page_33_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Credit Risk Fund_page_33_right.png
# ✅ Split Page 34:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Dynamic Bond Fund_page_34_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Dynamic Bond Fund_page_34_right.png
# ✅ Split Page 35:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Income Fund_page_35_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Income Fund_page_35_right.png
# ✅ Split Page 36:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Government Securities Fund_page_36_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Government Securities Fund_page_36_right.png
# ✅ Split Page 37:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Retirement Fund 'The 50s Plus - Debt Plan'_page_37_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Retirement Fund 'The 50s Plus - Debt Plan'_page_37_right.png
# ✅ Split Page 38:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Long Duration Fund_page_38_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Long Duration Fund_page_38_right.png
# ✅ Split Page 39:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\NIFTY SDL Plus PSU Bond Sep 2026 60colon40 Index Fund_page_39_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\NIFTY SDL Plus PSU Bond Sep 2026 60colon40 Index Fund_page_39_right.png
# ✅ Split Page 40:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\NIFTY SDL Plus PSU Bond Sep 2026 60colon40 Index Fund_page_40_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\NIFTY SDL Plus PSU Bond Sep 2026 60colon40 Index Fund_page_40_right.png
# ✅ Split Page 41:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Nifty SDL Apr 2027 Index Fund_page_41_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Nifty SDL Apr 2027 Index Fund_page_41_right.png
# ✅ Split Page 42:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Nifty SDL Apr 2027 Index Fund_page_42_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Nifty SDL Apr 2027 Index Fund_page_42_right.png
# ✅ Split Page 43:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL IBX 60colon40 SDL + AAA PSU - Apr 2027 Index Fund_page_43_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL IBX 60colon40 SDL + AAA PSU - Apr 2027 Index Fund_page_43_right.png
# ✅ Split Page 44:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Nifty SDL Sep 2025 Index Fund_page_44_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Nifty SDL Sep 2025 Index Fund_page_44_right.png
# ✅ Split Page 45:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL IBX Gilt - April 2026 Index Fund_page_45_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL IBX Gilt - April 2026 Index Fund_page_45_right.png
# ✅ Split Page 46:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL IBX 50colon50 Gilt Plus SDL Apr 2028 Index Fund_page_46_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL IBX 50colon50 Gilt Plus SDL Apr 2028 Index Fund_page_46_right.png
# ✅ Split Page 47:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL IBX Gilt Apr 2029 Index Fund_page_47_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL IBX Gilt Apr 2029 Index Fund_page_47_right.png
# ✅ Split Page 48:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Nifty SDL Sep 2027 Index Fund_page_48_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Nifty SDL Sep 2027 Index Fund_page_48_right.png
# ✅ Split Page 49:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL IBX Gilt Apr 2028 Index Fund_page_49_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL IBX Gilt Apr 2028 Index Fund_page_49_right.png
# ✅ Split Page 50:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL IBX SDL Jun 2032 Index Fund_page_50_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL IBX SDL Jun 2032 Index Fund_page_50_right.png
# ✅ Split Page 51:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL IBX 60cplon40 SDL + AAA PSU Apr 2026 Index Fund_page_51_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL IBX 60cplon40 SDL + AAA PSU Apr 2026 Index Fund_page_51_right.png
# ✅ Split Page 52:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL IBX Gilt April 2033 Index Fund_page_52_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL IBX Gilt April 2033 Index Fund_page_52_right.png
# ✅ Split Page 53:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL IBX Gilt June 2027 Index Fund_page_53_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL IBX Gilt June 2027 Index Fund_page_53_right.png
# ✅ Split Page 54:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL-IBX AAA NBFC-HFC Index - Dec 2025 Fund_page_54_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL-IBX AAA NBFC-HFC Index - Dec 2025 Fund_page_54_right.png
# ✅ Split Page 55:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL-IBX AAA NBFC-HFC Index - Sep 2026 Fund_page_55_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL-IBX AAA NBFC-HFC Index - Sep 2026 Fund_page_55_right.png
# ✅ Split Page 56:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL-IBX AAA Financial Services Index - Sep 2027 Fund_page_56_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL-IBX AAA Financial Services Index - Sep 2027 Fund_page_56_right.png
# ✅ Split Page 57:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL-IBX Financial Services 3 to 6 Months Debt Index Fund_page_57_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL-IBX Financial Services 3 to 6 Months Debt Index Fund_page_57_right.png
# ✅ Split Page 58:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL-IBX Financial Services 9-12 Months Debt Index Fund_page_58_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL-IBX Financial Services 9-12 Months Debt Index Fund_page_58_right.png
# ✅ Split Page 59:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\Gold ETF_page_59_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\Gold ETF_page_59_right.png
# ✅ Split Page 60:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL Liquid Overnight ETF_page_60_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL Liquid Overnight ETF_page_60_right.png
# ✅ Split Page 61:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL Broad Based Gilt ETF_page_61_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL Broad Based Gilt ETF_page_61_right.png
# ✅ Split Page 62:
#    Left  → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\left_half_screenshots\CRISIL 10 Year Gilt ETF_page_62_left.png
#    Right → D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\right_half_screenshots\CRISIL 10 Year Gilt ETF_page_62_right.png
#
# 🎯 All pages processed and saved successfully!

# %%
####################### Working Code to fetch text from screenshot after zooom and save it in excel file with fund distributed as tabs######################
import cv2
import numpy as np
import pytesseract
from PIL import Image
import os
import re

rating_set = set()
# Set Tesseract path (update for your system)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
pan = 'AAATB0102C'
mutual_fund = "Aditya Birla Mutual Fund"
# input_dir = "screenshots_cropped_at_rectangles\\{}".format(month_name)
input_dir_list = ["left_half_screenshots", "right_half_screenshots"]
# input_dir = "left_half_screenshots"
# input_dir = "right_half_screenshots"
A_pattern = pattern = re.compile(
    r"(AAA\(SO\)|AAA\(CE\)|AA\(CE\)|A1\+|AA\+|AA-|AAA|AA|A\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)"
)
non_A_patten = re.compile(r"(AAA\(SO\)|AAA\(CE\)|AA\(CE\)|A1\+|AA\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)")
agencies = ["CARE", "IND", "CRISIL", "ICRA", "FITCH", "India Ratings", "Brickwork", "Acuite"]


agency_pattern = re.compile(rf"({'|'.join(agencies)})")


def normalize_rating_text(text):
    replacements = {
        "＋": "+",  # fullwidth plus
        "–": "-",  # en dash
        "−": "-",  # minus
        "﹣": "-",  # small hyphen
        "‒": "-",  # figure dash
        "―": "-",  # horizontal bar
        "（": "(",  # fullwidth left parenthesis
        "）": ")",  # fullwidth right parenthesis
    }
    for bad, good in replacements.items():
        text = text.replace(bad, good)

    # Remove zero-width and non-breaking spaces
    text = re.sub(r"[\u200B-\u200D\uFEFF\u00A0]", "", text)
    return text

def agency_matching(normalized_text, agency=''):
    agency_match = agency_pattern.search(normalized_text.replace("INDIA", ""))
    if agency_match:
        agency = agency_match.group(1)
        print("agency:", agency)
        normalized_text = normalized_text.replace(agency, " ")
        print("agency_replaced_normalised_text :", normalized_text)
    return [normalized_text, agency]

def rating_matching(normalized_text, agency):
    rating=''
    if agency == '':
        pattern = non_A_patten
        print("agency pattern :", pattern)
    else:
        pattern = A_pattern
        print("agency pattern :", pattern)
    match = pattern.search(normalized_text)
    # print(f"Line: {normalized_text}")
    if match:
        rating = match.group(0)
        print(f"Rating: {rating}\n")
        normalized_text = normalized_text.replace(rating, " ")
        print("rating_replaced_normalised_text :", normalized_text)
    return [normalized_text, rating]

def AUM_matching(normalized_text, total_AUM=''):
    match_AUM = re.findall(r"\d+\.\d+", normalized_text)

    # If found, return the last one (but not if it's at start)
    if match_AUM:
        last = match_AUM[-1]
        # check position of last match
        m = re.finditer(r"\d+\.\d+", normalized_text)
        last_match = list(m)[-1]
        if last_match.start() == 0:
            total_AUM = None  # ignore if at start
        else:
            total_AUM = last
            # total_AUM = match_AUM[-1]
            print(f"Total AUM: {total_AUM}\n")
            print("AUM_replaced_normalised_text :", normalized_text)
            normalized_text = normalized_text.replace(total_AUM, "")
    return [normalized_text, total_AUM]

def MV_matching(normalized_text, market_value=''):
    match_MV = re.findall(r"\d+\.\d+", normalized_text)

    # If found, return the last one (but not if it's at start)
    if match_MV:
        last = match_MV[-1]
        # check position of last match
        m_mv = re.finditer(r"\d+\.\d+", normalized_text)
        last_match_mv = list(m_mv)[-1]
        if last_match_mv.start() == 0:
            market_value = None  # ignore if at start
        else:
            market_value = last
            # total_AUM = match_MV[-1]
            print(f"MV: {market_value}\n")
            print("MV_replaced_normalised_text :", normalized_text)
            normalized_text = normalized_text.replace(market_value, "")
    
    return [normalized_text, market_value]

# %%
def end_page(text):
    keywords = [
        "Total Net Assets",
        "Investment Performance",
        "mvestment rperrormance",
        "myvyestment rperrormance",
        "nvestment rerrormance",
        "investment rerrormance"  # seems like a typo version
    ]
    text_lower = text.lower()
    return any(k.lower() in text_lower for k in keywords)




import pandas as pd
test_df = pd.DataFrame(columns=['Issuer', "% to Net Assets", "Rating"])
correct_rating_df = pd.DataFrame(columns=['Pan', 'ISIN No.', 'Mutual Fund', 'Fund Name','Fund Type', 'Portfolio', "Agency", 'Ratings', "Category", '(%) Of Total AUM', "Factsheet Date", "URL", 'Filename'])
remaining_rating_df = pd.DataFrame(columns=['Text'])
for input_dir in input_dir_list:
    for filename in os.listdir(input_dir):
        start_printing = False
        print("---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------")
        if filename.endswith(".png"):
            Fund_Type = filename.split("_page")[0].replace("_", " ")
            Fund_Name = "Aditya Birla Sun Life " + Fund_Type
            image_path = os.path.join(input_dir, filename)
            print(image_path)
            image = cv2.imread(image_path)

            # Scale image (e.g., 1.5x zoom)
            # scale_percent = 120  # Adjust this value as needed (e.g., 150 means 150% size)
            scale_percent = 200
            width = int(image.shape[1] * scale_percent / 100)
            height = int(image.shape[0] * scale_percent / 100)
            dim = (width, height)

            # Resize image
            image = cv2.resize(image, dim, interpolation=cv2.INTER_LINEAR)

            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

            # Threshold to isolate dark lines (black separators)
            # _, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY_INV)

            # Adaptive threshold to handle gray lines and varying lighting
            thresh = cv2.adaptiveThreshold(
                gray, 255,
                cv2.ADAPTIVE_THRESH_MEAN_C,
                cv2.THRESH_BINARY_INV,
                blockSize=15,
                C=10
            )

            # Detect horizontal lines
            horizontal_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (50, 1))
            detected_lines = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, horizontal_kernel, iterations=2)

            # Find contours of the lines
            contours, _ = cv2.findContours(detected_lines, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

            # Get y-coordinates of all horizontal lines
            line_y_coords = sorted([cv2.boundingRect(cnt)[1] for cnt in contours])

            # Add image boundaries
            line_y_coords = [0] + line_y_coords + [image.shape[0]]

            # Process and print each row
            # print("\nExtracted Table Rows:")
            for i in range(len(line_y_coords) - 1):
                y_start = line_y_coords[i]
                y_end = line_y_coords[i + 1]
                
                # Skip very small regions (likely just the line itself)
                if y_end - y_start < 10:
                    continue

                # Extract the row region
                row_img = image[y_start:y_end, :]

                # OPTIONAL: Resize the row to improve OCR accuracy
                zoom_factor = 2.0
                row_img = cv2.resize(row_img, None, fx=zoom_factor, fy=zoom_factor, interpolation=cv2.INTER_LINEAR)

                # Convert to PIL Image for Tesseract
                row_pil = Image.fromarray(cv2.cvtColor(row_img, cv2.COLOR_BGR2RGB))

                # Tesseract OCR
                custom_config = r'--oem 3 --psm 6 -c preserve_interword_spaces=1'
                text = pytesseract.image_to_string(row_pil, config=custom_config).strip()
                text = text.replace("Al1", "A1")
                normalized_text = normalize_rating_text(text)
                agency = ""
                rating = ""
                portfolio = ""
                agency_2 = ''
                rating_2 = ''
                portfolio_2 = ''
                total_AUM = ''

                if text:
                    if "issuer" in text.lower() and "ratin" in text.lower():
                        # print("Issuer text :::::::::", text)
                        start_printing = True
                        continue
                    if start_printing:
                        if "@absi" in text.lower() or "https://mutualfund.adityabirlacapital.com" in text.lower():
                            continue
                        # if text == "a |" or text == "PT" or text == "PN":
                        #     break
                        if len(text.split("\n")[0].strip()) < 6 or end_page(text) == True:
                            break
                        cleaned_text = re.sub(r'^[^A-Za-z0-9]+', '', text).replace(";", ' ').replace("~", "")
                        patterns = [
                            r'}}©—',      # first one
                            r'}Â»&Â©',       # second one
                            r'# }»&©',   # with leading '#'
                        ]
                        
                        for p in patterns:
                            cleaned_text = re.sub(p, '', cleaned_text)
                        cleaned_text = re.sub(r'[^A-Za-z0-9+%]+$', '', cleaned_text).strip()
                        cleaned_text = re.sub(r'(—_—sav@it|.istYL|. isWxSL|—s|~\-s)$', '', cleaned_text).rstrip()
                        # print(cleaned_text)
                        # print(len(re.split(r'\s{2,}', cleaned_text)),"[][]", re.split(r'\s{2,}', cleaned_text)[-1])
                        if "an" == re.split(r'\s{2,}', cleaned_text)[-1]:
                            continue
                        if len(re.split(r'\s{2,}', cleaned_text)) == 3:
                            # print(len(re.split(r'\s{2,}', cleaned_text)),"[][]", re.split(r'\s{2,}', cleaned_text)[-1])
                            print(len(re.split(r'\s{2,}', cleaned_text)), "[][]", re.split(r'\s{2,}', cleaned_text))
                            cleaned_text = re.split(r'\s{2,}', cleaned_text)
                            if cleaned_text[1].startswith("Debt"):
                                # temp_df = pd.DataFrame([{
                                #                         "Issuer" : cleaned_text[1],
                                #                         "% to Net Assets" : cleaned_text[2],
                                #                         "Agency" : None,
                                #                         "Rating" : None,
                                #                         "Fund Name" : Fund_Name,
                                #                         "Fund Type" : Fund_Type
                                #                     }])
                                temp_df = pd.DataFrame([{
                                                        "Pan": pan,
                                                        "ISIN No." : None,
                                                        "Mutual Fund" : mutual_fund,
                                                        "Fund Name" : Fund_Name,
                                                        "Fund Type" : Fund_Type,
                                                        "Portfolio"  : cleaned_text[1],
                                                        "Agency" : None,
                                                        "Ratings" : None,
                                                        "Category" : None,
                                                        "(%) Of Total AUM" : cleaned_text[2],
                                                        "Factsheet Date" : None,
                                                        "URL" : None,
                                                        }])
                            else:
                                rating_and_agency = cleaned_text[2]
                                agency_matching_output = agency_matching(rating_and_agency)
                                remaining_text = agency_matching_output[0].strip()
                                agency = agency_matching_output[1].strip()
                                print("agency :", agency)


                                # rating_matching_output = rating_matching(remaining_text)
                                # remaining_text = rating_matching_output[0].strip()
                                # rating = rating_matching_output[1].strip()
                                rating = remaining_text
                                print("rating :", rating)
                                # temp_df = pd.DataFrame([{
                                #                 "Issuer" : cleaned_text[0],
                                #                 "% to Net Assets" : cleaned_text[1],
                                #                 "Agency" : agency,
                                #                 "Rating" : rating,
                                #                 "Fund Name" : Fund_Name,
                                #                 "Fund Type" : Fund_Type
                                #             }])
                                temp_df = pd.DataFrame([{
                                                        "Pan": pan,
                                                        "ISIN No." : None,
                                                        "Mutual Fund" : mutual_fund,
                                                        "Fund Name" : Fund_Name,
                                                        "Fund Type" : Fund_Type,
                                                        "Portfolio"  : cleaned_text[0],
                                                        "Agency" : agency,
                                                        "Ratings" : rating,
                                                        "Category" : None,
                                                        "(%) Of Total AUM" : cleaned_text[1],
                                                        "Factsheet Date" : None,
                                                        "URL" : None,
                                                        }])
                        elif len(re.split(r'\s{2,}', cleaned_text)) == 2:
                            print(len(re.split(r'\s{2,}', cleaned_text)), "[][]", re.split(r'\s{2,}', cleaned_text))
                            cleaned_text = re.split(r'\s{2,}', cleaned_text)
                            if cleaned_text[1].startswith("Debt"):
                                # temp_df = pd.DataFrame([{
                                #                         "Issuer" : cleaned_text[1],
                                #                         "% to Net Assets" : None,
                                #                         "Agency" : None,
                                #                         "Rating" : None,
                                #                         "Fund Name" : Fund_Name,
                                #                         "Fund Type" : Fund_Type
                                #                     }])
                                temp_df = pd.DataFrame([{
                                                        "Pan": pan,
                                                        "ISIN No." : None,
                                                        "Mutual Fund" : mutual_fund,
                                                        "Fund Name" : Fund_Name,
                                                        "Fund Type" : Fund_Type,
                                                        "Portfolio"  : cleaned_text[1],
                                                        "Agency" : None,
                                                        "Ratings" : None,
                                                        "Category" : None,
                                                        "(%) Of Total AUM" : None,
                                                        "Factsheet Date" : None,
                                                        "URL" : None,
                                                        }])
                            else:
                                # temp_df = pd.DataFrame([{
                                #                         "Issuer" : cleaned_text[0],
                                #                         "% to Net Assets" : cleaned_text[1],
                                #                         "Agency" : None,
                                #                         "Rating" : None,
                                #                         "Fund Name" : Fund_Name,
                                #                         "Fund Type" : Fund_Type
                                #                     }])
                                temp_df = pd.DataFrame([{
                                                        "Pan": pan,
                                                        "ISIN No." : None,
                                                        "Mutual Fund" : mutual_fund,
                                                        "Fund Name" : Fund_Name,
                                                        "Fund Type" : Fund_Type,
                                                        "Portfolio"  : cleaned_text[0],
                                                        "Agency" : None,
                                                        "Ratings" : None,
                                                        "Category" : None,
                                                        "(%) Of Total AUM" : cleaned_text[1],
                                                        "Factsheet Date" : None,
                                                        "URL" : None,
                                                        }])
                        elif len(re.split(r'\s{2,}', cleaned_text)) == 4:
                            print(len(re.split(r'\s{2,}', cleaned_text)), "[][]", re.split(r'\s{2,}', cleaned_text))
                            cleaned_text = [x for x in re.split(r'\s{2,}', cleaned_text) if x != ":"]
                            if cleaned_text[1].startswith("Debt"):
                                rating_and_agency = cleaned_text[3]
                                agency_matching_output = agency_matching(rating_and_agency)
                                remaining_text = agency_matching_output[0].strip()
                                agency = agency_matching_output[1].strip()
                                print("agency :", agency)


                                # rating_matching_output = rating_matching(remaining_text)
                                # remaining_text = rating_matching_output[0].strip()
                                # rating = rating_matching_output[1].strip()
                                rating = remaining_text
                                print("rating :", rating)
                                # temp_df = pd.DataFrame([{
                                #                         "Issuer" : cleaned_text[1],
                                #                         "% to Net Assets" : cleaned_text[2],
                                #                         "Agency" : agency,
                                #                         "Rating" : rating,
                                #                         "Fund Name" : Fund_Name,
                                #                         "Fund Type" : Fund_Type
                                #                     }])
                                temp_df = pd.DataFrame([{
                                                        "Pan": pan,
                                                        "ISIN No." : None,
                                                        "Mutual Fund" : mutual_fund,
                                                        "Fund Name" : Fund_Name,
                                                        "Fund Type" : Fund_Type,
                                                        "Portfolio"  : cleaned_text[1],
                                                        "Agency" : agency,
                                                        "Ratings" : rating,
                                                        "Category" : None,
                                                        "(%) Of Total AUM" : cleaned_text[2],
                                                        "Factsheet Date" : None,
                                                        "URL" : None,
                                                        }])
                            else:
                                rating_and_agency = cleaned_text[2]
                                agency_matching_output = agency_matching(rating_and_agency)
                                remaining_text = agency_matching_output[0].strip()
                                agency = agency_matching_output[1].strip()
                                print("agency :", agency)


                                # rating_matching_output = rating_matching(remaining_text)
                                # remaining_text = rating_matching_output[0].strip()
                                # rating = rating_matching_output[1].strip()
                                rating = remaining_text
                                print("rating :", rating)
                                # temp_df = pd.DataFrame([{
                                #                         "Issuer" : cleaned_text[0],
                                #                         "% to Net Assets" : cleaned_text[1],
                                #                         "Agency" : agency,
                                #                         "Rating" : rating,
                                #                         "Fund Name" : Fund_Name,
                                #                         "Fund Type" : Fund_Type
                                #                     }])
                                temp_df = pd.DataFrame([{
                                                        "Pan": pan,
                                                        "ISIN No." : None,
                                                        "Mutual Fund" : mutual_fund,
                                                        "Fund Name" : Fund_Name,
                                                        "Fund Type" : Fund_Type,
                                                        "Portfolio"  : cleaned_text[0],
                                                        "Agency" : agency,
                                                        "Ratings" : rating,
                                                        "Category" : None,
                                                        "(%) Of Total AUM" : cleaned_text[1],
                                                        "Factsheet Date" : None,
                                                        "URL" : None,
                                                        }])
                        else:
                            print("else block")
                            print(len(re.split(r'\s{2,}', cleaned_text)), "[][]", re.split(r'\s{2,}', cleaned_text))
                            # temp_df = pd.DataFrame([{
                            #                         "Issuer" : re.split(r'\s{2,}', cleaned_text)[0],
                            #                         "% to Net Assets" : None,
                            #                         "Agency" : None,
                            #                         "Rating" : None,
                            #                         "Fund Name" : Fund_Name,
                            #                         "Fund Type" : Fund_Type
                            #                     }])
                            temp_df = pd.DataFrame([{
                                                    "Pan": pan,
                                                    "ISIN No." : None,
                                                    "Mutual Fund" : mutual_fund,
                                                    "Fund Name" : Fund_Name,
                                                    "Fund Type" : Fund_Type,
                                                    "Portfolio"  : re.split(r'\s{2,}', cleaned_text)[0],
                                                    "Agency" : None,
                                                    "Ratings" : None,
                                                    "Category" : None,
                                                    "(%) Of Total AUM" : None,
                                                    "Factsheet Date" : None,
                                                    "URL" : None,
                                                    }])

                        correct_rating_df = pd.concat([correct_rating_df, temp_df])
                        # if "Total Net Assets".lower() in text.lower() or "Investment Performance".lower() in text.lower() or "investment rerrormance" in text.lower():
                        # if end_page(text) == True:
                        #     break
# Out:
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\Balanced Advantage Fund_page_11_left.png
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\Banking & PSU Debt Fund_page_29_left.png
# 2 [][] ['Fixed rates bonds - Corporate', '83.41%']
# 3 [][] ['Power Grid Corporation of India Limited', '4.52%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '3.34%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '2.82%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Small Industries Development Bank of India', '2.71%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['National Housing Bank', '2.46%', 'CARE AAA']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# rating : AAA
# 3 [][] ['State Bank of India - Tier Il - Basel Ill', '2.34%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '2.24%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['HDFC Bank Limited', '2.07%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '1.85%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Bajaj Finance Limited', '1.85%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '1.70%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Indian Railway Finance Corporation Limited', '1.67%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['National Bank for Financing Infrastructure and Dev', '1.66%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '1.57%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['LIC Housing Finance Limited', '1.51%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['HDFC Bank Limited', '1.41%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Bajaj Finance Limited', '1.41%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Tata Capital Limited', '1.40%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '1.40%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '1.37%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Indian Railway Finance Corporation Limited', '1.35%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Small Industries Development Bank of India', '1.34%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '1.29%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['HDFC Bank Limited', '1.14%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Indian Renewable Energy Development Agency Ltd', '1.14%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Small Industries Development Bank of India', '1.12%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['REC Limited', '1.11%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Housing & Urban Development Corporation Limited', '1.10%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Indian Railway Finance Corporation Limited', '1.09%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '1.06%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '1.00%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '0.96%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '0.95%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['LIC Housing Finance Limited', '0.84%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '0.84%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['LIC Housing Finance Limited', '0.84%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '0.83%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Tata Capital Housing Finance Limited', '0.83%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Indian Railway Finance Corporation Limited', '0.82%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Small Industries Development Bank of India', '0.73%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Mangalore Refinery and Petrochemicals Limited', '0.70%', 'CARE AAA']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# rating : AAA
# 3 [][] ['REC Limited', '0.66%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\Banking & PSU Debt Fund_page_30_left.png
# 3 [][] ['REC Limited', '0.27%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '0.23%', 'CRISILAAA']
# agency: CRISIL
# agency_replaced_normalised_text :  AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Tata Capital Limited', '0.23%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '0.22%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['L&T Metro Rail Hyderabad Ltd', '0.22%', 'CRISIL AAA(CE']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA(CE
# agency : CRISIL
# rating : AAA(CE
# 3 [][] ['Pipeline Infrastructure Limited', '0.18%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Indian Railway Finance Corporation Limited', '0.17%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['LIC Housing Finance Limited', '0.17%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Aditya Birla Finance Limited', '0.17%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Mahindra & Mahindra Financial Services Limited', '0.17%', 'CARE AAA']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '0.17%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Small Industries Development Bank of India', '0.17%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Bajaj Housing Finance Limited', '0.17%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Indian Railway Finance Corporation Limited', '0.12%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '0.12%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['NUCLEAR POWER CORPORATION OF INDIA LTD', '0.11%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Power Grid Corporation of India Limited', '0.09%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '0.06%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['HDFC Bank Limited', '0.06%', 'CRISILAAA']
# agency: CRISIL
# agency_replaced_normalised_text :  AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Power Grid Corporation of India Limited', '0.06%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['LIC Housing Finance Limited', '0.06%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Bajaj Housing Finance Limited', '0.06%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Power Grid Corporation of India Limited', '0.06%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Tata Capital Limited', '0.06%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '0.06%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '0.01%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['National Highways Authority of India', '0.01%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 2 [][] ['Government Bond', '7.13%']
# 3 [][] ['7.10% GOVT 08-Apr-2034', '1.74%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.17% GOVERNMENT OF INDIA 17APR30', '1.44%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['718% GOI 24-Jul-2037', '1.20%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.23% INDIA GOVERNMENT BOND 15APR2039', '0.44%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.34% INDIA GOVERNMENT BOND 22APR2064', '0.34%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['6.92% INDIA GOVT BOND 18NOV2039 GSEC', '0.33%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['6.33% INDIA GOVT BOND OSMAY2035 GSEC', '0.28%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.30% GOI 19JUN53', '0.24%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.18% GOVERNMENT ON INDIA 14AUG2033 GSEC', '0.18%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['6.79% INDIA GOV BOND 070CT2034 GSEC', '0.18%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.26% GOVERNMENT OF INDIA OGFEB33', '0.16%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.26% GOI 22AUG2032', '0.14%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.17% GOI (MD 08/01/2028)', '0.12%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.46% GOVERNMENT OF INDIA OGNOV73 G-SEC', '0.11%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.09% GOVERNMENT OF INDIA 25NOV74 G-SEC', '0.05%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.25% GOI 12JUN63', '0.04%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.54% GOVERNMENT OF INDIA 23MAY2036 GSEC', '0.04%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.37% GOI 230CT2028', '0.03%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.59% GOI (MD 20/03/2029)', '0.02%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.09% GOI OS5AUG2054', '0.02%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.57% GOI (MD 17/06/2033)', '0.01%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.10% GOVERNMENT OF INDIA 18APR29', '0.00%', 'SOV']
# agency :
# rating : SOV
# 2 [][] ['Money Market Instruments', '2.47%']
# 3 [][] ['Union Bank of India', '1.29%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['Union Bank of India', '1.07%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['Axis Bank Limited', '0.11%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 2 [][] ['Cash Management Bills', '2.25%']
# 3 [][] ['Government of India', '0.29%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['Government of India', '0.28%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['Government of India', '0.24%', 'SOV']
# agency :
# rating : SOV
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\Corporate Bond Fund_page_24_left.png
# 2 [][] ['Fixed rates bonds - Corporate', '71.20%']
# 3 [][] ['Small Industries Development Bank of India', '2.62%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '2.18%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Small Industries Development Bank of India', '2.11%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Jamnagar Utilities & Power Private Limited', '2.07%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Bajaj Housing Finance Limited', '1.97%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['REC Limited', '1.81%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Bajaj Finance Limited', '1.60%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Tata Capital Limited', '1.33%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['L&T Finance Limited', '1.22%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['LIC Housing Finance Limited', '1.17%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '1.17%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '1.16%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['LIC Housing Finance Limited', '1.16%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['LIC Housing Finance Limited', '1.14%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['REC Limited', '114%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '1.13%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Jamnagar Utilities & Power Private Limited', '1.01%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Embassy Office Parks REIT', '0.91%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['LIC Housing Finance Limited', '0.89%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['LIC Housing Finance Limited', '0.89%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Indian Railway Finance Corporation Limited', '0.86%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '0.86%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['LIC Housing Finance Limited', '0.85%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '0.84%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['LIC Housing Finance Limited', '0.81%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Embassy Office Parks REIT', '0.80%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Mahindra & Mahindra Financial Services Limited', '0.79%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Bajaj Finance Limited', '0.73%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Small Industries Development Bank of India', '0.71%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Tata Capital Limited', '0.71%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Small Industries Development Bank of India', '0.70%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Aditya Birla Housing Finance Limited', '0.67%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Bajaj Housing Finance Limited', '0.67%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Indian Railway Finance Corporation Limited', '0.64%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '0.62%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Tata Capital Limited', '0.62%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '0.62%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Poonawalla Fincorp Limited', '0.61%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Summit Digitel Infrastructure Private Limited', '0.61%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\Corporate Bond Fund_page_25_left.png
# 3 [][] ['REC Limited', '0.30%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '0.28%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Mindspace Business Parks REIT', '0.27%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '0.27%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Sundaram Home Finance Limited', '0.27%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '0.27%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Housing & Urban Development Corporation Limited', '0.27%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Aditya Birla Housing Finance Limited', '0.27%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Larsen & Toubro Limited', '0.26%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Bajaj Finance Limited', '0.26%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '0.26%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['LIC Housing Finance Limited', '0.25%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['NTPC Limited', '0.24%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Sundaram Home Finance Limited', '0.24%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Sundaram Home Finance Limited', '0.23%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['India Grid Trust', '0.23%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Housing & Urban Development Corporation Limited', '0.22%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Mindspace Business Parks REIT', '0.21%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Nexus Select Trust', '0.21%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Aditya Birla Finance Limited', '0.20%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '0.19%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '0.19%', 'CRISILAAA']
# agency: CRISIL
# agency_replaced_normalised_text :  AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Pipeline Infrastructure Limited', '0.18%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Indian Railway Finance Corporation Limited', '0.18%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Summit Digitel Infrastructure Private Limited', '0.18%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Kotak Mahindra Prime Limited', '0.18%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Aditya Birla Housing Finance Limited', '0.18%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Small Industries Development Bank of India', '0.18%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Kotak Mahindra Prime Limited', '0.18%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Reliance Life Sciences Pvt Ltd', '0.18%', 'CARE AAA']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# rating : AAA
# 3 [][] ['Hindustan Zinc Limited', '0.18%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '0.17%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Jio Credit Ltd', '0.17%', 'CRISILAAA']
# agency: CRISIL
# agency_replaced_normalised_text :  AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['NTPC Limited', '0.17%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Indian Railway Finance Corporation Limited', '0.17%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '0.17%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '0.17%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Bank of Baroda - Tier Il - Basel Ill', '0.16%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Sundaram Home Finance Limited', '0.16%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '0.14%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Bajaj Housing Finance Limited', '0.14%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Summit Digitel Infrastructure Private Limited', '0.14%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['NTPC Limited', '0.13%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Tata Capital Limited', '0.13%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '0.12%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Bajaj Housing Finance Limited', '0.11%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '0.09%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '0.09%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '0.09%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Small Industries Development Bank of India', '0.09%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['REC Limited', '0.09%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '0.09%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '0.09%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['HDB Financial Services Limited', '0.09%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Hindustan Zinc Limited', '0.09%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '0.09%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Housing & Urban Development Corporation Limited', '0.09%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Power Grid Corporation of India Limited', '0.09%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Sundaram Finance Limited', '0.09%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Indian Railway Finance Corporation Limited', '0.09%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['dio Credit Ltd', '0.09%', 'CRISILAAA']
# agency: CRISIL
# agency_replaced_normalised_text :  AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['REC Limited', '0.09%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['National Housing Bank', '0.09%', 'CARE AAA']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# rating : AAA
# 3 [][] ['Indian Railway Finance Corporation Limited', '0.09%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '0.08%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Embassy Office Parks REIT', '0.06%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Small Industries Development Bank of India', '0.05%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['LIC Housing Finance Limited', '0.05%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\Corporate Bond Fund_page_26_left.png
# 3 [][] ['India Universal Trust Al2', '0.25%', 'IND AAA(SO']
# agency: IND
# agency_replaced_normalised_text :   AAA(SO
# agency : IND
# rating : AAA(SO
# 3 [][] ['India Universal Trust Al2', '0.21%', 'IND AAA(SO']
# agency: IND
# agency_replaced_normalised_text :   AAA(SO
# agency : IND
# rating : AAA(SO
# 3 [][] ['First Business Receivables Trust', '0.09%', 'IND AAA(SO']
# agency: IND
# agency_replaced_normalised_text :   AAA(SO
# agency : IND
# rating : AAA(SO
# 3 [][] ['First Business Receivables Trust', '0.08%', 'IND AAA(SO']
# agency: IND
# agency_replaced_normalised_text :   AAA(SO
# agency : IND
# rating : AAA(SO
# 2 [][] ['Alternative Investment Funds (AIF)', '0.24%']
# 2 [][] ['Corporate Debt Market Development Fund', '0.24%']
# 2 [][] ['State Government bond', '0.17%']
# 3 [][] ['8.22% TAMIL NADU O9DEC2025 SDL', '0.04%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.16% KARNATAKA 26NOV2025 SDL', '0.02%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.99% MAHARASHTRA 280CT2025 SDL', '0.02%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.96% Gujarat SDL (14/10/2025)', '0.02%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.96% Maharashtra SDL (14/10/2025)', '0.02%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['GUJARAT GUJARA 8.23 09/09/25', '0.02%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['6.92% RAJASTHAN O4SEP25 SDL', '0.02%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['6.87% RAJASTHAN O8SEP2031 SDL', '0.01%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.27% TAMILNADU 23DEC2025 SDL', '0.01%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['6.91% RAJASTHAN O1SEP2031 SDL', '0.00%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['6.97% MAHARASHTRA 18FEB2028 SDL', '0.00%', 'SOV']
# agency :
# rating : SOV
# 2 [][] ['Cash Management Bills', '0.12%']
# 3 [][] ['Government of India', '0.05%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['Government of India', '0.02%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['Government of India', '0.02%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['Government of India', '0.01%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['Government of India', '0.01%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['Government of India', '0.01%', 'SOV']
# agency :
# rating : SOV
# 2 [][] ['Interest Rate Swaps', '0.00%']
# 2 [][] ['DBS Bank Ltd/India', '0.01%']
# 2 [][] ['ICICI Securities Primary Dealership Limited', '0.01%']
# 2 [][] ['ICICI Securities Primary Dealership Limited', '0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '0.00%']
# 2 [][] ['Standard Chartered Bank', '0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '0.00%']
# 2 [][] ['Clearing Corporation of India Limited', '0.00%']
# 2 [][] ['BARCLAYS BANK PLC', '0.00%']
# 2 [][] ['ICICI Securities Primary Dealership Limited', '0.00%']
# 2 [][] ['Clearing Corporation of India Limited', '0.00%']
# 2 [][] ['Clearing Corporation of India Limited', '0.00%']
# 2 [][] ['Clearing Corporation of India Limited', '0.00%']
# 2 [][] ['Clearing Corporation of India Limited', '0.00%']
# 2 [][] ['Clearing Corporation of India Limited', '0.00%']
# 2 [][] ['Clearing Corporation of India Limited', '0.00%']
# 2 [][] ['Clearing Corporation of India Limited', '0.00%']
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\Credit Risk Fund_page_33_left.png
# 2 [][] ['Fixed rates bonds - Corporate', '73.51%']
# 3 [][] ['JSW Steel Limited', '5.50%', 'ICRA AA']
# agency: ICRA
# agency_replaced_normalised_text :   AA
# agency : ICRA
# rating : AA
# 3 [][] ['Aditya Birla Real Estate Ltd.', '4.51%', 'CRISIL AA']
# agency: CRISIL
# agency_replaced_normalised_text :   AA
# agency : CRISIL
# rating : AA
# 3 [][] ['Jubilant Bevco Ltd', '3.06%', 'CRISIL AA']
# agency: CRISIL
# agency_replaced_normalised_text :   AA
# agency : CRISIL
# rating : AA
# 3 [][] ['Narayana Hrudayalaya Limited', '3.04%', 'ICRA AA']
# agency: ICRA
# agency_replaced_normalised_text :   AA
# agency : ICRA
# rating : AA
# 3 [][] ['JSW Energy Limited', '3.02%', 'ICRA AA']
# agency: ICRA
# agency_replaced_normalised_text :   AA
# agency : ICRA
# rating : AA
# 3 [][] ['Security and Intelligence Services (India) Limited', '3.01%', 'CRISIL AA']
# agency: CRISIL
# agency_replaced_normalised_text :   AA
# agency : CRISIL
# rating : AA
# 3 [][] ['Vedanta Limited', '3.00%', 'ICRA AA']
# agency: ICRA
# agency_replaced_normalised_text :   AA
# agency : ICRA
# rating : AA
# 3 [][] ['Hero Housing Finance Ltd', '2.99%', 'ICRA AA+']
# agency: ICRA
# agency_replaced_normalised_text :   AA+
# agency : ICRA
# rating : AA+
# 3 [][] ['360 ONE Prime Ltd', '2.99%', 'ICRA AA']
# agency: ICRA
# agency_replaced_normalised_text :   AA
# agency : ICRA
# rating : AA
# 3 [][] ['Hinduja Housing Finance Ltd', '2.92%', 'CARE AA+']
# agency: CARE
# agency_replaced_normalised_text :   AA+
# agency : CARE
# rating : AA+
# 3 [][] ['Sk Finance Ltd', '2.67%', 'ICRA AA']
# agency: ICRA
# agency_replaced_normalised_text :   AA
# agency : ICRA
# rating : AA
# 3 [][] ['GMR Airport Ltd', '2.59%', 'CARE A']
# agency: CARE
# agency_replaced_normalised_text :   A
# agency : CARE
# rating : A
# 3 [][] ['Indian Railway Finance Corporation Limited', '2.53%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Tata Projects Limited', '2.53%', 'IND AA']
# agency: IND
# agency_replaced_normalised_text :   AA
# agency : IND
# rating : AA
# 3 [][] ['Arka Fincap Limited', '2.51%', 'CRISIL AA']
# agency: CRISIL
# agency_replaced_normalised_text :   AA
# agency : CRISIL
# rating : AA
# 3 [][] ['Avanse Financial Services Ltd', '2.50%', 'CARE AA']
# agency: CARE
# agency_replaced_normalised_text :   AA
# agency : CARE
# rating : AA
# 3 [][] ['DLF Home Developers Ltd', '2.50%', 'ICRA AA']
# agency: ICRA
# agency_replaced_normalised_text :   AA
# agency : ICRA
# rating : AA
# 3 [][] ['Delhi International Airport Ltd', '2.49%', 'ICRA AA']
# agency: ICRA
# agency_replaced_normalised_text :   AA
# agency : ICRA
# rating : AA
# 3 [][] ['National Bank for Financing Infrastructure and Dev', '2.49%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Adani Airport Holdings Ltd', '2.31%', 'CRISIL A+']
# agency: CRISIL
# agency_replaced_normalised_text :   A+
# agency : CRISIL
# rating : A+
# 3 [][] ['Nuvama Wealth Finance Ltd', '2.21%', 'CARE AA']
# agency: CARE
# agency_replaced_normalised_text :   AA
# agency : CARE
# rating : AA
# 3 [][] ['CreditAccess Grameen Limited', '2.05%', 'IND AA']
# agency: IND
# agency_replaced_normalised_text :   AA
# agency : IND
# rating : AA
# 3 [][] ['JM Financial Products Limited', '2.00%', 'ICRA AA']
# agency: ICRA
# agency_replaced_normalised_text :   AA
# agency : ICRA
# rating : AA
# 3 [][] ['Avanse Financial Services Ltd', '2.00%', 'CRISIL AA']
# agency: CRISIL
# agency_replaced_normalised_text :   AA
# agency : CRISIL
# rating : AA
# 3 [][] ['Indian Railway Finance Corporation Limited', '1.95%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Eris Lifesciences Limited', '1.37%', 'IND AA']
# agency: IND
# agency_replaced_normalised_text :   AA
# agency : IND
# rating : AA
# 3 [][] ['Eris Lifesciences Limited', '1.37%', 'IND AA']
# agency: IND
# agency_replaced_normalised_text :   AA
# agency : IND
# rating : AA
# 3 [][] ['Phillips Carbon Black Ltd', '1.28%', 'CRISIL AA']
# agency: CRISIL
# agency_replaced_normalised_text :   AA
# agency : CRISIL
# rating : AA
# 3 [][] ['Power Finance Corporation Limited', '0.12%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 2 [][] ['IL&FS Tamil Nadu Power Company Limited', '0.00%']
# 2 [][] ['IL&FS Tamil Nadu Power Company Limited', '0.00%']
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\CRISIL 10 Year Gilt ETF_page_62_left.png
# 2 [][] ['Government Bond', '97.91%']
# 3 [][] ['6.79% INDIA GOV BOND 070CT2034 GSEC', '97.91%', 'SOV']
# agency :
# rating : SOV
# 2 [][] ['Cash & Current Assets', '2.09%']
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\CRISIL Broad Based Gilt ETF_page_61_left.png
# 2 [][] ['Government Bond', '98.72%']
# 3 [][] ['7.30% GOI 19JUN53', '19.31%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.32% GOI BOND T3NOV2030', '18.92%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.18% GOI 24-Jul-2037', '18.89%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.04% GOVERNMENT OF INDIA O3JUN29 G-SEC', '18.72%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.10% GOVT 08-Apr-2034', '11.53%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['6.79% INDIA GOV BOND 070CT2034 GSEC', '11.34%', 'SOV']
# agency :
# rating : SOV
# 2 [][] ['Cash & Current Assets', '1.28%']
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\CRISIL IBX 50colon50 Gilt Plus SDL Apr 2028 Index Fund_page_46_left.png
# 2 [][] ['State Government bond', '47.97%']
# 3 [][] ['8.28% Tamilnadu SDL (MD 14/03/2028)', '25.38%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.05% Tamilnadu SDL (MD 18/04/2028)', '6.30%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['6.98% TELANGANA 22APR2028 SDL', '4.10%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.44% RAJASTHAN O7MAR28 SDL', '2.83%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.43% TAMIL NADU SDL RED 07-MARCH-2028', '1.61%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['08.23 GUJARAT SDL 21FEB2028', '1.45%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.34% UTTAR PRADESH 28FEB28 SDL', '1.41%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.15% Chhattisgarh SDL (MD 27/03/2028)', '1.41%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.14% Haryana SDL (MD 27/03/2028)', '1.40%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.26% Gujarat SDL (MD 14/03/2028)', '1.10%', 'SOV']
# agency :
# rating : SOV
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\CRISIL IBX 60colon40 SDL + AAA PSU - Apr 2027 Index Fund_page_43_left.png
# 2 [][] ['State Government bond', '47.29%']
# 3 [][] ['7.61% TAMIL NADU 15FEB2027 SDL', '4.82%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.14% GUJARAT 11JAN2027 SDL', '4.47%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.59% BIHAR 15FEB2027 SDL', '3.88%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.62% UTTAR PRADESH 15FEB2027 SDL', '3.36%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.73% RAJASTHAN O1MAR2027 SDL', '3.22%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['6.72% KERALA 24MAR2027 SDL', '3.17%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.20 % KARNATAKA 25JAN2027 SDL', '2.87%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.59% GUJARAT 15FEB2027 SDL', '2.25%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.96% MAHARASHTRA 29JUN2026 SDL', '2.24%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.86% KARNATAKA 15MAR27 SDL', '1.94%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.80% KERALA TIMAR2027 SDL', '1.61%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.37% MAHARASHTRA 14SEP2026 SDL', '1.60%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.14% ANDHRA PRADESH 11JAN2027 SDL', '1.53%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.64% UTTAR PRADESH 29MAR2027 SDL', '1.29%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.60% MADHYA PRADESH 15FEB2027 SDL', '1.29%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.80% HARYAN 01MAR2027 SDL', '0.97%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.63% GUJARAT 12APR2027 SDL', '0.97%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.62% ANDHRA PRADESH 29MAR2027 SDL', '0.97%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.72% TAMIL NADU 19SEP2026 SDL', '0.91%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.40% TELANGANA O9NOV2026 SDL', '0.64%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.25% ANDHRA PRADESH 28DEC2026 SDL', '0.64%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.31% RAJASTHAN O8APR27 SDL', '0.33%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['RAJASTHAN 07.85% 15MAR27 SDL', '0.32%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.76% MADHYA PRADESH O01MAR27 SDL', '0.32%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.29% KERALA 28DEC2026 SDL', '0.32%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.18% UTTARAKHAND 11JAN2027 SDL', '0.32%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.12% BIHAR 11JAN27 SDL', '0.32%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['KARNATAKA 7.59% 29MAR27 SDL', '0.26%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['07.64% HARYANA 29MAR27 SDL', '0.18%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.77% KERALA O01MAR2027 SDL', '0.16%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.59% KARNATAKA 15FEB2027 SDL', '0.06%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.27% KARNATAKA 28DEC2026 SDL', '0.06%', 'SOV']
# agency :
# rating : SOV
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\CRISIL IBX 60cplon40 SDL + AAA PSU Apr 2026 Index Fund_page_51_left.png
# 2 [][] ['State Government bond', '47.75%']
# 3 [][] ['8.67% KARNATAKA 24FEB26 SDL', '20.45%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.42% KERALA 27JAN2026 SDL', '10.19%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.38% HARYANA 27JAN26 SDL', '5.09%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.67% MAHARASHTRA 24FEB2026 SDL', '3.27%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.51% HARYANA 10FEB2026 SDL', '2.24%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.08% CHHATTISGARH 23MAR2026 SDL', '2.04%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.17% KERALA 26NOV2025 SDL', '2.01%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.23% UTTAR PRADESH O9DEC2025 SDL', '1.22%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.27% TAMILNADU 23DEC2025 SDL', '0.82%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.17% TAMIL NADU 26NOV2025 SDL', '0.41%', 'SOV']
# agency :
# rating : SOV
# 2 [][] ['Fixed rates bonds - Corporate', '36.33%']
# 3 [][] ['National Bank For Agriculture and Rural Development', '14.12%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\CRISIL IBX Gilt - April 2026 Index Fund_page_45_left.png
# 2 [][] ['Government Bond', '96.20%']
# 3 [][] ['5.63% GOI 12APR2026', '73.97%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.59% GOI(MD 11/01/2026)', '11.74%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['6.99% GOVERNMENT OF INDIA 17APR26', '6.54%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.27% GOI OSAPR26', '3.96%', 'SOV']
# agency :
# rating : SOV
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\CRISIL IBX Gilt Apr 2028 Index Fund_page_49_left.png
# 2 [][] ['Government Bond', '96.59%']
# 3 [][] ['7.17% GOI (MD 08/01/2028)', '70.33%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['GOI 08.28% 21SEP27', '19.07%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['6.01% GOVERNMENT OF INDIA 25MAR2028', '4.91%', 'SOV']
# agency :
# rating : SOV
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\CRISIL IBX Gilt Apr 2029 Index Fund_page_47_left.png
# 2 [][] ['Government Bond', '91.95%']
# 3 [][] ['7.10% GOVERNMENT OF INDIA 18APR29', '91.04%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.59% GOI (MD 20/03/2029)', '0.72%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['07.26% GOI (MD 14/01/2029)', '0.19%', 'SOV']
# agency :
# rating : SOV
# 2 [][] ['Cash Management Bills', '6.50%']
# 3 [][] ['Government of India', '4.48%', 'SOV']
# agency :
# rating : SOV
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\CRISIL IBX Gilt April 2033 Index Fund_page_52_left.png
# 2 [][] ['Government Bond', '96.81%']
# 3 [][] ['7.26% GOVERNMENT OF INDIA OGFEB33', '83.75%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.26% GOI 22AUG2032', '13.06%', 'SOV']
# agency :
# rating : SOV
# 2 [][] ['Cash & Current Assets', '3.19%']
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\CRISIL IBX Gilt June 2027 Index Fund_page_53_left.png
# 2 [][] ['Government Bond', '96.39%']
# 3 [][] ['7.38% GOI 20JUN2027', '96.39%', 'SOV']
# agency :
# rating : SOV
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\CRISIL IBX SDL Jun 2032 Index Fund_page_50_left.png
# 2 [][] ['State Government bond', '76.46%']
# 3 [][] ['7.35% MAHARASHTRA 14JUN2032 SDL', '17.80%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.73% HARYANA O1MAR2032 SDL', '16.35%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.70% ANDHRA PRADESH 13SEP2027 SDL', '16.35%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.14% TAMIL NADU O2MAR2032 SDL', '12.72%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.42% RAJASTHAN 22MAY2032 SDL', '6.45%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.75% HIMACHAL PRADESH 29MAR2032 SDL', '3.27%', 'SOV']
# agency :
# rating : SOV
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\CRISIL Liquid Overnight ETF_page_60_left.png
# 2 [][] ['Cash & Current Assets', '100.00%']
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# left_half_screenshots\CRISIL-IBX AAA Financial Services Index - Sep 2027 Fund_page_56_left.png
# 2 [][] ['Fixed rates bonds - Corporate', '94.12%']
# 3 [][] ['HDB Financial Services Limited', '15.14%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Mahindra & Mahindra Financial Services Limited', '14.99%', 'CARE AAA']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# rating : AAA
# 3 [][] ['Tata Capital Limited', '14.97%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Bajaj Housing Finance Limited', '7.56%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Bajaj Finance Limited', '7.55%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Aditya Birla Finance Limited', '7.53%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# ...
# agency : ICRA
# rating : Al+
# 3 [][] ['Puniab National Bank', '0.39%', 'CRISIL A1+']
# agency: CRISIL
# agency_replaced_normalised_text :   A1+
# agency : CRISIL
# rating : A1+
# 3 [][] ['CanaraBank ©', '0.89%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['Axis Bank Limited', '0.76%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['indian Bank', '0.76%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['Union Bank of India', '0.63%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['Tata Teleservices Maharashtra Limited', '0.53%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['GIC Housing Finance Limited', '0.52%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['Axis Bank Limited', '0.51%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['The Federal Bank Limited', '0.51%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['Small Industries Develooment Bank of India', '0.51%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['Indusind Bank Limited |', '0.51%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['Union Bank of India', '0.51%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['Canara Bank', '0.51%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['Canara Bank', '0.51%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['Export Import Bank of India', '0.51%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['Puniab National Bank', '0.50%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['CTBC Bank Limited', '0.50%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['Indusind Bank Limited', '0.50%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['Nuvoco Vistas Corp Limited', '0.38%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 4 [][] ['Canara Bank', ':', '0.38%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['HDFC Bank Limited', '0.38%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['Export Import Bank of India', '0.38%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['HDFC Bank Limited', '0.26%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['Barclavs Invest & Loans India Limited', '0.25%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['Tata Proiects Limited', '0.25%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['Kotak Mahindra Bank Limited', '0.25%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['Puniab National Bank', '0.25%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['Nuvama Clearing Services Ltd', '0.25%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['Bharti Telecom Limited', '0.13%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['Axis Bank Limited', '0.13%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['IDFC First Bank Limited', '0.13%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['Union Bank of India', '0.13%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['HDFC Bank Limited', '0.13%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 3 [][] ['Kotak Mahindra Bank Limited', '0.13%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 3 [][] ['Kotak Mahindra Bank Limited', '0.12%', 'CRISIL Al+']
# agency: CRISIL
# agency_replaced_normalised_text :   Al+
# agency : CRISIL
# rating : Al+
# 2 [][] ['State Government bond', '724%']
# 3 [][] ['7.25% GUJARAT 07FEB2026 SDL', '197%', 'soV']
# agency :
# rating : soV
# 3 [][] ['2 14% RAJASTHAN 13NOV25 SDL', '1.23%', 'sOoV']
# agency :
# rating : sOoV
# 3 [][] ['6.9% TAMIL NADU SDL 160CT25', '0.78%', 'sOoV']
# agency :
# rating : sOoV
# 3 [][] ['GUJARAT GUJARA 8.23 09/09/25', '0.52%', 'SOV']
# agency :
# rating : SOV
# 2 [][] ['ae', '- a']
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# right_half_screenshots\Savings Fund_page_20_right.png
# 2 [][] ['Clearing Corporation of India Limited', '-0.00%']
# 2 [][] ['Clearing Corporation of India Limited', '-0.00%']
# 2 [][] ['Clearing Corporation of India Limited', '-0.00%']
# 2 [][] ['Clearing Corporation of India Limited', '-0.00%']
# 2 [][] ['HSBC Bank', '-0.00%']
# 2 [][] ['HSBC Bank', '-0.00%']
# 2 [][] ['BARCLAYS BANK PLC', '-0.00%']
# 2 [][] ['ICICI Securities Primary Dealership Limited', '-0.00%']
# 2 [][] ['Clearing Corporation of India Limited', '-0.00%']
# 2 [][] ['BARCLAYS BANK PLC', '-0.00%']
# 2 [][] ['Clearing Corporation of India Limited', '-0.00%']
# 2 [][] ['BARCLAYS BANK PLC', '-0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '-0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '-0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '-0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '-0.00%']
# 2 [][] ['Standard Chartered Bank', '-0.00%']
# 2 [][] ['ICICI Bank Limited', '-0.00%']
# 2 [][] ['HSBC Bank', '-0.00%']
# 2 [][] ['Standard Chartered Bank', '-0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '-0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '-0.00%']
# 2 [][] ['Standard Chartered Bank', '-0.00%']
# 2 [][] ['HSBC Bank', '-0.00%']
# 2 [][] ['Standard Chartered Bank', '-0.00%']
# 2 [][] ['HSBC Bank', '-0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '-0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '-0.00%']
# 2 [][] ['HSBC Bank', '-0.00%']
# 2 [][] ['ICICI Securities Primary Dealership Limited', '-0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '-0.00%']
# 2 [][] ['ICICI Bank Limited', '-0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '-0.00%']
# 2 [][] ['Standard Chartered Bank', '-0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '-0.00%']
# 2 [][] ['DBS Bank Ltd/India', '-0.00%']
# 2 [][] ['Standard Chartered Bank', '-0.00%']
# 2 [][] ['HSBC Bank', '-0.00%']
# 2 [][] ['HSBC Bank', '-0.00%']
# 2 [][] ['Standard Chartered Bank', '-0.00%']
# 2 [][] ['Standard Chartered Bank', '-0.01%']
# 2 [][] ['HSBC Bank', '-0.01%']
# 2 [][] ['Standard Chartered Bank', '-0.01%']
# 2 [][] ['Cash & Current Assets', '4.18%']
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# right_half_screenshots\Short Term Fund_page_27_right.png
# 3 [][] ['Mindspace Business Parks REIT', '0.57%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['State Bank of India - Tier Il - Basel Ill', '0.54%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Power Finance Corporation Limited', '0.50%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '0.50%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Bajaj Finance Limited', '0.50%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['National Housing Bank', '0.49%', 'IND AAA']
# agency: IND
# agency_replaced_normalised_text :   AAA
# agency : IND
# rating : AAA
# 3 [][] ['Tata Capital Housing Finance Limited', '0.49%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['SMFG India Home Finance Company Limited', '0.49%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['REC Limited', '0.49%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Hinduja Housing Finance Ltd', '0.49%', 'CARE AA+']
# agency: CARE
# agency_replaced_normalised_text :   AA+
# agency : CARE
# rating : AA+
# 3 [][] ['Tata Capital Housing Finance Limited', '0.49%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['JSW Energy Limited', '0.49%', 'ICRA AA']
# agency: ICRA
# agency_replaced_normalised_text :   AA
# agency : ICRA
# rating : AA
# 3 [][] ['REC Limited', '0.49%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Small Industries Development Bank of India', '0.49%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Tata Capital Limited', '0.49%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Mindspace Business Parks REIT', '0.49%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['JM Financial Credit Solutions Ltd', '0.48%', 'ICRA AA']
# agency: ICRA
# agency_replaced_normalised_text :   AA
# agency : ICRA
# rating : AA
# 3 [][] ['Indian Railway Finance Corporation Limited', '0.48%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '0.39%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '0.39%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Indian Railway Finance Corporation Limited', '0.38%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Bajaj Housing Finance Limited', '0.35%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Narayana Hrudayalaya Limited', '0.34%', 'ICRA AA']
# agency: ICRA
# agency_replaced_normalised_text :   AA
# agency : ICRA
# rating : AA
# 3 [][] ['SMFG India Home Finance Company Limited', '0.34%', 'CARE AAA']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# rating : AAA
# 3 [][] ['Small Industries Development Bank of India', '0.25%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '0.25%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Small Industries Development Bank of India', '0.25%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['National Housing Bank', '0.25%', 'CARE AAA']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '0.25%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['National Bank For Agriculture and Rural Development', '0.25%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Tata Capital Housing Finance Limited', '0.25%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Small Industries Development Bank of India', '0.25%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Export Import Bank of India', '0.25%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['Shriram Finance Ltd', '0.24%', 'CRISIL AA+']
# agency: CRISIL
# agency_replaced_normalised_text :   AA+
# agency : CRISIL
# rating : AA+
# 3 [][] ['Small Industries Development Bank of India', '0.24%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# 3 [][] ['Muthoot Finance Limited', '0.24%', 'ICRA AA+']
# agency: ICRA
# agency_replaced_normalised_text :   AA+
# agency : ICRA
# rating : AA+
# 3 [][] ['Nexus Select Trust', '0.24%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['DLF Home Developers Ltd', '0.24%', 'ICRA AA']
# agency: ICRA
# agency_replaced_normalised_text :   AA
# agency : ICRA
# rating : AA
# 3 [][] ['Muthoot Finance Limited', '0.24%', 'ICRA AA+']
# agency: ICRA
# agency_replaced_normalised_text :   AA+
# agency : ICRA
# rating : AA+
# 3 [][] ['REC Limited', '0.24%', 'ICRAAAA']
# agency: ICRA
# agency_replaced_normalised_text :  AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['REC Limited', '0.24%', 'ICRA AAA']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# rating : AAA
# 3 [][] ['HDB Financial Services Limited', '0.22%', 'CRISIL AAA']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# rating : AAA
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# right_half_screenshots\Short Term Fund_page_28_right.png
# 3 [][] ['Government of India', '0.08%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['Government of India', '0.04%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['Government of India', '0.00%', 'SOV']
# agency :
# rating : SOV
# 2 [][] ['Money Market Instruments', '0.48%']
# 3 [][] ['Sharekhan Ltd', '0.48%', 'ICRA Al+']
# agency: ICRA
# agency_replaced_normalised_text :   Al+
# agency : ICRA
# rating : Al+
# 2 [][] ['State Government bond', '0.37%']
# 3 [][] ['7.00% RAJASTHAN 25SEP2025 SDL', '0.24%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.64% GUJARAT OS8NOV27 SDL', '0.05%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['07.64% HARYANA 29MAR27 SDL', '0.03%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.25% GJ 25APR28 SDL', '0.03%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['8.60% BIHAR O9MAR2026 SDL', '0.01%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.51% UTTAR PRADESH 27MAR2038 SDL', '0.01%', 'SOV']
# agency :
# rating : SOV
# 3 [][] ['7.88% Chattisgarh SDL (MD 15/03/2027)', '0.01%', 'SOV']
# agency :
# rating : SOV
# 2 [][] ['Alternative Investment Funds (AIF)', '0.23%']
# 2 [][] ['Corporate Debt Market Development Fund', '0.23%']
# 2 [][] ['interest Rate Swaps', '0.01%']
# 2 [][] ['BNP Paribas - Indian branches', '0.01%']
# 2 [][] ['BARCLAYS BANK PLC', '0.00%']
# 2 [][] ['BARCLAYS BANK PLC', '0.00%']
# 2 [][] ['BARCLAYS BANK PLC', '0.00%']
# 2 [][] ['DBS Bank Ltd/India', '0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '0.00%']
# 2 [][] ['Standard Chartered Bank', '0.00%']
# 2 [][] ['BARCLAYS BANK PLC', '0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '0.00%']
# 2 [][] ['BARCLAYS BANK PLC', '0.00%']
# 2 [][] ['BARCLAYS BANK PLC', '0.00%']
# 2 [][] ['BARCLAYS BANK PLC', '0.00%']
# 2 [][] ['BARCLAYS BANK PLC', '0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '0.00%']
# 2 [][] ['BARCLAYS BANK PLC', '0.00%']
# 2 [][] ['DBS Bank Ltd/India', '0.00%']
# 2 [][] ['Standard Chartered Bank', '0.00%']
# 2 [][] ['DBS Bank Ltd/India', '-0.00%']
# 2 [][] ['Standard Chartered Bank', '-0.00%']
# 2 [][] ['IDFC First Bank Limited', '-0.00%']
# 2 [][] ['BNP Paribas - Indian branches', '-0.00%']
# 2 [][] ['Cash & Current Assets', '1.97%']

# %%
correct_rating_df.to_csv("test_ABC.csv", index=False)

# %%
# Save correct_rating_df to Excel file with separate sheets for each 'fund'
month_name = 'July'
output_excel = "output_data\\correct_rating_df_grouped_by_fund_ABC{}.xlsx".format(month_name)

with pd.ExcelWriter(output_excel, engine='openpyxl') as writer:
    for fund, group_df in correct_rating_df.groupby("Fund Type"):
        # Clean sheet name: max 31 characters, remove invalid characters
        # print("input_sheeet_name", str(fund))
        fund = fund.replace(" ", "").replace("CRISIL", "C")
        sheet_name = str(fund)[:31]
        invalid_chars = r'[:\\/?*[\]]'
        sheet_name = re.sub(invalid_chars, "_", sheet_name)
        print("output_sheeet_name", sheet_name)
        # print(f"Writing sheet: {sheet_name}")
        group_df.to_excel(writer, sheet_name=sheet_name, index=False)
        # group_df.drop(columns=["Fund Name"], errors="ignore").to_excel(writer, sheet_name=sheet_name, index=False)
        # print("--------------------------------------------")

print(f"✅ Processed data saved to: {output_excel}")
# Out:
# output_sheeet_name BalancedAdvantageFund
# output_sheeet_name Banking&PSUDebtFund
# output_sheeet_name C10YearGiltETF
# output_sheeet_name CBroadBasedGiltETF
# output_sheeet_name CIBX50colon50GiltPlusSDLApr2028
# output_sheeet_name CIBX60colon40SDL+AAAPSU-Apr2027
# output_sheeet_name CIBX60cplon40SDL+AAAPSUApr2026I
# output_sheeet_name CIBXGilt-April2026IndexFund
# output_sheeet_name CIBXGiltApr2028IndexFund
# output_sheeet_name CIBXGiltApr2029IndexFund
# output_sheeet_name CIBXGiltApril2033IndexFund
# output_sheeet_name CIBXGiltJune2027IndexFund
# output_sheeet_name CIBXSDLJun2032IndexFund
# output_sheeet_name CLiquidOvernightETF
# output_sheeet_name C-IBXAAAFinancialServicesIndex-
# output_sheeet_name C-IBXAAANBFC-HFCIndex-Dec2025Fu
# output_sheeet_name C-IBXAAANBFC-HFCIndex-Sep2026Fu
# output_sheeet_name C-IBXFinancialServices3to6Month
# output_sheeet_name C-IBXFinancialServices9-12Month
# output_sheeet_name CorporateBondFund
# output_sheeet_name CreditRiskFund
# output_sheeet_name DynamicBondFund
# output_sheeet_name EquityHybrid'95Fund
# output_sheeet_name EquitySavingsFund
# output_sheeet_name FloatingRateFund
# output_sheeet_name GoldETF
# output_sheeet_name GovernmentSecuritiesFund
# output_sheeet_name IncomeFund
# output_sheeet_name LargeCapFund
# output_sheeet_name LiquidFund
# output_sheeet_name LongDurationFund
# output_sheeet_name LowDurationFund
# output_sheeet_name MediumTermPlan
# output_sheeet_name MoneyManagerFund
# output_sheeet_name MultiAssetAllocationFund
# output_sheeet_name NIFTYSDLPlusPSUBondSep202660col
# output_sheeet_name NiftySDLApr2027IndexFund
# output_sheeet_name NiftySDLSep2025IndexFund
# output_sheeet_name NiftySDLSep2027IndexFund
# output_sheeet_name OvernightFund
# output_sheeet_name RegularSavingsFund
# output_sheeet_name RetirementFund'The50sPlus-DebtP
# output_sheeet_name RetirementFund-The30sPlan
# output_sheeet_name RetirementFund-The40sPlan
# output_sheeet_name RetirementFund-The50sPlan
# output_sheeet_name SavingsFund
# output_sheeet_name ShortTermFund
# ✅ Processed data saved to: correct_rating_df_grouped_by_fund_ABC_July.xlsx

# %%
################################ Code to check total number of sheets in excel file ########################################
import pandas as pd

excel_file = pd.ExcelFile(r"D:\Nexensus_Projects\pdfEtraction\Aditya_Birla_Capital\correct_rating_df_grouped_by_fund_ABC_July.xlsx")
total_sheets = len(excel_file.sheet_names)

print("Total sheets:", total_sheets)
print("Sheet names:", excel_file.sheet_names)
# Out:
# Total sheets: 47
# Sheet names: ['BalancedAdvantageFund', 'Banking&PSUDebtFund', 'C10YearGiltETF', 'CBroadBasedGiltETF', 'CIBX50colon50GiltPlusSDLApr2028', 'CIBX60colon40SDL+AAAPSU-Apr2027', 'CIBX60cplon40SDL+AAAPSUApr2026I', 'CIBXGilt-April2026IndexFund', 'CIBXGiltApr2028IndexFund', 'CIBXGiltApr2029IndexFund', 'CIBXGiltApril2033IndexFund', 'CIBXGiltJune2027IndexFund', 'CIBXSDLJun2032IndexFund', 'CLiquidOvernightETF', 'C-IBXAAAFinancialServicesIndex-', 'C-IBXAAANBFC-HFCIndex-Dec2025Fu', 'C-IBXAAANBFC-HFCIndex-Sep2026Fu', 'C-IBXFinancialServices3to6Month', 'C-IBXFinancialServices9-12Month', 'CorporateBondFund', 'CreditRiskFund', 'DynamicBondFund', "EquityHybrid'95Fund", 'EquitySavingsFund', 'FloatingRateFund', 'GoldETF', 'GovernmentSecuritiesFund', 'IncomeFund', 'LargeCapFund', 'LiquidFund', 'LongDurationFund', 'LowDurationFund', 'MediumTermPlan', 'MoneyManagerFund', 'MultiAssetAllocationFund', 'NIFTYSDLPlusPSUBondSep202660col', 'NiftySDLApr2027IndexFund', 'NiftySDLSep2025IndexFund', 'NiftySDLSep2027IndexFund', 'OvernightFund', 'RegularSavingsFund', "RetirementFund'The50sPlus-DebtP", 'RetirementFund-The30sPlan', 'RetirementFund-The40sPlan', 'RetirementFund-The50sPlan', 'SavingsFund', 'ShortTermFund']
