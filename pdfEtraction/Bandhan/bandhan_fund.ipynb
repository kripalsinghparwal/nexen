# %%
############## Code to split pdf to keep only pages with Rating table in it #####################
import pdfplumber
from PyPDF2 import PdfWriter, PdfReader
from datetime import datetime

# month_name = datetime.now().strftime("%b")
month_name = "Oct"

input_pdf_path = "8dfe25ff-bandhan-passive-factsheet-oct-2025.pdf"
output_pdf_path = "filtered_{}.pdf".format(input_pdf_path.split(".")[0])

reader = PdfReader(input_pdf_path)
writer = PdfWriter()
fund_list = [
    "Gilt April 2026 Index Fund",
    "Gilt June 2027 Index Fund",
    "Gilt April 2028 Index Fund",
    "Gilt April 2032 Index Fund",
    "90colon10 SDL Plus Gilt- November 2026 Index Fund",
    "90colon10 SDL Plus Gilt- September 2027 Index Fund",
    "90colon10 SDL Plus Gilt-April 2032 Index Fund",
    "10colon90 Gilt + SDL Index - Dec 2029 Fund",
    "Financial Services 3-6 Months Debt Index Fund",
]

with pdfplumber.open(input_pdf_path) as pdf:
    for page_num, page in enumerate(pdf.pages):
        words = page.extract_words()
        page_heading = page.extract_text_lines()[0]['text'].strip().replace(" ", "_")
        capital_words = [word['text'] for word in words if word['text'].isupper()]
        if "PORTFOLIO" in capital_words:
            for word in words:
                if 'Rating' in word['text']:
                    print(f"\n=== Page {page_num + 1} ===")
                    # print(page_num,capital_words)
                    print("page heading :", page_heading.split("Fund")[0] + "Fund")
                    # fund_list.append(page_heading.split("Fund")[0].replace(":", "double_colon") + "Fund")
                    print([word['text'] for word in words])
                    writer.add_page(reader.pages[page_num])
                    break  # add this page once, then move to next page

# Save the filtered PDF
with open(output_pdf_path, "wb") as f_out:
    writer.write(f_out)
# Out:
# === Page 22 ===
# page heading : Bandhan_CRISIL_IBX_Gilt_April_2026_Index_Fund
# ['Bandhan', 'CRISIL', 'IBX', 'Gilt', 'April', '2026', 'Index', 'Fund', 'Click', 'here', 'to', 'Know', 'more', 'A', 'w', 'n', 'it', 'h', 'o', 'p', 'R', 'e', 'e', 'n', 'la', '-e', 'ti', 'n', 'v', 'd', 'e', 'e', 'ly', 'd', 'H', 'T', 'i', 'a', 'g', 'r', 'h', 'g', 'e', 'in', 't', 't', 'M', 'er', 'a', 'e', 't', 's', 'u', 't', 'r', 'r', 'it', 'a', 'y', 't', 'e', 'In', 'r', 'd', 'is', 'e', 'k', 'x', 'a', 'F', 'n', 'u', 'd', 'n', 'R', 'd', 'e', 'in', 'la', 'v', 't', 'e', 'iv', 's', 'e', 'ti', 'l', 'n', 'y', 'g', 'L', 'i', 'o', 'n', 'w', 'c', 'o', 'C', 'n', 're', 'st', 'd', 'i', 'i', 't', 't', 'u', 'R', 'e', 'i', 'n', 's', 't', 'k', 's', 'of', 'Crisil', 'IBX', 'Gilt', 'Index', '-', 'April', '2026', 'P', 'R', 'o', 'is', 't', 'A', 'e', 'k', 'n', 'C', '-', 't', 'l', 'I', 'i', 'a', 'a', 'I', 's', 'l', 'I', 's', '31st', 'October', '2025', 'FUND', 'FEATURES', 'PORTFOLIO', 'About', 'the', 'Fund:', 'The', 'investment', 'objective', 'of', 'the', 'scheme', 'Name', 'Rating', '%', 'of', 'NAV', 'is', 'to', 'provide', 'investment', 'returns', 'corresponding', 'to', 'the', 'total', 'returns', 'of', 'the', 'securities', 'as', 'represented', 'by', 'the', 'CRISIL', 'IBX', 'Gilt', 'Index', '-', 'April', '2026', 'before', 'expenses,', 'subject', 'to', 'tracking', 'errors.', 'Government', 'Bond', '96.72%', 'However,', 'there', 'can', 'be', 'no', 'assurance', 'or', 'guarantee', 'that', 'the', '6.99%', '-', '2026', 'G-Sec', 'SOV', '37.54%', 'investment', 'objective', 'of', 'the', 'Scheme', 'will', 'be', 'achieved.', '5.63%', '-', '2026', 'G-Sec', 'SOV', '25.87%', 'Category:', 'Index', 'Fund', '7.59%', '-', '2026', 'G-Sec', 'SOV', '17.10%', 'Monthly', 'Avg', 'AUM:', '`', '401.48', 'Crores', '5.15%', '-', '2025', 'G-Sec', 'SOV', '11.20%', 'Month', 'end', 'AUM:', '`', '401.95', 'Crores', 'Inception', 'Date:', '20', 'October,', '2022', '7.27%', '-', '2026', 'G-Sec', 'SOV', '5.01%', 'Fund', 'Manager:', 'Mr.', 'Gautam', 'Kaul', 'Net', 'Cash', 'and', 'Cash', 'Equivalent', '3.28%', 'Other', 'Parameter:', 'Grand', 'Total', '100.00%', 'Modified', 'Duration', '123', 'Days', 'Average', 'Maturity', '127', 'Days', 'Macaulay', 'Duration', '126', 'Days', 'Yield', 'to', 'Maturity', '5.67%', 'Total', 'Expense', 'Ratio', 'Regular', '0.44%', 'Direct', '0.19%', 'Tracking', 'Error', '(1', 'year)*', '0.12%', 'Benchmark:', 'CRISIL', 'IBX', 'Gilt', 'Index', '-', 'April', '2026', 'SIP', '(Minimum', 'Amount):', '`', '100/-', 'and', 'in', 'multiples', 'of', 'Re.1', 'thereafter', 'SIP', 'Frequency:', 'Monthly/Quarterly', 'SIP', 'Dates', '(Monthly/Quarterly)@@:', 'Investor', 'may', 'choose', 'any', 'day', 'of', 'the', 'month', 'from', '1st', 'to', '31st', 'as', 'the', 'date', 'of', 'the', 'instalment.', 'Investment', 'Objective:', 'Refer', 'Pg', 'No.', '42', 'Minimum', 'Investment', 'Amount:', '`', '1,000/-', 'and', 'in', 'multiples', 'of', 'Re.', '1/-', 'thereafter', 'Option', 'Available:', 'Growth', '&', 'Income', 'Distribution', 'cum', 'capital', 'withdrawal', 'Option', '(Payout,', 'Reinvestment', 'or', 'Sweep', 'facility).', 'Exit', 'Load:', 'Nil', 'NAV', '(`)', 'as', 'on', 'October', '31,', '2025', 'Plan', 'Option', 'Freq', 'NAV', 'Regular', 'Plan', 'Growth', '-', '12.3383', 'Regular', 'Plan', 'IDCW@', '-', '10.3502', '@Income', 'Distribution', 'and', 'Capital', 'Withdrawal.', 'ASSET', 'QUALITY', '*For', 'funds', 'in', 'existence', 'for', 'less', 'than', '1', 'year,', 'tracking', 'error', 'computed', 'since', 'inception.', 'Potential', 'Risk', 'Class', 'Matrix', 'Credit', 'Risk', 'of', 'the', 'scheme\uf022', 'Relatively', 'Moderate', 'Relatively', 'Low', '(Class', '(Class', 'B)', 'High', '(Class', 'C)', 'Interest', 'Rate', 'Risk', 'of', 'the', 'A)', 'scheme\uf024', 'Relatively', 'Low', '(Class', 'I)', 'Moderate', '(Class', 'II)', 'Relatively', 'High', '(Class', 'III)', 'A-III', 'A', 'Scheme', 'with', 'Relatively', 'High', 'Interest', 'Rate', 'Risk', 'and', 'Relatively', 'Low', 'Credit', 'Risk.', 'PERFORMANCE', 'TABLE', 'Scheme', 'Name', 'CAGR', 'Returns', '(%)', 'Current', 'Value', ' ...
#
# === Page 23 ===
# page heading : Bandhan_CRISIL_IBX_Gilt_June_2027_Index_Fund
# ['Bandhan', 'CRISIL', 'IBX', 'Gilt', 'June', '2027', 'Index', 'Fund', 'An', 'open-ended', 'Target', 'Maturity', 'Index', 'fund', 'investing', 'in', 'constituents', 'of', 'CRISIL', 'IBX', 'Gilt', 'June', '2027', 'Click', 'here', 'to', 'Know', 'more', 'P', 'R', 'o', 'is', 't', 'A', 'e', 'k', 'n', 'C', '-', 't', 'l', 'I', 'i', 'a', 'a', 'I', 's', 'l', 'I', 's', 'with', 'Relatively', 'High', 'Interest', 'Rate', 'Risk', 'and', 'Relatively', 'Low', 'Credit', 'Risk.', '31st', 'October', '2025', 'Satellite', 'Bucket', 'FUND', 'FEATURES', 'PORTFOLIO', 'About', 'the', 'Fund:', 'The', 'fund', 'seeks', 'to', 'invest', 'in', 'government', 'Name', 'Rating', '%', 'of', 'NAV', 'securities', 'and', 'treasury', 'bills', 'that', 'form', 'part', 'of', 'its', 'respective', 'index.', 'This', 'is', 'a', 'target', 'maturity', 'index', 'fund,', 'therefore', 'it', 'Government', 'Bond', '96.42%', 'terminates', 'on', 'a', 'specific', 'date', '(June', '30,', '2027)', '7.38%', '-', '2027', 'G-Sec', 'SOV', '59.44%', 'Category:', 'Index', 'Fund', '6.79%', '-', '2027', 'G-Sec', 'SOV', '15.96%', 'Monthly', 'Avg', 'AUM:', '`', '6,396.91', 'Crores', '8.24%', '-', '2027', 'G-Sec', 'SOV', '15.75%', 'Month', 'end', 'AUM:', '`', '6,370.66', 'Crores', '7.02%', '-', '2027', 'G-Sec', 'SOV', '5.28%', 'Inception', 'Date:', '23', 'March', '2021', 'Fund', 'Manager:', 'Mr.', 'Harshal', 'Joshi', '(w.e.f.', '28th', 'July', '2021)', 'Net', 'Cash', 'and', 'Cash', 'Equivalent', '3.58%', 'Mr.', 'Gautam', 'Kaul', '(w.e.f.', '1st', 'December', '2021)', 'Grand', 'Total', '100.00%', 'Other', 'Parameter:', 'Modified', 'Duration', '1.41', 'years', 'Average', 'Maturity', '1.54', 'years', 'Macaulay', 'Duration', '1.45', 'years', 'Yield', 'to', 'Maturity', '5.79%', 'Total', 'Expense', 'Ratio', 'Regular', '0.46%', 'Direct', '0.21%', 'Tracking', 'Error', '(1', 'year)*', '0.15%', 'Benchmark:', 'CRISIL-IBX', 'Gilt', 'Index', '-', 'June', '2027', 'SIP', '(Minimum', 'Amount):', '`', '100/-', 'and', 'in', 'multiples', 'of', 'Re.1', 'thereafter', '(minimum', '6', 'installments)', 'SIP', 'Frequency:', 'Monthly/Quarterly', 'SIP', 'Dates', '(Monthly/Quarterly)@@:', 'Investor', 'may', 'choose', 'any', 'day', 'of', 'the', 'month', 'from', '1st', 'to', '31st', 'as', 'the', 'date', 'of', 'the', 'instalment.', 'Investment', 'Objective:', 'Refer', 'Pg', 'No.', '42', 'Minimum', 'Investment', 'Amount:', '`', '1,000/-', 'and', 'any', 'amount', 'thereafter', 'Option', 'Available:', 'Growth', '&', 'Income', 'Distribution', 'cum', 'capital', 'withdrawal', 'Option', '(Payout,', 'Reinvestment', 'or', 'Sweep', 'facility)', 'Exit', 'Load:', 'Nil', 'NAV', '(`)', 'as', 'on', 'October', '31,', '2025', 'Plan', 'Option', 'Freq', 'NAV', 'Regular', 'Plan', 'Growth', '-', '13.1430', 'Regular', 'Plan', 'IDCW@', '-', '10.2047', '@Income', 'Distribution', 'and', 'Capital', 'Withdrawal.', '*For', 'funds', 'in', 'existence', 'for', 'less', 'than', '1', 'year,', 'tracking', 'error', 'computed', 'since', 'inception.', 'ASSET', 'QUALITY', 'Potential', 'Risk', 'Class', 'Matrix', 'Credit', 'Risk', 'of', 'the', 'scheme\uf022', 'Relatively', 'Moderate', 'Relatively', 'Low', '(Class', '(Class', 'B)', 'High', '(Class', 'C)', 'Interest', 'Rate', 'Risk', 'of', 'the', 'A)', 'scheme\uf024', 'Relatively', 'Low', '(Class', 'I)', 'Moderate', '(Class', 'II)', 'Relatively', 'High', '(Class', 'III)', 'A-III', 'A', 'Scheme', 'with', 'Relatively', 'High', 'Interest', 'Rate', 'Risk', 'and', 'Relatively', 'Low', 'Credit', 'Risk.', 'PERFORMANCE', 'TABLE', 'Scheme', 'Name', 'CAGR', 'Returns', '(%)', 'Current', 'Value', 'of', 'Investment', 'of', '`', '10,000', 'Since', 'Since', '1', 'Year', '3', 'Years', '5', 'Years', '1', 'Year', '3', 'Years', '5', 'Years', 'Inception*', 'Inception*', 'Bandhan', 'CRISIL', 'IBX', 'Gilt', 'June', '2027', 'Index', '7.89%', '7.80%', 'NA', '6.11%', '10,789', '12,531', 'NA', '13,143', 'CRISIL-IBX', 'Gilt', 'Index', '-', 'June', '2027#', '8.32%', '8.24%', 'NA', '6.53%', '10,832', '12,684', 'NA', '13,387', '10', 'Year', 'GOI## ...
#
# === Page 24 ===
# page heading : Bandhan_CRISIL_IBX_Gilt_April_2028_Index_Fund
# ['Bandhan', 'CRISIL', 'IBX', 'Gilt', 'April', '2028', 'Index', 'Fund', 'Click', 'here', 'to', 'Know', 'more', 'A', 'w', 'n', 'it', 'h', 'o', 'p', 'R', 'e', 'e', 'n', 'la', '-e', 'ti', 'n', 'v', 'd', 'e', 'e', 'ly', 'd', 'H', 'T', 'i', 'a', 'g', 'r', 'h', 'g', 'e', 'in', 't', 't', 'M', 'er', 'a', 'e', 't', 's', 'u', 't', 'r', 'r', 'it', 'a', 'y', 't', 'e', 'In', 'r', 'd', 'is', 'e', 'k', 'x', 'a', 'f', 'n', 'u', 'd', 'n', 'd', 'R', 'e', 'in', 'la', 'v', 't', 'e', 'i', 's', 'v', 't', 'e', 'in', 'ly', 'g', 'L', 'i', 'o', 'n', 'w', 'c', 'o', 'C', 'n', 'r', 's', 'e', 't', 'd', 'it', 'it', 'u', 'e', 'R', 'n', 'is', 't', 'k', 's', '.', 'of', 'CRISIL', 'IBX', 'Gilt', 'April', '2028', 'Index', 'P', 'R', 'o', 'is', 't', 'A', 'e', 'k', 'n', 'C', '-', 't', 'l', 'I', 'i', 'a', 'a', 'I', 's', 'l', 'I', 's', '31st', 'October', '2025', 'Satellite', 'Bucket', 'FUND', 'FEATURES', 'PORTFOLIO', 'About', 'the', 'Fund:', 'The', 'fund', 'seeks', 'to', 'invest', 'in', 'government', 'Name', 'Rating', '%', 'of', 'NAV', 'securities', 'and', 'treasury', 'bills', 'that', 'form', 'part', 'of', 'its', 'respective', 'index.', 'This', 'is', 'a', 'target', 'maturity', 'index', 'fund,', 'therefore', 'it', 'Government', 'Bond', '97.91%', 'terminates', 'on', 'a', 'specific', 'date', '(April', '05,', '2028)', '7.17%', '-', '2028', 'G-Sec', 'SOV', '57.47%', 'Category:', 'Index', 'Fund', '8.28%', '-', '2027', 'G-Sec', 'SOV', '39.98%', 'Monthly', 'Avg', 'AUM:', '`', '4,272.47', 'Crores', '7.38%', '-', '2027', 'G-Sec', 'SOV', '0.45%', 'Month', 'end', 'AUM:', '`', '4,244.71', 'Crores', 'Net', 'Cash', 'and', 'Cash', 'Equivalent', '2.09%', 'Grand', 'Total', '100.00%', 'Inception', 'Date:', '23', 'March', '2021', 'Fund', 'Manager:', 'Mr.', 'Harshal', 'Joshi', '(w.e.f.', '28th', 'July', '2021)', 'Mr.', 'Gautam', 'Kaul', '(w.e.f.', '1st', 'December', '2021)', 'Other', 'Parameter:', 'Modified', 'Duration', '1.86', 'years', 'Average', 'Maturity', '2.06', 'years', 'Macaulay', 'Duration', '1.91', 'years', 'Yield', 'to', 'Maturity', '5.87%', 'Total', 'Expense', 'Ratio', 'Regular', '0.46%', 'Direct', '0.21%', 'Tracking', 'Error', '(1', 'year)*', '0.19%', 'Benchmark:', 'CRISIL-IBX', 'Gilt', 'Index', '-', 'April', '2028', 'SIP', '(Minimum', 'Amount):', '`', '100/-', 'and', 'in', 'multiples', 'of', 'Re.1', 'thereafter', '(minimum', '6', 'installments)', 'SIP', 'Frequency:', 'Monthly/Quarterly', 'SIP', 'Dates', '(Monthly/Quarterly)@@:', 'Investor', 'may', 'choose', 'any', 'day', 'of', 'the', 'month', 'from', '1st', 'to', '31st', 'as', 'the', 'date', 'of', 'the', 'instalment.', 'Investment', 'Objective:', 'Refer', 'Pg', 'No.', '42', 'Minimum', 'Investment', 'Amount:', '`', '1,000/-', 'and', 'any', 'amount', 'thereafter', 'Option', 'Available:', 'Growth', '&', 'Income', 'Distribution', 'cum', 'capital', 'withdrawal', 'Option', '(Payout,', 'Reinvestment', 'or', 'Sweep', 'facility)', 'Exit', 'Load:', 'Nil', 'ASSET', 'QUALITY', 'NAV', '(`)', 'as', 'on', 'October', '31,', '2025', 'Plan', 'Option', 'Freq', 'NAV', 'Potential', 'Risk', 'Class', 'Matrix', 'Regular', 'Plan', 'Growth', '-', '13.2352', 'Regular', 'Plan', 'IDCW@', '-', '10.2361', 'Credit', 'Risk', 'of', 'the', 'scheme\uf022', 'Relatively', 'Moderate', 'Relatively', 'Low', '(Class', '@Income', 'Distribution', 'and', 'Capital', 'Withdrawal.', 'Interest', 'Rate', 'Risk', 'of', 'the', 'A)', '(Class', 'B)', 'High', '(Class', 'C)', 'scheme\uf024', '*For', 'funds', 'in', 'existence', 'for', 'less', 'than', '1', 'year,', 'tracking', 'error', 'computed', 'since', 'inception.', 'Relatively', 'Low', '(Class', 'I)', 'Moderate', '(Class', 'II)', 'Relatively', 'High', '(Class', 'III)', 'A-III', 'A', 'Scheme', 'with', 'Relatively', 'High', 'Interest', 'Rate', 'Risk', 'and', 'Relatively', 'Low', 'Credit', 'Risk', 'PERFORMANCE', 'TABLE', 'Scheme', 'Name', 'CAGR', 'Returns', '(%)', 'Current', 'Value', 'of', 'Investment', 'of', '`', '10,000', 'Since', 'Since', '1', 'Year', '3', 'Years', '5', 'Years', '1', 'Year', '3', 'Years', '5', 'Years', 'Incepti ...
#
# === Page 25 ===
# page heading : Bandhan_CRISIL_IBX_Gilt_April_2032_Index_Fund
# ['Bandhan', 'CRISIL', 'IBX', 'Gilt', 'April', '2032', 'Index', 'Fund', 'Click', 'here', 'to', 'Know', 'more', 'A', 'Re', 'n', 'l', 'a', 'o', 't', 'p', 'iv', 'e', 'e', 'n', 'l', '-', 'y', 'e', 'n', 'H', 'd', 'ig', 'e', 'h', 'd', 'i', 'T', 'n', 'a', 't', 'r', 'e', 'g', 'r', 'e', 'e', 't', 's', 't', 'M', 'ra', 'a', 't', 't', 'e', 'u', 'r', 'r', 'i', 'i', 't', 's', 'y', 'k', 'I', 'a', 'n', 'n', 'd', 'd', 'e', 'x', 'R', 'F', 'e', 'u', 'la', 'n', 't', 'd', 'iv', 'i', 'e', 'n', 'l', 'v', 'y', 'e', 'L', 's', 'o', 'ti', 'w', 'n', 'g', 'C', 'r', 'in', 'e', 'd', 'co', 'it', 'n', 'R', 's', 'i', 't', 's', 'i', 'k', 'tuents', 'of', 'Crisil', 'IBX', 'Gilt', 'Index', '-', 'April', '2032', 'with', 'P', 'R', 'o', 'is', 't', 'A', 'e', 'k', 'n', 'C', '-', 't', 'l', 'I', 'i', 'a', 'a', 'I', 's', 'l', 'I', 's', '31st', 'October', '2025', 'FUND', 'FEATURES', 'PORTFOLIO', 'About', 'the', 'Fund:', 'This', 'Target', 'Maturity', 'Index', 'Fund', 'aims', 'to', 'Name', 'Rating', '%', 'of', 'NAV', 'provide', 'the', 'investment', 'returns', 'corresponding', 'to', 'the', 'total', 'returns', 'of', 'the', 'securities', 'as', 'represented', 'by', 'the', 'CRISIL', 'IBX', 'Government', 'Bond', '97.54%', 'Gilt', 'Index', '–', 'April', '2032', 'before', 'expenses,', 'subject', 'to', 'tracking', 'errors.', 'The', 'scheme', 'will', 'terminate', 'on', '30th', 'April', '2032', '6.54%', '-', '2032', 'G-Sec', 'SOV', '77.16%', '6.1%', '-', '2031', 'G-Sec', 'SOV', '20.38%', 'Category:', 'Index', 'Fund', 'Net', 'Cash', 'and', 'Cash', 'Equivalent', '2.46%', 'Monthly', 'Avg', 'AUM:', '`', '438.21', 'Crores', 'Grand', 'Total', '100.00%', 'Month', 'end', 'AUM:', '`', '436.94', 'Crores', 'Inception', 'Date:', '15', 'February', '2023', 'Fund', 'Manager:', 'Mr.', 'Harshal', 'Joshi', '&', 'Mr.', 'Gautam', 'Kaul', 'Other', 'Parameter:', 'Modified', 'Duration', '4.86', 'years', 'Average', 'Maturity', '6.07', 'years', 'Macaulay', 'Duration', '5.02', 'years', 'Yield', 'to', 'Maturity', '6.51%', 'Total', 'Expense', 'Ratio', 'Regular', '0.47%', 'Direct', '0.21%', 'Tracking', 'Error', '(1', 'year)*', '0.57%', 'Benchmark:', 'Crisil', 'IBX', 'Gilt', 'Index', '-', 'April', '2032', 'SIP', '(Minimum', 'Amount):', '`', '100/-', 'and', 'in', 'multiples', 'of', 'Re.1', 'thereafter', 'SIP', 'Frequency:', 'Monthly/Quarterly', 'SIP', 'Dates', '(Monthly/Quarterly)@@:', 'Investor', 'may', 'choose', 'any', 'day', 'of', 'the', 'month', 'from', '1st', 'to', '31st', 'as', 'the', 'date', 'of', 'the', 'instalment.', 'ASSET', 'QUALITY', 'Investment', 'Objective:', 'Refer', 'Pg', 'No.', '42', 'Minimum', 'Investment', 'Amount:', '`', '1,000/-', 'and', 'in', 'multiples', 'of', 'Re.', '1/-', 'thereafter', 'Option', 'Available:', 'Growth', '&', 'Income', 'Distribution', 'cum', 'capital', 'withdrawal', 'Option', '(Payout,', 'Reinvestment', 'or', 'Sweep', 'facility).', 'Exit', 'Load:', 'Nil', 'NAV', '(`)', 'as', 'on', 'October', '31,', '2025', 'Plan', 'Option', 'Freq', 'NAV', 'Regular', 'Plan', 'Growth', '-', '12.5168', 'Regular', 'Plan', 'IDCW@', '-', '10.7991', '@Income', 'Distribution', 'and', 'Capital', 'Withdrawal.', '*For', 'funds', 'in', 'existence', 'for', 'less', 'than', '1', 'year,', 'tracking', 'error', 'computed', 'since', 'inception.', 'Potential', 'Risk', 'Class', 'Matrix', 'Credit', 'Risk', 'of', 'the', 'scheme\uf022', 'Relatively', 'Low', '(Class', 'A)', 'Moderate', '(Class', 'B)', 'Relatively', 'High', '(Class', 'C)', 'Interest', 'Rate', 'Risk', 'of', 'the', 'scheme\uf024', 'Relatively', 'Low', '(Class', 'I)', 'Moderate', '(Class', 'II)', 'Relatively', 'High', '(Class', 'III)', 'A-III', 'A', 'Scheme', 'with', 'Relatively', 'High', 'Interest', 'Rate', 'Risk', 'and', 'Relatively', 'Low', 'Credit', 'Risk', 'PERFORMANCE', 'TABLE', 'Scheme', 'Name', 'CAGR', 'Returns', '(%)', 'Current', 'Value', 'of', 'Investment', 'of', '`', '10,000', 'Since', 'Since', '1', 'Year', '3', 'Years', '5', 'Years', '1', 'Year', '3', 'Years', '5', 'Years', 'Inception*', 'Inception*', 'Bandhan', 'CRISIL', 'IBX', 'Gilt', 'April' ...
#
# === Page 26 ===
# page heading : Bandhan_CRISIL_IBX_90:10_SDL_Plus_Gilt_–_November_2026_Index_Fund
# ['Bandhan', 'CRISIL', 'IBX', '90:10', 'SDL', 'Plus', 'Gilt', '–', 'November', '2026', 'Index', 'Fund', 'A', 'G', 'n', 'ilt', 'o', 'I', 'p', 'n', 'e', 'd', 'n', 'e', '-', 'x', 'e', '–', 'n', 'N', 'd', 'o', 'ed', 've', 'T', 'm', 'ar', 'b', 'g', 'e', 'e', 'r', 't', '2', 'M', '02', 'a', '6', 'tu', 'w', 'ri', 'i', 't', 't', 'y', 'h', 'I', 'R', 'nd', 'el', 'e', 'a', 'x', 't', 'i', 'F', 'v', 'u', 'e', 'n', 'ly', 'd', 'H', 'in', 'ig', 'v', 'h', 'e', 's', 'i', 't', 'n', 'i', 't', 'n', 'e', 'g', 'r', 'e', 'in', 's', 't', 'c', 'o', 'ra', 'n', 't', 's', 'e', 't', 'i', 'r', 't', 'i', 'u', 'sk', 'e', 'n', 'a', 't', 'n', 's', 'd', 'o', 'R', 'f', 'e', 'C', 'l', 'R', 'at', 'IS', 'iv', 'I', 'e', 'L', 'l', 'I', 'y', 'B', 'L', 'X', 'o', '9', 'w', '0', ':', 'C', '1', 'r', '0', 'e', 'd', 'SD', 'it', 'L', 'R', 'p', 'is', 'l', 'k', 'u', 's', 'Click', 'here', 'to', 'Know', 'more', 'P', 'R', 'o', 'is', 't', 'A', 'e', 'k', 'n', 'C', '-', 't', 'l', 'I', 'i', 'a', 'a', 'I', 's', 'l', 'I', 's', '31st', 'October', '2025', 'FUND', 'FEATURES', 'PORTFOLIO', 'About', 'the', 'Fund:', 'This', 'Target', 'Maturity', 'Index', 'Fund', 'aims', 'to', 'Name', 'Rating', '%', 'of', 'NAV', 'provide', 'the', 'investment', 'returns', 'corresponding', 'to', 'the', 'total', 'returns', 'of', 'the', 'securities', 'as', 'represented', 'by', 'the', 'CRISIL', 'IBX', 'State', 'Government', 'Bond', '86.70%', '90:10', 'SDL', 'plus', 'Gilt', 'Index', '–', 'November', '2026', 'before', 'expenses,', 'subject', 'to', 'tracking', 'errors.', 'The', 'scheme', 'will', 'terminate', 'on', '30th', '7.57%', 'Gujarat', 'SDL', '-', '2026', 'SOV', '17.29%', 'November', '2026.', '6.24%', 'Maharashtra', 'SDL', '-', '2026', 'SOV', '14.63%', 'Category:', 'Index', 'Fund', '7.4%', 'Madhya', 'Pradesh', 'SDL', '-', '2026', 'SOV', '9.87%', 'Monthly', 'Avg', 'AUM:', '`', '102.70', 'Crores', '7.49%', 'Gujarat', 'SDL', '-', '2026', 'SOV', '6.04%', '7.58%', 'Tamilnadu', 'SDL', '-', '2026', 'SOV', '4.93%', 'Month', 'end', 'AUM:', '`', '102.94', 'Crores', '7.22%', 'Maharashtra', 'SDL', '-', '2026', 'SOV', '4.92%', 'Inception', 'Date:', '17', 'November,', '2022', '7.17%', 'Rajasthan', 'SDL', '-', '2026', 'SOV', '4.91%', 'Fund', 'Manager:', 'Mr.', 'Gautam', 'Kaul', '&', 'Mr.', 'Harshal', 'Joshi', '7.04%', 'Gujarat', 'SDL', '-', '2026', 'SOV', '4.90%', 'Other', 'Parameter:', '7.59%', 'Kerala', 'SDL', '-', '2026', 'SOV', '3.94%', 'Modified', 'Duration', '307', 'days', 'Average', 'Maturity', '327', 'days', '7.41%', 'Uttar', 'Pradesh', 'SDL', '-', '2026', 'SOV', '3.45%', 'Macaulay', 'Duration', '316', 'days', '7.16%', 'Madhya', 'Pradesh', 'SDL', '-', '2026', 'SOV', '3.38%', 'Yield', 'to', 'Maturity', '5.83%', '8.72%', 'Tamilnadu', 'SDL', '-', '2026', 'SOV', '2.39%', 'Total', 'Expense', 'Ratio', '7.19%', 'West', 'Bangal', 'SDL', '-', '2026', 'SOV', '1.97%', 'Regular', '0.35%', 'Direct', '0.10%', '7.69%', 'Uttar', 'Pradesh', 'SDL', '-', '2026', 'SOV', '1.03%', '7.15%', 'Madhya', 'Pradesh', 'SDL', '-', '2026', 'SOV', '0.98%', 'Tracking', 'Error', '(1', 'year)*', '0.40%', '7.18%', 'Haryana', 'SDL', '-', '2026', 'SOV', '0.98%', 'Benchmark:', 'CRISIL', 'IBX', '90:10', 'SDL', 'plus', 'Gilt', 'Index', '–', '7.38%', 'Rajasthan', 'SDL', '-', '2026', 'SOV', '0.57%', 'November', '2026', '6.82%', 'Maharashtra', 'SDL', '-', '2026', 'SOV', '0.49%', 'SIP', '(Minimum', 'Amount):', '`', '100/-', 'and', 'in', 'multiples', 'of', 'Re.1', 'thereafter', '7.69%', 'Tamilnadu', 'SDL', '-', '2026', 'SOV', '0.02%', 'SIP', 'Frequency:', 'Monthly/Quarterly', 'Government', 'Bond', '8.26%', '5.74%', '-', '2026', 'G-Sec', 'SOV', '8.26%', 'SIP', 'Dates', '(Monthly/Quarterly)@@:', 'Investor', 'may', 'choose', 'any', 'day', 'of', 'the', 'month', 'from', '1st', 'to', '31st', 'as', 'the', 'date', 'of', 'the', 'Net', 'Cash', 'and', 'Cash', 'Equivalent', '5.04%', 'instalment.', 'Grand', 'Total', '100.00%', 'Investment', 'Objective:', 'Refer', 'Pg', 'No.', '42', 'Minimum', 'Investment', 'Amount:', '`', '1,000/-', 'and', 'in', 'multiples', 'of', 'Re.', '1/-', ' ...
#
# === Page 27 ===
# page heading : Bandhan_CRISIL_IBX_90:10_SDL_Plus_Gilt–_September_2027_Index_Fund
# ['Bandhan', 'CRISIL', 'IBX', '90:10', 'SDL', 'Plus', 'Gilt–', 'September', '2027', 'Index', 'Fund', 'A', 'G', 'n', 'ilt', 'o', 'I', 'p', 'n', 'e', 'd', 'n', 'e', '-', 'x', 'e', '–', 'n', 'd', 'S', 'e', 'e', 'd', 'p', 't', 'T', 'e', 'a', 'm', 'rg', 'b', 'e', 'e', 't', 'r', 'M', '20', 'a', '2', 'tu', '7', 'r', 'w', 'ity', 'it', 'h', 'In', 'R', 'd', 'e', 'e', 'l', 'x', 'a', 'F', 'ti', 'u', 'v', 'n', 'e', 'd', 'ly', 'i', 'H', 'nv', 'ig', 'e', 'h', 'st', 'I', 'i', 'n', 'n', 't', 'g', 'e', 'i', 'r', 'n', 'e', 's', 'c', 't', 'o', 'R', 'n', 'a', 'st', 't', 'i', 'e', 't', 'u', 'R', 'e', 'is', 'n', 'k', 't', 's', 'a', 'o', 'nd', 'f', 'C', 'R', 'R', 'e', 'I', 'l', 'S', 'a', 'I', 't', 'L', 'iv', 'I', 'e', 'B', 'l', 'X', 'y', '9', 'L', '0', 'o', ':', 'w', '1', '0', 'C', 'S', 're', 'D', 'd', 'L', 'i', 't', 'P', 'R', 'lu', 'is', 's', 'k', 'Click', 'here', 'to', 'Know', 'more', 'P', 'R', 'o', 'is', 't', 'A', 'e', 'k', 'n', 'C', '-', 't', 'l', 'I', 'i', 'a', 'a', 'I', 's', 'l', 'I', 's', '31st', 'October', '2025', 'FUND', 'FEATURES', 'PORTFOLIO', 'About', 'the', 'Fund:', 'This', 'Target', 'Maturity', 'Index', 'Fund', 'aims', 'Name', 'Rating', '%', 'of', 'NAV', 'to', 'provide', 'the', 'investment', 'returns', 'corresponding', 'to', 'the', 'total', 'returns', 'of', 'the', 'securities', 'as', 'represented', 'by', 'the', 'State', 'Government', 'Bond', '90.27%', 'CRISIL', 'IBX', '90:10', 'SDL', 'plus', 'Gilt', 'Index', '–', 'September', '2027', 'before', 'expenses,', 'subject', 'to', 'tracking', 'errors.', 'The', 'scheme', '7.33%', 'Maharashtra', 'SDL', '-', '2027', 'SOV', '19.68%', 'will', 'terminate', 'on', '30th', 'September', '2027.', '7.18%', 'Tamilnadu', 'SDL', '-', '2027', 'SOV', '17.21%', 'Category:', 'Index', 'Fund', '7.2%', 'Maharashtra', 'SDL', '-', '2027', 'SOV', '14.88%', 'Monthly', 'Avg', 'AUM:', '`', '151.01', 'Crores', '7.28%', 'Madhya', 'Pradesh', 'SDL', '-', '2027', 'SOV', '13.55%', '7.25%', 'Gujarat', 'SDL', '-', '2027', 'SOV', '6.76%', 'Month', 'end', 'AUM:', '`', '150.55', 'Crores', '6.2%', 'Rajasthan', 'SDL', '-', '2027', 'SOV', '6.65%', 'Inception', 'Date:', '24', 'November,', '2022', '7.27%', 'Tamilnadu', 'SDL', '-', '2027', 'SOV', '4.06%', 'Fund', 'Manager:', 'Mr.', 'Gautam', 'Kaul', '&', 'Mr.', 'Harshal', 'Joshi', '7.21%', 'Tamilnadu', 'SDL', '-', '2027', 'SOV', '3.38%', 'Other', 'Parameter:', '8.49%', 'Andhra', 'Pradesh', 'SDL', '-', '2027', 'SOV', '3.01%', 'Modified', 'Duration', '1.59', 'years', '7.51%', 'Maharashtra', 'SDL', '-', '2027', 'SOV', '0.68%', 'Average', 'Maturity', '1.74', 'years', 'Macaulay', 'Duration', '1.64', 'years', '7.47%', 'Chhattisgarh', 'SDL', '-', '2027', 'SOV', '0.41%', 'Yield', 'to', 'Maturity', '6.14%', 'Government', 'Bond', '6.35%', 'Total', 'Expense', 'Ratio', '7.38%', '-', '2027', 'G-Sec', 'SOV', '6.35%', 'Regular', '0.35%', 'Net', 'Cash', 'and', 'Cash', 'Equivalent', '3.39%', 'Direct', '0.10%', 'Grand', 'Total', '100.00%', 'Tracking', 'Error', '(1', 'year)*', '0.58%', 'Benchmark:', 'CRISIL', 'IBX', '90:10', 'SDL', 'plus', 'Gilt', 'Index', '–', 'September', '2027', 'SIP', '(Minimum', 'Amount):', '`', '100/-', 'and', 'in', 'multiples', 'of', 'Re.1', 'thereafter', 'SIP', 'Frequency:', 'Monthly/Quarterly', 'SIP', 'Dates', '(Monthly/Quarterly)@@:', 'Investor', 'may', 'choose', 'any', 'day', 'of', 'the', 'month', 'from', '1st', 'to', '31st', 'as', 'the', 'date', 'of', 'the', 'instalment.', 'Investment', 'Objective:', 'Refer', 'Pg', 'No.', '42', 'Minimum', 'Investment', 'Amount:', '`', '1,000/-', 'and', 'in', 'multiples', 'of', 'Re.', '1/-', 'thereafter', 'Option', 'Available:', 'Growth', '&', 'Income', 'Distribution', 'cum', 'capital', 'withdrawal', 'Option', '(Payout,', 'Reinvestment', 'or', 'Sweep', 'facility)..', 'Exit', 'Load:', 'Nil', 'NAV', '(`)', 'as', 'on', 'October', '31,', '2025', 'ASSET', 'QUALITY', 'Plan', 'Option', 'Freq', 'NAV', 'Regular', 'Plan', 'Growth', '-', '12.4510', 'Regular', 'Plan', 'IDCW@', '-', '10.3430', 'Potential', 'Risk', 'Class', 'Matrix', '@Income', 'Distribution',  ...
#
# === Page 28 ===
# page heading : Bandhan_CRISIL_IBX_90:10_SDL_Plus_Gilt–April_2032_Index_Fund
# ['Bandhan', 'CRISIL', 'IBX', '90:10', 'SDL', 'Plus', 'Gilt–April', '2032', 'Index', 'Fund', 'Click', 'here', 'to', 'Know', 'more', 'A', 'G', 'n', 'ilt', 'o', 'I', 'p', 'n', 'e', 'd', 'n', 'e', '-', 'x', 'e', '–', 'n', 'd', 'A', 'e', 'p', 'd', 'ri', 'T', 'l', '2', 'ar', '0', 'g', '3', 'e', '2', 't', 'w', 'M', 'it', 'a', 'h', 'tu', 'R', 'r', 'e', 'it', 'l', 'y', 'a', 't', 'In', 'iv', 'd', 'e', 'e', 'ly', 'x', 'H', 'Fu', 'ig', 'n', 'h', 'd', 'I', 'n', 'in', 't', 'v', 'e', 'e', 'r', 's', 'e', 't', 's', 'i', 't', 'n', 'R', 'g', 'a', 'in', 'te', 'c', 'o', 'R', 'n', 'is', 's', 'k', 't', 'i', 'a', 't', 'n', 'u', 'd', 'e', 'n', 'R', 't', 'e', 's', 'l', 'o', 'at', 'f', 'i', 'v', 'C', 'e', 'R', 'l', 'I', 'y', 'S', 'L', 'IL', 'o', 'I', 'w', 'B', 'X', 'C', 'r', '9', 'e', '0', 'd', ':1', 'it', '0', 'R', 'S', 'is', 'D', 'k', 'L', 'plus', 'P', 'R', 'o', 'is', 't', 'A', 'e', 'k', 'n', 'C', '-', 't', 'l', 'I', 'i', 'a', 'a', 'I', 's', 'l', 'I', 's', '31st', 'October', '2025', 'FUND', 'FEATURES', 'PORTFOLIO', 'About', 'the', 'Fund:', 'This', 'Target', 'Maturity', 'Index', 'Fund', 'aims', 'Name', 'Rating', '%', 'of', 'NAV', 'to', 'provide', 'the', 'investment', 'returns', 'corresponding', 'to', 'the', 'State', 'Government', 'Bond', '83.07%', 'total', 'returns', 'of', 'the', 'securities', 'as', 'represented', 'by', 'the', '7.28%', 'Uttar', 'Pradesh', 'SDL', '-', '2032', 'SOV', '11.90%', 'CRISIL', 'IBX', '90:10', 'SDL', 'plus', 'Gilt', 'Index', '–', 'April', '2032', 'before', '7.23%', 'Tamilnadu', 'SDL', '-', '2032', 'SOV', '7.37%', 'expenses,', 'subject', 'to', 'tracking', 'errors.', 'The', 'scheme', 'will', 'terminate', 'on', '30th', 'April', '2032.', '7.73%', 'Maharashtra', 'SDL', '-', '2032', 'SOV', '6.83%', '7.72%', 'Haryana', 'SDL', '-', '2032', 'SOV', '6.09%', 'Category:', 'Index', 'Fund', '7.2%', 'Odisha', 'SDL', '-', '2032', 'SOV', '5.93%', 'Monthly', 'Avg', 'AUM:', '`', '440.79', 'Crores', '7.63%', 'Gujarat', 'SDL', '-', '2032', 'SOV', '5.58%', '7.3%', 'Tamilnadu', 'SDL', '-', '2032', 'SOV', '3.58%', 'Month', 'end', 'AUM:', '`', '424.74', 'Crores', '7.26%', 'Haryana', 'SDL', '-', '2032', 'SOV', '3.57%', 'Inception', 'Date:', '29', 'November,', '2022', '7.68%', 'Karnataka', 'SDL', '-', '2031', 'SOV', '3.01%', '7.72%', 'Maharashtra', 'SDL', '-', '2032', 'SOV', '2.93%', 'Fund', 'Manager:', 'Mr.', 'Gautam', 'Kaul', '&', 'Mr.', 'Harshal', 'Joshi', '7.14%', 'Tamilnadu', 'SDL', '-', '2032', 'SOV', '2.58%', 'Other', 'Parameter:', '7.68%', 'Haryana', 'SDL', '-', '2031', 'SOV', '2.44%', 'Modified', 'Duration', '4.90', 'years', '7.13%', 'Haryana', 'SDL', '-', '2032', 'SOV', '2.37%', 'Average', 'Maturity', '6.26', 'years', '7.02%', 'Tamilnadu', 'SDL', '-', '2031', 'SOV', '2.37%', 'Macaulay', 'Duration', '5.07', 'years', '7.09%', 'Rajasthan', 'SDL', '-', '2032', 'SOV', '2.36%', 'Yield', 'to', 'Maturity', '7.02%', '7.05%', 'Madhya', 'Pradesh', 'SDL', '-', '2032', 'SOV', '1.88%', 'Total', 'Expense', 'Ratio', '7.93%', 'Karnataka', 'SDL', '-', '2031', 'SOV', '1.23%', 'Regular', '0.28%', '7.8%', 'Andhra', 'Pradesh', 'SDL', '-', '2031', 'SOV', '1.22%', 'Direct', '0.10%', '7.74%', 'Andhra', 'Pradesh', 'SDL', '-', '2032', 'SOV', '1.22%', '7.29%', 'Gujarat', 'SDL', '-', '2032', 'SOV', '1.19%', 'Tracking', 'Error', '(1', 'year)*', '1.48%', '7.25%', 'Gujarat', 'SDL', '-', '2032', 'SOV', '1.19%', 'Benchmark:', 'CRISIL', 'IBX', '90:10', 'SDL', 'plus', 'Gilt', 'Index', '–', 'April', '7.17%', 'Kerala', 'SDL', '-', '2032', 'SOV', '1.19%', '2032', '7.12%', 'Gujarat', 'SDL', '-', '2032', 'SOV', '1.18%', 'SIP', '(Minimum', 'Amount):', '`', '100/-', 'and', 'in', 'multiples', 'of', 'Re.1', '6.97%', 'Tamilnadu', 'SDL', '-', '2031', 'SOV', '1.18%', 'thereafter', '7.57%', 'Gujarat', 'SDL', '-', '2032', 'SOV', '0.73%', '7.57%', 'Gujarat', 'SDL', '-', '2031', 'SOV', '0.59%', 'SIP', 'Frequency:', 'Monthly/Quarterly', '6.9%', 'Andhra', 'Pradesh', 'SDL', '-', '2032', 'SOV', '0.47%', 'SIP', 'Dates', '(Monthly/Quarterly)@@:', 'Investor', 'may', '7.22%', 'Rajasthan', 'SDL', '-', '20 ...
#
# === Page 29 ===
# page heading : Bandhan_CRISIL-IBX_10:90_Gilt_+_SDL_Index_–_Dec_2029_Fund
# ['Bandhan', 'CRISIL-IBX', '10:90', 'Gilt', '+', 'SDL', 'Index', '–', 'Dec', '2029', 'Fund', 'An', 'open-ended', 'Target', 'Maturity', 'Index', 'Fund', 'predominately', 'investing', 'in', 'constituents', 'of', 'Click', 'here', 'to', 'Know', 'more', 'CRISIL-IBX', '10:90', 'Gilt', '+', 'SDL', 'Index', '–', 'Dec', '2029.', '31st', 'October', '2025', 'FUND', 'FEATURES', 'PORTFOLIO', 'About', 'the', 'Fund:', 'The', 'investment', 'objective', 'of', 'the', 'Name', 'Rating', '%', 'of', 'NAV', 'scheme', 'is', 'to', 'provide', 'investment', 'returns', 'closely', 'Government', 'Bond', '92.38%', 'corresponding', 'to', 'the', 'total', 'returns', 'of', 'the', 'securities', 'as', '6.79%', '-', '2029', 'G-Sec', 'SOV', '92.38%', 'represented', 'by', 'the', 'CRISIL-IBX', '10:90', 'Gilt', '+', 'SDL', 'Index', '–', 'Net', 'Cash', 'and', 'Cash', 'Equivalent', '7.62%', 'Dec', '2029', 'before', 'expenses,', 'subject', 'to', 'tracking', 'errors.', 'However,', 'there', 'is', 'no', 'assurance', 'or', 'guarantee', 'that', 'the', 'Grand', 'Total', '100.00%', 'investment', 'objectives', 'of', 'the', 'scheme', 'will', 'be', 'realized', 'and', 'the', 'scheme', 'does', 'not', 'assure', 'or', 'guarantee', 'any', 'returns.', 'Category:', 'Index', 'Fund', 'Monthly', 'Avg', 'AUM:', '`', '0.38', 'Crores', 'Month', 'end', 'AUM:', '`', '0.38', 'Crores', 'Inception', 'Date:', '10', 'March,', '2025', 'Fund', 'Manager:', 'Mr.Brijesh', 'Shah', 'Other', 'Parameter:', 'Modified', 'Duration', '3.31', 'years', 'Average', 'Maturity', '3.93', 'years', 'Macaulay', 'Duration', '3.42', 'years', 'Yield', 'to', 'Maturity', '6.19%', 'Total', 'Expense', 'Ratio', 'Regular', '0.34%', 'Direct', '0.04%', 'Tracking', 'Error', '(1', 'year)*', '1.38%', 'Benchmark:', 'CRISIL-IBX', '10:90', 'Gilt', '+', 'SDL', 'Index', '–', 'Dec', '2029', 'SIP', '(Minimum', 'Amount):', '`', '100/-', 'and', 'in', 'multiples', 'of', 'Re.1', 'thereafter', 'SIP', 'Frequency:', 'Monthly/Quarterly', 'SIP', 'Dates', '(Monthly/Quarterly)@@:', 'Investor', 'may', 'choose', 'any', 'day', 'of', 'the', 'month', 'from', '1st', 'to', '31st', 'as', 'the', 'date', 'of', 'the', 'instalment.', 'Investment', 'Objective:', 'Refer', 'Pg', 'No.', '42', 'Minimum', 'Investment', 'Amount:', '`', '1,000/-', 'and', 'in', 'multiples', 'of', 'Re.', '1/-', 'thereafter', 'Option', 'Available:', 'Growth', '&', 'Income', 'Distribution', 'cum', 'ASSET', 'QUALITY', 'capital', 'withdrawal', 'Option', '(Payout,', 'Reinvestment', 'or', 'Sweep', 'facility).', 'Potential', 'Risk', 'Class', 'Matrix', 'Exit', 'Load:', 'Nil', 'Credit', 'Risk', 'of', 'the', 'NAV', '(`)', 'as', 'on', 'October', '31,', '2025', 'scheme\uf022', 'Relatively', 'Moderate', 'Relatively', 'Low', '(Class', 'Plan', 'Option', 'Freq', 'NAV', 'Interest', 'Rate', 'Risk', 'of', 'the', 'A)', '(Class', 'B)', 'High', '(Class', 'C)', 'Regular', 'Plan', 'Growth', '-', '10.5549', 'scheme\uf024', 'Regular', 'Plan', 'IDCW@', '-', '10.5549', 'Relatively', 'Low', '(Class', 'I)', '@Income', 'Distribution', 'and', 'Capital', 'Withdrawal.', 'Moderate', '(Class', 'II)', '*For', 'funds', 'in', 'existence', 'for', 'less', 'than', '1', 'year,', 'tracking', 'error', 'Relatively', 'High', '(Class', 'III)', 'A-III', 'computed', 'since', 'inception.', 'A', 'Scheme', 'with', 'Relatively', 'High', 'Interest', 'Rate', 'Risk', 'and', 'Relatively', 'AAAEquivalent', 'Low', 'Credit', 'Risk.', '100.00%', 'PERFORMANCE', 'TABLE', 'Scheme', 'Name', 'Simple', 'annualised', '(%)', '6', 'months', 'Bandhan', 'CRISIL-IBX', '10', '90', 'Gilt', 'Plus', 'SDL', 'Index', '-', 'Dec', '2029', 'Fund', '-', 'Regular', 'Plan', '-', 'Growth', '4.92%', 'CRISIL-IBX', '10:90', 'Gilt', '+SDL', 'Index', '-', 'Dec', '2029#', '5.40%', 'CRISIL', '10', 'Year', 'Gilt', 'Index##', '2.25%', 'Note:', 'Simple', 'annualized', 'returns', 'have', 'been', 'provided', 'as', 'per', 'the', 'extant', 'guidelines', 'since', 'This', 'product', 'is', 'suitable', 'for', 'Scheme', 'Benchmark', 'the', 'scheme', 'has', 'completed', '6', 'months', 'but', 'not', ...
#
# === Page 30 ===
# page heading : Bandhan_CRISIL-IBX_Financial_Services_3-6_Months_Debt_Index_Fund
# ['Bandhan', 'CRISIL-IBX', 'Financial', 'Services', '3-6', 'Months', 'Debt', 'Index', 'Fund', 'An', 'open', 'ended', 'Constant', 'Maturity', 'Index', 'Fund', 'tracking', 'the', 'CRISIL-IBX', 'Financial', 'Services', '3-6', 'Months', 'Click', 'here', 'to', 'Know', 'more', 'Debt', 'Index.', 'A', 'relatively', 'low', 'interest', 'rate', 'risk', 'and', 'relatively', 'low', 'credit', 'risk.', '31st', 'October', '2025', 'FUND', 'FEATURES', 'PORTFOLIO', 'About', 'the', 'Fund:', 'The', 'investment', 'objective', 'of', 'the', 'Name', 'Rating', '%', 'of', 'NAV', 'Scheme', 'is', 'to', 'generate', 'returns', 'corresponding', 'to', 'the', 'total', 'Certificate', 'of', 'Deposit', '43.18%', 'returns', 'of', 'the', 'securities', 'as', 'represented', 'by', 'the', 'CRISIL-', 'Small', 'Industries', 'Dev', 'Bank', 'of', 'India', 'A1+', '9.24%', 'IBX', 'Financial', 'Services', '3-6', 'Months', 'Debt', 'Index', 'before', 'NABARD', 'A1+', '9.22%', 'expenses,', 'subject', 'to', 'tracking', 'errors.', 'However,', 'there', 'can', 'be', 'no', 'assurance', 'or', 'guarantee', 'that', 'the', 'investment', 'HDFC', 'Bank', 'A1+', '8.09%', 'objective', 'of', 'the', 'Scheme', 'will', 'be', 'achieved', 'and', 'the', 'scheme', 'Axis', 'Bank', 'A1+', '5.77%', 'does', 'not', 'assure', 'or', 'guarantee', 'any', 'returns.', 'Canara', 'Bank', 'A1+', '5.76%', 'Union', 'Bank', 'of', 'India', 'A1+', '2.33%', 'Category:', 'Index', 'Fund', 'Punjab', 'National', 'Bank', 'A1+', '1.61%', 'Monthly', 'Avg', 'AUM:', '`', '381.55', 'Crores', 'Bank', 'of', 'Baroda', 'A1+', '1.16%', 'Month', 'end', 'AUM:', '`', '424.44', 'Crores', 'Commercial', 'Paper', '30.00%', 'ICICI', 'Securities', 'A1+', '9.21%', 'Inception', 'Date:', '13', 'March,', '2025', 'Aditya', 'Birla', 'Capital', 'A1+', '6.92%', 'Fund', 'Manager:', 'Mr.Brijesh', 'Shah', '&', 'Mr.Harshal', 'Joshi', 'Tata', 'Capital', 'A1+', '5.79%', 'Sundaram', 'Finance', 'A1+', '5.77%', 'Other', 'Parameter:', 'NABARD', 'A1+', '2.31%', 'Modified', 'Duration', '115', 'Days', 'Corporate', 'Bond', '24.81%', 'Average', 'Maturity', '117', 'Days', 'Kotak', 'Mahindra', 'Prime', 'AAA', '7.08%', 'Macaulay', 'Duration', '117', 'Days', 'Export', 'Import', 'Bank', 'of', 'India', 'AAA', '5.91%', 'Yield', 'to', 'Maturity', '6.34%', 'Bajaj', 'Finance', 'AAA', '5.91%', 'Total', 'Expense', 'Ratio', 'LIC', 'Housing', 'Finance', 'AAA', '5.91%', 'Regular', '1.01%', 'Net', 'Cash', 'and', 'Cash', 'Equivalent', '2.02%', 'Direct', '0.11%', 'Grand', 'Total', '100.00%', 'Tracking', 'Error', '(1', 'year)*', '0.11%', 'Benchmark:', 'CRISIL-IBX', 'Financial', 'Services', '3-6', 'Months', 'Debt', 'Index', 'Fund', 'SIP', '(Minimum', 'Amount):', '`', '100/-', 'and', 'in', 'multiples', 'of', 'Re.1', 'thereafter', 'SIP', 'Frequency:', 'Monthly/Quarterly', 'SIP', 'Dates', '(Monthly/Quarterly)@@:', 'Investor', 'may', 'choose', 'any', 'day', 'of', 'the', 'month', 'from', '1st', 'to', '31st', 'as', 'the', 'date', 'of', 'the', 'instalment.', 'Investment', 'Objective:', 'Refer', 'Pg', 'No.', '42', 'Minimum', 'Investment', 'Amount:', '`', '1,000/-', 'and', 'in', 'multiples', 'of', 'Re.', '1/-', 'thereafter', 'Option', 'Available:', 'Growth', '&', 'Income', 'Distribution', 'cum', 'capital', 'withdrawal', 'Option', '(Payout,', 'Reinvestment', 'or', 'Sweep', 'facility).', 'Exit', 'Load:', 'Nil', 'ASSET', 'QUALITY', 'NAV', '(`)', 'as', 'on', 'October', '31,', '2025', 'Plan', 'Option', 'Freq', 'NAV', 'Potential', 'Risk', 'Class', 'Matrix', 'Regular', 'Plan', 'Growth', '-', '10.4454', 'Credit', 'Risk', 'of', 'the', 'scheme\uf022', 'Relatively', 'Moderate', 'Relatively', '*For', 'funds', 'in', 'existence', 'for', 'less', 'than', '1', 'year,', 'tracking', 'error', 'Low', '(Class', '(Class', 'B)', 'High', '(Class', 'C)', 'computed', 'since', 'inception.', 'Interest', 'Rate', 'Risk', 'of', 'the', 'A)', 'scheme\uf024', 'Relatively', 'Low', '(Class', 'I)', 'A-I', 'Moderate', '(Class', 'II)', 'Relatively', 'High', '(Class', 'III)', 'A', 'Scheme', 'with', 'Relatively', 'Low', 'Interest', 'Ra ...

# %%
############ Code to save screenshot of right_half of every page that contains rating table ################
import os
from pdf2image import convert_from_path
import cv2
import numpy as np

# === Configuration ===
pdf_path = output_pdf_path  # Replace with your actual PDF file path
output_dir = "right_half_screenshots_Bandhan\\{}".format(month_name)
# top_strip_dir = "top_strip_screenshots_bandhan"  # <== NEW FOLDER
os.makedirs(output_dir, exist_ok=True)
# os.makedirs(top_strip_dir, exist_ok=True)

# === Step 1: Convert PDF pages to images ===
images = convert_from_path(pdf_path, dpi=300)  # Use high DPI for better clarity

# === Step 2: Crop right half and save ===
for idx, pil_image in enumerate(images):
    # Convert PIL to OpenCV (BGR)
    image = np.array(pil_image)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    # Get dimensions
    height, width, _ = image.shape


    # Crop right half (60% to 100%)
    x_start = int(0.33 * width)
    y_start = int(0.08 * height)  # 15% from top
    right_half = image[y_start:, x_start:]
    # right_half = image[:, x_start:]

    # Save cropped image
    fund_name = fund_list[idx]
    print(fund_name)
    output_path = os.path.join(output_dir, f"{fund_name}_page_{idx+1}_right_half.png")
    cv2.imwrite(output_path, right_half)

    print(f"✅ Saved: {output_path}")

print("\n✅ All screenshots of right half completed.")
# Out:
# Gilt April 2026 Index Fund
# ✅ Saved: right_half_screenshots_Bandhan\Oct\Gilt April 2026 Index Fund_page_1_right_half.png
# Gilt June 2027 Index Fund
# ✅ Saved: right_half_screenshots_Bandhan\Oct\Gilt June 2027 Index Fund_page_2_right_half.png
# Gilt April 2028 Index Fund
# ✅ Saved: right_half_screenshots_Bandhan\Oct\Gilt April 2028 Index Fund_page_3_right_half.png
# Gilt April 2032 Index Fund
# ✅ Saved: right_half_screenshots_Bandhan\Oct\Gilt April 2032 Index Fund_page_4_right_half.png
# 90colon10 SDL Plus Gilt- November 2026 Index Fund
# ✅ Saved: right_half_screenshots_Bandhan\Oct\90colon10 SDL Plus Gilt- November 2026 Index Fund_page_5_right_half.png
# 90colon10 SDL Plus Gilt- September 2027 Index Fund
# ✅ Saved: right_half_screenshots_Bandhan\Oct\90colon10 SDL Plus Gilt- September 2027 Index Fund_page_6_right_half.png
# 90colon10 SDL Plus Gilt-April 2032 Index Fund
# ✅ Saved: right_half_screenshots_Bandhan\Oct\90colon10 SDL Plus Gilt-April 2032 Index Fund_page_7_right_half.png
# 10colon90 Gilt + SDL Index - Dec 2029 Fund
# ✅ Saved: right_half_screenshots_Bandhan\Oct\10colon90 Gilt + SDL Index - Dec 2029 Fund_page_8_right_half.png
# Financial Services 3-6 Months Debt Index Fund
# ✅ Saved: right_half_screenshots_Bandhan\Oct\Financial Services 3-6 Months Debt Index Fund_page_9_right_half.png
#
# ✅ All screenshots of right half completed.

# %%
####################### Code to fetch text from screenshot after zooom with top crop ######################
import cv2
import numpy as np
import pytesseract
from PIL import Image
import os
import re

rating_set = set()
# Set Tesseract path (update for your system)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

input_dir = "right_half_screenshots_Bandhan\\{}".format(month_name)
pan = "AAETS9556K"
mutual_fund = "Bandhan Mutual Fund"
import pandas as pd
correct_rating_df = pd.DataFrame(columns=['Pan', 'ISIN No.', 'Mutual Fund', 'Fund Name','Fund Type', 'Portfolio', "Agency", 'Ratings', "Category", '(%) Of Total AUM', "Factsheet Date", "URL"])
remaining_rating_df = pd.DataFrame(columns=['Text'])
for filename in os.listdir(input_dir)[:]:
    print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")
    # start_printing = False
    if filename.endswith(".png"):
        image_path = os.path.join(input_dir, filename)
        print(image_path)
        image = cv2.imread(image_path)

        # Scale image (e.g., 1.5x zoom)
        # scale_percent = 120  # Adjust this value as needed (e.g., 150 means 150% size)
        scale_percent = 200
        width = int(image.shape[1] * scale_percent / 100)
        height = int(image.shape[0] * scale_percent / 100)
        dim = (width, height)

        # Resize image
        image = cv2.resize(image, dim, interpolation=cv2.INTER_LINEAR)

        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # Threshold to isolate dark lines (black separators)
        # _, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY_INV)

        # Adaptive threshold to handle gray lines and varying lighting
        thresh = cv2.adaptiveThreshold(
            gray, 255,
            cv2.ADAPTIVE_THRESH_MEAN_C,
            cv2.THRESH_BINARY_INV,
            blockSize=15,
            C=10
        )

        # Detect horizontal lines
        horizontal_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (50, 1))
        detected_lines = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, horizontal_kernel, iterations=2)

        # Find contours of the lines
        contours, _ = cv2.findContours(detected_lines, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        # Get y-coordinates of all horizontal lines
        line_y_coords = sorted([cv2.boundingRect(cnt)[1] for cnt in contours])

        # Add image boundaries
        line_y_coords = [0] + line_y_coords + [image.shape[0]]

        # Process and print each row
        print("\nExtracted Table Rows:")
        for i in range(len(line_y_coords) - 1):
            y_start = line_y_coords[i]
            y_end = line_y_coords[i + 1]
            
            # Skip very small regions (likely just the line itself)
            if y_end - y_start < 10:
                continue

            # Extract the row region
            row_img = image[y_start:y_end, :]

            # OPTIONAL: Resize the row to improve OCR accuracy
            zoom_factor = 2.0
            row_img = cv2.resize(row_img, None, fx=zoom_factor, fy=zoom_factor, interpolation=cv2.INTER_LINEAR)

            # Convert to PIL Image for Tesseract
            row_pil = Image.fromarray(cv2.cvtColor(row_img, cv2.COLOR_BGR2RGB))

            # Tesseract OCR
            custom_config = r'--oem 3 --psm 6 -c preserve_interword_spaces=1'
            text = pytesseract.image_to_string(row_pil, config=custom_config).strip()

            if text:
                if "ASSET OUALITY" in text :
                        break
                if "PORTFOLIO" in text or "% of NAV" in text or "|" in text:
                     continue
                # print(text.split("\n"))
                # print(len(re.split(r'\s{2,}', text)), re.split(r'\s{2,}', text))
                for t in text.split("\n"):
                    print(re.split(r'\s{2,}', t))
                    print(len(re.split(r'\s{2,}', t)))
                    print("--------------------------------------")
                    splited_row = re.split(r'\s{2,}', t)

                    if len(re.split(r'\s{2,}', t)) ==3:
                        temp_df = pd.DataFrame([{
                        "Pan": pan,
                        "ISIN No." : None,
                        "Mutual Fund" : mutual_fund,
                        "Fund Name" : "Bandhan " + filename.split("_page")[0].replace("colon", ":").replace("_", " "),
                        "Fund Type" : filename.split("_page")[0].replace("colon", ":").replace("_", " "),
                        "Portfolio"  : splited_row[0],
                        "Agency" : None,
                        "Ratings" : splited_row[1].replace("Ai+", "A1+"),
                        "Category" : None,
                        "(%) Of Total AUM" : splited_row[2],
                        "Factsheet Date" : None,
                        "URL" : None,
                        # "Filename" : filename,        
                                                        }])
                        correct_rating_df = pd.concat([correct_rating_df, temp_df])
                    elif len(re.split(r'\s{2,}', t)) ==2:
                        temp_df = pd.DataFrame([{
                        "Pan": pan,
                        "ISIN No." : None,
                        "Mutual Fund" : mutual_fund,
                        "Fund Name" : "Bandhan " + filename.split("_page")[0].replace("colon", ":").replace("_", " "),
                        "Fund Type" : filename.split("_page")[0].replace("colon", ":").replace("_", " "),
                        "Portfolio"  : splited_row[0],
                        "Agency" : None,
                        "Ratings" : None,
                        "Category" : None,
                        "(%) Of Total AUM" : splited_row[1],
                        "Factsheet Date" : None,
                        "URL" : None,
                        # "Filename" : filename, 
                        }])
                        correct_rating_df = pd.concat([correct_rating_df, temp_df])
                    else:
                         print("remaining ones :", t)
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# right_half_screenshots_Bandhan\Oct\10colon90 Gilt + SDL Index - Dec 2029 Fund_page_8_right_half.png
#
# Extracted Table Rows:
# ['Government Bond', '92.38%']
# 2
# --------------------------------------
# ['6.79% - 2029 G-Sec', 'SOV', '92.38%']
# 3
# --------------------------------------
# ['Net Cash and Cash Equivalent', '7.62%']
# 2
# --------------------------------------
# ['Grand Total', '100.00%']
# 2
# --------------------------------------
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# right_half_screenshots_Bandhan\Oct\90colon10 SDL Plus Gilt- November 2026 Index Fund_page_5_right_half.png
#
# Extracted Table Rows:
# ['State Government Bond', '86.70%']
# 2
# --------------------------------------
# ['7.57% Gujarat SDL - 2026', 'SOV', '17.29%']
# 3
# --------------------------------------
# ['6.24% Maharashtra SDL - 2026', 'SOV', '14.63%']
# 3
# --------------------------------------
# ['7.4% Madhya Pradesh SDL - 2026', 'SOV', '9.87%']
# 3
# --------------------------------------
# ['7.49% Gujarat SDL - 2026', 'SOV', '6.04%']
# 3
# --------------------------------------
# ['7.58% Tamilnadu SDL - 2026', 'SOV', '4.93%']
# 3
# --------------------------------------
# ['7.22% Maharashtra SDL - 2026', 'SOV', '4.92%']
# 3
# --------------------------------------
# ['7.17% Rajasthan SDL - 2026', 'SOV', '4.91%']
# 3
# --------------------------------------
# ['7.04% Gujarat SDL - 2026', 'SOV', '4.90%']
# 3
# --------------------------------------
# ['7.59% Kerala SDL - 2026', 'SOV', '3.94%']
# 3
# --------------------------------------
# ['7.41% Uttar Pradesh SDL - 2026', 'SOV', '3.45%']
# 3
# --------------------------------------
# ['7.16% Madhya Pradesh SDL - 2026', 'SOV', '3.38%']
# 3
# --------------------------------------
# ['8.72% Tamilnadu SDL - 2026', 'SOV', '2.39%']
# 3
# --------------------------------------
# ['7.19% West Bangal SDL - 2026', 'SOV', '1.97%']
# 3
# --------------------------------------
# ['7.69% Uttar Pradesh SDL - 2026', 'SOV', '1.03%']
# 3
# --------------------------------------
# ['7.15% Madhya Pradesh SDL - 2026', 'SOV', '0.98%']
# 3
# --------------------------------------
# ['7.18% Haryana SDL - 2026', 'SOV', '0.98%']
# 3
# --------------------------------------
# ['7.38% Rajasthan SDL - 2026', 'SOV', '0.57%']
# 3
# --------------------------------------
# ['6.82% Maharashtra SDL - 2026', 'SOV', '0.49%']
# 3
# --------------------------------------
# ['7.69% Tamilnadu SDL - 2026', 'SOV', '0.02%']
# 3
# --------------------------------------
# ['Government Bond', '8.26%']
# 2
# --------------------------------------
# ['5.74% - 2026 G-Sec', 'SOV', '8.26%']
# 3
# --------------------------------------
# ['Net Cash and Cash Equivalent', '5.04%']
# 2
# --------------------------------------
# ['Grand Total', '100.00%']
# 2
# --------------------------------------
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# right_half_screenshots_Bandhan\Oct\90colon10 SDL Plus Gilt- September 2027 Index Fund_page_6_right_half.png
#
# Extracted Table Rows:
# ['State Government Bond', '90.27%']
# 2
# --------------------------------------
# ['7.33% Maharashtra SDL - 2027', 'SOV', '19.68%']
# 3
# --------------------------------------
# ['7.18% Tamilnadu SDL - 2027', 'SOV', '17.21%']
# 3
# --------------------------------------
# ['7.2% Maharashtra SDL - 2027', 'SOV', '14.88%']
# 3
# --------------------------------------
# ['7.28% Madhya Pradesh SDL - 2027', 'SOV', '13.55%']
# 3
# --------------------------------------
# ['7.25% Gujarat SDL - 2027', 'SOV', '6.76%']
# 3
# --------------------------------------
# ['6.2% Rajasthan SDL - 2027', 'SOV', '6.65%']
# 3
# --------------------------------------
# ['7.27% Tamilnadu SDL - 2027', 'SOV', '4.06%']
# 3
# --------------------------------------
# ['7.21% Tamilnadu SDL - 2027', 'SOV', '3.38%']
# 3
# --------------------------------------
# ['8.49% Andhra Pradesh SDL - 2027', 'SOV', '3.01%']
# 3
# --------------------------------------
# ['7.51% Maharashtra SDL - 2027', 'SOV', '0.68%']
# 3
# --------------------------------------
# ['7.47% Chhattisgarh SDL - 2027', 'SOV', '0.41%']
# 3
# --------------------------------------
# ['Government Bond', '6.35%']
# 2
# --------------------------------------
# ['7.38% - 2027 G-Sec', 'SOV', '6.35%']
# 3
# --------------------------------------
# ['Net Cash and Cash Equivalent', '3.39%']
# 2
# --------------------------------------
# ['Grand Total', '100.00%']
# 2
# --------------------------------------
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# right_half_screenshots_Bandhan\Oct\90colon10 SDL Plus Gilt-April 2032 Index Fund_page_7_right_half.png
#
# Extracted Table Rows:
# ['State Government Bond', '83.07%']
# 2
# --------------------------------------
# ['7.28% Uttar Pradesh SDL - 2032', 'SOV', '11.90%']
# 3
# --------------------------------------
# ['7.23% Tamilnadu SDL - 2032', 'SOV', '7.37%']
# 3
# --------------------------------------
# ['7.73% Maharashtra SDL - 2032', 'SOV', '6.83%']
# 3
# --------------------------------------
# ['7.72% Haryana SDL - 2032', 'SOV', '6.09%']
# 3
# --------------------------------------
# ['7.2% Odisha SDL - 2032', 'SOV', '5.93%']
# 3
# --------------------------------------
# ['7.63% Gujarat SDL - 2032', 'SOV', '5.58%']
# 3
# --------------------------------------
# ['7.3% Tamilnadu SDL - 2032', 'SOV', '3.58%']
# 3
# --------------------------------------
# ['7.26% Haryana SDL - 2032', 'SOV', '3.57%']
# 3
# --------------------------------------
# ['7.68% Karnataka SDL - 2031', 'SOV', '3.01%']
# 3
# --------------------------------------
# ['7.72% Maharashtra SDL - 2032', 'SOV', '2.93%']
# 3
# --------------------------------------
# ['7.14% Tamilnadu SDL - 2032', 'SOV', '2.58%']
# 3
# --------------------------------------
# ['7.68% Haryana SDL - 2031', 'SOV', '2.44%']
# 3
# --------------------------------------
# ['7.13% Haryana SDL - 2032', 'SOV', '2.37%']
# 3
# --------------------------------------
# ['7.02% Tamilnadu SDL - 2031', 'SOV', '2.37%']
# 3
# --------------------------------------
# ['7.09% Rajasthan SDL - 2032', 'SOV', '2.36%']
# 3
# --------------------------------------
# ['7.05% Madhya Pradesh SDL - 2032', 'SOV', '1.88%']
# 3
# --------------------------------------
# ['7.93% Karnataka SDL - 2031', 'SOV', '1.23%']
# 3
# --------------------------------------
# ['7.8% Andhra Pradesh SDL - 2031', 'SOV', '1.22%']
# 3
# --------------------------------------
# ['7.74% Andhra Pradesh SDL - 2032', 'SOV', '1.22%']
# 3
# --------------------------------------
# ['7.29% Gujarat SDL - 2032', 'SOV', '1.19%']
# 3
# --------------------------------------
# ['7.25% Gujarat SDL - 2032', 'SOV', '1.19%']
# 3
# --------------------------------------
# ['7.17% Kerala SDL - 2032', 'SOV', '1.19%']
# 3
# --------------------------------------
# ['7.12% Gujarat SDL - 2032', 'SOV', '1.18%']
# 3
# --------------------------------------
# ['6.97% Tamilnadu SDL - 2031', 'SOV', '1.18%']
# 3
# --------------------------------------
# ['7.57% Gujarat SDL - 2032', 'SOV', '0.73%']
# 3
# --------------------------------------
# ['7.57% Gujarat SDL - 2031', 'SOV', '0.59%']
# 3
# --------------------------------------
# ['6.9% Andhra Pradesh SDL - 2032', 'SOV', '0.47%']
# 3
# --------------------------------------
# ['7.22% Rajasthan SDL - 2032', 'SOV', '0.45%']
# 3
# --------------------------------------
# ['6.84% Gujarat SDL - 2031', 'SOV', '0.21%']
# 3
# --------------------------------------
# ['7.19% Tamilnadu SDL - 2032', 'SOV', '0.12%']
# 3
# --------------------------------------
# ['7.24% Rajasthan SDL - 2032', 'SOV', '0.12%']
# 3
# --------------------------------------
# ['Government Bond', '15.38%']
# 2
# --------------------------------------
# ['6.54% - 2032 G-Sec', 'SOV', '14.31%']
# 3
# --------------------------------------
# ['6.1% - 2031 G-Sec', 'SOV', '1.07%']
# 3
# --------------------------------------
# ['Net Cash and Cash Equivalent', '1.55%']
# 2
# --------------------------------------
# ['Grand Total', '100.00%']
# 2
# --------------------------------------
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# right_half_screenshots_Bandhan\Oct\Financial Services 3-6 Months Debt Index Fund_page_9_right_half.png
#
# Extracted Table Rows:
# ['Certificate of Deposit', '43.18%']
# 2
# --------------------------------------
# ['Small Industries Dev Bank of India', 'A1+', '9.24%']
# 3
# --------------------------------------
# ['NABARD', 'A1+', '9.22%']
# 3
# --------------------------------------
# ['HDFC Bank', 'A1+', '8.09%']
# 3
# --------------------------------------
# ['Axis Bank', 'A1+', '5.77%']
# 3
# --------------------------------------
# ['Canara Bank', 'A1+', '5.76%']
# 3
# --------------------------------------
# ['Union Bank of India', 'A1+', '2.33%']
# 3
# --------------------------------------
# ['Punjab National Bank', 'A1+', '1.61%']
# 3
# --------------------------------------
# ['Bank of Baroda', 'A1+', '1.16%']
# 3
# --------------------------------------
# ['Commercial Paper', '30.00%']
# 2
# --------------------------------------
# ['ICICI Securities', 'A1+', '9.21%']
# 3
# --------------------------------------
# ['Aditya Birla Capital', 'A1+', '6.92%']
# 3
# --------------------------------------
# ['Tata Capital', 'A1+', '5.79%']
# 3
# --------------------------------------
# ['Sundaram Finance', 'A1+', '5.77%']
# 3
# --------------------------------------
# ['NABARD', 'A1+', '2.31%']
# 3
# --------------------------------------
# ['Corporate Bond', '24.81%']
# 2
# --------------------------------------
# ['Kotak Mahindra Prime', 'AAA', '7.08%']
# 3
# --------------------------------------
# ['Export Import Bank of India', 'AAA', '5.91%']
# 3
# --------------------------------------
# ['Bajaj Finance', 'AAA', '5.91%']
# 3
# --------------------------------------
# ['LIC Housing Finance', 'AAA', '5.91%']
# 3
# --------------------------------------
# ['Net Cash and Cash Equivalent', '2.02%']
# 2
# --------------------------------------
# ['Grand Total', '100.00%']
# 2
# --------------------------------------
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# right_half_screenshots_Bandhan\Oct\Gilt April 2026 Index Fund_page_1_right_half.png
#
# Extracted Table Rows:
# ['Government Bond', '96.72%']
# 2
# --------------------------------------
# ['6.99% - 2026 G-Sec', 'SOV', '37.54%']
# 3
# --------------------------------------
# ['5.63% - 2026 G-Sec', 'SOV', '25.87%']
# 3
# --------------------------------------
# ['7.59% - 2026 G-Sec', 'SOV', '17.10%']
# 3
# --------------------------------------
# ['5.15% - 2025 G-Sec', 'SOV', '11.20%']
# 3
# --------------------------------------
# ['7.27% - 2026 G-Sec', 'SOV', '5.01%']
# 3
# --------------------------------------
# ['Net Cash and Cash Equivalent', '3.28%']
# 2
# --------------------------------------
# ['Grand Total', '100.00%']
# 2
# --------------------------------------
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# right_half_screenshots_Bandhan\Oct\Gilt April 2028 Index Fund_page_3_right_half.png
#
# Extracted Table Rows:
# ['Government Bond', '97.91%']
# 2
# --------------------------------------
# ['7.17% - 2028 G-Sec', 'SOV', '57.47%']
# 3
# --------------------------------------
# ['8.28% - 2027 G-Sec', 'SOV', '39.98%']
# 3
# --------------------------------------
# ['7.38% - 2027 G-Sec', 'SOV', '0.45%']
# 3
# --------------------------------------
# ['Net Cash and Cash Equivalent', '2.09%']
# 2
# --------------------------------------
# ['Grand Total', '100.00%']
# 2
# --------------------------------------
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# right_half_screenshots_Bandhan\Oct\Gilt April 2032 Index Fund_page_4_right_half.png
#
# Extracted Table Rows:
# ['Government Bond', '97.54%']
# 2
# --------------------------------------
# ['6.54% - 2032 G-Sec', 'SOV', '77.16%']
# 3
# --------------------------------------
# ['6.1% - 2031 G-Sec', 'SOV', '20.38%']
# 3
# --------------------------------------
# ['Net Cash and Cash Equivalent', '2.46%']
# 2
# --------------------------------------
# ['Grand Total', '100.00%']
# 2
# --------------------------------------
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# right_half_screenshots_Bandhan\Oct\Gilt June 2027 Index Fund_page_2_right_half.png
#
# Extracted Table Rows:
# ['Government Bond', '96.42%']
# 2
# --------------------------------------
# ['7.38% - 2027 G-Sec', 'SOV', '59.44%']
# 3
# --------------------------------------
# ['6.79% - 2027 G-Sec', 'SOV', '15.96%']
# 3
# --------------------------------------
# ['8.24% - 2027 G-Sec', 'SOV', '15.75%']
# 3
# --------------------------------------
# ['7.02% - 2027 G-Sec', 'SOV', '5.28%']
# 3
# --------------------------------------
# ['Net Cash and Cash Equivalent', '3.58%']
# 2
# --------------------------------------
# ['Grand Total', '100.00%']
# 2
# --------------------------------------

# %%
########################## Block to map isin number to fund name ##############################################
# isin_df = pd.read_csv(r"D:\Nexensus_Projects\pdfEtraction\isin_Mastersheet.csv")
# # Create a mapping dictionary
# isin_map = dict(zip(isin_df['Fund Name'], isin_df['ISIN No.']))

# # Add mapped ISIN to df2
# correct_rating_df['ISIN No.'] = correct_rating_df['Fund Name'].map(isin_map)

# Save correct_rating_df to Excel file with separate sheets for each 'fund'
output_excel = "output_data\\correct_rating_df_grouped_by_fund_Bandhan_{}.xlsx".format(month_name)

with pd.ExcelWriter(output_excel, engine='openpyxl') as writer:
    for fund, group_df in correct_rating_df.groupby("Fund Name"):
        # Clean sheet name: max 31 characters, remove invalid characters
        sheet_name = str(fund).replace("Bandhan ", "").replace("CRISIL IBX", "").replace("CRISIL-IBX", "")[:31]
        invalid_chars = r'[:\\/?*[\]]'
        sheet_name = re.sub(invalid_chars, "_", sheet_name)

        print(f"Writing sheet: {sheet_name}")
        group_df.to_excel(writer, sheet_name=sheet_name, index=False)
        # group_df.drop(columns=["Fund Name"], errors="ignore").to_excel(writer, sheet_name=sheet_name, index=False)
        print("--------------------------------------------")

print(f"✅ Processed data saved to: {output_excel}")
# Out:
# Writing sheet: 10_90 Gilt + SDL Index - Dec 20
# --------------------------------------------
# Writing sheet: 90_10 SDL Plus Gilt- November 2
# --------------------------------------------
# Writing sheet: 90_10 SDL Plus Gilt- September
# --------------------------------------------
# Writing sheet: 90_10 SDL Plus Gilt-April 2032
# --------------------------------------------
# Writing sheet: Financial Services 3-6 Months D
# --------------------------------------------
# Writing sheet: Gilt April 2026 Index Fund
# --------------------------------------------
# Writing sheet: Gilt April 2028 Index Fund
# --------------------------------------------
# Writing sheet: Gilt April 2032 Index Fund
# --------------------------------------------
# Writing sheet: Gilt June 2027 Index Fund
# --------------------------------------------
# ✅ Processed data saved to: output_data\correct_rating_df_grouped_by_fund_Bandhan_Oct.xlsx

# %%
correct_rating_df.to_csv("test.csv", index=False)
