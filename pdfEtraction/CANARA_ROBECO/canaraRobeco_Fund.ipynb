# %%
############## Code to split pdf to keep only pages with Rating table in it #####################
import pdfplumber
from PyPDF2 import PdfWriter, PdfReader
from datetime import datetime

# month_name = datetime.now().strftime("%b")
month_name = "June"

input_pdf_path = "Final-Factsheet-June-25.pdf"
output_pdf_path = "filtered_{}.pdf".format(input_pdf_path.split(".")[0])

reader = PdfReader(input_pdf_path)
writer = PdfWriter()
fund_list = []

reader = PdfReader(input_pdf_path)
writer = PdfWriter()

with pdfplumber.open(input_pdf_path) as pdf:
    for page_num, page in enumerate(pdf.pages):
        words = page.extract_words()
        lines = page.extract_text_lines()
        capital_words = [word['text'].upper() for word in words]
        lines_list = [line['text'] for line in lines]
        if "PORTFOLIO" in capital_words and  any("Name of the Instruments" in line['text'] for line in lines):
            # if page_num ==50:
            #     for w in lines:
            #         print(w['text'])
            for word in words:
                # if 'Rating' in word['text'] or "RATING" in word['text']:
                if capital_words.count("RATING") >= 2:
                    print(f"\n=== Page {page_num + 1} ===")
                    # print(page_num,capital_words)
                    # print([word['text'] for word in words])
                    print(capital_words)
                    writer.add_page(reader.pages[page_num])
                    break  # add this page once, then move to next page

# Save the filtered PDF
with open(output_pdf_path, "wb") as f_out:
    writer.write(f_out)
# Out:
# === Page 21 ===
# ['CANARA', 'ROBECO', 'OVERNIGHT', 'FUND', '(CROF)', '(AS', 'ON', 'JUNE', '30,', '2025)', 'THIS', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'INVESTORS', 'WHO', 'ARE', 'SEEKING*:', 'POTENTIAL', 'RISK', 'CLASS', '(PRC)', 'MATRIX', 'REGULAR', 'INCOME', 'OVER', 'SHORT', 'TERM', 'THAT', 'MAY', 'BE', 'IN', 'LINE', 'WITH', 'THE', 'OVERNIGHT', 'CALL', 'RATES', 'INVESTMENT', 'IN', 'OVERNIGHT', 'SECURITIES.', '*INVESTORS', 'SHOULD', 'CONSULT', 'THEIR', 'FINANCIAL', 'ADVISERS', 'IF', 'IN', 'DOUBT', 'ABOUT', 'WHETHER', 'THE', 'SCHEME', 'RISKOMETER', 'BENCHMARK', 'RISKOMETER', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'THEM.', 'THE', 'SCHEME', 'AND', 'BENCHMARK', 'RISKOMETERS', 'ARE', 'EVALUATED', 'ON', 'A', 'MONTHLY', 'BASIS', 'AND', 'THE', 'ABOVE', 'RISKOMETERS', 'ARE', 'BASED', 'ON', 'THE', 'EVALUATION', 'OF', 'THE', 'PORTFOLIOS', 'FOR', 'THE', 'MONTH', 'ENDED', 'JUNE', '30,', '2025.', 'FUND', 'INFORMATION', 'PRODUCT', 'POSITIONING', 'RATING', 'PROFILE', '(%', 'TO', 'NET', 'ASSETS)', 'CATEGORY/TYPE:', 'OVERNIGHT', 'FUND', '-', 'AN', 'OPEN-ENDED', 'FUND', 'PREDOMINANTLY', 'INVESTS', 'IN', 'TRI-PARTY', 'REPOS,', 'DEBT', 'SCHEME', 'INVESTING', 'IN', 'OVERNIGHT', 'SECURITIES.', 'A', 'OVERNIGHT', 'REVERSE', 'REPOS', 'AND', 'FIXED', 'INCOME', 'RELATIVELY', 'LOW', 'INTEREST', 'RATE', 'RISK', 'AND', 'RELATIVELY', 'LOW', 'CREDIT', 'SECURITIES/INSTRUMENTS', 'WITH', 'MATURITY', 'OF', 'ONE', '(1)', 'RISK.', 'BUSINESS', 'DAY.', 'FUND', 'HAS', 'MINIMAL', 'INTEREST', 'RATE', 'AND', 'CREDIT', 'SCHEME', 'OBJECTIVE:', 'RISK', 'AND', 'TENDS', 'TO', 'ENSURE', 'A', 'HIGH', 'DEGREE', 'OF', 'LIQUIDITY', 'IN', 'THE', 'THE', 'INVESTMENT', 'OBJECTIVE', 'OF', 'THE', 'SCHEME', 'IS', 'TO', 'GENERATE', 'PORTFOLIO.', 'FUND', 'OFFERS', 'AN', 'ALTERNATIVE', 'TO', 'CORPORATE', 'AND', 'RETURNS', 'COMMENSURATE', 'WITH', 'LOW', 'RISK', 'AND', 'PROVIDING', 'INDIVIDUAL', 'INVESTORS', 'WHO', 'MAY', 'WANT', 'TO', 'PARK', 'THEIR', 'IDLE', 'HIGH', 'LEVEL', 'OF', 'LIQUIDITY,', 'THROUGH', 'INVESTMENTS', 'MADE', 'FUNDS', 'FOR', 'SHORT', 'PERIOD', 'OF', 'TIME', 'AND', 'EXPECTING', 'MINIMAL', 'PRIMARILY', 'IN', 'OVERNIGHT', 'SECURITIES.', 'HOWEVER,', 'THERE', 'CAN', 'INTEREST', 'RATE', 'AND', 'CREDIT', 'RISK.', 'TRI-PARTY', 'REPO/REPO/', '90.25%', 'BE', 'NO', 'ASSURANCE', 'THAT', 'THE', 'INVESTMENT', 'OBJECTIVE', 'OF', 'THE', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', 'SCHEME', 'WILL', 'BE', 'REALIZED.', 'QUANTITATIVE', 'INFORMATION$', 'TREASURY', 'BILLS/SOVEREIGN', '9.75%', 'MONTHEND', 'AUM', '#', ':', '`', '204.96CRORES', 'MONTHLY', 'AVG', 'AUM', ':', '`', '396.84CRORES', 'ANNUALISED', 'PORTFOLIO', 'YTM', '5.40%', 'ASSET', 'ALLOCATION', '(%', 'TO', 'NET', 'ASSETS)', 'NAV:', '(AS', 'ON', 'JUNE', '30,', '2025)', 'MODIFIED', 'DURATION', '0.00', 'YEARS', 'REGULAR', 'PLAN', '-', 'RESIDUAL', 'MATURITY', '0.01', 'YEARS', 'DAILY', 'IDCW', '(REINVESTMENT)', '`', '1,001.0000', 'DIRECT', 'PLAN', '-', 'DAILY', 'IDCW', '(REINVESTMENT)`', '1,001.0012', 'MACAULAY', 'DURATION', '0.01', 'YEARS', 'DIRECT', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '1,337.3846', 'REGULAR', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '1,336.0820', 'MATURITY', 'PROFILE', 'DATE', 'OF', 'ALLOTMENT:', '24TH', 'JULY,', '2019', 'ASSET', 'ALLOCATION:', '%', 'ALLOCATION', 'TRI-PARTY', 'REPO/REPO/', '90.25%', 'OVERNIGHT', 'SECURITIES', '*-', '0%', '-', '100%', '(RISK', '-', 'LOW)', 'NET', 'CURRENT', 'ASSETS/', 'CDMDF', '0.02%', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', '*OVERNIGHT', 'SECURITIES:', 'DEBT', 'AND', 'MONEY', 'MARKET', 'INSTRUMENTS', 'WITH', 'OVERNIGHT', 'INTEREST', 'RATE', 'RISK', 'SUCH', 'AS', '0', 'TO', '3', 'MONTHS', '99.98%', 'TREASURY', 'BILLS/SOVEREIGN', '9.75%', 'DEBT', 'INSTRUMENTS', 'WITH', 'ONE', 'BUSINESS', 'DAY', 'RESIDUAL', 'MATURITY.', 'OVERNIGHT', 'SECURITIES', 'INCLUDE', 'SYNTHETIC', 'OVERNIGHT', 'POSITIONS', 'SUCH', 'AS', 'REVERSE', 'REPO/TRI-PARTY', 'REPO', 'PORTFOLIO', '&', 'OTHER', 'TRANSACTIONS', 'WHERE', 'THE', 'INTEREST', 'RATE', 'IS', 'RESET', 'EVERY', 'BUSINESS', 'DAY.', 'NAME', 'OF', 'THE', ' ...
#
# === Page 22 ===
# ['CANARA', 'ROBECO', 'LIQUID', 'FUND', '(CRL)', '(AS', 'ON', 'JUNE', '30,', '2025)', 'THIS', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'INVESTORS', 'WHO', 'ARE', 'SEEKING*:', 'POTENTIAL', 'RISK', 'CLASS', '(PRC)', 'MATRIX', 'INCOME/', 'CAPITAL', 'APPRECIATION', 'WHILE', 'MAINTAINING', 'A', 'LEVEL', 'OF', 'HIGH', 'LIQUIDITY', 'INVESTMENT', 'IN', 'A', 'MIX', 'OF', 'DEBT', 'AND', 'MONEY', 'MARKET', 'INSTRUMENTS', 'WITH', 'MATURITY', 'OF', 'UPTO', '91', 'DAYS', 'ONLY', '*INVESTORS', 'SHOULD', 'CONSULT', 'THEIR', 'FINANCIAL', 'ADVISERS', 'IF', 'IN', 'DOUBT', 'ABOUT', 'WHETHER', 'THE', 'SCHEME', 'RISKOMETER', 'BENCHMARK', 'RISKOMETER', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'THEM.', 'THE', 'SCHEME', 'AND', 'BENCHMARK', 'RISKOMETERS', 'ARE', 'EVALUATED', 'ON', 'A', 'MONTHLY', 'BASIS', 'AND', 'THE', 'ABOVE', 'RISKOMETERS', 'ARE', 'BASED', 'ON', 'THE', 'EVALUATION', 'OF', 'THE', 'PORTFOLIOS', 'FOR', 'THE', 'MONTH', 'ENDED', 'JUNE', '30,', '2025.', 'FUND', 'INFORMATION', 'ENTRY', 'LOAD:', 'NIL', 'RATING', 'PROFILE', '(%', 'TO', 'NET', 'ASSETS)', 'EXIT', 'LOAD:', 'CATEGORY/TYPE:', 'LIQUID', 'FUND', '-', 'AN', 'OPEN', 'ENDED', 'LIQUID', 'IF', 'REDEEMED', 'ON', 'DAY', '1', '-', 'EXIT', 'LOAD', 'IS', '0.0070%', 'SCHEME.', 'A', 'RELATIVELY', 'LOW', 'INTEREST', 'RATE', 'RISK', 'AND', 'RELATIVELY', 'LOW', 'IF', 'REDEEMED', 'ON', 'DAY', '2', '-EXIT', 'LOAD', 'IS', '0.0065%', 'CREDIT', 'RISK.', 'IF', 'REDEEMED', 'ON', 'DAY', '3', '-EXIT', 'LOAD', 'IS', '0.0060%', 'SCHEME', 'OBJECTIVE:', 'THE', 'SCHEME', 'HAS', 'BEEN', 'FORMULATED', 'IF', 'REDEEMED', 'ON', 'DAY', '4', '-EXIT', 'LOAD', 'IS', '0.0055%', 'WITH', 'THE', 'OBJECTIVE', 'OF', 'ENHANCEMENT', 'OF', 'INCOME,', 'WHILE', 'IF', 'REDEEMED', 'ON', 'DAY', '5', '-EXIT', 'LOAD', 'IS', '0.0050%', 'MAINTAINING', 'A', 'LEVEL', 'OF', 'HIGH', 'LIQUIDITY,', 'THROUGH', 'INVESTMENT', 'IN', 'TRI-PARTY', 'REPO/REPO/', '6.55%', 'IF', 'REDEEMED', 'ON', 'DAY', '6', '-EXIT', 'LOAD', 'IS', '0.0045%', 'A', 'MIX', 'OF', 'MONEY', 'MARKET', 'INSTRUMENTS', '&', 'DEBT', 'SECURITIES.', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', 'IF', 'REDEEMED', 'ON', 'OR', 'AFTER', 'DAY', '7', '-', 'EXIT', 'LOAD', 'IS', 'NIL', 'HOWEVER,', 'THERE', 'CAN', 'BE', 'NO', 'ASSURANCE', 'THAT', 'THE', 'INVESTMENT', 'AAA', '&', 'EQUIVALENT', '3.34%', 'EXPENSE', 'RATIO^:', 'O', 'M', 'B', 'O', 'JE', 'N', 'C', 'T', 'T', 'H', 'IV', 'E', 'E', 'N', 'O', 'D', 'F', 'A', 'T', 'U', 'HE', 'M', 'S', '#', 'C', 'HEME', 'W', ':', 'I', 'L', 'L', 'B', '`', 'E', 'R', 'E', '5', 'A', ',', 'LI', '3', 'Z', '8', 'E', '3', 'D.', '.13', 'CRORES', 'R', 'B', 'E', 'EN', 'GU', 'C', 'L', 'H', 'A', 'M', 'R', 'P', 'A', 'LA', 'R', 'N', 'K', ':', '(', '%', 'CR', ')', 'I', ':', 'S', '0', 'I', '.', 'L', '2', 'L', '0', 'IQ', 'U', '(CID:29)', 'ID', 'D', 'D', 'E', 'I', 'B', 'RE', 'T', 'C', 'A', 'T', '-', 'P', 'I', 'I', 'L', 'N', 'A', 'D', 'N', 'E', '(', 'X', '%):0.07', 'T', 'A', 'R', '1', 'E', '+', 'A', '&', 'SU', 'R', 'E', 'Y', 'Q', 'B', 'U', 'I', 'I', 'L', 'V', 'LS', 'A', '/', 'LE', 'S', 'N', 'O', 'T', 'VEREIGN', '7', '1', '6', '3', '.', '.', '4', '52', '3%', '%', 'MONTHLY', 'AVG', 'AUM', ':', '`', '6,039.71', 'CRORES', 'FUND', 'MANAGER:', '1)', 'MR.', 'KUNAL', 'JAIN', '2)', 'MR.', 'AVNISH', 'JAIN', 'UNIT', 'FUNDS', '0.17%', 'NAV:', '(AS', 'ON', 'JUNE', '30,', '2025)', 'TOTAL', 'EXPERIENCE:', '1)', '17', 'YEARS', '2)', '30', 'YEARS', 'DIRECT', 'PLAN', '-', 'DAILY', 'IDCW', '(REINVESTMENT)', '`', '1,005.5000', 'MANAGING', 'THIS', 'FUND:', '1)', 'SINCE', '18-JULY-22', 'ASSET', 'ALLOCATION', '(%', 'TO', 'NET', 'ASSETS)', 'DIRECT', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '3,160.8214', '2)SINCE', '01-APRIL-22', 'DIRECT', 'PLAN', '-', 'UNCLAIMED', 'REDEMPTION', '&', 'DIVIDEND', 'PLAN-DIRECT', 'GROWTH', 'OPTION', '`', '1,724.4396', 'PRODUCT', 'POSITIONING', 'DIRECT', 'PLAN-IDCW', '(PAYOUT/REINVESTMENT)', '`', '2,262.0302', 'DIRECT', 'PLAN', '-', 'MONTHLY', 'IDCW', 'CANARA', 'ROBECO', 'LIQUID', 'FUND', 'IS', 'AN', 'OPEN', 'ENDED', 'DEBT', 'SCHEME', '(PAYOUT/REINVESTMENT)', '`', '1,001.2129' ...
#
# === Page 23 ===
# ['CANARA', 'ROBECO', 'ULTRA', 'SHORT', 'TERM', 'FUND', '(CRUSTF)', '(AS', 'ON', 'JUNE', '30,', '2025)', 'THIS', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'INVESTORS', 'WHO', 'ARE', 'SEEKING*:', 'POTENTIAL', 'RISK', 'CLASS', '(PRC)', 'MATRIX', 'INCOME/', 'CAPITAL', 'APPRECIATION', 'OVER', 'ULTRA-SHORT', 'TERM', 'THROUGH', 'A', 'LOW', 'RISK', 'STRATEGY', 'INVESTMENT', 'IN', 'A', 'MIX', 'OF', 'DEBT', 'AND', 'MONEY', 'MARKET', 'INSTRUMENTS', 'SUCH', 'THAT', 'THE', 'MACAULAY', 'DURATION', 'OF', 'THE', 'PORTFOLIO', 'IS', 'BETWEEN', '3', 'MONTHS', 'AND', '6', 'MONTHS', '*INVESTORS', 'SHOULD', 'CONSULT', 'THEIR', 'FINANCIAL', 'ADVISERS', 'IF', 'IN', 'DOUBT', 'ABOUT', 'WHETHER', 'THE', 'SCHEME', 'RISKOMETER', 'BENCHMARK', 'RISKOMETER', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'THEM.', '(CRISIL', 'ULTRA', 'SHORT', 'DURATION', 'DEBT', 'A-I', 'INDEX)', 'THE', 'SCHEME', 'AND', 'BENCHMARK', 'RISKOMETERS', 'ARE', 'EVALUATED', 'ON', 'A', 'MONTHLY', 'BASIS', 'AND', 'THE', 'ABOVE', 'RISKOMETERS', 'ARE', 'BASED', 'ON', 'THE', 'EVALUATION', 'OF', 'THE', 'PORTFOLIOS', 'FOR', 'THE', 'MONTH', 'ENDED', 'JUNE', '30,', '2025.', 'FUND', 'INFORMATION', 'CUM', 'CAPITAL', 'WITHDRAWAL', 'OPTION', 'RATING', 'PROFILE', '(%', 'TO', 'NET', 'ASSETS)', 'DIRECT', 'PLAN', '-', 'MONTHLY', 'REINVESTMENT', 'OF', 'INCOME', 'CATEGORY/TYPE', ':', 'ULTRA', 'SHORT', 'DURATION', 'FUND', '-', 'AN', 'OPEN', 'DISTRIBUTION', 'CUM', 'CAPITAL', 'WITHDRAWAL', 'OPTION', 'ENDED', 'ULTRA-SHORT', 'TERM', 'DEBT', 'SCHEME', 'INVESTING', 'IN', 'DEBT', 'DIRECT', 'PLAN', '-', 'MONTHLY', 'PAYOUT', 'OF', 'INCOME', 'DISTRIBUTION', '&', 'MONEY', 'MARKET', 'INSTRUMENTS', 'SUCH', 'THAT', 'THE', 'MACAULAY', 'CUM', 'CAPITAL', 'WITHDRAWAL', 'OPTION', 'DURATION', 'OF', 'THE', 'PORTFOLIO', 'IS', 'BETWEEN', '3', 'MONTHS', 'AND', '6', 'DIRECT', 'PLAN', '-', 'PAYOUT', 'OF', 'INCOME', 'DISTRIBUTION', 'CUM', 'CAPITAL', 'MONTHS.', 'A', 'RELATIVELY', 'LOW', 'INTEREST', 'RATE', 'RISK', 'AND', 'WITHDRAWAL', 'OPTION', 'MODERATE', 'CREDIT', 'RISK.', 'DIRECT', 'PLAN', '-', 'GROWTH', 'OPTION', 'SCHEME', 'OBJECTIVE:', 'TO', 'GENERATE', 'RETURNS', 'BY', 'INVESTING', 'IN', 'A', 'WIDE', 'RANGE', 'OF', 'ENTRY', 'LOAD:', 'NIL', 'TRI-PARTY', 'REPO/REPO/', '4.97%', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', 'DEBT', 'SECURITIES', 'AND', 'MONEY', 'MARKET', 'INSTRUMENTS', 'OF', 'EXIT', 'LOAD:', 'NIL', 'AAA', '&', 'EQUIVALENT', '12.08%', 'VARIOUS', 'MATURITIES', 'AND', 'RISK', 'PROFILE.', 'HOWEVER,', 'THERE', 'IS', 'EXPENSE', 'RATIO^:', 'A1+', '&', 'EQUIVALENT', '78.39%', 'NO', 'ASSURANCE', 'THAT', 'THE', 'OBJECTIVE', 'OF', 'THE', 'FUND', 'WILL', 'BE', 'REGULAR', 'PLAN', '(%)', ':', '0.95', 'TREASURY', 'BILLS/SOVEREIGN', '4.27%', 'REALISED.', 'DIRECT', 'PLAN', '(%)', ':', '0.34', 'MONTHEND', 'AUM', '#', ':', '`', '583.17', 'CRORES', 'UNIT', 'FUNDS', '0.29%', 'BENCHMARK:', 'MONTHLY', 'AVG', 'AUM', ':', '`', '576.54', 'CRORES', 'CRISIL', 'ULTRA', 'SHORT', 'DURATION', 'DEBT', 'A-I', 'INDEX', 'NAV:', '(AS', 'ON', 'JUNE', '30,', '2025)', 'ASSET', 'ALLOCATION', '(%', 'TO', 'NET', 'ASSETS)', 'DIRECT', 'PLAN', '-', 'DAILY', 'IDCW', '(REINVESTMENT)', '`', '1,240.7100', 'FUND', 'MANAGER:', '1)', 'MR.', 'KUNAL', 'JAIN', '2)', 'MR.', 'AVNISH', 'JAIN', 'DIRECT', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '4,044.1866', 'TOTAL', 'EXPERIENCE:', '1)', '17', 'YEARS', '2)', '30', 'YEARS', 'DIRECT', 'PLAN', '-', 'MANAGING', 'THIS', 'FUND:', '1)', 'SINCE', '16-SEPT.-24', 'IDCW', '(PAYOUT/REINVESTMENT)', '`', '2,314.5938', '2)', 'SINCE', '01-APRIL-22', 'DIRECT', 'PLAN', '-', 'MONTHLY', 'IDCW', '(PAYOUT/REINVESTMENT)`', '1,004.1815', 'PRODUCT', 'POSITIONING', 'REGULAR', 'PLAN', '-', 'IDCW', '(PAYOUT)', '`', '1,562.1893', 'REGULAR', 'PLAN', '-', 'CANARA', 'ROBECO', 'ULTRA', 'SHORT', 'TERM', 'FUND', 'IS', 'AN', 'OPEN', 'TRI-PARTY', 'REPO/REPO/', '4.97%', 'DAILY', 'IDCW', '(REINVESTMENT)', '`', '1,240.7100', 'ENDED', 'ULTRA-SHORT', 'TERM', 'DEBT', 'SCHEME', 'WHICH', 'SEEKS', 'TO', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', 'REGULAR', 'PLAN', '-', ' ...
#
# === Page 24 ===
# ['CANARA', 'ROBECO', 'SAVINGS', 'FUND', '(CRSF)', '(AS', 'ON', 'JUNE', '30,', '2025)', 'THIS', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'INVESTORS', 'WHO', 'ARE', 'SEEKING*:', 'POTENTIAL', 'RISK', 'CLASS', '(PRC)', 'MATRIX', 'INCOME', '/', 'CAPITAL', 'APPRECIATION', 'THROUGH', 'A', 'LOW', 'DURATION', 'STRATEGY', 'INVESTMENT', 'IN', 'DEBT', '&', 'MONEY', 'MARKET', 'INSTRUMENTS', 'SUCH', 'THAT', 'THE', 'MACAULAY', 'DURATION', 'OF', 'THE', 'PORTFOLIO', 'IS', 'BETWEEN', '6', 'MONTHS', 'AND', '12', 'MONTHS', '*INVESTORS', 'SHOULD', 'CONSULT', 'THEIR', 'FINANCIAL', 'ADVISERS', 'IF', 'IN', 'DOUBT', 'ABOUT', 'WHETHER', 'THE', 'SCHEME', 'RISKOMETER', 'BENCHMARK', 'RISKOMETER', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'THEM.', '(CRISIL', 'LOW', 'DURATION', 'DEBT', 'A-I', 'INDEX)', 'THE', 'SCHEME', 'AND', 'BENCHMARK', 'RISKOMETERS', 'ARE', 'EVALUATED', 'ON', 'A', 'MONTHLY', 'BASIS', 'AND', 'THE', 'ABOVE', 'RISKOMETERS', 'ARE', 'BASED', 'ON', 'THE', 'EVALUATION', 'OF', 'THE', 'PORTFOLIOS', 'FOR', 'THE', 'MONTH', 'ENDED', 'JUNE', '30,', '2025.', 'FUND', 'INFORMATION', 'DIRECT', 'PLAN', '-', 'DAILY', 'REINVESTMENT', 'OF', 'INCOME', 'RATING', 'PROFILE', '(%', 'TO', 'NET', 'ASSETS)', 'DISTRIBUTION', 'CUM', 'CAPITAL', 'WITHDRAWAL', 'OPTION', 'CATEGORY/TYPE', ':', 'LOW', 'DURATION', 'FUND', '-', 'AN', 'OPEN-ENDED', 'DIRECT', 'PLAN', '-', 'WEEKLY', 'PAYOUT', 'OF', 'INCOME', 'DISTRIBUTION', 'LOW', 'DURATION', 'DEBT', 'SCHEME', 'INVESTING', 'IN', 'DEBT', '&', 'MONEY', 'CUM', 'CAPITAL', 'WITHDRAWAL', 'OPTION', 'MARKET', 'INSTRUMENTS', 'SUCH', 'THAT', 'THE', 'MACAULAY', 'DURATION', 'DIRECT', 'PLAN', '-', 'WEEKLY', 'REINVESTMENT', 'OF', 'INCOME', 'OF', 'THE', 'PORTFOLIO', 'IS', 'BETWEEN', '6', 'MONTHS', 'AND', '12', 'MONTHS.', 'A', 'DISTRIBUTION', 'CUM', 'CAPITAL', 'WITHDRAWAL', 'OPTION', 'RELATIVELY', 'LOW', 'INTEREST', 'RATE', 'RISK', 'AND', 'MODERATE', 'CREDIT', 'DIRECT', 'PLAN', '-', 'MONTHLY', 'PAYOUT', 'OF', 'INCOME', 'DISTRIBUTION', 'RISK.', 'CUM', 'CAPITAL', 'WITHDRAWAL', 'OPTION', 'TRI-PARTY', 'REPO/REPO/', '12.41%', 'SCHEME', 'OBJECTIVE:', 'TO', 'GENERATE', 'INCOME', '/', 'CAPITAL', 'DIRECT', 'PLAN', '-', 'MONTHLY', 'REINVESTMENT', 'OF', 'INCOME', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', 'APPRECIATION', 'BY', 'INVESTING', 'IN', 'A', 'PORTFOLIO', 'COMPRISING', 'OF', 'DISTRIBUTION', 'CUM', 'CAPITAL', 'WITHDRAWAL', 'OPTION', 'AAA', '&', 'EQUIVALENT', '49.25%', 'LOW', 'DURATION', 'DEBT', 'INSTRUMENTS', 'AND', 'MONEY', 'MARKET', 'DIRECT', 'PLAN', '-', 'GROWTH', 'OPTION', 'A1+', '&', 'EQUIVALENT', '37.73%', 'INSTRUMENTS.', 'HOWEVER,', 'THERE', 'CAN', 'BE', 'NO', 'ASSURANCE', 'THAT', 'ENTRY', 'LOAD:', 'NIL', 'TREASURY', 'BILLS/SOVEREIGN', '0.39%', 'THE', 'INVESTMENT', 'OBJECTIVE', 'OF', 'THE', 'SCHEME', 'WILL', 'BE', 'EXIT', 'LOAD:', 'NIL', 'UNIT', 'FUNDS', '0.22%', 'REALIZED.', 'EXPENSE', 'RATIO^:', 'MONTHEND', 'AUM', '#', ':', '`', '1,342.26CRORES', 'REGULAR', 'PLAN(%)', ':', '0.50', 'ASSET', 'ALLOCATION', '(%', 'TO', 'NET', 'ASSETS)', 'MONTHLY', 'AVG', 'AUM', ':', '`', '1,350.48CRORES', 'DIRECT', 'PLAN(%)', ':', '0.21', 'NAV', ':', '(AS', 'ON', 'JUNE', '30,', '2025)', 'BENCHMARK:', 'CRISIL', 'LOW', 'DURATION', 'DEBT', 'A-I', 'INDEX', 'REGULAR', 'PLAN', '-', 'DAILY', 'IDCW', '(REINVESTMENT)', '`', '10.2600', 'FUND', 'MANAGER:', '1)', 'MR.', 'KUNAL', 'JAIN', '2)', 'MR.', 'AVNISH', 'JAIN', 'DIRECT', 'PLAN', '-', 'DAILY', 'IDCW', '(REINVESTMENT)', '`', '10.2600', 'TOTAL', 'EXPERIENCE:', '1)', '17', 'YEARS', '2)', '30', 'YEARS', 'DIRECT', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '43.4050', 'MANAGING', 'THIS', 'FUND:', '1)', 'SINCE', '18-JULY-22', 'REGULAR', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '42.2377', '2)', 'SINCE', '01-APRIL-22', 'REGULAR', 'PLAN', '-', 'TRI-PARTY', 'REPO/REPO/', '12.41%', 'IDCW', '(PAYOUT/REINVESTMENT)', '`', '37.8361', 'PRODUCT', 'POSITIONING', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', 'DIRECT', 'PLAN', '-', 'IDCW', '(PAYOUT/REINVESTMENT)`', '38.7807', 'CANARA', 'ROBECO', 'SAVINGS', 'FUND', 'AN', 'OPEN-ENDED', 'LOW',  ...
#
# === Page 25 ===
# ['CANARA', 'ROBECO', 'SHORT', 'DURATION', 'FUND', '(CRSDF)', '(AS', 'ON', 'JUNE', '30,', '2025)', 'THIS', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'INVESTORS', 'WHO', 'ARE', 'SEEKING*:', 'POTENTIAL', 'RISK', 'CLASS', '(PRC)', 'MATRIX', 'INCOME', '/', 'CAPITAL', 'APPRECIATION', 'OVER', 'SHORT', 'TERM', 'INVESTMENT', 'IN', 'DEBT', '&', 'MONEY', 'MARKET', 'INSTRUMENTS', 'SUCH', 'THAT', 'THE', 'MACAULAY', 'DURATION', 'OF', 'THE', 'PORTFOLIO', 'IS', 'BETWEEN', '1', 'YEAR', 'AND', '3', 'YEARS', '*INVESTORS', 'SHOULD', 'CONSULT', 'THEIR', 'FINANCIAL', 'ADVISERS', 'IF', 'IN', 'DOUBT', 'ABOUT', 'WHETHER', 'THE', 'SCHEME', 'RISKOMETER', 'BENCHMARK', 'RISKOMETER', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'THEM.', '(CRISIL', 'SHORT', 'DURATION', 'DEBT', 'A-II', 'INDEX)', 'THE', 'SCHEME', 'AND', 'BENCHMARK', 'RISKOMETERS', 'ARE', 'EVALUATED', 'ON', 'A', 'MONTHLY', 'BASIS', 'AND', 'THE', 'ABOVE', 'RISKOMETERS', 'ARE', 'BASED', 'ON', 'THE', 'EVALUATION', 'OF', 'THE', 'PORTFOLIOS', 'FOR', 'THE', 'MONTH', 'ENDED', 'JUNE', '30,', '2025.', 'FUND', 'INFORMATION', 'EXPENSE', 'RATIO^:', 'RATING', 'PROFILE', '(%', 'TO', 'NET', 'ASSETS)', 'REGULAR', 'PLAN', '(%)', ':', '1.02', 'CATEGORY/TYPE:', 'SHORT', 'DURATION', 'FUND', '-', 'AN', 'OPEN', 'DIRECT', 'PLAN', '(%)', ':', '0.40', 'ENDED', 'SHORT', 'TERM', 'DEBT', 'SCHEME', 'INVESTING', 'IN', 'DEBT', '&', 'BENCHMARK:', 'MONEY', 'MARKET', 'INSTRUMENTS', 'SUCH', 'THAT', 'THE', 'MACAULAY', 'CRISIL', 'SHORT', 'DURATION', 'DEBT', 'A-II', 'INDEX', 'DURATION', 'OF', 'THE', 'PORTFOLIO', 'IS', 'BETWEEN', '1', 'YEAR', 'AND', '3', 'YEARS.', 'FUND', 'MANAGER:', '1)', 'MS.', 'SUMAN', 'PRASAD', 'A', 'MODERATE', 'INTEREST', 'RATE', 'RISK', 'AND', 'MODERATE', 'CREDIT', 'RISK.', '2)', 'MR.', 'AVNISH', 'JAIN', 'SCHEME', 'OBJECTIVE', ':', 'TO', 'GENERATE', 'RETURNS', 'BY', 'INVESTING', 'TOTAL', 'EXPERIENCE', ':', '1)', '27', 'YEARS', 'IN', 'A', 'WIDE', 'RANGE', 'OF', 'DEBT', 'SECURITIES', 'AND', 'MONEY', 'MARKET', '2)', '30', 'YEARS', 'TRI-PARTY', 'REPO/REPO/', '6.36%', 'INSTRUMENTS', 'OF', 'VARIOUS', 'MATURITIES', 'AND', 'RISK', 'PROFILE.', 'HOWEVER,', 'THERE', 'IS', 'NO', 'ASSURANCE', 'THAT', 'THE', 'OBJECTIVE', 'OF', 'MANAGING', 'THIS', 'FUND', ':', '1)', 'SINCE', '16-SEP-12', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', 'THE', 'FUND', 'WILL', 'BE', 'REALISED.', '2)', 'SINCE', '18-JULY-22', 'AAA', '&', 'EQUIVALENT', '63.40%', 'A1+', '&', 'EQUIVALENT', '11.31%', 'MONTHEND', 'AUM', '#', ':', '`', '465.62', 'CRORES', 'PRODUCT', 'POSITIONING', 'TREASURY', 'BILLS/SOVEREIGN', '18.60%', 'MONTHLY', 'AVG', 'AUM', ':', '`', '456.99', 'CRORES', 'UNIT', 'FUNDS', '0.33%', 'NAV:', '(AS', 'ON', 'JUNE', '30,', '2025)', 'CANARA', 'ROBECO', 'SHORT', 'DURATION', 'FUND', 'IS', 'SUITABLE', 'FOR', 'INVESTORS', 'HAVING', 'SHORT', 'TO', 'MEDIUM', 'TERM', 'INVESTMENT', 'DIRECT', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '27.7672', 'REGULAR', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '25.4566', 'HORIZON', 'WITH', 'LOW', 'VOLATILITY.', 'THE', 'FUND', 'AIM', 'TO', 'GENERATES', 'ASSET', 'ALLOCATION', '(%', 'TO', 'NET', 'ASSETS)', 'INCOME', 'PREDOMINANTLY', 'FROM', 'ACCRUAL', 'YIELDS', 'ON', 'HIGH', 'DIRECT', 'PLAN', '-', 'QUALITY', 'MONEY', 'MARKET', 'INSTRUMENTS,', 'WHILE', 'AN', 'ACTIVE', 'MONTHLY', 'IDCW', '(PAYOUT/REINVESTMENT)', '`', '18.1601', 'TRADING', 'STRATEGY', 'IS', 'FOLLOWED', 'FOR', 'GENERATING', 'ALPHA.', 'REGULAR', 'PLAN', '-', 'MONTHLY', 'IDCW', '(PAYOUT/REINVESTMENT)', '`', '15.7439', 'REGULAR', 'PLAN', '-', 'QUANTITATIVE', 'INFORMATION$', 'QUARTERLY', 'IDCW', '(PAYOUT/REINVESTMENT)', '`', '15.4074', 'ANNUALISED', 'PORTFOLIO', 'YTM', '6.52%', 'DIRECT', 'PLAN', '-', 'QUARTERLY', 'IDCW', '(PAYOUT/REINVESTMENT)', '`', '17.1441', 'MODIFIED', 'DURATION', '2.30', 'YEARS', 'TRI-PARTY', 'REPO/REPO/', '6.36%', 'RESIDUAL', 'MATURITY', '2.83', 'YEARS', 'DAT', 'E', 'OF', 'ALLOTMENT', ':', '25', 'APRIL,', '2011', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', 'MACAULAY', 'DURATION', '2.44', 'YEARS', 'ASSET', 'ALLOCATION', ':', 'CERTIFICATE', 'OF', ...
#
# === Page 26 ===
# ['CANARA', 'ROBECO', 'INCOME', 'FUND', '(CRINC)', '(AS', 'ON', 'JUNE', '30,', '2025)', 'THIS', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'INVESTORS', 'WHO', 'ARE', 'SEEKING*:', 'POTENTIAL', 'RISK', 'CLASS', '(PRC)', 'MATRIX', 'INCOME', '/', 'CAPITAL', 'APPRECIATION', 'OVER', 'MEDIUM', 'TO', 'LONG', 'TERM', 'INVESTMENT', 'IN', 'DEBT', '&', 'MONEY', 'MARKET', 'INSTRUMENTS', 'SUCH', 'THAT', 'THE', 'MACAULAY', 'DURATION', 'OF', 'THE', 'PORTFOLIO', 'IS', 'BETWEEN', '4', 'YEARS', 'AND', '7', 'YEARS', '(PORTFOLIO', 'MACAULAY', 'DURATION', 'UNDER', 'ANTICIPATED', 'ADVERSE', 'SITUATION', 'IS', '1', 'YEAR', 'TO', '7', 'YEARS)', 'SCHEME', 'RISKOMETER', 'BENCHMARK', 'RISKOMETER', '*INVESTORS', 'SHOULD', 'CONSULT', 'THEIR', 'FINANCIAL', 'ADVISERS', 'IF', 'IN', 'DOUBT', 'ABOUT', 'WHETHER', 'THE', '(CRISIL', 'MEDIUM', 'TO', 'LONG', 'DURATION', 'DEBT', 'A-III', 'INDEX)', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'THEM.', 'THE', 'SCHEME', 'AND', 'BENCHMARK', 'RISKOMETERS', 'ARE', 'EVALUATED', 'ON', 'A', 'MONTHLY', 'BASIS', 'AND', 'THE', 'ABOVE', 'RISKOMETERS', 'ARE', 'BASED', 'ON', 'THE', 'EVALUATION', 'OF', 'THE', 'PORTFOLIOS', 'FOR', 'THE', 'MONTH', 'ENDED', 'JUNE', '30,', '2025.', 'FUND', 'INFORMATION', 'FUND', 'MANAGER:', '1)', 'MR.', 'AVNISH', 'JAIN', 'RATING', 'PROFILE', '(%', 'TO', 'NET', 'ASSETS)', '2)', 'MR.', 'KUNAL', 'JAIN', 'CATEGORY/TYPE:', 'MEDIUM', 'TO', 'LONG', 'DURATION', 'FUND', '-', 'AN', 'OPEN', 'ENDED', 'MEDIUM', 'TERM', 'DEBT', 'SCHEME', 'INVESTING', 'IN', 'TOTAL', 'EXPERIENCE', ':', '1)', '30', 'YEARS', 'DEBT', '&', 'MONEY', 'MARKET', 'INSTRUMENTS', 'SUCH', 'THAT', 'THE', '2)', '17', 'YEARS', 'MACAULAY', 'DURATION', 'OF', 'THE', 'PORTFOLIO', 'IS', 'BETWEEN', '4', 'YEARS', '–', 'MANAGING', 'THIS', 'FUND', ':', '1)', 'SINCE', '25-JUNE-14', '7', 'YEARS.', '(PORTFOLIO', 'MACAULAY', 'DURATION', 'UNDER', '2)', 'SINCE', '18-JULY-22', 'ANTICIPATED', 'ADVERSE', 'SITUATION', 'IS', '1', 'YEAR', 'TO', '7', 'YEARS).', 'A', 'RELATIVELY', 'HIGH', 'INTEREST', 'RATE', 'RISK', 'AND', 'MODERATE', 'CREDIT', 'PRODUCT', 'POSITIONING', 'RISK.', 'TRI-PARTY', 'REPO/REPO/', '12.75%', 'SCHEME', 'OBJECTIVE:', 'CANARA', 'ROBECO', 'INCOME', 'FUND', 'IS', 'AN', 'OPEN', 'ENDED', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', 'MEDIUM', 'TERM', 'DEBT', 'SCHEME', 'INVESTING', 'IN', 'DEBT', '&', 'MONEY', 'THE', 'SCHEME', 'SEEKS', 'TO', 'GENERATE', 'INCOME', 'AND', 'CAPITAL', 'AAA', '&', 'EQUIVALENT', '7.96%', 'MARKET', 'INSTRUMENTS', 'SUCH', 'THAT', 'THE', 'MACAULAY', 'DURATION', 'APPRECIATION', 'THROUGH', 'A', 'PORTFOLIO', 'CONSTITUTED', 'OF', 'OF', 'THE', 'PORTFOLIO', 'IS', 'BETWEEN', '4', 'YEARS', '–7', 'YEARS.', 'HOWEVER,', 'TREASURY', 'BILLS/SOVEREIGN', '79.00%', 'MEDIUM', 'TO', 'LONG', 'TERM', 'DEBT', 'AND', 'MONEY', 'MARKET', 'THE', 'PORTFOLIO', 'MACAULAY', 'DURATION', 'UNDER', 'ANTICIPATED', 'UNIT', 'FUNDS', '0.28%', 'SECURITIES', 'AND', 'ISSUERS', 'OF', 'DIFFERENT', 'RISK', 'PROFILES.', 'ADVERSE', 'SITUATION', 'MAY', 'BE', 'BETWEEN', '1', 'YEAR', 'AND', '7', 'YEARS.', 'HOWEVER,', 'THERE', 'CAN', 'BE', 'NO', 'ASSURANCE', 'THAT', 'THE', 'FUND', 'MANAGER', 'TAKES', 'AN', 'ACTIVE', 'VIEW', 'OF', 'THE', 'INTEREST', 'RATE', 'INVESTMENT', 'OBJECTIVE', 'OF', 'THE', 'SCHEME', 'WILL', 'BE', 'REALIZED.', 'MOVEMENTS.', 'BASED', 'ON', 'THE', 'INTEREST', 'RATE', 'VIEW,', 'THE', 'ASSET', 'ALLOCATION', '(%', 'TO', 'NET', 'ASSETS)', 'MONTHEND', 'AUM', '#', ':', '`', '125.81', 'CRORES', 'DURATION', 'OF', 'THE', 'PORTFOLIO', 'WILL', 'BE', 'DECIDED', 'ALONG', 'WITH', 'THE', 'ASSET', 'ALLOCATION', 'PATTERN', 'BETWEEN', 'SOVEREIGN', '&', 'MONTHLY', 'AVG', 'AUM', ':', '`', '123.66CRORES', 'CORPORATE', 'BONDS.', 'AS', 'MAJORITY', 'OF', 'THE', 'PORTFOLIO', 'GETS', 'NAV:', '(AS', 'ON', 'JUNE', '30,', '2025)', 'INVESTED', 'IN', 'HIGH', 'QUALITY', 'DEBT', 'PAPERS,', 'WHICH', 'PROVIDES', 'DIRECT', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '62.1200', 'CONSISTENT', 'ACCRUAL', 'INCOME', 'TO', 'THE', 'PORTFOLIO.', 'REGULAR', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '55.3990', 'REGULAR', 'PLAN' ...
#
# === Page 27 ===
# ['CANARA', 'ROBECO', 'DYNAMIC', 'BOND', 'FUND', '(CRDBF)', '(AS', 'ON', 'JUNE', '30,', '2025)', 'THIS', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'INVESTORS', 'WHO', 'ARE', 'SEEKING*:', 'POTENTIAL', 'RISK', 'CLASS', '(PRC)', 'MATRIX', 'INCOME/', 'CAPITAL', 'APPRECIATION', 'BY', 'DYNAMICALLY', 'MANAGING', 'DURATION', 'INVESTMENT', 'IN', 'DEBT', 'AND', 'MONEY', 'MARKET', 'SECURITIES', 'ACROSS', 'DURATION', '*INVESTORS', 'SHOULD', 'CONSULT', 'THEIR', 'FINANCIAL', 'ADVISERS', 'IF', 'IN', 'DOUBT', 'ABOUT', 'WHETHER', 'THE', 'SCHEME', 'RISKOMETER', 'BENCHMARK', 'RISKOMETER', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'THEM.', '(CRISIL', 'DYNAMIC', 'BOND', 'A-III', 'INDEX)', 'THE', 'SCHEME', 'AND', 'BENCHMARK', 'RISKOMETERS', 'ARE', 'EVALUATED', 'ON', 'A', 'MONTHLY', 'BASIS', 'AND', 'THE', 'ABOVE', 'RISKOMETERS', 'ARE', 'BASED', 'ON', 'THE', 'EVALUATION', 'OF', 'THE', 'PORTFOLIOS', 'FOR', 'THE', 'MONTH', 'ENDED', 'JUNE', '30,', '2025.', 'FUND', 'INFORMATION', 'TOTAL', 'EXPERIENCE:', '1)', '17', 'YEARS', 'RATING', 'PROFILE', '(%', 'TO', 'NET', 'ASSETS)', '2)', '30', 'YEARS', 'CATEGORY/TYPE:', 'DYNAMIC', 'BOND', '-', 'AN', 'OPEN', 'ENDED', 'DYNAMIC', 'DEBT', 'SCHEME', 'INVESTING', 'ACROSS', 'DURATION.', 'A', 'MANAGING', 'THIS', 'FUND:', '1)', 'SINCE', '18-JULY-22', 'RELATIVELY', 'HIGH', 'INTEREST', 'RATE', 'RISK', 'AND', 'MODERATE', 'CREDIT', '2)', 'SINCE', '01-APRIL-22', 'RISK.', 'SCHEME', 'OBJECTIVE:', 'PRODUCT', 'POSITIONING', 'THE', 'OBJECTIVE', 'OF', 'THE', 'FUND', 'IS', 'TO', 'SEEK', 'TO', 'GENERATE', 'INCOME', 'FROM', 'A', 'PORTFOLIO', 'OF', 'DEBT', 'AND', 'MONEY', 'MARKET', 'SECURITIES.', 'CANARA', 'ROBECO', 'DYNAMIC', 'BOND', 'FUND', 'INTENDS', 'TO', 'INVEST', 'HOWEVER,', 'THERE', 'CAN', 'BE', 'NO', 'ASSURANCE', 'THAT', 'THE', 'AND', 'TRADE', 'IN', 'G-SECS', 'AND', 'CORPORATE', 'DEBT', 'BY', 'IDENTIFYING', 'INVESTMENT', 'OBJECTIVE', 'OF', 'THE', 'SCHEME', 'WILL', 'BE', 'REALIZED', 'AND', 'MISPRICED', 'OPPORTUNITIES', '&', 'CAPTURING', 'VOLATILITY', 'TRENDS.', 'TRI-PARTY', 'REPO/REPO/', '5.59%', 'THE', 'FUND', 'DOES', 'NOT', 'ASSURE', 'OR', 'GUARANTEE', 'ANY', 'RETURNS.', 'THE', 'FUND', 'AIMS', 'AT', 'GENERATING', 'ALPHA', 'THROUGH', 'FREE-STYLE', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', 'DURATION', 'MANAGEMENT', 'DEPENDING', 'ON', 'THE', 'INTEREST', 'RATE', 'MONTHEND', 'AUM', '#', ':', '`', '124.31', 'CRORES', 'VIEW.', 'AT', 'THE', 'SAME', 'TIME', 'IT', 'ENDEAVOURS', 'TO', 'CAPTURE', 'TREASURY', 'BILLS/SOVEREIGN', '94.13%', 'MONTHLY', 'AVG', 'AUM', ':', '`', '126.93', 'CRORES', 'ACCRUALS', 'IN', 'THE', 'FORM', 'OF', 'PORTFOLIO', 'RUNNING', 'YIELDS', 'ON', 'HIGH-', 'UNIT', 'FUNDS', '0.28%', 'QUALITY', 'DEBT', 'INSTRUMENTS.', 'NAV:', '(AS', 'ON', 'JUNE', '30,', '2025)', 'DIRECT', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '32.3136', 'ASSET', 'ALLOCATION', '(%', 'TO', 'NET', 'ASSETS)', 'DIRECT', 'PLAN', '-', 'QUANTITATIVE', 'INFORMATION$', 'IDCW', '(PAYOUT/REINVESTMENT)', '`', '15.3378', 'REGULAR', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '29.2961', 'ANNUALISED', 'PORTFOLIO', 'YTM', '6.75%', 'REGULAR', 'PLAN', '-', 'MODIFIED', 'DURATION', '8.59', 'YEARS', 'IDCW', '(PAYOUT/REINVESTMENT)', '`', '13.7473', 'DATE', 'OF', 'ALLOTMENT:', 'MAY', '29,', '2009', 'RESIDUAL', 'MATURITY', '17.03', 'YEARS', 'ASSET', 'ALLOCATION:', 'MACAULAY', 'DURATION', '8.94', 'YEARS', 'GOVERNMENT', 'OF', 'INDIA', '&', 'CORPORATE', 'DEBT', 'SECURITIES', 'TRI-PARTY', 'REPO/REPO/', '5.59%', '(INCLUDING', 'SECURITISED', 'DEBT)*', '-', '0%', 'TO', '100%', '(RISK-', 'LOW', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', 'TO', 'MEDIUM)', 'MATURITY', 'PROFILE', 'MONEY', 'MARKET', 'INSTRUMENTS', '-', '0%', 'TO', '100%', '(RISK-', 'LOW)', 'TREASURY', 'BILLS/SOVEREIGN', '94.13%', '*', 'EXCLUDING', 'DEBT/GOI', 'SECURITIES', 'WITH', 'INITIAL', 'MATURITY', 'OF', '%', 'ALLOCATION', 'UNIT', 'FUNDS', '0.28%', 'LESS', 'THAN', 'ONE', 'YEAR', 'AND', 'TREASURY', 'BILLS', 'NET', 'CURRENT', 'ASSETS/', 'CDMDF', '1.65%', 'MINIMUM', 'INVESTMENT', ':', '`', '5000', 'AND', 'IN', 'MULTIPLES' ...
#
# === Page 28 ===
# ['CANARA', 'ROBECO', 'CORPORATE', 'BOND', 'FUND', '(CRCBF)', '(AS', 'ON', 'JUNE', '30,', '2025)', 'THIS', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'INVESTORS', 'WHO', 'ARE', 'SEEKING*:', 'POTENTIAL', 'RISK', 'CLASS', '(PRC)', 'MATRIX', 'INCOME', '/', 'CAPITAL', 'APPRECIATION', 'THROUGH', 'A', 'LOW', 'CREDIT', 'RISK', 'STRATEGY', 'INVESTMENT', 'IN', 'A', 'PORTFOLIO', 'CONSTITUTED', 'PREDOMINANTLY', 'OF', 'AA+', 'AND', 'ABOVE', 'RATED', 'CORPORATE', 'BONDS', '*INVESTORS', 'SHOULD', 'CONSULT', 'THEIR', 'FINANCIAL', 'ADVISERS', 'IF', 'IN', 'DOUBT', 'ABOUT', 'WHETHER', 'THE', 'SCHEME', 'RISKOMETER', 'BENCHMARK', 'RISKOMETER', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'THEM.', '(CRISIL', 'CORPORATE', 'DEBT', 'A-II', 'INDEX)', 'THE', 'SCHEME', 'AND', 'BENCHMARK', 'RISKOMETERS', 'ARE', 'EVALUATED', 'ON', 'A', 'MONTHLY', 'BASIS', 'AND', 'THE', 'ABOVE', 'RISKOMETERS', 'ARE', 'BASED', 'ON', 'THE', 'EVALUATION', 'OF', 'THE', 'PORTFOLIOS', 'FOR', 'THE', 'MONTH', 'ENDED', 'JUNE', '30,', '2025.', 'FUND', 'INFORMATION', 'TOTAL', 'EXPERIENCE:', '1)', '30', 'YEARS', 'RATING', 'PROFILE', '(%', 'TO', 'NET', 'ASSETS)', '2)', '27', 'YEARS', 'CATEGORY/TYPE', ':', 'CORPORATE', 'BOND', 'FUND', '-', 'AN', 'OPEN', 'ENDED', 'DEBT', 'SCHEME', 'PREDOMINANTLY', 'INVESTING', 'IN', 'AA+', 'MANAGING', 'THIS', 'FUND:', '1)', 'SINCE', '7-FEB-14', 'AND', 'ABOVE', 'RATED', 'CORPORATE', 'BONDS.', 'A', 'RELATIVELY', 'HIGH', '2)', 'SINCE', '18-JULY-22', 'INTEREST', 'RATE', 'RISK', 'AND', 'MODERATE', 'CREDIT', 'RISK.', 'SCHEME', 'OBJECTIVE', ':', 'THE', 'SCHEME', 'SEEKS', 'TO', 'GENERATE', 'PRODUCT', 'POSITIONING', 'INCOME', 'AND', 'CAPITAL', 'APPRECIATION', 'THROUGH', 'A', 'PORTFOLIO', 'CANARA', 'ROBECO', 'COROPRATE', 'BOND', 'FUND', 'ENDEAVOURS', 'TO', 'CONSTITUTED', 'PREDOMINANTLY', 'OF', 'AA+', 'AND', 'ABOVE', 'RATED', 'GENERATE', 'ACCRUAL', 'INCOME', 'BY', 'INVESTING', 'IN', 'HIGH', 'QUALITY', 'CORPORATE', 'DEBT', 'ACROSS', 'MATURITIES.', 'HOWEVER,', 'THERE', 'CAN', 'DEBT', 'PAPERS.', 'THE', 'FUND', 'LOOKS', 'TO', 'BENEFIT', 'FROM', 'THE', 'BE', 'NO', 'ASSURANCE', 'THAT', 'THE', 'INVESTMENT', 'OBJECTIVE', 'OF', 'THE', 'TRI-PARTY', 'REPO/REPO/', '14.98%', 'MISPRICED', 'OPPORTUNITIES', 'IN', 'THE', 'MARKETS', 'AND', 'A', 'POSSIBLE', 'SCHEME', 'WILL', 'BE', 'REALIZED', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', 'UPGRADE', 'OF', 'RATING', 'OF', 'THE', 'INSTRUMENTS', 'IN', 'WHICH', 'MONTHEND', 'AUM', '#', ':', '`', '115.92', 'CRORES', 'INVESTMENTS', 'ARE', 'MADE.', 'THE', 'FUND', 'IS', 'SUITABLE', 'FOR', 'AAA', '&', 'EQUIVALENT', '70.40%', 'MONTHLY', 'AVG', 'AUM', ':', '`', '116.30', 'CRORES', 'INVESTORS', 'WHO', 'HAVE', 'A', 'MEDIUM', 'TO', 'LONG', 'TERM', 'INVESTMENT', 'TREASURY', 'BILLS/SOVEREIGN', '14.14%', 'HORIZON', '&', 'A', 'MODERATE', 'RISK', 'APPETITE.', 'UNIT', 'FUNDS', '0.47%', 'NAV:', '(AS', 'ON', 'JUNE', '30,', '2025)', 'DIRECT', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '23.3191', 'QUANTITATIVE', 'INFORMATION$', 'REGULAR', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '21.7652', 'ASSET', 'ALLOCATION', '(%', 'TO', 'NET', 'ASSETS)', 'REGULAR', 'PLAN', '-', 'ANNUALISED', 'PORTFOLIO', 'YTM', '6.49%', 'IDCW', '(PAYOUT/REINVESTMENT)', '`', '11.6071', 'MODIFIED', 'DURATION', '2.66', 'YEARS', 'DIRECT', 'PLAN', '-', 'RESIDUAL', 'MATURITY', '3.43', 'YEARS', 'IDCW', '(PAYOUT/REINVESTMENT)', '`', '12.4182', 'MACAULAY', 'DURATION', '2.81', 'YEARS', 'DAT', 'E', 'OF', 'ALLOTMENT', ':', '7TH', 'FEBRUARY,', '2014', 'ASSET', 'ALLOCATION', ':', 'MATURITY', 'PROFILE', 'AA+', 'AND', 'ABOVE', 'RATED', 'CORPORATE', 'DEBT', 'OF', 'VARYING', 'MATURITIES', '-', '80%', 'TO', '100%', '(RISK-', 'LOW', 'TO', 'MEDIUM)', '%', 'ALLOCATION', 'OTHER', 'DEBT', '(INCLUDING', 'GOVERNMENT', 'SECURITIES)', 'AND', 'NET', 'CURRENT', 'ASSETS/', 'CDMDF', '3.38%', 'TRI-PARTY', 'REPO/REPO/', '14.98%', 'MONEY', 'MARKET', 'INSTRUMENTS', '-', '0%', 'TO', '20%', '(RISK-', 'LOW', 'TO', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', '0', 'TO', '3', 'MONTHS', '12.08%', 'MEDIUM)', 'NCDS/BONDS', '70.40%', '3', 'TO', ...
#
# === Page 29 ===
# ['CANARA', 'ROBECO', 'GILT', 'FUND', '(CRGILT)', '(AS', 'ON', 'JUNE', '30,', '2025)', 'THIS', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'INVESTORS', 'WHO', 'ARE', 'SEEKING*:', 'POTENTIAL', 'RISK', 'CLASS', '(PRC)', 'MATRIX', 'RELATIVELY', 'HIGH', 'INTEREST', 'RATE', 'RISK', 'AND', 'LOW', 'CREDIT', 'RISK', 'RISK', 'FREE', 'RETURN', '(EXCEPT', 'INTEREST', 'RATE', 'RISK)', 'AND', 'LONG', 'TERM', 'CAPITAL', 'APPRECIATION', 'INVESTMENT', 'IN', 'GOVERNMENT', 'SECURITIES', 'ACROSS', 'MATURITY', '*INVESTORS', 'SHOULD', 'CONSULT', 'THEIR', 'FINANCIAL', 'ADVISERS', 'IF', 'IN', 'DOUBT', 'ABOUT', 'WHETHER', 'THE', 'SCHEME', 'RISKOMETER', 'BENCHMARK', 'RISKOMETER', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'THEM.', 'THE', 'SCHEME', 'AND', 'BENCHMARK', 'RISKOMETERS', 'ARE', 'EVALUATED', 'ON', 'A', 'MONTHLY', 'BASIS', 'AND', 'THE', 'ABOVE', 'RISKOMETERS', 'ARE', 'BASED', 'ON', 'THE', 'EVALUATION', 'OF', 'THE', 'PORTFOLIOS', 'FOR', 'THE', 'MONTH', 'ENDED', 'JUNE', '30,', '2025.', 'FUND', 'INFORMATION', 'MANAGING', 'THIS', 'FUND:', '1)', 'SINCE', '18-JULY-22', 'RATING', 'PROFILE', '(%', 'TO', 'NET', 'ASSETS)', '2)', 'SINCE', '01-APRIL-22', 'CATEGORY/TYPE:', 'GILT', 'FUND', '-', 'AN', 'OPEN-ENDED', 'DEBT', 'SCHEME', 'INVESTING', 'IN', 'GOVERNMENT', 'SECURITIES', 'ACROSS', 'PRODUCT', 'POSITIONING', 'MATURITY.', 'A', 'RELATIVELY', 'HIGH', 'INTEREST', 'RATE', 'RISK', 'AND', 'RELATIVELY', 'LOW', 'CREDIT', 'RISK.', 'CANARA', 'ROBECO', 'GILT', 'FUND', 'INVESTS', 'IN', 'G-SECS', 'OF', 'VARYING', 'SCHEME', 'OBJECTIVE:', 'TO', 'PROVIDE', 'RISK', 'FREE', 'RETURN', '(EXCEPT', 'MATURITY', 'ISSUED', 'BY', 'RESERVE', 'BANK', 'OF', 'INDIA', '(RBI).', 'BEING', 'INTEREST', 'RATE', 'RISK)', 'WHILE', 'MAINTAINING', 'STABILITY', 'OF', 'CAPITAL', 'INVESTED', 'IN', 'SOVEREIGN', 'PAPERS,', 'THE', 'FUND', 'DOES', 'NOT', 'EXPOSE', 'AND', 'LIQUIDITY.', 'BEING', 'A', 'DEDICATED', 'GILT', 'SCHEME,', 'THE', 'FUNDS', 'ITS', 'INVESTORS', 'TO', 'CREDIT', 'RISK', 'AS', 'IN', 'THE', 'CASE', 'OF', 'OTHER', 'BOND', 'WILL', 'BE', 'INVESTED', 'IN', 'SECURITIES', 'AS', 'DEFINED', 'UNDER', 'SEC.', '2', '(2)', 'FUNDS.', 'OF', 'PUBLIC', 'DEBT', 'ACT,', '1944.', 'HOWEVER,', 'THERE', 'CAN', 'BE', 'NO', 'TRI-PARTY', 'REPO/REPO/', '9.18%', 'ASSURANCE', 'THAT', 'THE', 'INVESTMENT', 'OBJECTIVE', 'OF', 'THE', 'SCHEME', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', 'WILL', 'BE', 'REALIZED.', 'QUANTITATIVE', 'INFORMATION$', 'TREASURY', 'BILLS/SOVEREIGN', '90.82%', 'MONTHEND', 'AUM', '#', ':', '`', '157.22', 'CRORES', 'ANNUALISED', 'PORTFOLIO', 'YTM', '6.69%', 'MONTHLY', 'AVG', 'AUM', ':', '`', '154.47', 'CRORES', 'MODIFIED', 'DURATION', '8.56', 'YEARS', 'NAV:', '(AS', 'ON', 'JUNE', '30,', '2025)', 'ASSET', 'ALLOCATION', '(%', 'TO', 'NET', 'ASSETS)', 'DIRECT', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '81.0905', 'RESIDUAL', 'MATURITY', '19.35', 'YEARS', 'REGULAR', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '75.3035', 'REGULAR', 'PLAN', '-', 'MACAULAY', 'DURATION', '8.92', 'YEARS', 'IDCW', '(PAYOUT/REINVESTMENT)', '`', '15.2162', 'DIRECT', 'PLAN', '-', 'MATURITY', 'PROFILE', 'IDCW', '(PAYOUT/REINVESTMENT)', '`', '16.5816', 'DATE', 'OF', 'ALLOTMENT:', 'DECEMBER', '29,', '1999', '%', 'ALLOCATION', 'ASSET', 'ALLOCATION:', 'NET', 'CURRENT', 'ASSETS/', 'CDMDF', '1.25%', 'GOVT.', 'SECURITIES', '-', '80%', 'TO', '100%', '(RISK-', 'LOW)', 'TRI-PARTY', 'REPO/REPO/', '9.18%', 'MONEY', 'MARKET', 'INSTRUMENTS', '-', '0%', 'TO', '20%', '(RISK-', 'LOW', 'TO', '0', 'TO', '3', 'MONTHS', '7.93%', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', 'MEDIUM)', 'TREASURY', 'BILLS/SOVEREIGN', '90.82%', 'MINIMUM', 'INVESTMENT:', '1', '-2', 'YEARS', '1.64%', '`', '5000', 'AND', 'IN', 'MULTIPLES', 'OF', '`', '1', 'THEREAFTER', 'GREATER', 'THAN', '2', 'YEARS', '89.18%', 'SUBSEQUENT', 'PURCHASES:', 'MINIMUM', 'AMOUNT', 'OF', '`', '1000', 'AND', 'MULTIPLES', 'OF', '`', '1', 'THEREAFTER', 'PORTFOLIO', 'SIP:', 'FOR', 'ANY', 'DATE/MONTHLY', 'FREQUENCY', '–', '`', '1000', 'AND', 'IN', 'MULTIPLES', 'OF', '`', '1', 'THEREAFTER', 'NAME', 'OF',  ...
#
# === Page 30 ===
# ['CANARA', 'ROBECO', 'BANKING', 'AND', 'PSU', 'DEBT', 'FUND', '(CRBPDF)', '(AS', 'ON', 'JUNE', '30,', '2025)', 'THIS', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'INVESTORS', 'WHO', 'ARE', 'SEEKING*:', 'POTENTIAL', 'RISK', 'CLASS', '(PRC)', 'MATRIX', 'INCOME/CAPITAL', 'APPRECIATION', 'OVER', 'SHORT', 'TO', 'MEDIUM', 'TERM', 'INVESTMENT', 'IN', 'DEBT', 'AND', 'MONEY', 'MARKET', 'INSTRUMENTS', 'ISSUED', 'BY', 'BANKS,', 'PUBLIC', 'SECTOR', 'UNDERTAKINGS', '(PSUS),', 'PUBLIC', 'FINANCIAL', 'INSTITUTIONS', '(PFIS)', 'AND', 'MUNICIPAL', 'BONDS', '*INVESTORS', 'SHOULD', 'CONSULT', 'THEIR', 'FINANCIAL', 'ADVISERS', 'IF', 'IN', 'DOUBT', 'ABOUT', 'WHETHER', 'THE', 'SCHEME', 'RISKOMETER', 'BENCHMARK', 'RISKOMETER', 'PRODUCT', 'IS', 'SUITABLE', 'FOR', 'THEM.', '(CRISIL', 'BANKING', 'AND', 'PSU', 'DEBT', 'A-II', 'INDEX)', 'THE', 'SCHEME', 'AND', 'BENCHMARK', 'RISKOMETERS', 'ARE', 'EVALUATED', 'ON', 'A', 'MONTHLY', 'BASIS', 'AND', 'THE', 'ABOVE', 'RISKOMETERS', 'ARE', 'BASED', 'ON', 'THE', 'EVALUATION', 'OF', 'THE', 'PORTFOLIOS', 'FOR', 'THE', 'MONTH', 'ENDED', 'JUNE', '30,', '2025.', 'FUND', 'INFORMATION', 'ENTRY', 'LOAD:', 'NA', 'RATING', 'PROFILE', '(%', 'TO', 'NET', 'ASSETS)', 'EXIT', 'LOAD', ':', 'NIL', 'CATEGORY/TYPE:', 'BANKING', 'AND', 'PSU', 'FUND', '-', 'AN', 'OPEN-', 'ENDED', 'DEBT', 'SCHEME', 'PREDOMINANTLY', 'INVESTING', 'IN', 'DEBT', 'EXPENSE', 'RATIO^:', 'INSTRUMENTS', 'OF', 'BANKS,', 'PUBLIC', 'SECTOR', 'UNDERTAKINGS,', 'REGULAR', 'PLAN', '(%)', ':', '0.71', 'PUBLIC', 'FINANCIAL', 'INSTITUTIONS', 'AND', 'MUNICIPAL', 'BONDS.', 'A', 'DIRECT', 'PLAN', '(%)', ':', '0.38', 'RELATIVELY', 'HIGH', 'INTEREST', 'RATE', 'RISK', 'AND', 'MODERATE', 'CREDIT', 'BENCHMARK:', 'CRISIL', 'BANKING', 'AND', 'PSU', 'DEBT', 'A-II', 'INDEX', 'RISK.', 'FUND', 'MANAGER:', '1)', 'MS.', 'SUMAN', 'PRASAD', 'SCHEME', 'OBJECTIVE:', 'TO', 'GENERATE', 'INCOME', 'AND/OR', '2)', 'MR.', 'AVNISH', 'JAIN', 'CAPITAL', 'APPRECIATION', 'THROUGH', 'A', 'PORTFOLIO', 'OF', 'HIGH', 'QUALITY', 'TOTAL', 'EXPERIENCE:', '1)', '27', 'YEARS', 'TRI-PARTY', 'REPO/REPO/', '6.11%', 'DEBT', 'AND', 'MONEY', 'MARKET', 'INSTRUMENTS', 'ISSUED', 'BY', 'ENTITIES', '2)', '30', 'YEARS', 'REVERSE', 'REPO', '&', 'NET', 'CURRENT', 'ASSETS', 'SUCH', 'AS', 'BANKS,', 'PUBLIC', 'SECTOR', 'UNDERTAKINGS', '(PSUS),', 'PUBLIC', 'FINANCIAL', 'INSTITUTIONS', '(PFIS)', 'AND', 'MUNICIPAL', 'MANAGING', 'THIS', 'FUND:', '1)', 'SINCE', '16-SEPT.-24', 'AAA', '&', 'EQUIVALENT', '64.45%', 'BONDS.', 'HOWEVER,', 'THERE', 'IS', 'NO', 'ASSURANCE', 'THAT', 'THE', '2)', 'SINCE', '22-AUGUST-22', 'A1+', '&', 'EQUIVALENT', '19.39%', 'TREASURY', 'BILLS/SOVEREIGN', '9.54%', 'OBJECTIVE', 'OF', 'THE', 'FUND', 'WILL', 'BE', 'REALISED.', 'PRODUCT', 'POSITIONING', 'UNIT', 'FUNDS', '0.52%', 'MONTHEND', 'AUM', '#', ':', '`', '229.25', 'CRORES', 'CANARA', 'ROBECO', 'BANKING', 'AND', 'PSU', 'DEBT', 'FUND', 'WOULD', 'BE', 'MONTHLY', 'AVG', 'AUM', ':', '`', '230.61', 'CRORES', 'AN', '“ACTIVELY', 'MANAGED', 'FUND”', 'THAT', 'AIMS', 'TO', 'CAPTURE', 'OPPORTUNITIES', 'IN', 'THE', 'INTEREST', 'RATE', 'CYCLE', 'AND', 'MISPRICING', 'ASSET', 'ALLOCATION', '(%', 'TO', 'NET', 'ASSETS)', 'NAV:', '(AS', 'ON', 'JUNE', '30,', '2025)', 'ON', 'THE', 'YIELD', 'CURVE.', 'DIRECT', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '12.1914', 'THE', 'FUND', 'WILL', 'ENDEAVOUR', 'TO', 'INVEST', 'IN', '“HIGH', 'GRADE', 'REGULAR', 'PLAN', '-', 'GROWTH', 'OPTION', '`', '12.0879', 'ASSETS”', 'THAT', 'ARE', 'EITHER', 'GOVERNMENT', '–BACKED', 'ENTITIES', 'OR', 'REGULAR', 'PLAN', '-', 'SYSTEMICALLY', 'IMPORTANT', 'PRIVATE', 'BANKS/ENTITIES.', 'THIS', 'IDCW', '(PAYOUT/REINVESTMENT)', '`', '10.6636', 'POTENTIALLY', 'PROVIDES', 'LOWER', 'CREDIT', 'RISK.', 'DIRECT', 'PLAN', '-', 'IDCW', '(PAYOUT/REINVESTMENT)', '`', '10.7408', 'THE', 'FUND', 'IS', 'SUITABLE', 'FOR', 'INVESTORS', 'WHO', 'HAVE', 'A', '“MEDIUM-', 'TERM', 'INVESTMENT', 'HORIZON”', 'OF', '3-4YEARS', '&', 'HAVING', 'DATE', 'OF', 'ALLOTMENT:', 'AUGUST', '22,', '2022', 'RELATIVELY', '“LOW', 'TO', 'MEDIUM', 'RISK', 'APPET ...

# %%
############ Code to save screenshot of right_half of every page that contains rating table ################
import os
from pdf2image import convert_from_path
import cv2
import numpy as np

fund_list = [
"OVERNIGHT FUND (CROF)",
"LIQUID FUND (CRL)",
"ULTRA SHORT TERM FUND (CRUSTF)",
"SAVINGS FUND (CRSF)",
"SHORT DURATION FUND (CRSDF)",
"INCOME FUND (CRINC)",
"DYNAMIC BOND FUND (CRDBF)",
"CORPORATE BOND FUND (CRCBF)",
"GILT FUND (CRGILT)",
"BANKING AND PSU DEBT FUND (CRBPDF)"
]

# === Configuration ===
pdf_path = output_pdf_path  # Replace with your actual PDF file path
output_dir = "right_half_screenshots_CANARA_ROBECO\\{}".format(month_name)
# top_strip_dir = "top_strip_screenshots_bandhan"  # <== NEW FOLDER
os.makedirs(output_dir, exist_ok=True)
# os.makedirs(top_strip_dir, exist_ok=True)

# === Step 1: Convert PDF pages to images ===
images = convert_from_path(pdf_path, dpi=300)  # Use high DPI for better clarity

# === Step 2: Crop right half and save ===
for idx, pil_image in enumerate(images):
    # Convert PIL to OpenCV (BGR)
    image = np.array(pil_image)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    # Get dimensions
    height, width, _ = image.shape


    # Crop right half (60% to 100%)
    x_start = int(0.345 * width)
    y_start = int(0.01 * height)  # 15% from top
    right_half = image[y_start:, x_start:]
    # right_half = image[:, x_start:]

    # Save cropped image
    fund_name = fund_list[idx]
    print(fund_name)
    # output_path = os.path.join(output_dir, f"{fund_name}_page_{idx+1}_right_half.png")
    output_path = os.path.join(output_dir, f"{fund_name}_page_{idx+1}_right_half.png")
    cv2.imwrite(output_path, right_half)

    print(f"✅ Saved: {output_path}")

print("\n✅ All screenshots of right half completed.")
# Out:
# OVERNIGHT FUND (CROF)
# ✅ Saved: right_half_screenshots_CANARA_ROBECO\June\OVERNIGHT FUND (CROF)_page_1_right_half.png
# LIQUID FUND (CRL)
# ✅ Saved: right_half_screenshots_CANARA_ROBECO\June\LIQUID FUND (CRL)_page_2_right_half.png
# ULTRA SHORT TERM FUND (CRUSTF)
# ✅ Saved: right_half_screenshots_CANARA_ROBECO\June\ULTRA SHORT TERM FUND (CRUSTF)_page_3_right_half.png
# SAVINGS FUND (CRSF)
# ✅ Saved: right_half_screenshots_CANARA_ROBECO\June\SAVINGS FUND (CRSF)_page_4_right_half.png
# SHORT DURATION FUND (CRSDF)
# ✅ Saved: right_half_screenshots_CANARA_ROBECO\June\SHORT DURATION FUND (CRSDF)_page_5_right_half.png
# INCOME FUND (CRINC)
# ✅ Saved: right_half_screenshots_CANARA_ROBECO\June\INCOME FUND (CRINC)_page_6_right_half.png
# DYNAMIC BOND FUND (CRDBF)
# ✅ Saved: right_half_screenshots_CANARA_ROBECO\June\DYNAMIC BOND FUND (CRDBF)_page_7_right_half.png
# CORPORATE BOND FUND (CRCBF)
# ✅ Saved: right_half_screenshots_CANARA_ROBECO\June\CORPORATE BOND FUND (CRCBF)_page_8_right_half.png
# GILT FUND (CRGILT)
# ✅ Saved: right_half_screenshots_CANARA_ROBECO\June\GILT FUND (CRGILT)_page_9_right_half.png
# BANKING AND PSU DEBT FUND (CRBPDF)
# ✅ Saved: right_half_screenshots_CANARA_ROBECO\June\BANKING AND PSU DEBT FUND (CRBPDF)_page_10_right_half.png
#
# ✅ All screenshots of right half completed.

# %%
import cv2
import numpy as np
import pytesseract
from PIL import Image
import os
import re

rating_set = set()
# Set Tesseract path (update for your system)
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'
pan = 'AAATC3901G'
mutual_fund = "CANARA ROBECO MUTUAL FUND"
pattern = re.compile(r"(AAA\(SO\)|AAA\(CE\)|AA\(CE\)|A1\+|AA\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)")
agencies = ["CARE", "IND", "CRISIL", "ICRA", "FITCH", "India Ratings", "Brickwork", "Acuite"]


agency_pattern = re.compile(rf"({'|'.join(agencies)})")


def normalize_rating_text(text):
    replacements = {
        "＋": "+",  # fullwidth plus
        "–": "-",  # en dash
        "−": "-",  # minus
        "﹣": "-",  # small hyphen
        "‒": "-",  # figure dash
        "―": "-",  # horizontal bar
        "（": "(",  # fullwidth left parenthesis
        "）": ")",  # fullwidth right parenthesis
    }
    for bad, good in replacements.items():
        text = text.replace(bad, good)

    # Remove zero-width and non-breaking spaces
    text = re.sub(r"[\u200B-\u200D\uFEFF\u00A0]", "", text)
    return text

def agency_matching(normalized_text, agency=''):
    agency_match = agency_pattern.search(normalized_text.replace("INDIA", ""))
    if agency_match:
        agency = agency_match.group(1)
        print("agency:", agency)
        normalized_text = normalized_text.replace(agency, " ").replace("( )", " ")
        print("agency_replaced_normalised_text :", normalized_text)
    return [normalized_text, agency]

def rating_matching(normalized_text, rating=''):
    match = pattern.search(normalized_text)
    # print(f"Line: {normalized_text}")
    if match:
        rating = match.group(0)
        print(f"Rating: {rating}\n")
        normalized_text = normalized_text.replace(rating, " ")
        print("rating_replaced_normalised_text :", normalized_text)
    return [normalized_text, rating]

def AUM_matching(normalized_text, total_AUM=''):
    match_AUM = re.findall(r"\d+\.\d+", normalized_text)

    # If found, return the last one (but not if it's at start)
    if match_AUM:
        last = match_AUM[-1]
        # check position of last match
        m = re.finditer(r"\d+\.\d+", normalized_text)
        last_match = list(m)[-1]
        if last_match.start() == 0:
            total_AUM = None  # ignore if at start
        else:
            total_AUM = last
            # total_AUM = match_AUM[-1]
            print(f"Total AUM: {total_AUM}\n")
            normalized_text = normalized_text.replace(total_AUM, "")
            print("AUM_replaced_normalised_text :", normalized_text)
    return [normalized_text, total_AUM]

# %%
import cv2
import pytesseract
from PIL import Image
import os
import pandas as pd

# OPTIONAL (Windows only): specify path to tesseract.exe
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'
input_dir = output_dir
# output_dir = "final_images"
# os.makedirs(output_dir, exist_ok=True)
correct_rating_df = pd.DataFrame(columns=['Pan', 'ISIN No.', 'Mutual Fund', 'Fund Name','Fund Type', 'Portfolio', "Agency", 'Ratings', "Category", '(%) Of Total AUM', "Factsheet Date", "URL", 'Filename'])

for filename in os.listdir(input_dir):
    print("---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------")
    if filename.endswith(".png"):
        start_printing = False
        image_path = os.path.join(input_dir, filename)
        print(image_path)
        image = cv2.imread(image_path)
        # Load image using OpenCV
        # image = cv2.imread(r"D:\Nexensus_Projects\pdfEtraction\LIC\right_half_screenshots_bandhan\page_2_right_half.png")

        # Convert to grayscale for better OCR

        scale_percent = 200
        width = int(image.shape[1] * scale_percent / 100)
        height = int(image.shape[0] * scale_percent / 100)
        dim = (width, height)

        # Resize image
        image = cv2.resize(image, dim, interpolation=cv2.INTER_LINEAR)
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # (Optional) Apply thresholding for better results
        # gray = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

        # Save preprocessed image temporarily (optional)
        cv2.imwrite("temp_gray.png", gray)

        # Extract text
        text = pytesseract.image_to_string(Image.open("temp_gray.png"))
        # print(text)
        if "name of the instruments rating % to nav" not in text.lower():
            print("not here")
            text = pytesseract.image_to_string(cv2.imread(image_path))
        for line in text.split("\n"):
            # print(line)
            # line = line.strip()
            if line:
                # print(line)
                agency = ""
                rating = ""
                portfolio = ""
                total_AUM = ''
                # if "PORTFOLIO" in line or "Rating" in line or line.startswith("There is") or line is None:
                #     continue
                # elif line[0].islower() and len(line) > 60:
                #     # print("skipping ",line )
                #     continue
                if "Name of the Instruments"  in line:
                    start_printing = True
                    continue
                if  line.strip() == "—_" or line.strip() == "°" or line.strip() == "is)" or re.fullmatch(r"\d+", line.strip()):
                    continue
                # if "Grand Total" in line and start_printing:
                if "Other Current Assets" in line:
                    print(line)
                    normalized_text = normalize_rating_text(line)

                    AUM_matching_output = AUM_matching(normalized_text)
                    normalized_text = AUM_matching_output[0]
                    total_AUM = AUM_matching_output[1]

                    temp_df = pd.DataFrame([{
                    "Pan" : pan,
                    "ISIN No." : None,
                    "Mutual Fund" : mutual_fund,
                    "Fund Name" : "CANARA ROBECO " + filename.split("_page")[0].replace("_", " "),
                    "Fund Type" : filename.split("_page")[0].replace("_", " "),
                    "Portfolio"  : normalized_text,
                    "Agency" : None,
                    "Ratings" : None,
                    "Category" : None,
                    "(%) Of Total AUM" : total_AUM,
                    "Factsheet Date" : None,
                    "URL" : None,
                    "Filename" : filename,
                    }])
                    correct_rating_df = pd.concat([correct_rating_df, temp_df])

                    ############# Manually adding Grand total row ##############################
                    temp_df = pd.DataFrame([{
                    "Pan" : pan,
                    "ISIN No." : None,
                    "Mutual Fund" : mutual_fund,
                    "Fund Name" : "CANARA ROBECO " + filename.split("_page")[0].replace("_", " "),
                    "Fund Type" : filename.split("_page")[0].replace("_", " "),
                    "Portfolio"  : "Grand Total ( Net Asset)",
                    "Agency" : None,
                    "Ratings" : None,
                    "Category" : None,
                    "(%) Of Total AUM" : "100.00",
                    "Factsheet Date" : None,
                    "URL" : None,
                    "Filename" : filename,
                    }])
                    correct_rating_df = pd.concat([correct_rating_df, temp_df])
                    break
                # elif "SCHEME" in line:
                #     break
                elif start_printing:
                    print("else block", line)
                    normalized_text = normalize_rating_text(line)

                    agency_matching_output = agency_matching(normalized_text)
                    normalized_text = agency_matching_output[0]
                    agency = agency_matching_output[1]


                    rating_matching_output = rating_matching(normalized_text)
                    normalized_text = rating_matching_output[0]
                    rating = rating_matching_output[1]

                    AUM_matching_output = AUM_matching(normalized_text)
                    normalized_text = AUM_matching_output[0]
                    total_AUM = AUM_matching_output[1]

                    temp_df = pd.DataFrame([{
                    "Pan" : pan,
                    "ISIN No." : None,
                    "Mutual Fund" : mutual_fund,
                    "Fund Name" : "CANARA ROBECO " + filename.split("_page")[0].replace("_", " "),
                    "Fund Type" : filename.split("_page")[0].replace("_", " "),
                    "Portfolio"  : normalized_text,
                    "Agency" : agency,
                    "Ratings" : rating,
                    "Category" : None,
                    "(%) Of Total AUM" : total_AUM,
                    "Factsheet Date" : None,
                    "URL" : None,
                    "Filename" : filename,
                    }])
                    correct_rating_df = pd.concat([correct_rating_df, temp_df])

                print(",,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,")
# Out:
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# right_half_screenshots_CANARA_ROBECO\June\BANKING AND PSU DEBT FUND (CRBPDF)_page_10_right_half.png
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Debt Instruments 64.45
# Total AUM: 64.45
#
# AUM_replaced_normalised_text : Debt Instruments
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block REC Ltd AAA(CRISIL) 8.78
# agency: CRISIL
# agency_replaced_normalised_text : REC Ltd AAA  8.78
# Rating: AAA
#
# rating_replaced_normalised_text : REC Ltd    8.78
# Total AUM: 8.78
#
# AUM_replaced_normalised_text : REC Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block HDFC Bank Ltd AAA(CRISIL) 6.82
# agency: CRISIL
# agency_replaced_normalised_text : HDFC Bank Ltd AAA  6.82
# Rating: AAA
#
# rating_replaced_normalised_text : HDFC Bank Ltd    6.82
# Total AUM: 6.82
#
# AUM_replaced_normalised_text : HDFC Bank Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Indian Railway Finance Corporation Ltd AAA(CRISIL) 6.81
# agency: CRISIL
# agency_replaced_normalised_text : Indian Railway Finance Corporation Ltd AAA  6.81
# Rating: AAA
#
# rating_replaced_normalised_text : Indian Railway Finance Corporation Ltd    6.81
# Total AUM: 6.81
#
# AUM_replaced_normalised_text : Indian Railway Finance Corporation Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block LIC Housing Finance Ltd AAA(CRISIL) 6.70
# agency: CRISIL
# agency_replaced_normalised_text : LIC Housing Finance Ltd AAA  6.70
# Rating: AAA
#
# rating_replaced_normalised_text : LIC Housing Finance Ltd    6.70
# Total AUM: 6.70
#
# AUM_replaced_normalised_text : LIC Housing Finance Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block NHPC Ltd AAA(CARE) 6.61
# agency: CARE
# agency_replaced_normalised_text : NHPC Ltd AAA  6.61
# Rating: AAA
#
# rating_replaced_normalised_text : NHPC Ltd    6.61
# Total AUM: 6.61
#
# AUM_replaced_normalised_text : NHPC Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Small Industries Development Bank Of India AAA(CRISIL) 6.59
# agency: CRISIL
# agency_replaced_normalised_text : Small Industries Development Bank Of India AAA  6.59
# Rating: AAA
#
# rating_replaced_normalised_text : Small Industries Development Bank Of India    6.59
# Total AUM: 6.59
#
# AUM_replaced_normalised_text : Small Industries Development Bank Of India
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block National Bank For Agriculture & Rural Development AAA(ICRA) 6.55
# agency: ICRA
# agency_replaced_normalised_text : National Bank For Agriculture & Rural Development AAA  6.55
# Rating: AAA
#
# rating_replaced_normalised_text : National Bank For Agriculture & Rural Development    6.55
# Total AUM: 6.55
#
# AUM_replaced_normalised_text : National Bank For Agriculture & Rural Development
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Power Finance Corporation Ltd AAA(CRISIL) 4.52
# agency: CRISIL
# agency_replaced_normalised_text : Power Finance Corporation Ltd AAA  4.52
# Rating: AAA
#
# rating_replaced_normalised_text : Power Finance Corporation Ltd    4.52
# Total AUM: 4.52
#
# AUM_replaced_normalised_text : Power Finance Corporation Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block HDB Financial Services Ltd AAA(CRISIL) 4.40
# agency: CRISIL
# agency_replaced_normalised_text : HDB Financial Services Ltd AAA  4.40
# Rating: AAA
#
# rating_replaced_normalised_text : HDB Financial Services Ltd    4.40
# Total AUM: 4.40
#
# AUM_replaced_normalised_text : HDB Financial Services Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Power Finance Corporation Ltd AAA(CRISIL) 4.36
# agency: CRISIL
# agency_replaced_normalised_text : Power Finance Corporation Ltd AAA  4.36
# Rating: AAA
#
# rating_replaced_normalised_text : Power Finance Corporation Ltd    4.36
# Total AUM: 4.36
#
# AUM_replaced_normalised_text : Power Finance Corporation Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block HDFC Bank Ltd AAA(CRISIL) 2.31
# agency: CRISIL
# agency_replaced_normalised_text : HDFC Bank Ltd AAA  2.31
# Rating: AAA
#
# rating_replaced_normalised_text : HDFC Bank Ltd    2.31
# Total AUM: 2.31
#
# AUM_replaced_normalised_text : HDFC Bank Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Government Securities 9.12
# Total AUM: 9.12
#
# AUM_replaced_normalised_text : Government Securities
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.23% GOI 2039 (15-APR-2039) Sovereign 4.58
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.23% GOI 2039 (15-APR-2039)   4.58
# Total AUM: 4.58
#
# AUM_replaced_normalised_text : 7.23% GOI 2039 (15-APR-2039)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.18% GOI 2033 (14-AUG-2033) Sovereign 2.29
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.18% GOI 2033 (14-AUG-2033)   2.29
# Total AUM: 2.29
#
# AUM_replaced_normalised_text : 7.18% GOI 2033 (14-AUG-2033)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.30% GOI 2053 (19-JUN-2053) Sovereign 2.25
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.30% GOI 2053 (19-JUN-2053)   2.25
# Total AUM: 2.25
#
# AUM_replaced_normalised_text : 7.30% GOI 2053 (19-JUN-2053)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Alternative Investment Fund 0.52
# Total AUM: 0.52
#
# AUM_replaced_normalised_text : Alternative Investment Fund
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block CORPORATE DEBT MARKET DEVELOPMENT FUND CLASS A2 0.52
# Total AUM: 0.52
#
# AUM_replaced_normalised_text : CORPORATE DEBT MARKET DEVELOPMENT FUND CLASS A2
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Money Market Instruments 23.41
# Total AUM: 23.41
#
# AUM_replaced_normalised_text : Money Market Instruments
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Kotak Mahindra Bank Ltd A1+(CRISIL) 8.69
# agency: CRISIL
# agency_replaced_normalised_text : Kotak Mahindra Bank Ltd A1+  8.69
# Rating: A1+
#
# rating_replaced_normalised_text : Kotak Mahindra Bank Ltd    8.69
# Total AUM: 8.69
#
# AUM_replaced_normalised_text : Kotak Mahindra Bank Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block ICICI] Bank Ltd A1+(ICRA) 6.52
# agency: ICRA
# agency_replaced_normalised_text : ICICI] Bank Ltd A1+  6.52
# Rating: A1+
#
# rating_replaced_normalised_text : ICICI] Bank Ltd    6.52
# Total AUM: 6.52
#
# AUM_replaced_normalised_text : ICICI] Bank Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Punjab National Bank A1+(CARE) 4.18
# agency: CARE
# agency_replaced_normalised_text : Punjab National Bank A1+  4.18
# Rating: A1+
#
# rating_replaced_normalised_text : Punjab National Bank    4.18
# Total AUM: 4.18
#
# AUM_replaced_normalised_text : Punjab National Bank
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Treasury Bills 0.42
# Total AUM: 0.42
#
# AUM_replaced_normalised_text : Treasury Bills
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block TREPS 3.60
# Total AUM: 3.60
#
# AUM_replaced_normalised_text : TREPS
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# Other Current Assets 2.50
# Total AUM: 2.50
#
# AUM_replaced_normalised_text : Other Current Assets
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# right_half_screenshots_CANARA_ROBECO\June\CORPORATE BOND FUND (CRCBF)_page_8_right_half.png
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Debt Instruments 70.40
# Total AUM: 70.40
#
# AUM_replaced_normalised_text : Debt Instruments
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Power Finance Corporation Ltd AAA(CRISIL) 8.99
# agency: CRISIL
# agency_replaced_normalised_text : Power Finance Corporation Ltd AAA  8.99
# Rating: AAA
#
# rating_replaced_normalised_text : Power Finance Corporation Ltd    8.99
# Total AUM: 8.99
#
# AUM_replaced_normalised_text : Power Finance Corporation Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block LIC Housing Finance Ltd AAA(CRISIL) 8.83
# agency: CRISIL
# agency_replaced_normalised_text : LIC Housing Finance Ltd AAA  8.83
# Rating: AAA
#
# rating_replaced_normalised_text : LIC Housing Finance Ltd    8.83
# Total AUM: 8.83
#
# AUM_replaced_normalised_text : LIC Housing Finance Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Grasim industries Ltd AAA(CRISIL) 8.83
# agency: CRISIL
# agency_replaced_normalised_text : Grasim industries Ltd AAA  8.83
# Rating: AAA
#
# rating_replaced_normalised_text : Grasim industries Ltd    8.83
# Total AUM: 8.83
#
# AUM_replaced_normalised_text : Grasim industries Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Kotak Mahindra Prime Ltd AAA(CRISIL) 8.77
# agency: CRISIL
# agency_replaced_normalised_text : Kotak Mahindra Prime Ltd AAA  8.77
# Rating: AAA
#
# rating_replaced_normalised_text : Kotak Mahindra Prime Ltd    8.77
# Total AUM: 8.77
#
# AUM_replaced_normalised_text : Kotak Mahindra Prime Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block REC Ltd AAA(CRISIL) 8.71
# agency: CRISIL
# agency_replaced_normalised_text : REC Ltd AAA  8.71
# Rating: AAA
#
# rating_replaced_normalised_text : REC Ltd    8.71
# Total AUM: 8.71
#
# AUM_replaced_normalised_text : REC Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Small Industries Development Bank Of India AAA(CRISIL) 8.68
# agency: CRISIL
# agency_replaced_normalised_text : Small Industries Development Bank Of India AAA  8.68
# Rating: AAA
#
# rating_replaced_normalised_text : Small Industries Development Bank Of India    8.68
# Total AUM: 8.68
#
# AUM_replaced_normalised_text : Small Industries Development Bank Of India
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Indian Railway Finance Corporation Ltd AAA(CRISIL) 4.53
# agency: CRISIL
# agency_replaced_normalised_text : Indian Railway Finance Corporation Ltd AAA  4.53
# Rating: AAA
#
# rating_replaced_normalised_text : Indian Railway Finance Corporation Ltd    4.53
# Total AUM: 4.53
#
# AUM_replaced_normalised_text : Indian Railway Finance Corporation Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block National Bank For Agriculture & Rural Development AAA(CRISIL) 4.40
# agency: CRISIL
# agency_replaced_normalised_text : National Bank For Agriculture & Rural Development AAA  4.40
# Rating: AAA
#
# rating_replaced_normalised_text : National Bank For Agriculture & Rural Development    4.40
# Total AUM: 4.40
#
# AUM_replaced_normalised_text : National Bank For Agriculture & Rural Development
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block HDB Financial Services Ltd AAA(CARE) 4.33
# agency: CARE
# agency_replaced_normalised_text : HDB Financial Services Ltd AAA  4.33
# Rating: AAA
#
# rating_replaced_normalised_text : HDB Financial Services Ltd    4.33
# Total AUM: 4.33
#
# AUM_replaced_normalised_text : HDB Financial Services Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Bajaj Finance Ltd AAA(CRISIL) 4.33
# agency: CRISIL
# agency_replaced_normalised_text : Bajaj Finance Ltd AAA  4.33
# Rating: AAA
#
# rating_replaced_normalised_text : Bajaj Finance Ltd    4.33
# Total AUM: 4.33
#
# AUM_replaced_normalised_text : Bajaj Finance Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Government Securities 13.31
# Total AUM: 13.31
#
# AUM_replaced_normalised_text : Government Securities
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 6.79% GOI 2034 (07-OCT-2034) Sovereign 8.87
# Rating: Sovereign
#
# rating_replaced_normalised_text : 6.79% GOI 2034 (07-OCT-2034)   8.87
# Total AUM: 8.87
#
# AUM_replaced_normalised_text : 6.79% GOI 2034 (07-OCT-2034)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 6.79% GOI 2031 (30-DEC-2031) Sovereign 4.44
# Rating: Sovereign
#
# rating_replaced_normalised_text : 6.79% GOI 2031 (30-DEC-2031)   4.44
# Total AUM: 4.44
#
# AUM_replaced_normalised_text : 6.79% GOI 2031 (30-DEC-2031)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Alternative Investment Fund 0.47
# Total AUM: 0.47
#
# AUM_replaced_normalised_text : Alternative Investment Fund
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block CORPORATE DEBT MARKET DEVELOPMENT FUND CLASS A2 0.47
# Total AUM: 0.47
#
# AUM_replaced_normalised_text : CORPORATE DEBT MARKET DEVELOPMENT FUND CLASS A2
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Money Market Instruments 12.92
# Total AUM: 12.92
#
# AUM_replaced_normalised_text : Money Market Instruments
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Treasury Bills 0.84
# Total AUM: 0.84
#
# AUM_replaced_normalised_text : Treasury Bills
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block TREPS 12.08
# Total AUM: 12.08
#
# AUM_replaced_normalised_text : TREPS
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# Other Current Assets 2.90
# Total AUM: 2.90
#
# AUM_replaced_normalised_text : Other Current Assets
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# right_half_screenshots_CANARA_ROBECO\June\DYNAMIC BOND FUND (CRDBF)_page_7_right_half.png
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Government Securities 94.12
# Total AUM: 94.12
#
# AUM_replaced_normalised_text : Government Securities
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 6.92% GOI 2039 (18-NOV-2039) Sovereign 18.51
# Rating: Sovereign
#
# rating_replaced_normalised_text : 6.92% GOI 2039 (18-NOV-2039)   18.51
# Total AUM: 18.51
#
# AUM_replaced_normalised_text : 6.92% GOI 2039 (18-NOV-2039)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.18% GOI 2037 (24-JUL-2037) Sovereign 15.32
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.18% GOI 2037 (24-JUL-2037)   15.32
# Total AUM: 15.32
#
# AUM_replaced_normalised_text : 7.18% GOI 2037 (24-JUL-2037)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.34% GOI 2064 (22-APR-2064) Sovereign 14.50
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.34% GOI 2064 (22-APR-2064)   14.50
# Total AUM: 14.50
#
# AUM_replaced_normalised_text : 7.34% GOI 2064 (22-APR-2064)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.30% GOI 2053 (19-JUN-2053) Sovereign 13.68
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.30% GOI 2053 (19-JUN-2053)   13.68
# Total AUM: 13.68
#
# AUM_replaced_normalised_text : 7.30% GOI 2053 (19-JUN-2053)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 6.63% TAMIL NADU SDL 23-DEC-35 Sovereign 11.90
# Rating: Sovereign
#
# rating_replaced_normalised_text : 6.63% TAMIL NADU SDL 23-DEC-35   11.90
# Total AUM: 11.90
#
# AUM_replaced_normalised_text : 6.63% TAMIL NADU SDL 23-DEC-35
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 6.33% GOI 2035 (05-MAY-2035) Sovereign 8.05
# Rating: Sovereign
#
# rating_replaced_normalised_text : 6.33% GOI 2035 (05-MAY-2035)   8.05
# Total AUM: 8.05
#
# AUM_replaced_normalised_text : 6.33% GOI 2035 (05-MAY-2035)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.23% GOI 2039 (15-APR-2039) Sovereign 5.06
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.23% GOI 2039 (15-APR-2039)   5.06
# Total AUM: 5.06
#
# AUM_replaced_normalised_text : 7.23% GOI 2039 (15-APR-2039)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.32% GOI 2030 (13-NOV-2030) Sovereign 4.24
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.32% GOI 2030 (13-NOV-2030)   4.24
# Total AUM: 4.24
#
# AUM_replaced_normalised_text : 7.32% GOI 2030 (13-NOV-2030)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.38% GOI 2027 (20-JUN-2027) Sovereign 2.07
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.38% GOI 2027 (20-JUN-2027)   2.07
# Total AUM: 2.07
#
# AUM_replaced_normalised_text : 7.38% GOI 2027 (20-JUN-2027)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.17% GOI 2030 (17-APR-2030) Sovereign 0.60
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.17% GOI 2030 (17-APR-2030)   0.60
# Total AUM: 0.60
#
# AUM_replaced_normalised_text : 7.17% GOI 2030 (17-APR-2030)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 6.68% GOI 2031 (17-SEP-2031) Sovereign 0.19
# Rating: Sovereign
#
# rating_replaced_normalised_text : 6.68% GOI 2031 (17-SEP-2031)   0.19
# Total AUM: 0.19
#
# AUM_replaced_normalised_text : 6.68% GOI 2031 (17-SEP-2031)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Alternative Investment Fund 0.28
# Total AUM: 0.28
#
# AUM_replaced_normalised_text : Alternative Investment Fund
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block CORPORATE DEBT MARKET DEVELOPMENT FUND CLASS A2 0.28
# Total AUM: 0.28
#
# AUM_replaced_normalised_text : CORPORATE DEBT MARKET DEVELOPMENT FUND CLASS A2
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Money Market Instruments 4.22
# Total AUM: 4.22
#
# AUM_replaced_normalised_text : Money Market Instruments
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block TREPS 4.22
# Total AUM: 4.22
#
# AUM_replaced_normalised_text : TREPS
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# Other Current Assets 1.38
# Total AUM: 1.38
#
# AUM_replaced_normalised_text : Other Current Assets
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# right_half_screenshots_CANARA_ROBECO\June\GILT FUND (CRGILT)_page_9_right_half.png
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Government Securities 90.82
# Total AUM: 90.82
#
# AUM_replaced_normalised_text : Government Securities
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.34% GOI 2064 (22-APR-2064) Sovereign 31.12
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.34% GOI 2064 (22-APR-2064)   31.12
# Total AUM: 31.12
#
# AUM_replaced_normalised_text : 7.34% GOI 2064 (22-APR-2064)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 6.92% GOI 2039 (18-NOV-2039) Sovereign 17.89
# Rating: Sovereign
#
# rating_replaced_normalised_text : 6.92% GOI 2039 (18-NOV-2039)   17.89
# Total AUM: 17.89
#
# AUM_replaced_normalised_text : 6.92% GOI 2039 (18-NOV-2039)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.32% GOI 2030 (13-NOV-2030) Sovereign 13.40
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.32% GOI 2030 (13-NOV-2030)   13.40
# Total AUM: 13.40
#
# AUM_replaced_normalised_text : 7.32% GOI 2030 (13-NOV-2030)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 6.33% GOI 2035 (05-MAY-2035) Sovereign 9.55
# Rating: Sovereign
#
# rating_replaced_normalised_text : 6.33% GOI 2035 (05-MAY-2035)   9.55
# Total AUM: 9.55
#
# AUM_replaced_normalised_text : 6.33% GOI 2035 (05-MAY-2035)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.23% GOI 2039 (15-APR-2039) Sovereign 6.01
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.23% GOI 2039 (15-APR-2039)   6.01
# Total AUM: 6.01
#
# AUM_replaced_normalised_text : 7.23% GOI 2039 (15-APR-2039)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.30% GOI 2053 (19-JUN-2053) Sovereign 5.57
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.30% GOI 2053 (19-JUN-2053)   5.57
# Total AUM: 5.57
#
# AUM_replaced_normalised_text : 7.30% GOI 2053 (19-JUN-2053)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.18% GOI 2037 (24-JUL-2037) Sovereign 4.51
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.18% GOI 2037 (24-JUL-2037)   4.51
# Total AUM: 4.51
#
# AUM_replaced_normalised_text : 7.18% GOI 2037 (24-JUL-2037)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.38% GOI 2027 (20-JUN-2027) Sovereign 1.64
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.38% GOI 2027 (20-JUN-2027)   1.64
# Total AUM: 1.64
#
# AUM_replaced_normalised_text : 7.38% GOI 2027 (20-JUN-2027)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.17% GOI 2030 (17-APR-2030) Sovereign 1.06
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.17% GOI 2030 (17-APR-2030)   1.06
# Total AUM: 1.06
#
# AUM_replaced_normalised_text : 7.17% GOI 2030 (17-APR-2030)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 8.13% GO! 2045 (22-JUN-2045) Sovereign 0.07
# Rating: Sovereign
#
# rating_replaced_normalised_text : 8.13% GO! 2045 (22-JUN-2045)   0.07
# Total AUM: 0.07
#
# AUM_replaced_normalised_text : 8.13% GO! 2045 (22-JUN-2045)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Money Market Instruments 7.93
# Total AUM: 7.93
#
# AUM_replaced_normalised_text : Money Market Instruments
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block TREPS 7.93
# Total AUM: 7.93
#
# AUM_replaced_normalised_text : TREPS
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# Other Current Assets 1.25
# Total AUM: 1.25
#
# AUM_replaced_normalised_text : Other Current Assets
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# right_half_screenshots_CANARA_ROBECO\June\INCOME FUND (CRINC)_page_6_right_half.png
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Debt Instruments 7.96
# Total AUM: 7.96
#
# AUM_replaced_normalised_text : Debt Instruments
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Bajaj Finance Ltd AAA(CRISIL) 7.96
# agency: CRISIL
# agency_replaced_normalised_text : Bajaj Finance Ltd AAA  7.96
# Rating: AAA
#
# rating_replaced_normalised_text : Bajaj Finance Ltd    7.96
# Total AUM: 7.96
#
# AUM_replaced_normalised_text : Bajaj Finance Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Government Securities 78.24
# Total AUM: 78.24
#
# AUM_replaced_normalised_text : Government Securities
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block GOI FRB 2034 (30-OCT-2034) Sovereign 20.31
# Rating: Sovereign
#
# rating_replaced_normalised_text : GOI FRB 2034 (30-OCT-2034)   20.31
# Total AUM: 20.31
#
# AUM_replaced_normalised_text : GOI FRB 2034 (30-OCT-2034)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.73% GUJARAT SDL 08-APR-29 Sovereign 12.47
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.73% GUJARAT SDL 08-APR-29   12.47
# Total AUM: 12.47
#
# AUM_replaced_normalised_text : 7.73% GUJARAT SDL 08-APR-29
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 8.14% GUJARAT SDL 20-MAR-29 Sovereign 8.41
# Rating: Sovereign
#
# rating_replaced_normalised_text : 8.14% GUJARAT SDL 20-MAR-29   8.41
# Total AUM: 8.41
#
# AUM_replaced_normalised_text : 8.14% GUJARAT SDL 20-MAR-29
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 8.19% KARNATAKA SDL 23-JAN-29 Sovereign 8.41
# Rating: Sovereign
#
# rating_replaced_normalised_text : 8.19% KARNATAKA SDL 23-JAN-29   8.41
# Total AUM: 8.41
#
# AUM_replaced_normalised_text : 8.19% KARNATAKA SDL 23-JAN-29
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block GOI FRB 2031 (07-DEC-2031) Sovereign 8.14
# Rating: Sovereign
#
# rating_replaced_normalised_text : GOI FRB 2031 (07-DEC-2031)   8.14
# Total AUM: 8.14
#
# AUM_replaced_normalised_text : GOI FRB 2031 (07-DEC-2031)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.02% KERALA SDL 03-MAR-28 Sovereign 8.12
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.02% KERALA SDL 03-MAR-28   8.12
# Total AUM: 8.12
#
# AUM_replaced_normalised_text : 7.02% KERALA SDL 03-MAR-28
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.30% GOI 2053 (19-JUN-2053) Sovereign 4.10
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.30% GOI 2053 (19-JUN-2053)   4.10
# Total AUM: 4.10
#
# AUM_replaced_normalised_text : 7.30% GOI 2053 (19-JUN-2053)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 6.79% GOI 2031 (30-DEC-2031) Sovereign 4.09
# Rating: Sovereign
#
# rating_replaced_normalised_text : 6.79% GOI 2031 (30-DEC-2031)   4.09
# Total AUM: 4.09
#
# AUM_replaced_normalised_text : 6.79% GOI 2031 (30-DEC-2031)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 6.53% TAMIL NADU SDL 06-JAN-31 Sovereign 3.96
# Rating: Sovereign
#
# rating_replaced_normalised_text : 6.53% TAMIL NADU SDL 06-JAN-31   3.96
# Total AUM: 3.96
#
# AUM_replaced_normalised_text : 6.53% TAMIL NADU SDL 06-JAN-31
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 8.47% MAHARASHTRA SDL 10-FEB-26 Sovereign 0.23
# Rating: Sovereign
#
# rating_replaced_normalised_text : 8.47% MAHARASHTRA SDL 10-FEB-26   0.23
# Total AUM: 0.23
#
# AUM_replaced_normalised_text : 8.47% MAHARASHTRA SDL 10-FEB-26
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Alternative Investment Fund 0.28
# Total AUM: 0.28
#
# AUM_replaced_normalised_text : Alternative Investment Fund
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block CORPORATE DEBT MARKET DEVELOPMENT FUND CLASS A2 0.28
# Total AUM: 0.28
#
# AUM_replaced_normalised_text : CORPORATE DEBT MARKET DEVELOPMENT FUND CLASS A2
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Money Market Instruments 11.74
# Total AUM: 11.74
#
# AUM_replaced_normalised_text : Money Market Instruments
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Treasury Bills 0.77
# Total AUM: 0.77
#
# AUM_replaced_normalised_text : Treasury Bills
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block TREPS 10.97
# Total AUM: 10.97
#
# AUM_replaced_normalised_text : TREPS
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# Other Current Assets 1.78
# Total AUM: 1.78
#
# AUM_replaced_normalised_text : Other Current Assets
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# right_half_screenshots_CANARA_ROBECO\June\LIQUID FUND (CRL)_page_2_right_half.png
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ...
# Rating: Sovereign
#
# rating_replaced_normalised_text : 8.37% TAMIL NADU SDL 05-DEC-28   5.74
# Total AUM: 5.74
#
# AUM_replaced_normalised_text : 8.37% TAMIL NADU SDL 05-DEC-28
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.10% GOI 2034 (08-APR-2034) Sovereign 4.49
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.10% GOI 2034 (08-APR-2034)   4.49
# Total AUM: 4.49
#
# AUM_replaced_normalised_text : 7.10% GOI 2034 (08-APR-2034)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.18% GOI 2037 (24-JUL-2037) Sovereign 4.49
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.18% GOI 2037 (24-JUL-2037)   4.49
# Total AUM: 4.49
#
# AUM_replaced_normalised_text : 7.18% GOI 2037 (24-JUL-2037)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.32% GOI 2030 (13-NOV-2030) Sovereign 3.39
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.32% GOI 2030 (13-NOV-2030)   3.39
# Total AUM: 3.39
#
# AUM_replaced_normalised_text : 7.32% GOI 2030 (13-NOV-2030)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block 7.86% KARNATAKA SDL 15-MAR-27 Sovereign 0.06
# Rating: Sovereign
#
# rating_replaced_normalised_text : 7.86% KARNATAKA SDL 15-MAR-27   0.06
# Total AUM: 0.06
#
# AUM_replaced_normalised_text : 7.86% KARNATAKA SDL 15-MAR-27
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Alternative Investment Fund 0.33
# Total AUM: 0.33
#
# AUM_replaced_normalised_text : Alternative Investment Fund
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block CORPORATE DEBT MARKET DEVELOPMENT FUND CLASS A2 0.33
# Total AUM: 0.33
#
# AUM_replaced_normalised_text : CORPORATE DEBT MARKET DEVELOPMENT FUND CLASS A2
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Money Market Instruments 16.07
# Total AUM: 16.07
#
# AUM_replaced_normalised_text : Money Market Instruments
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Union Bank of India A1+(IND) 5.05
# agency: IND
# agency_replaced_normalised_text : Union Bank of India A1+  5.05
# Rating: A1+
#
# rating_replaced_normalised_text : Union Bank of India    5.05
# Total AUM: 5.05
#
# AUM_replaced_normalised_text : Union Bank of India
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Punjab National Bank A1+(CARE) 3.09
# agency: CARE
# agency_replaced_normalised_text : Punjab National Bank A1+  3.09
# Rating: A1+
#
# rating_replaced_normalised_text : Punjab National Bank    3.09
# Total AUM: 3.09
#
# AUM_replaced_normalised_text : Punjab National Bank
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block ICICI Bank Ltd A1+(ICRA) 2.14
# agency: ICRA
# agency_replaced_normalised_text : ICICI Bank Ltd A1+  2.14
# Rating: A1+
#
# rating_replaced_normalised_text : ICICI Bank Ltd    2.14
# Total AUM: 2.14
#
# AUM_replaced_normalised_text : ICICI Bank Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block LIC Housing Finance Ltd A1+(CRISIL) 1.03
# agency: CRISIL
# agency_replaced_normalised_text : LIC Housing Finance Ltd A1+  1.03
# Rating: A1+
#
# rating_replaced_normalised_text : LIC Housing Finance Ltd    1.03
# Total AUM: 1.03
#
# AUM_replaced_normalised_text : LIC Housing Finance Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Treasury Bills 0.42
# Total AUM: 0.42
#
# AUM_replaced_normalised_text : Treasury Bills
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block TREPS 4.34
# Total AUM: 4.34
#
# AUM_replaced_normalised_text : TREPS
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# Other Current Assets 2.03
# Total AUM: 2.03
#
# AUM_replaced_normalised_text : Other Current Assets
# ---------------------------------------------------------->>>>>>>>>>>>>>>>>>>>>>>>--------------------------------------------------------------
# right_half_screenshots_CANARA_ROBECO\June\ULTRA SHORT TERM FUND (CRUSTF)_page_3_right_half.png
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Debt Instruments 12.08
# Total AUM: 12.08
#
# AUM_replaced_normalised_text : Debt Instruments
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Bajaj Housing Finance Ltd AAA(CRISIL) 4.32
# agency: CRISIL
# agency_replaced_normalised_text : Bajaj Housing Finance Ltd AAA  4.32
# Rating: AAA
#
# rating_replaced_normalised_text : Bajaj Housing Finance Ltd    4.32
# Total AUM: 4.32
#
# AUM_replaced_normalised_text : Bajaj Housing Finance Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Bajaj Housing Finance Ltd AAA(CRISIL) 4.31
# agency: CRISIL
# agency_replaced_normalised_text : Bajaj Housing Finance Ltd AAA  4.31
# Rating: AAA
#
# rating_replaced_normalised_text : Bajaj Housing Finance Ltd    4.31
# Total AUM: 4.31
#
# AUM_replaced_normalised_text : Bajaj Housing Finance Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block LIC Housing Finance Ltd AAA(CRISIL) 3.45
# agency: CRISIL
# agency_replaced_normalised_text : LIC Housing Finance Ltd AAA  3.45
# Rating: AAA
#
# rating_replaced_normalised_text : LIC Housing Finance Ltd    3.45
# Total AUM: 3.45
#
# AUM_replaced_normalised_text : LIC Housing Finance Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Government Securities 0.89
# Total AUM: 0.89
#
# AUM_replaced_normalised_text : Government Securities
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block GOI FRB 2033 (22-SEP-2033) Sovereign 0.89
# Rating: Sovereign
#
# rating_replaced_normalised_text : GOI FRB 2033 (22-SEP-2033)   0.89
# Total AUM: 0.89
#
# AUM_replaced_normalised_text : GOI FRB 2033 (22-SEP-2033)
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Alternative Investment Fund 0.29
# Total AUM: 0.29
#
# AUM_replaced_normalised_text : Alternative Investment Fund
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block CORPORATE DEBT MARKET DEVELOPMENT FUND CLASS A2 0.29
# Total AUM: 0.29
#
# AUM_replaced_normalised_text : CORPORATE DEBT MARKET DEVELOPMENT FUND CLASS A2
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Money Market Instruments 89.80
# Total AUM: 89.80
#
# AUM_replaced_normalised_text : Money Market Instruments
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block ICICI Bank Ltd A1+(ICRA) 8.38
# agency: ICRA
# agency_replaced_normalised_text : ICICI Bank Ltd A1+  8.38
# Rating: A1+
#
# rating_replaced_normalised_text : ICICI Bank Ltd    8.38
# Total AUM: 8.38
#
# AUM_replaced_normalised_text : ICICI Bank Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Export-Import Bank Of India A1+(CRISIL) 8.38
# agency: CRISIL
# agency_replaced_normalised_text : Export-Import Bank Of India A1+  8.38
# Rating: A1+
#
# rating_replaced_normalised_text : Export-Import Bank Of India    8.38
# Total AUM: 8.38
#
# AUM_replaced_normalised_text : Export-Import Bank Of India
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Kotak Mahindra Bank Ltd A1+(CRISIL) 8.35
# agency: CRISIL
# agency_replaced_normalised_text : Kotak Mahindra Bank Ltd A1+  8.35
# Rating: A1+
#
# rating_replaced_normalised_text : Kotak Mahindra Bank Ltd    8.35
# Total AUM: 8.35
#
# AUM_replaced_normalised_text : Kotak Mahindra Bank Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Small Industries Development Bank of India A1+(CARE) 8.35
# agency: CARE
# agency_replaced_normalised_text : Small Industries Development Bank of India A1+  8.35
# Rating: A1+
#
# rating_replaced_normalised_text : Small Industries Development Bank of India    8.35
# Total AUM: 8.35
#
# AUM_replaced_normalised_text : Small Industries Development Bank of India
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Axis Bank Ltd A1+(CRISIL) 4.24
# agency: CRISIL
# agency_replaced_normalised_text : Axis Bank Ltd A1+  4.24
# Rating: A1+
#
# rating_replaced_normalised_text : Axis Bank Ltd    4.24
# Total AUM: 4.24
#
# AUM_replaced_normalised_text : Axis Bank Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block HDFC Bank Ltd A1+(CARE) 4.24
# agency: CARE
# agency_replaced_normalised_text : HDFC Bank Ltd A1+  4.24
# Rating: A1+
#
# rating_replaced_normalised_text : HDFC Bank Ltd    4.24
# Total AUM: 4.24
#
# AUM_replaced_normalised_text : HDFC Bank Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Union Bank of India A1+(ICRA) 4.23
# agency: ICRA
# agency_replaced_normalised_text : Union Bank of India A1+  4.23
# Rating: A1+
#
# rating_replaced_normalised_text : Union Bank of India    4.23
# Total AUM: 4.23
#
# AUM_replaced_normalised_text : Union Bank of India
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Aditya Birla Capital Ltd A1+(ICRA) 4.23
# agency: ICRA
# agency_replaced_normalised_text : Aditya Birla Capital Ltd A1+  4.23
# Rating: A1+
#
# rating_replaced_normalised_text : Aditya Birla Capital Ltd    4.23
# Total AUM: 4.23
#
# AUM_replaced_normalised_text : Aditya Birla Capital Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Union Bank of India A1+(IND) 4.17
# agency: IND
# agency_replaced_normalised_text : Union Bank of India A1+  4.17
# Rating: A1+
#
# rating_replaced_normalised_text : Union Bank of India    4.17
# Total AUM: 4.17
#
# AUM_replaced_normalised_text : Union Bank of India
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Axis Bank Ltd A1+(CRISIL) AN
# agency: CRISIL
# agency_replaced_normalised_text : Axis Bank Ltd A1+  AN
# Rating: A1+
#
# rating_replaced_normalised_text : Axis Bank Ltd    AN
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block HDFC Bank Ltd A1+(CARE) 4.11
# agency: CARE
# agency_replaced_normalised_text : HDFC Bank Ltd A1+  4.11
# Rating: A1+
#
# rating_replaced_normalised_text : HDFC Bank Ltd    4.11
# Total AUM: 4.11
#
# AUM_replaced_normalised_text : HDFC Bank Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Indian Bank A1+(CRISIL) AN
# agency: CRISIL
# agency_replaced_normalised_text : Indian Bank A1+  AN
# Rating: A1+
#
# rating_replaced_normalised_text : Indian Bank    AN
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block ICICI Securities Ltd A1+(CRISIL) AN
# agency: CRISIL
# agency_replaced_normalised_text : ICICI Securities Ltd A1+  AN
# Rating: A1+
#
# rating_replaced_normalised_text : ICICI Securities Ltd    AN
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block ICICI Securities Ltd A1+(CRISIL) 4.09
# agency: CRISIL
# agency_replaced_normalised_text : ICICI Securities Ltd A1+  4.09
# Rating: A1+
#
# rating_replaced_normalised_text : ICICI Securities Ltd    4.09
# Total AUM: 4.09
#
# AUM_replaced_normalised_text : ICICI Securities Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block LIC Housing Finance Ltd A1+(CRISIL) 3.28
# agency: CRISIL
# agency_replaced_normalised_text : LIC Housing Finance Ltd A1+  3.28
# Rating: A1+
#
# rating_replaced_normalised_text : LIC Housing Finance Ltd    3.28
# Total AUM: 3.28
#
# AUM_replaced_normalised_text : LIC Housing Finance Ltd
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block Treasury Bills 3.38
# Total AUM: 3.38
#
# AUM_replaced_normalised_text : Treasury Bills
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# else block TREPS 8.04
# Total AUM: 8.04
#
# AUM_replaced_normalised_text : TREPS
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# Other Current Assets -3.06
# Total AUM: 3.06
#
# AUM_replaced_normalised_text : Other Current Assets -

# %%
# Save correct_rating_df to Excel file with separate sheets for each 'fund'
output_excel = "output_data\\correct_rating_df_grouped_by_fund_CANARA_ROBECO_{}.xlsx".format(month_name)

with pd.ExcelWriter(output_excel, engine='openpyxl') as writer:
    for fund, group_df in correct_rating_df.groupby("Fund Name"):
        # Clean sheet name: max 31 characters, remove invalid characters
        sheet_name = str(fund).replace("CANARA ROBECO ", "").replace("CRISIL ", "").replace("IBX", "")[:31]
        invalid_chars = r'[:\\/?*[\]]'
        sheet_name = re.sub(invalid_chars, "_", sheet_name)

        print(f"Writing sheet: {sheet_name}")
        group_df.to_excel(writer, sheet_name=sheet_name, index=False)
        # group_df.drop(columns=["Fund Name"], errors="ignore").to_excel(writer, sheet_name=sheet_name, index=False)
        print("--------------------------------------------")

print(f"✅ Processed data saved to: {output_excel}")
# Out:
# Writing sheet: BANKING AND PSU DEBT FUND (CRBP
# --------------------------------------------
# Writing sheet: CORPORATE BOND FUND (CRCBF)
# --------------------------------------------
# Writing sheet: DYNAMIC BOND FUND (CRDBF)
# --------------------------------------------
# Writing sheet: GILT FUND (CRGILT)
# --------------------------------------------
# Writing sheet: INCOME FUND (CRINC)
# --------------------------------------------
# Writing sheet: LIQUID FUND (CRL)
# --------------------------------------------
# Writing sheet: OVERNIGHT FUND (CROF)
# --------------------------------------------
# Writing sheet: SAVINGS FUND (CRSF)
# --------------------------------------------
# Writing sheet: SHORT DURATION FUND (CRSDF)
# --------------------------------------------
# Writing sheet: ULTRA SHORT TERM FUND (CRUSTF)
# --------------------------------------------
# ✅ Processed data saved to: output_data\correct_rating_df_grouped_by_fund_CANARA_ROBECO_June.xlsx
