# %%
# Out:
# ✅ New PDF created (left half only): filtered_left_half_Edelweiss_MF_Factsheet_July_2025_revised_11072025_120123_PM.pdf

# %%
# ############## Code to split pdf to keep only pages with Rating table in it #####################
# import pdfplumber
# from PyPDF2 import PdfWriter, PdfReader

# input_pdf_path = "Edelweiss_MF_Factsheet_July_2025_revised_11072025_120123_PM.pdf"
# output_pdf_path = "filtered_{}.pdf".format(input_pdf_path.split(".")[0])

# reader = PdfReader(input_pdf_path)
# writer = PdfWriter()
# fund_list = []

# with pdfplumber.open(input_pdf_path) as pdf:
#     for page_num, page in enumerate(pdf.pages):
#         page_heading = page.extract_text_lines()[0]['text'].strip().replace(" ", "_")
#         tables = page.extract_tables()

#         if not tables:
#             continue

#         for table in tables:
#             header = table[0]
#             if any("Composition by Ratings" in h for h in header if h):
#                 break  # skip this page
#             elif any("Rating" in h for h in header if h) and any("Instrument" in h for h in header if h):
#                 fund_list.append(page_heading)
#                 writer.add_page(reader.pages[page_num])
#                 break  # add this page once, then move to next page

# # Save the filtered PDF
# with open(output_pdf_path, "wb") as f_out:
#     writer.write(f_out)

# print(f"✅ New PDF created: {output_pdf_path}")
# Out:
# ✅ New PDF created: filtered_Edelweiss_MF_Factsheet_July_2025_revised_11072025_120123_PM.pdf

# %%
# ############ Code to save screenshot of right_half of every page that contains rating table ################
# import os
# from pdf2image import convert_from_path
# import cv2
# import numpy as np

# # === Configuration ===
# pdf_path = "filtered_left_half_Edelweiss_MF_Factsheet_July_2025_revised_11072025_120123_PM.pdf"  # Replace with your actual PDF file path
# output_dir = "left_half_screenshots_bandhan"
# # top_strip_dir = "top_strip_screenshots_bandhan"  # <== NEW FOLDER
# os.makedirs(output_dir, exist_ok=True)
# # os.makedirs(top_strip_dir, exist_ok=True)

# # === Step 1: Convert PDF pages to images ===
# images = convert_from_path(pdf_path, dpi=300)  # Use high DPI for better clarity

# # === Step 2: Crop right half and save ===
# for idx, pil_image in enumerate(images):
#     # Convert PIL to OpenCV (BGR)
#     image = np.array(pil_image)
#     image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

#     # Get dimensions
#     height, width, _ = image.shape


#     # Crop left half (0% to 50%)
#     x_start = 0
#     x_end = int(0.385 * width)  # left half
#     y_start = int(0.08 * height)  # 8% from top (same as before)
#     left_half = image[y_start:, x_start:x_end]

#     # Save cropped image
#     fund_name = fund_list[idx]
#     print(fund_name)
#     output_path = os.path.join(output_dir, f"{fund_name}_page_{idx+1}_left_half.png")
#     cv2.imwrite(output_path, left_half)

#     print(f"✅ Saved: {output_path}")

# print("\n✅ All screenshots of right half completed.")
# Out:
# An_open-ended_debt_scheme_investing
# ✅ Saved: left_half_screenshots_bandhan\An_open-ended_debt_scheme_investing_page_1_left_half.png
# An_open-ended_liquid_scheme._A_relatively
# ✅ Saved: left_half_screenshots_bandhan\An_open-ended_liquid_scheme._A_relatively_page_2_left_half.png
# Edelweiss_An_open_ended_debt_scheme_predominantly
# ✅ Saved: left_half_screenshots_bandhan\Edelweiss_An_open_ended_debt_scheme_predominantly_page_3_left_half.png
# Edelweiss_An_open-ended_debt_scheme_investing
# ✅ Saved: left_half_screenshots_bandhan\Edelweiss_An_open-ended_debt_scheme_investing_page_4_left_half.png
# Edelweiss_An_open_ended_debt_scheme_investing
# ✅ Saved: left_half_screenshots_bandhan\Edelweiss_An_open_ended_debt_scheme_investing_page_5_left_half.png
# Edelweiss_Low_An_open-ended_low_duration_debt_scheme_investing
# ✅ Saved: left_half_screenshots_bandhan\Edelweiss_Low_An_open-ended_low_duration_debt_scheme_investing_page_6_left_half.png
# An_open-ended_debt_Index_Fund_investing
# ✅ Saved: left_half_screenshots_bandhan\An_open-ended_debt_Index_Fund_investing_page_7_left_half.png
# Edelweiss_CRISIL_An_open-ended_target_maturity_Index_Fund
# ✅ Saved: left_half_screenshots_bandhan\Edelweiss_CRISIL_An_open-ended_target_maturity_Index_Fund_page_8_left_half.png
# Edelweiss_NIFTY_An_open-ended_target_maturity_Index_Fund
# ✅ Saved: left_half_screenshots_bandhan\Edelweiss_NIFTY_An_open-ended_target_maturity_Index_Fund_page_9_left_half.png
# Edelweiss_NIFTY_An_open-ended_target_maturity_Index_Fund
# ✅ Saved: left_half_screenshots_bandhan\Edelweiss_NIFTY_An_open-ended_target_maturity_Index_Fund_page_10_left_half.png
# Edelweiss_CRISIL_IBX_An_open-ended_target_maturity_Index_Fund
# ✅ Saved: left_half_screenshots_bandhan\Edelweiss_CRISIL_IBX_An_open-ended_target_maturity_Index_Fund_page_11_left_half.png
# Edelweiss_CRISIL_IBX_An_open-ended_target_Maturity_Index_Fund
# ✅ Saved: left_half_screenshots_bandhan\Edelweiss_CRISIL_IBX_An_open-ended_target_Maturity_Index_Fund_page_12_left_half.png
# Edelweiss_CRISIL_An_open-ended_target_maturity_debt_Index_Fund
# ✅ Saved: left_half_screenshots_bandhan\Edelweiss_CRISIL_An_open-ended_target_maturity_debt_Index_Fund_page_13_left_half.png
# Edelweiss_CRISIL-IBX_An_open-ended_Target_Maturity_Debt_Index_Fund
# ✅ Saved: left_half_screenshots_bandhan\Edelweiss_CRISIL-IBX_An_open-ended_Target_Maturity_Debt_Index_Fund_page_14_left_half.png
# Bharat_Bond_ETF_An_open_ended_Target_Maturity_Exchange
# ✅ Saved: left_half_screenshots_bandhan\Bharat_Bond_ETF_An_open_ended_Target_Maturity_Exchange_page_15_left_half.png
# Bharat_Bond_ETF_An_open_ended_Target_Maturity_Exchange
# ✅ Saved: left_half_screenshots_bandhan\Bharat_Bond_ETF_An_open_ended_Target_Maturity_Exchange_page_16_left_half.png
# Bharat_Bond_ETF_An_open_ended_Target_Maturity_Exchange
# ✅ Saved: left_half_screenshots_bandhan\Bharat_Bond_ETF_An_open_ended_Target_Maturity_Exchange_page_17_left_half.png
# Bharat_Bond_ETF_An_open-ended_Target_Maturity_Exchange
# ✅ Saved: left_half_screenshots_bandhan\Bharat_Bond_ETF_An_open-ended_Target_Maturity_Exchange_page_18_left_half.png
# Edelweiss_CRISIL_IBX_An_open-ended_target_maturity_Index_Fund
# ✅ Saved: left_half_screenshots_bandhan\Edelweiss_CRISIL_IBX_An_open-ended_target_maturity_Index_Fund_page_19_left_half.png
#
# ✅ All screenshots of right half completed.

# %%
############## Code to split pdf to keep only pages with Rating table in it #####################
import pdfplumber
from PyPDF2 import PdfWriter, PdfReader
from datetime import datetime

# month_name = datetime.now().strftime("%b")
month_name = "Oct"

input_pdf_path = "Edelweiss_MF_Factsheet_November_2025_11112025_123429_PM.pdf"
output_pdf_path = "filtered_{}.pdf".format(input_pdf_path.split(".")[0])

reader = PdfReader(input_pdf_path)
writer = PdfWriter()
fund_list = []

with pdfplumber.open(input_pdf_path) as pdf:
    for page_num, page in enumerate(pdf.pages):
        page_heading = page.extract_text_lines()[0]['text'].strip().replace(" ", "_")
        tables = page.extract_tables()

        if not tables:
            continue

        for table in tables:
            header = table[0]
            if any("Composition by Ratings" in h for h in header if h):
                break  # skip this page
            elif any("Rating" in h for h in header if h) and any("Instrument" in h for h in header if h):
                # fund_list.append(page_heading)
                writer.add_page(reader.pages[page_num])
                break  # add this page once, then move to next page

# Save the filtered PDF
with open(output_pdf_path, "wb") as f_out:
    writer.write(f_out)

print(f"✅ New PDF created: {output_pdf_path}")
# Out:
# ✅ New PDF created: filtered_Edelweiss_MF_Factsheet_November_2025_11112025_123429_PM.pdf

# %%
############ Code to save screenshot of heading of every page that contains rating table ################
import os
from pdf2image import convert_from_path
import cv2
import numpy as np

# === Configuration ===
pdf_path = output_pdf_path  # Replace with your actual PDF file path
output_dir = "heading_screenshots_Edelweiss\\{}".format(month_name)
# top_strip_dir = "top_strip_screenshots_bandhan"  # <== NEW FOLDER
os.makedirs(output_dir, exist_ok=True)
# os.makedirs(top_strip_dir, exist_ok=True)

# === Step 1: Convert PDF pages to images ===
images = convert_from_path(pdf_path, dpi=300)  # Use high DPI for better clarity

# === Step 2: Crop right half and save ===
for idx, pil_image in enumerate(images):
    # Convert PIL to OpenCV (BGR)
    image = np.array(pil_image)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    # Get dimensions
    height, width, _ = image.shape


    # Crop left half (0% to 50%)
    x_start = 0
    x_end = int(0.255 * width)  # left half
    y_start = 0  # 8% from top (same as before)
    y_end = int(0.11 * height)
    left_half = image[y_start:y_end, x_start:x_end]

    # Save cropped image
    # fund_name = fund_list[idx]
    # print(fund_name)
    output_path = os.path.join(output_dir, f"page_{idx+1}_left_half.png")
    cv2.imwrite(output_path, left_half)

    print(f"✅ Saved: {output_path}")

print("\n✅ All screenshots of right half completed.")


####################### Code to fetch text from screenshot after zooom with top crop ######################
import cv2
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
fund_list = []
import re

def numerical_sort(value):
    numbers = re.findall(r'\d+', value)
    return int(numbers[0]) if numbers else float('inf')


for filename in sorted(os.listdir(output_dir), key=numerical_sort):
    # print(filename)
    print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")
    print(filename)
    # start_printing = False
    if filename.endswith(".png"):
        image_path = os.path.join(output_dir, filename)
        # Read the image
        image = cv2.imread(image_path)

        # Convert to grayscale (better for OCR)
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)


        # Apply thresholding (optional, improves text detection)
        # You can tweak this or try adaptive thresholding if needed
        _, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)

        # Use pytesseract to extract text
        text = pytesseract.image_to_string(thresh)

        # print("🔎 Extracted Text:")
        # print(text)
        fund_list.append(text)

fund_list
# Out:
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_1_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_2_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_3_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_4_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_5_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_6_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_7_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_8_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_9_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_10_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_11_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_12_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_13_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_14_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_15_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_16_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_17_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_18_left_half.png
# ✅ Saved: heading_screenshots_Edelweiss\Oct\page_19_left_half.png
#
# ✅ All screenshots of right half completed.
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_1_left_half.png
# 🔎 Extracted Text:
# Edelweiss
# Overnight Fund
#
# ——
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_2_left_half.png
# 🔎 Extracted Text:
# Edelweiss
# Liquid Fund
#
# ——
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_3_left_half.png
# 🔎 Extracted Text:
# Edelweiss
# Banking & PSU
# Debt Fund
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_4_left_half.png
# 🔎 Extracted Text:
# Edelweiss
# Money Market
# Fund
#
# ———
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_5_left_half.png
# 🔎 Extracted Text:
# Edelweiss
# Government
# Securities Fund
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_6_left_half.png
# 🔎 Extracted Text:
# Edelweiss Low
# Duration Fund
#
# ——
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_7_left_half.png
# 🔎 Extracted Text:
# Edelweiss Nifty 1D
# Rate Liquid ETF
#
# ——
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_8_left_half.png
# 🔎 Extracted Text:
# Edelweiss CRISIL IBX
# 50:50 Gilt Plus SDL
# Short Duration Index
#
# Fund
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_9_left_half.png
# 🔎 Extracted Text:
# Edelweiss NIFTY
# PSU Bond Plus SDL
# Apr - 2026 50:50
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_10_left_half.png
# 🔎 Extracted Text:
# Edelweiss NIFTY
# PSU Bond Plus
# SDL Apr - 2027 50:50
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_11_left_half.png
# 🔎 Extracted Text:
# Edelweiss CRISIL IBX
# 50:50 Gilt Plus SDL
# June 2027 Index
#
# Fu nd
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_12_left_half.png
# 🔎 Extracted Text:
# Edelweiss CRISIL IBX
# 50:50 Gilt Plus SDL
# Sep 2028 Index Fund
#
# _—
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_13_left_half.png
# 🔎 Extracted Text:
# Edelweiss CRISIL
# IBX AAA Financial
# Services Bond - Jan
# 2028 Index Fund
#
# B Index Fund _
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_14_left_half.png
# 🔎 Extracted Text:
# Edelweiss CRISIL-IBX
# AAA Bond NBFC-HFC -
# Jun 2027 Index Fund
#
# ——
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_15_left_half.png
# 🔎 Extracted Text:
# Bharat Bond ETF
# APRIL 2030
#
# ——
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_16_left_half.png
# 🔎 Extracted Text:
# Bharat Bond ETF
# APRIL 2031
#
# ——
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_17_left_half.png
# 🔎 Extracted Text:
# Bharat Bond ETF
# APRIL 2032
#
# ——
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_18_left_half.png
# 🔎 Extracted Text:
# Bharat Bond ETF
# APRIL 2033
#
# ——
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_19_left_half.png
# 🔎 Extracted Text:
# Edelweiss CRISIL IBX
# 50:50 Gilt Plus SDL
# Apr 2037 Index Fund
#
# ee

# %%
fund_list = [
"Overnight Fund",
"Liquid Fund",
"Banking & PSU Debt Fund",
"Money Market Fund",
"Government Securities Fund",
"Low Duration Fund",
"CRISIL IBX 50:50 Gilt Plus SDL Short Duration Index Fund",
"CRISIL PSU Plus SDL 50:50 Oct 2025 Index Fund",
"NIFTY PSU Bond Plus SDL Apr - 2026 50:50 Index Fund",
"NIFTY PSU Bond Plus SDL Apr - 2027 50:50 Index Fund",
"CRISIL IBX 50:50 Gilt Plus SDL June 2027 Index Fund",
"CRISIL IBX 50:50 Gilt Plus SDL Sep 2028 Index Fund",
"CRISIL IBX AAA Financial Services Bond - Jan 2028 Index Fund",
"CRISIL-IBX AAA Bond NBFC-HFC - Jun 2027 Index Fund",
"Bharat Bond ETF APRIL 2030",
"Bharat Bond ETF APRIL 2031",
"Bharat Bond ETF APRIL 2032",
"Bharat Bond ETF APRIL 2033",
"CRISIL IBX 50:50 Gilt Plus SDL Apr 2037 Index Fund"
]
len(fund_list)
# Out:
# 19

# %%
####################### Working Code to fetch text from rating tale save it in excel file with fund distributed as tabs######################
import pdfplumber
from PyPDF2 import PdfWriter, PdfReader
import pandas as pd
import re

input_pdf_path = output_pdf_path

reader = PdfReader(input_pdf_path)
writer = PdfWriter()
# fund_list = []
A_pattern = pattern = re.compile(
    r"(AAA\(SO\)|AAA\(CE\)|AA\(CE\)|A1\+|AA\+|AA-|AAA|AA|A\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)"
)
non_A_patten = re.compile(r"(AAA\(SO\)|AAA\(CE\)|AA\(CE\)|A1\+|AA\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)")
agencies = ["CARE", "IND", "CRISIL", "ICRA", "FITCH", "India Ratings", "Brickwork", "Acuite"]
agency_pattern = re.compile(rf"({'|'.join(agencies)})")

pan = "AAAAE2916N"
mutual_fund = "Edelweiss Mutual Fund"
correct_rating_df = pd.DataFrame(columns=['Pan', 'ISIN No.', 'Mutual Fund', 'Fund Name','Fund Type', 'Portfolio', "Agency", 'Ratings', "Category", '(%) Of Total AUM', "Factsheet Date", "URL"])


def agency_matching(normalized_text, agency=''):
    agency_match = agency_pattern.search(normalized_text.replace("INDIA", ""))
    if agency_match:
        agency = agency_match.group(1)
        print("agency:", agency)
        normalized_text = normalized_text.replace(agency, " ")
        print("agency_replaced_normalised_text :", normalized_text)
    return [normalized_text, agency]

def rating_matching(normalized_text, agency):
    rating=''
    if agency == '':
        pattern = non_A_patten
        print("agency pattern :", pattern)
    else:
        pattern = A_pattern
        print("agency pattern :", pattern)
    match = pattern.search(normalized_text)
    # print(f"Line: {normalized_text}")
    if match:
        rating = match.group(0)
        print(f"Rating: {rating}\n")
        normalized_text = normalized_text.replace(rating, " ")
        print("rating_replaced_normalised_text :", normalized_text)
    return [normalized_text, rating]

with pdfplumber.open(input_pdf_path) as pdf:
    for page_num, page in enumerate(pdf.pages):
        print("page_num", page_num)
        fund_name = fund_list[page_num]
        page_heading = page.extract_text_lines()[0]['text'].strip().replace(" ", "_")
        tables = page.extract_tables()

        if not tables:
            continue

        for table in tables:
            header = table[0]
            if any("Composition by Ratings" in h for h in header if h):
                break  # skip this page
            elif any("Rating" in h for h in header if h) and any("Instrument" in h for h in header if h):
                # fund_list.append(page_heading)
                # writer.add_page(reader.pages[page_num])
                # print(table)
                for row in table[1:]:
                    if len(row) == 6:
                        row = row[:3]
                        # Count total \n across all strings
                        newline_count = sum(item.count("\n") for item in row if item is not None)

                        print(f"Total '\\n' found: {newline_count}")
                        print(len(row), row)
                        agency_and_rating_text = row[1]
                        if agency_and_rating_text is not None:
                            agency_matching_output = agency_matching(agency_and_rating_text)
                            remaining_text = agency_matching_output[0]
                            agency = agency_matching_output[1]
                            print("agency :", agency)


                            # rating_matching_output = rating_matching(remaining_text)
                            rating_matching_output = rating_matching(remaining_text, agency)
                            remaining_text = rating_matching_output[0]
                            rating = rating_matching_output[1]
                            print("rating :", rating)
                        else:
                            agency = None
                            rating = None

                        temp_df = pd.DataFrame([{
                        "Pan": pan,
                        "ISIN No." : None,
                        "Mutual Fund" : mutual_fund,
                        "Fund Name" : "Edelweiss " + fund_name,
                        "Fund Type" : fund_name,
                        "Portfolio"  : row[0],
                        "Agency" : agency,
                        "Ratings" : rating,
                        "Category" : None,
                        "(%) Of Total AUM" : row[2],
                        "Factsheet Date" : None,
                        "URL" : None,
                                                }])
                        correct_rating_df = pd.concat([correct_rating_df, temp_df])
                    else:
                        newline_count = sum(item.count("\n") for item in row if item is not None)

                        print(f"Total '\\n' found: {newline_count}")
                        if newline_count == 3:
                            row_1 = [item.split("\n")[0] for item in row]
                            row_2 = [item.split("\n")[1] for item in row]
                            # print(len(row), row)
                            # print("row_1 ", row_1)
                            # print("row_2 ", row_2)

                            agency_and_rating_text = row_1[1]
                            if agency_and_rating_text is not None:
                                agency_matching_output = agency_matching(agency_and_rating_text)
                                remaining_text = agency_matching_output[0]
                                agency = agency_matching_output[1]
                                print("agency :", agency)


                                # rating_matching_output = rating_matching(remaining_text)
                                rating_matching_output = rating_matching(remaining_text, agency)
                                remaining_text = rating_matching_output[0]
                                rating = rating_matching_output[1]
                                print("rating :", rating)
                            else:
                                agency = None
                                rating = None
                            temp_df = pd.DataFrame([{
                            "Pan": pan,
                            "ISIN No." : None,
                            "Mutual Fund" : mutual_fund,
                            "Fund Name" : "Edelweiss " + fund_name,
                            "Fund Type" : fund_name,
                            "Portfolio"  : row_1[0],
                            "Agency" : agency,
                            "Ratings" : rating,
                            "Category" : None,
                            "(%) Of Total AUM" : row_1[2],
                            "Factsheet Date" : None,
                            "URL" : None,
                                                    }])
                            correct_rating_df = pd.concat([correct_rating_df, temp_df])

                            agency_and_rating_text = row_2[1]
                            if agency_and_rating_text is not None:
                                agency_matching_output = agency_matching(agency_and_rating_text)
                                remaining_text = agency_matching_output[0]
                                agency = agency_matching_output[1]
                                print("agency :", agency)


                                # rating_matching_output = rating_matching(remaining_text)
                                rating_matching_output = rating_matching(remaining_text, agency)
                                remaining_text = rating_matching_output[0]
                                rating = rating_matching_output[1]
                                print("rating :", rating)
                            else:
                                agency = None
                                rating = None
                            temp_df = pd.DataFrame([{
                            "Pan": pan,
                            "ISIN No." : None,
                            "Mutual Fund" : mutual_fund,
                            "Fund Name" : "Edelweiss " + fund_name,
                            "Fund Type" : fund_name,
                            "Portfolio"  : row_2[0],
                            "Agency" : agency,
                            "Ratings" : rating,
                            "Category" : None,
                            "(%) Of Total AUM" : row_2[2],
                            "Factsheet Date" : None,
                            "URL" : None,
                                                    }])
                            correct_rating_df = pd.concat([correct_rating_df, temp_df])
                        else:
                            print(len(row), row)

                            agency_and_rating_text = row[1]
                            if agency_and_rating_text is not None:
                                agency_matching_output = agency_matching(agency_and_rating_text)
                                remaining_text = agency_matching_output[0]
                                agency = agency_matching_output[1]
                                print("agency :", agency)


                                # rating_matching_output = rating_matching(remaining_text)
                                rating_matching_output = rating_matching(remaining_text, agency)
                                remaining_text = rating_matching_output[0]
                                rating = rating_matching_output[1]
                                print("rating :", rating)
                            else:
                                agency = None
                                rating = None    
                            temp_df = pd.DataFrame([{
                            "Pan": pan,
                            "ISIN No." : None,
                            "Mutual Fund" : mutual_fund,
                            "Fund Name" : "Edelweiss " + fund_name,
                            "Fund Type" : fund_name,
                            "Portfolio"  : row[0],
                            "Agency" : agency,
                            "Ratings" : rating,
                            "Category" : None,
                            "(%) Of Total AUM" : row[2],
                            "Factsheet Date" : None,
                            "URL" : None,
                                                    }])
                            correct_rating_df = pd.concat([correct_rating_df, temp_df])
                break  # add this page once, then move to next page
        print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")

# Save the filtered PDF
# with open(output_pdf_path, "wb") as f_out:
#     writer.write(f_out)

# print(f"✅ New PDF created: {output_pdf_path}")
# Out:
# page_num 0
# Total '\n' found: 0
# 3 ['TREPS_RED_03.11.2025', '', '99.71%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# Total '\n' found: 0
# 3 ['Cash & Cash Equivalent', '', '0.29%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num 1
# Total '\n' found: 0
# 3 ['HDFC BANK CD RED 22-12-2025', 'CARE AAA', '5.60%']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['91 DAYS TBILL RED 18-12-2025', 'SOV', '4.68%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['INDIAN BANK CD RED 19-12-2025', 'FITCH AAA', '3.27%']
# agency: FITCH
# agency_replaced_normalised_text :   AAA
# agency : FITCH
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['91 DAYS TBILL RED 23-01-2026', 'SOV', '3.26%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['PUNJAB NATIONAL BANK CD 18-12-25', 'CRISIL AAA', '3.04%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['91 DAYS TBILL RED 11-12-2025', 'SOV', '2.81%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['91 DAYS TBILL RED 04-12-2025', 'SOV', '2.81%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['CANARA BANK CD RED 27-11-25', 'CRISIL AAA', '2.81%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['UNION BANK OF INDIA CD RED 22-12-2025', 'ICRA AAA', '2.80%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['182 DAYS TBILL RED 13-11-2025', 'SOV', '2.02%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['INDUSIND BANK LTD CD RED 20-11-2025', 'CRISIL AA+', '1.88%']
# agency: CRISIL
# agency_replaced_normalised_text :   AA+
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AA+
#
# rating_replaced_normalised_text :
# rating : AA+
# Total '\n' found: 0
# 3 ['NABARD CP RED 19-11-2025', 'CRISIL AAA', '1.88%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['CANARA BANK CD RED 21-11-2025', 'CRISIL AAA', '1.88%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['NTPC LTD CP RED 03-12-25', 'CRISIL AAA', '1.87%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['CANARA BANK CD RED 19-12-2025', 'CRISIL AAA', '1.87%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['LIC HSG FIN CP RED 21-01-2026', 'CRISIL AAA', '1.86%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['BANK OF BARODA CD RED 27-01-2026', 'ICRA AAA', '1.62%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['INDIAN OIL CORP LTD CP RED 04-11-2025', 'CRISIL AAA', '1.41%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['INDIAN OIL CORP LTD CP RED 16-12-2025', 'CRISIL AAA', '1.40%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['KOTAK MAHINDRA BANK CD RED 04-12-2025', 'CRISIL AAA', '1.40%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['PUNJAB NATIONAL BANK CD RED 11-12-2025', 'CRISIL AAA', '1.40%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['SMFG INDIA HOME FIN LT CP 27-01-26', 'CRISIL AAA', '1.39%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['91 DAYS TBILL RED 29-01-2026', 'SOV', '1.39%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['ICICI SECURITIES CP RED 17-12-25', 'CRISIL AAA', '1.17%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['HDFC BANK CD RED 18-11-2025', 'CARE AAA', '0.94%']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['ICICI BANK CD RED 14-11-2025', 'CARE AAA', '0.94%']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['AXIS SECURITIES LTD. CP RED 18-11-2025', 'ICRA AAA', '0.94%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['ADITYA BIRLA MONEY CP RED 18-11-2025', 'CRISIL AA+', '0.94%']
# agency: CRISIL
# agency_replaced_normalised_text :   AA+
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AA+
#
# rating_replaced_normalised_text :
# rating : AA+
# Total '\n' found: 0
# 3 ['ADITYA BIRLA CAPITAL CP 03-12-25', 'CRISIL AAA', '0.94%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['ICICI SECURITIES PRIM DEAL CP 04-11-25', 'CRISIL AAA', '0.94%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['TREPS_RED_03.11.2025', '', '2.09%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# Total '\n' found: 0
# 3 ['Cash & Cash Equivalent', '', '-0.04%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# Total '\n' found: 0
# 3 ['Others', '', '36.79%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num 2
# Total '\n' found: 0
# 3 ['BANK OF BARODA CD RED 09-01-2026', 'ICRA AAA', '8.27%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.41% IOC NCD RED 22-10-2029', 'FITCH AAA', '6.88%']
# agency: FITCH
# agency_replaced_normalised_text :   AAA
# agency : FITCH
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.48% IRFC NCD RED 13-08-2029', 'CRISIL AAA', '6.85%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.03% HPCL NCD RED 12-04-2030', 'CRISIL AAA', '6.75%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['6.68% GOVT OF INDIA RED 07-07-2040', 'SOV', '6.56%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 1
# 3 ['7.64% FOOD CORP GOI GRNT NCD 12-12-2029', 'CRISIL\nAAA(CE)', '6.52%']
# agency: CRISIL
# agency_replaced_normalised_text :
# AAA(CE)
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA(CE)
#
# rating_replaced_normalised_text :
#
# rating : AAA(CE)
# Total '\n' found: 0
# 3 ['8.85% REC LTD. NCD RED 16-04-2029', 'CRISIL AAA', '5.33%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.49% NHAI NCD RED 01-08-2029', 'CRISIL AAA', '4.47%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.83% EXIM BK OF INDIA NCD RED 03-11-29', 'CRISIL AAA', '3.60%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.41% HUDCO NCD GOI SERVICED 15-03-2029', 'ICRA AAA', '3.52%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.12% NHPC NCD GOI SERVICED 22-03-2029', 'CARE AAA', '3.51%']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.27% NHAI NCD RED 28-03-2029', 'CRISIL AAA', '3.51%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.13% NUCLEAR POWER CORP NCD 28-03-2029', 'CRISIL AAA', '3.50%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.09% NLC INDIA LTD NCD RED 29-05-2029', 'ICRA AAA', '3.49%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.34% POWER GRID CORP NCD 13-07-2029', 'CRISIL AAA', '3.42%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.41% POWER FIN CORP NCD RED 25-02-2030', 'CRISIL AAA', '3.42%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.50% REC LTD. NCD RED 28-02-2030', 'CRISIL AAA', '2.75%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.40% NUCLEAR POW COR IN LTD NCD28-11-29', 'CRISIL AAA', '1.78%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.18% GOVT OF INDIA RED 14-08-2033', 'SOV', '1.74%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['6.33% GOVT OF INDIA RED 05-05-2035', 'SOV', '1.65%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['8.79% INDIAN RAIL FIN NCD RED 04-05-2030', 'CRISIL AAA', '0.43%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['SBI CDMDF--A2', '', '0.34%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# Total '\n' found: 0
# 3 ['TREPS_RED_03.11.2025', '', '9.06%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# Total '\n' found: 0
# 3 ['Cash & Cash Equivalent', '', '2.61%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num 3
# Total '\n' found: 0
# 3 ['BANK OF BARODA CD RED 13-03-2026', 'ICRA AAA', '5.88%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['EXIM BANK CD RED 11-06-2026', 'CRISIL AAA', '5.79%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['SIDBI CD RED 11-03-2026', 'CRISIL AAA', '4.41%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['HDFC BANK CD RED 12-03-2026', 'CARE AAA', '4.41%']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['364 DAYS TBILL RED 26-03-2026', 'SOV', '4.41%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['TATA CAPITAL HSNG CP 25-03-26', 'CRISIL AAA', '4.40%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['PUNJAB NATIONAL BANK CD RED 25-03-2026', 'CRISIL AAA', '4.40%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['HDFC BANK CD RED 24-03-2026', 'CARE AAA', '4.40%']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['HDB FINANCIAL SERV CP RED 16-03-2026', 'CRISIL AAA', '4.40%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['364 DAYS TBILL RED 23-07-2026', 'SOV', '3.18%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['LIC HSG FIN CP RED 21-01-2026', 'CRISIL AAA', '2.97%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['TATA CAPITAL HSNG FIN CP RED 16-01-2026', 'CRISIL AAA', '2.97%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['MUTHOOT FINANCE CP RED 20-01-2026', 'CRISIL AA+', '2.96%']
# agency: CRISIL
# agency_replaced_normalised_text :   AA+
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AA+
#
# rating_replaced_normalised_text :
# rating : AA+
# Total '\n' found: 0
# 3 ['SIDBI CD RED 27-02-2026', 'CRISIL AAA', '2.95%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['TATA CAPITAL LTD CP RED 13-03-2026', 'CRISIL AAA', '2.94%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['CANARA BANK CD RED 18-03-2026', 'CRISIL AAA', '2.94%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['364 DAYS TBILL RED 19-03-2026', 'SOV', '2.94%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['NABARD CD RED 10-03-2026', 'CRISIL AAA', '2.94%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['EXIM BANK CD RED 20-03-2026', 'CRISIL AAA', '2.94%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['INDIAN BANK CD RED 30-04-2026', 'FITCH AAA', '2.92%']
# agency: FITCH
# agency_replaced_normalised_text :   AAA
# agency : FITCH
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['PIRAMAL ENTERPRISES CP RED 17-03-2026', 'CRISIL AA', '2.92%']
# agency: CRISIL
# agency_replaced_normalised_text :   AA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AA
#
# rating_replaced_normalised_text :
# rating : AA
# Total '\n' found: 0
# 3 ['REC LTD. CP RED 10-06-2026', 'CRISIL AAA', '2.90%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['L&T FINANCE LTD CP RED 21-05-2026', 'CRISIL AAA', '2.90%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['AXIS BANK LTD CD RED 11-06-2026', 'CRISIL AAA', '2.90%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['AXIS BANK LTD CD RED 25-06-2026', 'CRISIL AAA', '2.89%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.27% KARNATAKA SDL RED 23-12-2025', 'SOV', '1.51%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['CANARA BANK CD RED 04-03-2026', 'CRISIL AAA', '1.47%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['ADITYA BIRLA CAPITAL CP RED 18-03-2026', 'CRISIL AAA', '1.47%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['KOTAK MAHINDRA BANK CD RED 27-02-2026', 'CRISIL AAA', '1.47%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['CANARA BANK CD RED 06-03-2026', 'CRISIL AAA', '1.47%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['Cash & Cash Equivalent', '', '-4.69%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# Total '\n' found: 0
# 3 ['TREPS_RED_03.11.2025', '', '1.47%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num 4
# Total '\n' found: 0
# 3 ['6.68% GOVT OF INDIA RED 07-07-2040', 'SOV', '54.34%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['6.9% GOVT OF INDIA RED 15-04-2065', 'SOV', '17.54%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.34% GOVT OF INDIA RED 22-04-2064', 'SOV', '15.44%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['6.33% GOVT OF INDIA RED 05-05-2035', 'SOV', '6.07%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['8.38% GUJARAT SDL RED 27-02-2029', 'SOV', '0.06%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['Cash & Cash Equivalent', '', '1.44%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# Total '\n' found: 0
# 3 ['TREPS_RED_03.11.2025', '', '5.11%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num 5
# Total '\n' found: 0
# 3 ['KOTAK MAHINDRA BANK CD RED 13-03-2026', 'CRISIL AAA', '9.02%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['EXIM BANK CD RED 20-03-2026', 'CRISIL AAA', '9.01%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['INDIAN BANK CD RED 19-03-2026', 'FITCH AAA', '9.01%']
# agency: FITCH
# agency_replaced_normalised_text :   AAA
# agency : FITCH
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['HDB FINANCIAL SERV CP RED 16-03-2026', 'CRISIL AAA', '9.00%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.7% NABARD NCD SR 25A RED 30-09-2027', 'ICRA AAA', '4.69%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.80% NABARD NCD SR 24E RED 15-03-2027', 'ICRA AAA', '4.67%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.123% TATA CAP HSG FI SR B R 21-07-2027', 'CRISIL AAA', '4.62%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.23% SIDBI NCD RED 09-03-2026', 'ICRA AAA', '4.62%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['6.6%REC LTD SR 250A NCD 30-06-27', 'ICRA AAA', '4.61%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.1104% ADITYA BIRLA HSG SR D1 R30-07-27', 'CRISIL AAA', '4.61%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['BANK OF BARODA CD RED 09-01-2026', 'ICRA AAA', '4.56%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['ICICI SECURITIES CP RED 06-03-2026', 'CRISIL AAA', '4.51%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['AXIS BANK LTD CD RED 12-06-2026', 'CRISIL AAA', '4.44%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['360 ONE PRIME LTD. CP 29-05-26', 'ICRA AA', '4.41%']
# agency: ICRA
# agency_replaced_normalised_text :   AA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AA
#
# rating_replaced_normalised_text :
# rating : AA
# Total '\n' found: 0
# 3 ['8.05% MUTHOOT FIN SR 44A OP 1 25-11-27', 'CRISIL AA+', '1.85%']
# agency: CRISIL
# agency_replaced_normalised_text :   AA+
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AA+
#
# rating_replaced_normalised_text :
# rating : AA+
# Total '\n' found: 0
# 3 ['8.08% MAHARASHTRA SDL RED 15-06-2026', 'SOV', '0.94%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['Cash & Cash Equivalent', '', '15.43%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num 6
# Total '\n' found: 0
# 3 ['TREPS_RED_03.11.2025', '', '99.25%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# Total '\n' found: 0
# 3 ['Cash & Cash Equivalent', None, '0.75%']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num 7
# Total '\n' found: 0
# 3 ['7.32% GOVT OF INDIA RED 13-11-2030', 'SOV', '21.38%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.59% GUJARAT SDL RED 15-02-2027', 'SOV', '20.81%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.17% GOVT OF INDIA RED 17-04-2030', 'SOV', '17.62%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.59% KARNATAKA SDL 15-02-2027', 'SOV', '17.34%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['8.28% GUJARAT SDL RED 13-02-2029', 'SOV', '3.57%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.10% GOVT OF INDIA RED 18-04-2029', 'SOV', '3.52%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.76% KARNATAKA SDL RED 13-12-2027', 'SOV', '3.51%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['6.75% GOVT OF INDIA RED 23-12-2029', 'SOV', '3.48%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.06% GOVT OF INDIA RED 10-04-2028', 'SOV', '2.10%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['6.13% GOVT OF INDIA RED 04-06-2028', 'SOV', '2.06%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.38% GOVT OF INDIA RED 20-06-2027', 'SOV', '1.22%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['Cash & Cash Equivalent', '', '3.39%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num 8
# Total '\n' found: 0
# 3 ['7.58% POWER FIN SR 222 NCD RED 15-01-26', 'CRISIL AAA', '8.63%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.10% EXIM NCD RED 18-03-2026', 'CRISIL AAA', '7.35%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.40% NABARD NCD RED 30-01-2026', 'CRISIL AAA', '7.13%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.23% SIDBI NCD RED 09-03-2026', 'ICRA AAA', '6.78%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.54% SIDBI NCD SR VIII RED 12-01-2026', 'ICRA AAA', '6.06%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['6.18% GUJARAT SDL RED 31-03-2026', 'SOV', '4.28%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['8.51% MAHARASHTRA SDL RED 09-03-2026', 'SOV', '3.81%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['8.28% KARNATAKA SDL RED 06-03-2026', 'SOV', '3.66%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['8.53% TAMIL NADU SDL RED 09-03-2026', 'SOV', '3.23%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.35% NTPC LTD. SR 80 NCD RED 17-04-2026', 'CRISIL AAA', '3.04%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.57% NABARD NCD SR 23 G RED 19-03-2026', 'CRISIL AAA', '2.85%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.67% KARNATAKA SDL RED 24-02-2026', 'SOV', '2.80%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.54% HUDCO NCD RED 11-02-2026', 'ICRA AAA', '2.49%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.76% MADHYA PRADESH SDL RED 24-02-2026', 'SOV', '2.22%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.60% REC LTD. NCD SR 219 RED 27-02-2026', 'CRISIL AAA', '2.14%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.57% ANDHRA PRADESH SDL RED 09-03-2026', 'SOV', '2.08%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['8.48% RAJASTHAN SDL RED 10-02-2026', 'SOV', '1.65%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['9.18% NUCLEAR POWER NCD RED 23-01-2026', 'CRISIL AAA', '1.60%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.60% BIHAR SDL RED 09-03-2026', 'SOV', '1.58%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['8.88% WEST BENGAL SDL RED 24-02-2026', 'SOV', '1.51%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['5.94% REC LTD. NCD RED 31-01-2026', 'CRISIL AAA', '1.42%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.49% TAMIL NADU SDL RED 10-02-2026', 'SOV', '1.29%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['6.18% MANGALORE REF & PET NCD 29-12-2025', 'CARE AAA', '1.21%']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# ...
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.11% EXIM BANK SR T05 NCD R 11-07-2031', 'CRISIL AAA', '0.44%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.30% NABARD NCD RED 26-12-2031', 'CRISIL AAA', '0.33%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.17% NHPC LTD SR U-1 NCD 27-06-2031', 'CARE AAA', '0.15%']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.49% NTPC LTD NCD RED 07-11-2031', 'CRISIL AAA', '0.10%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.24% NHPC LTD SER U NCD RED 27-06-2031', 'CARE AAA', '0.10%']
# agency: CARE
# agency_replaced_normalised_text :   AAA
# agency : CARE
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.02% EXIM BANK NCD RED SR T 25-11-2031', 'CRISIL AAA', '0.09%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.25% NPCIL NCD RED 15-12-2031 XXXIII E', 'CRISIL AAA', '0.05%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['TREPS_RED_03.11.2025', None, '0.23%']
# Total '\n' found: 0
# 3 ['Cash & Cash Equivalent', None, '4.09%']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num 17
# Total '\n' found: 0
# 3 ['7.26% GOVT OF INDIA RED 06-02-2033', 'SOV', '9.78%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.55% NPCL NCD RED 23-12-2032', 'ICRA AAA', '8.77%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['6.90% HUDCO NCD RED 23-04-2032', 'ICRA AAA', '7.88%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.54% HPCL NCD RED 15-04-2033', 'CRISIL AAA', '6.65%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.47% IRFC SR166 NCD RED 15-04-2033', 'CRISIL AAA', '6.40%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.58% POWER FIN NCD RED 15-04-2033', 'CRISIL AAA', '6.14%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.54% NABARD NCD RED 15-04-2033', 'CRISIL AAA', '6.08%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.44% NTPC LTD. SR 79 NCD RED 15-04-2033', 'CRISIL AAA', '5.71%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.53% RECL SR 217 NCD RED 31-03-2033', 'CRISIL AAA', '5.69%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.52% HUDCO SERIES B NCD RED 15-04-2033', 'ICRA AAA', '5.69%']
# agency: ICRA
# agency_replaced_normalised_text :   AAA
# agency : ICRA
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.75% IRFC NCD RED 15-04-2033', 'CRISIL AAA', '5.68%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['6.92% REC LTD NCD RED 20-03-2032', 'CRISIL AAA', '3.79%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 3
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['8.5% EXIM BANK NCD RED 14-03-2033', 'CRISIL AAA', '2.49%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.69% RECL SR 218 NCD RED 31-01-2033', 'CRISIL AAA', '2.46%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['6.92% POWER FINANCE NCD 14-04-32', 'CRISIL AAA', '2.13%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.82% PFC SR BS225 NCD RED 11-03-2033', 'CRISIL AAA', '1.65%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.65% IRFC NCD SR167 RED 30-12-2032', 'CRISIL AAA', '1.48%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.44% NTPC LTD. SR 78 NCD RED 25-08-2032', 'CRISIL AAA', '1.31%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.65% IRFC SR 168B NCD RED 18-04-2033', 'CRISIL AAA', '0.41%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.40% EXIM BANK NCD SR Z02 RED 14-03-29', 'CRISIL AAA', '0.40%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['7.69% NABARD NCD SR LTIF 1E 31-03-2032', 'CRISIL AAA', '0.16%']
# agency: CRISIL
# agency_replaced_normalised_text :   AAA
# agency : CRISIL
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|A\\b|SOVEREIGN|SOVRN SOV|SOVRN|SOV)')
# Rating: AAA
#
# rating_replaced_normalised_text :
# rating : AAA
# Total '\n' found: 0
# 3 ['TREPS_RED_03.11.2025', '', '0.11%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# Total '\n' found: 0
# 3 ['Cash & Cash Equivalent', '', '4.03%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num 18
# Total '\n' found: 0
# 3 ['7.41% GOVT OF INDIA RED 19-12-2036', 'SOV', '37.82%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.84% TELANGANA SDL RED 03-08-2036', 'SOV', '12.79%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.74% UTTAR PRADESH SDL 15-03-2037', 'SOV', '9.85%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.54% GOVT OF INDIA RED 23-05-2036', 'SOV', '9.72%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['8.03% ANDHRA PRADESH SDL RED 20-07-2036', 'SOV', '5.41%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.89% TELANGANA SDL RED 27-10-2036', 'SOV', '5.35%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.75% RAJASTHAN SDL RED 08-11-2036', 'SOV', '5.31%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.72% ANDHRA PRADESH SDL RED 25-10-2036', 'SOV', '3.29%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.83% TELANGANA SDL RED 04-10-2036', 'SOV', '3.20%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.47% ANDHRA PRADESH SDL RED 26-04-2037', 'SOV', '1.04%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.24% KARNATAKA SDL RED 10-03-2037', 'SOV', '1.02%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.94% TELANGANA SDL RED 29-06-2036', 'SOV', '0.54%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 3
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.45% MAHARASHTRA SDL RED 20-03-2037', 'SOV', '0.52%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['7.45% KARNATAKA SDL RED 20-03-2037', 'SOV', '0.52%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# Rating: SOV
#
# rating_replaced_normalised_text :
# rating : SOV
# Total '\n' found: 0
# 3 ['Cash & Cash Equivalent', '', '2.53%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# Total '\n' found: 0
# 3 ['TREPS_RED_03.11.2025', '', '0.02%']
# agency :
# agency pattern : re.compile('(AAA\\(SO\\)|AAA\\(CE\\)|AA\\(CE\\)|A1\\+|AA\\+|AA-|AAA|AA|SOVEREIGN|SOVRN SOV|SOVRN|SOV|Sovereign)')
# rating :
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# %%
########################## Block to map isin number to fund name ##############################################
# isin_df = pd.read_csv(r"D:\Nexensus_Projects\pdfEtraction\isin_Mastersheet.csv")
# # Create a mapping dictionary
# isin_map = dict(zip(isin_df['Fund Name'], isin_df['ISIN No.']))

# # Add mapped ISIN to df2
# correct_rating_df['ISIN No.'] = correct_rating_df['Fund Name'].map(isin_map)

# Save correct_rating_df to Excel file with separate sheets for each 'fund'
output_excel = "output_data\\correct_rating_df_grouped_by_fund_Edelweiss_{}.xlsx".format(month_name)
with pd.ExcelWriter(output_excel, engine='openpyxl') as writer:
    for fund, group_df in correct_rating_df.groupby("Fund Name"):
        # Clean sheet name: max 31 characters, remove invalid characters
        # sheet_name = str(fund).replace("Edelweiss ", "").replace("CRISIL", "").replace("IBX", "").replace(" - ", "-").replace("Plus", "+").replace("colon", ":")[:31]
        sheet_name = str(fund).replace("Edelweiss ", "").replace(" - ", "-").replace("Plus", "+").replace("colon", ":")[:31]
        invalid_chars = r'[:\\/?*[\]]'
        sheet_name = re.sub(invalid_chars, "_", sheet_name)

        print(f"Writing sheet: {sheet_name}")
        group_df.to_excel(writer, sheet_name=sheet_name, index=False)
        # group_df.drop(columns=["Fund Name"], errors="ignore").to_excel(writer, sheet_name=sheet_name, index=False)
        print("--------------------------------------------")

print(f"✅ Processed data saved to: {output_excel}")
# Out:
# Writing sheet: Banking & PSU Debt Fund
# --------------------------------------------
# Writing sheet: Bharat Bond ETF APRIL 2030
# --------------------------------------------
# Writing sheet: Bharat Bond ETF APRIL 2031
# --------------------------------------------
# Writing sheet: Bharat Bond ETF APRIL 2032
# --------------------------------------------
# Writing sheet: Bharat Bond ETF APRIL 2033
# --------------------------------------------
# Writing sheet: CRISIL IBX 50_50 Gilt + SDL Apr
# --------------------------------------------
# Writing sheet: CRISIL IBX 50_50 Gilt + SDL Jun
# --------------------------------------------
# Writing sheet: CRISIL IBX 50_50 Gilt + SDL Sep
# --------------------------------------------
# Writing sheet: CRISIL IBX 50_50 Gilt + SDL Sho
# --------------------------------------------
# Writing sheet: CRISIL IBX AAA Financial Servic
# --------------------------------------------
# Writing sheet: CRISIL PSU + SDL 50_50 Oct 2025
# --------------------------------------------
# Writing sheet: CRISIL-IBX AAA Bond NBFC-HFC-Ju
# --------------------------------------------
# Writing sheet: Government Securities Fund
# --------------------------------------------
# Writing sheet: Liquid Fund
# --------------------------------------------
# Writing sheet: Low Duration Fund
# --------------------------------------------
# Writing sheet: Money Market Fund
# --------------------------------------------
# Writing sheet: NIFTY PSU Bond + SDL Apr-2026 5
# --------------------------------------------
# Writing sheet: NIFTY PSU Bond + SDL Apr-2027 5
# --------------------------------------------
# Writing sheet: Overnight Fund
# --------------------------------------------
# ✅ Processed data saved to: output_data\correct_rating_df_grouped_by_fund_Edelweiss_Oct.xlsx

# %%
################################ Code to check total number of sheets in excel file ########################################
import pandas as pd

excel_file = pd.ExcelFile(r"D:\Nexensus_Projects\pdfEtraction\EDELWEISS\output_data\correct_rating_df_grouped_by_fund_Edelweiss_Oct.xlsx")
total_sheets = len(excel_file.sheet_names)

print("Total sheets:", total_sheets)
print("Sheet names:", excel_file.sheet_names)
# Out:
# Total sheets: 19
# Sheet names: ['Banking & PSU Debt Fund', 'Bharat Bond ETF APRIL 2030', 'Bharat Bond ETF APRIL 2031', 'Bharat Bond ETF APRIL 2032', 'Bharat Bond ETF APRIL 2033', 'CRISIL IBX 50_50 Gilt + SDL Apr', 'CRISIL IBX 50_50 Gilt + SDL Jun', 'CRISIL IBX 50_50 Gilt + SDL Sep', 'CRISIL IBX 50_50 Gilt + SDL Sho', 'CRISIL IBX AAA Financial Servic', 'CRISIL PSU + SDL 50_50 Oct 2025', 'CRISIL-IBX AAA Bond NBFC-HFC-Ju', 'Government Securities Fund', 'Liquid Fund', 'Low Duration Fund', 'Money Market Fund', 'NIFTY PSU Bond + SDL Apr-2026 5', 'NIFTY PSU Bond + SDL Apr-2027 5', 'Overnight Fund']

# %%
correct_rating_df.to_csv("test_edel.csv", index=False)

# %%
fund_list = [
"Overnight Fund",
"Liquid Fund",
"Banking & PSU Debt Fund",
"Money Market Fund",
"Government Securities Fund",
"Low Duration Fund",
"CRISIL IBX 50colon50 Gilt Plus SDL Short Duration Index Fund",
"CRISIL PSU Plus SDL 50colon50 Oct 2025 Index Fund",
"NIFTY PSU Bond Plus SDL Apr - 2026 50colon50 Index Fund",
"NIFTY PSU Bond Plus SDL Apr - 2027 50colon50 Index Fund",
"CRISIL IBX 50colon50 Gilt Plus SDL June 2027 Index Fund",
"CRISIL IBX 50colon50 Gilt Plus SDL Sep 2028 Index Fund",
"CRISIL IBX AAA Financial Services Bond - Jan 2028 Index Fund",
"CRISIL-IBX AAA Bond NBFC-HFC - Jun 2027 Index Fund",
"Bharat Bond ETF APRIL 2030",
"Bharat Bond ETF APRIL 2031",
"Bharat Bond ETF APRIL 2032",
"Bharat Bond ETF APRIL 2033",
"CRISIL IBX 50colon50 Gilt Plus SDL Apr 2037 Index Fund"
]
len(fund_list)
# Out:
# 19
