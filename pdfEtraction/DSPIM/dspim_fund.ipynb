# %%
############## Code to split pdf to keep only pages with Rating table in it #####################
import pdfplumber
from PyPDF2 import PdfWriter, PdfReader
from datetime import datetime

# month_name = datetime.now().strftime("%b")
month_name = "June"

input_pdf_path = "dsp-factsheet-june-2025.pdf"
output_pdf_path = "filtered_{}.pdf".format(input_pdf_path.split(".")[0])

reader = PdfReader(input_pdf_path)
writer = PdfWriter()
fund_list = []

with pdfplumber.open(input_pdf_path) as pdf:
    for page_num, page in enumerate(pdf.pages):
        page_heading = page.extract_text_lines()[0]['text'].strip().replace(" ", "_")
        tables = page.extract_tables()

        if not tables:
            continue

        for table in tables:
            header = table[0]
            if any("Composition by Ratings" in h for h in header if h):
                break  # skip this page
            elif any("Rating" in h for h in header if h) and any("Instrument" in h for h in header if h):
                fund_list.append(page_heading)
                writer.add_page(reader.pages[page_num])
                break  # add this page once, then move to next page
            elif header == ['Name of Instrument', None, None, '% to Net\nAssets']:
                fund_list.append(page_heading)
                writer.add_page(reader.pages[page_num])
                break  # add this page once, then move to next page


# Save the filtered PDF
with open(output_pdf_path, "wb") as f_out:
    writer.write(f_out)

print(f"✅ New PDF created: {output_pdf_path}")
# Out:
# ✅ New PDF created: filtered_dsp-factsheet-june-2025.pdf

# %%
############## Code to split pdf to keep only pages with Rating table in it #####################
import pdfplumber
from PyPDF2 import PdfWriter, PdfReader
from datetime import datetime

# month_name = datetime.now().strftime("%b")
month_name = "June"

input_pdf_path = "dsp-factsheet-june-2025.pdf"
output_pdf_path = "filtered_{}.pdf".format(input_pdf_path.split(".")[0])
output_pdf_path = "BBNPP_MF_Fund_Facts_June_2025_13196.pdf"
reader = PdfReader(output_pdf_path)
writer = PdfWriter()
fund_list = []

with pdfplumber.open(output_pdf_path) as pdf:
    for page_num, page in enumerate(pdf.pages):
        print("page_num :", page_num + 1)
        page_heading = page.extract_text_lines()[0]['text'].strip().replace(" ", "_")
        tables = page.extract_tables()
        print("table in page :", len(tables))

        if not tables:
            continue

        for table in tables:
            header = table[0]
            for t in table:
                if t == ['', None, '', ''] or t == ['', '', '', '']:
                    pass
                else:
                    print(t, len(t))
            # if any("Rating" in h for h in header if h) and any("Instrument" in h for h in header if h):
            #     for t in table:
            #         if t == ['', None, '', ''] or t == ['', '', '', '']:
            #             pass
            #         else:
            #             print(t, len(t))
            # elif header == ['Name of Instrument', None, None, '% to Net\nAssets']:
            #     for t in table:
            #         if t == ['', None, '', ''] or t == ['', '', '', '']:
            #             pass
            #         else:
            #             print(t, len(t))


            print("\n")
        
        print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")
# Out:
# page_num : 1
# table in page : 1
# ['', ''] 2
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 2
# table in page : 7
# ['', 'Equity Schemes', '', ''] 4
#
#
# ['', 'Fund of Fund Scheme', '', ''] 4
#
#
# ['', 'Hybrid Schemes', '', ''] 4
#
#
# ['', 'Solution Oriented Fund', '', ''] 4
#
#
# ['', 'Debt Schemes', '', ''] 4
#
#
# ['', 'Other Schemes', '', ''] 4
#
#
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 3
# table in page : 0
# page_num : 4
# table in page : 0
# page_num : 5
# table in page : 0
# page_num : 6
# table in page : 2
# ['', None, 'Jun\n24', 'Jul\n24', 'Aug\n24', 'Sep\n24', 'Oct\n24', 'Nov\n24', 'Dec\n24', 'Jan\n25', 'Feb\n25', 'Mar\n25', 'Apr\n25', 'May\n25', 'Jun\n25'] 15
# ['Banking', None, '', '', '', '', '', '', '', '', '', '', '', '', ''] 15
# ['Currency in circulation (% YoY)', None, '6.0', '6.4', '5.5', '5.9', '7.0', '5.7', '5.9', '5.3', '5.6', '5.8', '6.5', '7.0', ''] 15
# ['M3 (% YoY)', None, '9.7', '10.0', '10.2', '10.8', '11.1', '11.1', '9.3', '9.6', '9.6', '9.6', '9.6', '9.5', ''] 15
# ['Bank non-food credit growth (%YoY)', None, '13.9', '15.0', '14.9', '14.1', '13.1', '11.8', '12.4', '12.5', '12.0', '12.1', '11.3', '10.2', '10.4'] 15
# ['Personal credit (%YoY)', None, '16.6', '17.8', '16.9', '16.4', '15.8', '16.3', '14.9', '14.2', '14.0', '14.0', '14.5', '13.7', ''] 15
# ['Credit to industry (%YoY)', None, '7.7', '10.2', '9.8', '9.1', '8.0', '8.1', '7.4', '8.2', '7.3', '8.0', '6.7', '4.9', ''] 15
# ['Credit to services (%YoY)', None, '15.1', '15.4', '15.6', '15.2', '14.1', '14.4', '13.0', '13.8', '13.0', '13.4', '11.2', '9.4', ''] 15
# ['Deposit growth (%YoY)', None, '10.6', '11.0', '11.3', '12.2', '12.2', '11.1', '10.2', '10.6', '10.6', '10.5', '10.5', '10.1', '10.6'] 15
# ['Credit to deposit ratio (%)', None, '77.3', '77.3', '77.5', '77.0', '77.2', '77.7', '78.7', '79.0', '79.0', '79.2', '77.9', '77.4', '77.8'] 15
# ['10 year G-Sec yields (%)', None, '7.01', '6.93', '6.86', '6.75', '6.85', '6.74', '6.76', '6.70', '6.73', '6.6', '6.4', '6.3', '6.3'] 15
# ['Weighted average deposit rate of banks (%)', None, '6.91', '6.92', '6.93', '6.95', '6.96', '6.98', '7.00', '7.02', '7.02', '7.03', '7.01', '7.07', ''] 15
# ['Weighted average lending rate of banks (%)', None, '9.91', '9.91', '9.91', '9.90', '9.90', '9.89', '9.88', '9.87', '9.80', '9.77', '9.70', '9.69', ''] 15
# ['Median MCLR (%)', None, '8.85', '8.85', '8.90', '8.95', '8.95', '9.00', '9.00', '9.00', '9.05', '9.0', '9.0', '9.0', '8.9'] 15
# ['Commercial Paper issuance (%YoY)', None, '(2.5)', '3.2', '4.7', '(3.6)', '7.6', '12.7', '19.7', '20.9', '14.2', '14.0', '32.6', '37.1', ''] 15
# ['Industry', None, '', '', '', '', '', '', '', '', '', '', '', '', ''] 15
# ['Cement production (%YoY)', None, '2.4', '5.5', '(3.0)', '7.2', '3.1', '13.0', '4.6', '14.6', '10.8', '12.2', '6.3', '9.2', ''] 15
# ['Steel production (%YoY)', None, '6.3', '6.4', '3.9', '1.6', '5.2', '4.8', '6.2', '4.7', '6.9', '9.3', '4.4', '6.7', ''] 15
# ['IIP (%YoY)', None, '4.7', '4.7', '(0.1)', '3.1', '3.5', '5.0', '3.5', '5.2', '2.7', '3.9', '2.6', '1.2', ''] 15
# ['Mining (%YoY)', None, '10.3', '3.8', '(4.3)', '0.2', '0.9', '1.9', '2.7', '4.4', '1.6', '1.2', '(0.2)', '(0.1)', ''] 15
# ['Manufacturing (%YoY)', None, '3.2', '4.4', '1.0', '3.9', '4.1', '5.5', '3.4', '5.8', '2.8', '4.0', '3.1', '2.6', ''] 15
# ['Electricity (%YoY)', None, '8.6', '7.9', '(3.7)', '0.5', '2.0', '4.4', '6.2', '2.4', '3.6', '7.5', '1.7', '(5.8)', ''] 15
# ['Capital goods production (%YoY)', None, '3.8', '11.8', '0.7', '3.6', '3.1', '8.8', '10.4', '10.3', '8.2', '3.6', '14.0', '14.1', ''] 15
# ['Consumer durable production (%YoY)', None, '8.7', '8.3', '5.2', '6.5', '5.9', '14.1', '8.3', '7.2', '3.7', '6.9', '6.2', '-0.7', ''] 15
# ['Consumer non-durable production (%YoY)', None, '(1.5)', '(4.3)', '(4.5)', '2.2', '2.7', '0.4', '(7.5)', '(0.3)', '(2.1)', '-4.0', '-2.7', '-2.4', ''] 15
# ['PMI Manufacturing Index', None, '58.3', '58.1', '57.5', '56.5', '57.5', '56.5', '56.4', '57.7', '56.3', '58.1', '58.2', '57.6', '58.4'] 15
# ['PMI Services Index', None, '60.5', '60.3', '60.9', '57.7', '58.5', '58.4', '59.3', '56.5', '59.0', '58.5', '58.7', '58.8', ''] 15
# ['PMI Composite Index', None, '60.9', '60.7', '60.7', '58.3', '59.1', '58.6', '59.2', '57.7', '58.8', '59.5', '59.7', '59.3', ''] 15
# ['Consumer', None, '', '', '', '', '', '', '', '', '', '', '', '', ''] 15
# ['Rural wage (%YoY)', None, '6.0', '5.6', '6.3', '6.7', '6.6', '6.4', '6.4', '6.5', '6.8', '7.1', '7.5', '', ''] 15
# ['Urban unemployment (%)', None, '8.9', '7.9', '8.7', '9.2', '8.6', '8.4', '8.4', '8.4', '7.8', '8.6', '8.1', '', ''] 15
# ['Rural unemployment (%)', None, '9.3', '7.5', '8.4', '7.0', '8.8', '7.9', '7.4', '7.7', '8.8', '7.2', '7.5', '6.1', ''] 15
# ['Naukri job speak index (%YoY)', None, '(7.6)', '11.8', '(3.4)', '(3.8)', '10.0', '2.0', '8.7', '3.9', '4.0', '-0.7', '4.4', '0.1', ''] 15
# ['Motorvehicle sales (%YoY)', None, '16.9', '8.4', '6.5', '11.8', '11.4', '(0.2)', '(4.7)', '2.0', '(6.6)', '9.6', '-13.0', '1.7', ''] 15
# ['Passenger vehicle (%YoY)', None, '3.1', '(2.5)', '(1.8)', '(1.4)', '0.9', '4.0', '10.0', '1.6', '1.9', '3.6', '3.9', '-0.8', ''] 15
# ['Commercial vehicle (%YoY)', None, '0.2', '(10.2)', '(11.0)', '(12.5)', '(3.4)', '1.3', '4.7', '2.4', '(0.4)', '4.5', '-0.5', '1.8', ''] 15
# ['Two wheeler (%YoY)', None, '21.3', '12.5', '9.3', '15.8', '14.2', '(1.1)', '(8.8)', '2.1', '(9.0)', '11.4', '-16.7', '2.2', ''] 15
# ['Tractor sales', None, '3.6', '1.6', '(5.8)', '3.7', '22.4', '(1.3)', '14.0', '11.4', '35.9', '25.4', '7.7', '9.1', ''] 15
# ['Petrol consumption (%YoY)', None, '4.6', '10.5', '8.6', '3.0', '8.7', '9.6', '11.1', '6.7', '3.5', '5.7', '5.0', '9.2', ''] 15
# ['Diesel consumption (%YoY)', None, '1.0', '4.5', '(2.5)', '(1.9)', '0.1', '8.5', '6.0', '4.2', '(1.3)', '0.9', '4.4', '2.2', ''] 15
# ['', None, '5.8', '7.3', '5.7', '6.4', '8.1', '11.9', '8.2', '11.3', '11.0', '8.8', '8.5', '1.9', ''] 15
# ['Foreign tourist arrivals (%YoY)', None, '9.0', '(1.3)', '(4.2)', '0.4', '(1.4)', '3.0', '(3.8)', '(0.2)', '(8.6)', '', '', '', ''] 15
# ['Freight', None, '', '', '', '', '', '', '', '', '', '', '', '', ''] 15
# ['', None, '6.8', '6.0', '6.7', '5.9', '(3.4)', '(5.0)', '3.4', '6.2', '7.4', '13.3', '7.0', '4.4', ''] 15
# ['', '', '10.1', '4.6', '(3.3)', '(0.0)', '1.4', '1.4', '1.7', '0.0', '(3.0)', '3.0', '3.6', '', ''] 15
# ['E-way bills generated (%YoY)', None, '16.3', '19.2', '12.9', '18.5', '16.9', '16.3', '17.6', '23.1', '14.7', '20.2', '23.4', '18.9', ''] 15
# ['Foreign Trade', None, '', '', '', '', '', '', '', '', '', '', '', '', ''] 15
# ['Export growth (%YoY)', None, '2.4', '(2.0)', '(9.9)', '(0.3)', '16.6', '(5.1)', '(1.0)', '(2.4)', '(10.9)', '0.7', '9.0', '(2.2)', ''] 15
# ['Import growth (%YoY)', None, '4.6', '6.3', '0.4', '(0.9)', '(1.2)', '16.0', '4.9', '10.3', '(16.3)', '11.4', '19.1', '(1.7)', ''] 15
# ['Non-oil, non-gold imports (%YoY)', None, '5.4', '4.4', '1.0', '2.1', '(6.8)', '(9.8)', '2.0', '18.8', '(3.0)', '2.2', '17.3', '12.9', ''] 15
# ['Capital goods imports (%YoY)', None, '12.9', '3.0', '9.0', '19.4', '8.1', '12.9', '12.8', '24.4', '7.0', '6.8', '25.2', '25.1', ''] 15
# ['Fiscal', None, '', '', '', '', '', '', '', '', '', '', '', '', ''] 15
# ['Central Government expenditure (%YoY)', None, '(18.4)', '0.12', '20.9', '2.6', '31.7', '3.6', '22.1', '12.4', '(17.7)', '9.7', '10.0', '40.3', ''] 15
# ['Indirect tax (%YoY)', None, '4.7', '13.7', '17.6', '3.3', '9.8', '7.3', '2.5', '11.9', '0.4', '(10.9)', '3.6', '17.1', ''] 15
# ['GST Collections (Rs.bn)', None, '1738.1', '1820.8', '1749.6', '1732.4', '1873.5', '1822.7', '1768.6', '1955.1', '1836.5', '1961.4', '2367.2', '2010.5', '1846.0'] 15
# ['GST collections (YoY)', None, '7.6%', '10.3%', '10.0%', '6.5%', '8.9%', '8.5%', '7.3%', '12.3%', '9.1%', '10.2%', '12.6%', '16.4%', '6.2%'] 15
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', ''] 15
# ['CPI (%YoY)', None, '5.08', '3.60', '3.65', '5.49', '6.21', '5.48', '5.22', '4.26', '3.61', '3.3', '3.2', '2.8', ''] 15
# ['Core CPI (%YoY)', None, '3.14', '3.39', '3.40', '3.50', '3.67', '3.64', '3.58', '3.67', '3.95', '4.1', '4.1', '4.2', ''] 15
# ['WPI (%YoY)', None, '3.36', '2.04', '1.31', '1.84', '2.36', '1.89', '2.37', '2.31', '2.38', '2.0', '0.85', '0.4', ''] 15
# ['', None, '', '', '', '', '', '', '', '', '', '', '', '', ''] 15
# ['Negative', '( + )', '14', '12', '20', '18', '15', '16', '11', '10', '17', '10', '12', '13', '3'] 15
# ['Positive (', '+ )', '36', '38', '30', '32', '35', '34', '39', '40', '33', '39', '37', '32', '3'] 15
#
#
# ['', ''] 2
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 7
# table in page : 29
# ['This product is suitable for investors who are\nseeking*:\nWealth Creation in long term.\nInvestments in diversified and actively managed\nportfolio of equity and equity related securities\nwith bias to large cap companies\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (Nifty 100 TRI): basis it’s constituents; as on June 30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Banks', '21.89%'] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Industrial Manufacturing', '0.86%'] 3
#
#
# ['', 'Aerospace & Defense', '0.80%'] 3
#
#
# ['', 'LESS THAN 0.75% EXPOSURE', '3.08%'] 3
# ['', 'FUTURES LONG POSITION', '1.80%'] 3
#
#
# ['', 'IT - Software', '8.82%'] 3
#
#
# ['', 'TOTAL EQUITY HOLDING', '96.60%'] 3
#
#
# ['', 'Petroleum Products', '6.95%'] 3
#
#
# ['', 'FIXED INCOME HOLDINGS', 'Rating', '% of Net\nAssets'] 4
# ['', 'Treasury Bill', '', '0.95%'] 4
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v2,659.68 Crores'] 2
# ['AUM## As on June 30, 2025', ': v2,719.22 Crores'] 2
#
#
# ['', 'Pharmaceuticals & Biotechnology', '5.69%'] 3
#
#
# ['', 'Total Fixed Income Holdings', '', '0.95%'] 4
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'GRAND TOTAL', '', '100.00%'] 4
#
#
# ['', 'Electrical Equipment', '4.64%'] 3
#
#
# ['', 'Finance', '4.49%'] 3
#
#
# ['', 'Telecom - Services', '4.04%'] 3
#
#
# ['', 'Power', '4.04%'] 3
#
#
# ['', 'Construction', '3.64%'] 3
#
#
# ['', 'Cement & Cement Products', '3.24%'] 3
#
#
# ['', 'Diversified FMCG', '3.12%'] 3
#
#
# ['', 'Retailing', '2.87%'] 3
#
#
# ['', 'Beverages', '2.24%'] 3
#
#
# ['', 'Insurance', '2.16%'] 3
#
#
# ['', 'Diversified Metals', '1.70%'] 3
#
#
# ['', 'Auto Components', '1.62%'] 3
#
#
# ['', 'Food Products', '1.47%'] 3
#
#
# ['', 'Agricultural, Commercial & Construction\nVehicles', '0.94%'] 3
#
#
# ['', 'Oil', '0.93%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 8
# table in page : 30
# ['This product is suitable for investors who are\nseeking*:\nCapital appreciation over long term\nInvestment predominantly in equity and equity\nrelated instruments of large and midcap stocks\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (BSE 250 Large & Mid Cap TRI): basis it’s constituents; as\non June 30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Banks', '20.48%'] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Power', '1.14%'] 3
#
#
# ['', 'Agricultural, Commercial &\nConstruction Vehicles', '1.11%'] 3
#
#
# ['', 'LESS THAN 0.75% EXPOSURE', '0.69%'] 3
# ['', 'TOTAL EQUITY HOLDING', '95.53%'] 3
#
#
# ['', 'Finance', '8.41%'] 3
#
#
# ['', 'Total Fixed Income Holdings', '', ''] 4
#
#
# ['', 'Pharmaceuticals & Biotechnology', '8.25%'] 3
#
#
# ['', 'GRAND TOTAL', '', '100.00%'] 4
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v1,610.73 Crores'] 2
# ['AUM## As on June 30, 2025', ': v1,650.49 Crores'] 2
#
#
# ['', 'IT - Software', '7.54%'] 3
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'Petroleum Products', '5.65%'] 3
#
#
# ['', 'Telecom - Services', '4.81%'] 3
#
#
# ['', 'Insurance', '4.04%'] 3
#
#
# ['', 'Electrical Equipment', '3.54%'] 3
#
#
# ['', 'Retailing', '3.19%'] 3
#
#
# ['', 'Consumer Durables', '2.97%'] 3
#
#
# ['', 'Textiles & Apparels', '2.69%'] 3
#
#
# ['', 'Leisure Services', '2.30%'] 3
#
#
# ['', 'Auto Components', '2.25%'] 3
#
#
# ['', 'Industrial Manufacturing', '2.22%'] 3
#
#
# ['', 'Food Products', '2.13%'] 3
#
#
# ['', 'Automobiles', '2.06%'] 3
#
#
# ['', 'Oil', '2.04%'] 3
#
#
# ['', 'Cement & Cement Products', '1.94%'] 3
#
#
# ['', 'Financial Technology (Fintech)', '1.84%'] 3
#
#
# ['', 'Transport Services', '1.81%'] 3
#
#
# ['', 'Construction', '1.27%'] 3
#
#
# ['', 'Healthcare Services', '1.16%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 9
# table in page : 36
# ['This product is suitable for investors who are\nseeking*:\nWealth Creation in long term.\nInvestments in companies in mid capitalization\nsegment.\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (Nifty Midcap 150 TRI): basis it’s constituents; as on June\n30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Pharmaceuticals & Biotechnology', '11.78%'] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Gas', '1.02%'] 3
#
#
# ['', 'Retailing', '1.01%'] 3
#
#
# ['', 'Oil', '0.98%'] 3
#
#
# ['', 'IT - Services', '0.92%'] 3
#
#
# ['', 'Electrical Equipment', '8.55%'] 3
#
#
# ['', 'Leisure Services', '0.86%'] 3
#
#
# ['', 'LESS THAN 0.75% EXPOSURE', '1.70%'] 3
# ['', 'FUTURES LONG POSITION', '0.64%'] 3
#
#
# ['', 'Auto Components\nSchaeffler India Limited', '7.50%\n1.65%'] 3
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v2,166.51 Crores'] 2
# ['AUM## As on June 30, 2025', ': v2,213.06 Crores'] 2
#
#
# ['', 'FIXED INCOME HOLDINGS', 'Rating', '% of Net\nAssets'] 4
# ['T', 'reasury Bill', '', '0.88%'] 4
#
#
# ['', 'Banks', '7.17%'] 3
#
#
# ['', 'Total Fixed Income Holdings', '', '0.88%'] 4
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'GRAND TOTAL', '', '100.00%'] 4
#
#
# ['', 'IT - Software', '5.35%'] 3
#
#
# ['', 'Insurance', '4.37%'] 3
#
#
# ['', 'Fertilizers & Agrochemicals', '3.94%'] 3
#
#
# ['', 'Healthcare Services', '3.53%'] 3
#
#
# ['', 'Agricultural, Commercial & Construction\nVehicles', '3.00%'] 3
#
#
# ['', 'Financial Technology (Fintech)', '2.88%'] 3
#
#
# ['', 'Cement & Cement Products', '2.63%'] 3
#
#
# ['', 'Realty', '2.29%'] 3
#
#
# ['', 'Petroleum Products', '2.18%'] 3
#
#
# ['', 'Chemicals & Petrochemicals', '2.18%'] 3
#
#
# ['', 'Automobiles', '2.14%'] 3
#
#
# ['', 'Beverages', '1.42%'] 3
#
#
# ['', 'Agricultural Food & other Products', '1.41%'] 3
#
#
# ['', 'Personal Products', '1.33%'] 3
#
#
# ['', 'Textiles & Apparels', '1.23%'] 3
#
#
# ['', 'Consumer Durables', '1.14%'] 3
#
#
# ['', 'Non - Ferrous Metals', '1.13%'] 3
#
#
# ['', 'Telecom - Services', '1.10%'] 3
#
#
# ['', 'Diversified', '1.03%'] 3
#
#
# ['', 'Food Products', '1.02%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 10
# table in page : 37
# ['This product is suitable for investors who are\nseeking*:\nLong term capital growth\nInvestment in equity & equity related securities\npredominantly in small cap Stocks\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (Nifty Small Cap 250 TRI): basis it’s constituents; as on\nJune 30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Electrical Equipment', '8.88%'] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
#
#
# ['', 'Paper, Forest & Jute Products', '1.46%'] 3
#
#
# ['', 'Household Products', '1.44%'] 3
#
#
# ['', 'Banks', '7.21%'] 3
#
#
# ['', 'Construction', '1.39%'] 3
#
#
# ['', 'Realty', '1.18%'] 3
#
#
# ['', 'Industrial Products', '7.20%'] 3
#
#
# ['', 'Personal Products', '1.08%'] 3
#
#
# ['', 'Non - Ferrous Metals', '1.02%'] 3
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v1,297.67 Crores'] 2
# ['AUM## As on June 30, 2025', ': v1,318.47 Crores'] 2
#
#
# ['', 'Agricultural Food & other Products', '0.99%'] 3
#
#
# ['', 'Auto Components', '6.27%'] 3
#
#
# ['', 'Diversified', '0.94%'] 3
#
#
# ['', 'LESS THAN 0.75% EXPOSURE', '2.36%'] 3
# ['', 'FUTURES LONG POSITION', '1.05%'] 3
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'TOTAL EQUITY HOLDING', '93.96%'] 3
#
#
# ['', 'Pharmaceuticals & Biotechnology', '6.18%'] 3
#
#
# ['', 'FIXED INCOME HOLDINGS R', 'ating', '% of Net\nAssets'] 4
# ['', 'Treasury Bill', '', '1.11%'] 4
#
#
# ['', 'Consumer Durables', '4.92%'] 3
#
#
# ['', 'Total Fixed Income Holdings', '', '1.11%'] 4
#
#
# ['', 'GRAND TOTAL', '', '100.00%'] 4
#
#
# ['', 'IT - Services', '4.12%'] 3
#
#
# ['', 'Capital Markets', '4.01%'] 3
#
#
# ['', 'Chemicals & Petrochemicals', '3.91%'] 3
#
#
# ['', 'Finance', '3.90%'] 3
#
#
# ['', 'Gas', '3.70%'] 3
#
#
# ['', 'Food Products', '3.11%'] 3
#
#
# ['', 'Leisure Services', '3.05%'] 3
#
#
# ['', 'Commercial Services & Supplies', '2.93%'] 3
#
#
# ['', 'Agricultural, Commercial &\nConstruction Vehicles', '2.37%'] 3
#
#
# ['', 'Cement & Cement Products', '2.28%'] 3
#
#
# ['', 'Power', '2.10%'] 3
#
#
# ['', 'Textiles & Apparels', '1.90%'] 3
#
#
# ['', 'Petroleum Products', '1.53%'] 3
#
#
# ['', 'Healthcare Services', '1.48%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 11
# table in page : 28
# ['This product is suitable for investors who are\nseeking*:\nWealth Creation in long term.\nInvestment in equity and equity related\nsecurities across market capitalizations\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (Nifty 500 TRI): basis it’s constituents; as on June 30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Banks', '21.88%'] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Food Products', '1.56%'] 3
#
#
# ['', 'Construction', '1.54%'] 3
#
#
# ['', 'Power', '1.11%'] 3
#
#
# ['', 'IT - Software', '6.77%'] 3
#
#
# ['', 'LESS THAN 0.75% EXPOSURE', '2.48%'] 3
# ['', 'TOTAL EQUITY HOLDING', '95.79%'] 3
#
#
# ['', 'Total Fixed Income Holdings', '', ''] 4
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v1,285.77 Crores'] 2
# ['AUM## As on June 30, 2025', ': v1,310.22 Crores'] 2
#
#
# ['', 'Pharmaceuticals & Biotechnology', '6.05%'] 3
#
#
# ['', 'GRAND TOTAL', '', '100.00%'] 4
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'Electrical Equipment', '5.88%'] 3
#
#
# ['', 'Petroleum Products', '5.87%'] 3
#
#
# ['', 'Finance', '5.36%'] 3
#
#
# ['', 'Auto Components', '5.26%'] 3
#
#
# ['', 'Telecom - Services', '4.97%'] 3
#
#
# ['', 'Retailing', '4.73%'] 3
#
#
# ['', 'Healthcare Services', '4.41%'] 3
#
#
# ['', 'Textiles & Apparels', '2.45%'] 3
#
#
# ['', 'Industrial Manufacturing', '2.33%'] 3
#
#
# ['', 'Consumer Durables', '2.24%'] 3
#
#
# ['', 'Oil', '2.07%'] 3
#
#
# ['', 'Insurance', '1.95%'] 3
#
#
# ['', 'Chemicals & Petrochemicals', '1.90%'] 3
#
#
# ['', 'Transport Services', '1.71%'] 3
#
#
# ['', 'Beverages', '1.70%'] 3
#
#
# ['', 'Financial Technology (Fintech)', '1.57%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 12
# table in page : 35
# ['This product is suitable for investors who are\nseeking*:\nCapital appreciation over long term\nInvestments predominantly in equity and equity\nrelated instruments.\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (Nifty 500 Multicap 50:25:25 TRI): basis it’s constituents; as on June 30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Banks', '13.43%'] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Telecom - Services', '1.81%'] 3
#
#
# ['', 'Construction', '1.73%'] 3
#
#
# ['', 'Personal Products', '1.70%'] 3
#
#
# ['', 'Finance', '7.29%'] 3
#
#
# ['', 'Leisure Services', '1.43%'] 3
#
#
# ['', 'Gas', '1.42%'] 3
#
#
# ['', 'Cement & Cement Products', '1.40%'] 3
#
#
# ['', 'IT - Software', '5.61%'] 3
#
#
# ['', 'Paper, Forest & Jute Products', '1.37%'] 3
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v2,882.80 Crores'] 2
# ['AUM## As on June 30, 2025', ': v2,944.23 Crores'] 2
#
#
# ['', 'Minerals & Mining', '1.19%'] 3
#
#
# ['', 'Industrial Products', '1.15%'] 3
#
#
# ['', 'Chemicals & Petrochemicals', '4.80%'] 3
#
#
# ['', 'TOTAL EQUITY HOLDING', '97.41%'] 3
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'FIXED INCOME HOLDINGS', 'Rating', '% of Net\nAssets'] 4
# ['', 'Treasury Bill', '', '0.66%'] 4
#
#
# ['', 'Pharmaceuticals & Biotechnology', '4.61%'] 3
#
#
# ['', 'Healthcare Services', '4.46%'] 3
#
#
# ['', 'GRAND TOTAL', '', '100.00%'] 4
#
#
# ['', 'Consumer Durables', '4.43%'] 3
#
#
# ['', 'Retailing', '4.42%'] 3
#
#
# ['', 'Capital Markets', '3.88%'] 3
#
#
# ['', 'Petroleum Products', '3.82%'] 3
#
#
# ['', 'Electrical Equipment', '3.66%'] 3
#
#
# ['', 'Beverages', '3.40%'] 3
#
#
# ['', 'Financial Technology (Fintech)', '3.21%'] 3
#
#
# ['', 'Automobiles', '3.09%'] 3
#
#
# ['', 'Industrial Manufacturing', '2.92%'] 3
#
#
# ['', 'Food Products', '2.91%'] 3
#
#
# ['', 'Auto Components', '2.33%'] 3
#
#
# ['', 'Transport Services', '2.11%'] 3
#
#
# ['', 'Insurance', '1.93%'] 3
#
#
# ['', 'IT - Services', '1.90%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 13
# table in page : 28
# ['This product is suitable for investors who are\nseeking*:\nCapital appreciation over long term\nInvestment predominantly in a portfolio of equity\nand equity related securities by following a value\ninvestment strategy\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (Nifty 500 TRI): basis it’s constituents; as on June 30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Banks', '19.83%'] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
#
#
# ['', 'Diversified FMCG', '2.05%'] 3
#
#
# ['', 'Industrial Products', '1.92%'] 3
#
#
# ['', 'Pharmaceuticals & Biotechnology', '12.48%'] 3
#
#
# ['', 'Aerospace & Defense', '1.90%'] 3
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v1,313.49 Crores'] 2
# ['AUM## As on June 30, 2025', ': v1,332.16 Crores'] 2
#
#
# ['', 'Oil', '1.63%'] 3
#
#
# ['', 'Consumable Fuels', '1.47%'] 3
#
#
# ['', 'Agricultural Food & other Products', '0.98%'] 3
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'Household Products', '0.84%'] 3
#
#
# ['', 'Petroleum Products', '9.02%'] 3
#
#
# ['', 'TOTAL EQUITY HOLDING', '93.91%'] 3
#
#
# ['', 'FIXED INCOME HOLDINGS', 'Rating', '% of Net\nAssets'] 4
# ['', 'Treasury Bill', '', '1.48%'] 4
#
#
# ['', 'IT - Software', '7.17%'] 3
#
#
# ['', 'Total Fixed Income Holdings', '', '1.48%'] 4
#
#
# ['', 'Power', '5.63%'] 3
#
#
# ['', 'GRAND TOTAL', '', '100.00%'] 4
#
#
# ['', 'Gas', '4.96%'] 3
#
#
# ['', 'Electrical Equipment', '4.53%'] 3
#
#
# ['', 'Finance', '4.01%'] 3
#
#
# ['', 'Automobiles', '3.42%'] 3
#
#
# ['', 'Auto Components', '3.42%'] 3
#
#
# ['', 'Insurance', '3.26%'] 3
#
#
# ['', 'Construction', '2.75%'] 3
#
#
# ['', 'Cement & Cement Products', '2.64%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 14
# table in page : 33
# ['This product is suitable for investors who are\nseeking*:\nLong term capital appreciation\nInvestment predominantly in equity and equity\nrelated instruments of dividend yielding\ncompanies\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (Nifty 500 TRI): basis it’s constituents; as on June 30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Banks', '19.97%'] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
#
#
# ['', 'Industrial Products', '1.19%'] 3
#
#
# ['', 'Beverages', '1.17%'] 3
#
#
# ['', 'Leisure Services', '1.13%'] 3
#
#
# ['', 'Petroleum Products', '10.80%'] 3
#
#
# ['', 'Agricultural, Commercial &\nConstruction Vehicles', '1.06%'] 3
#
#
# ['', 'Household Products', '1.03%'] 3
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v990.98 Crores'] 2
# ['AUM## As on June 30, 2025', ': v1,008.23 Crores'] 2
#
#
# ['', 'Chemicals & Petrochemicals', '1.02%'] 3
#
#
# ['', 'IT - Software', '9.35%'] 3
#
#
# ['', 'Consumable Fuels', '0.97%'] 3
#
#
# ['', 'Consumer Durables', '0.77%'] 3
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'TOTAL EQUITY HOLDING', '95.75%'] 3
#
#
# ['', 'FIXED INCOME HOLDINGS', 'Rating', '% of Net\nAssets'] 4
# ['', 'Treasury Bill', '', '1.94%'] 4
#
#
# ['', 'Pharmaceuticals & Biotechnology', '9.16%'] 3
#
#
# ['', 'Total Fixed Income Holdings', '', '1.94%'] 4
#
#
# ['', 'GRAND TOTAL', '', '100.00%'] 4
#
#
# ['', 'Automobiles', '5.70%'] 3
#
#
# ['', 'Power', '5.21%'] 3
#
#
# ['', 'Gas', '4.08%'] 3
#
#
# ['', 'Finance', '3.71%'] 3
#
#
# ['', 'Insurance', '3.39%'] 3
#
#
# ['', 'Electrical Equipment', '3.02%'] 3
#
#
# ['', 'Food Products', '2.50%'] 3
#
#
# ['', 'Construction', '2.37%'] 3
#
#
# ['', 'Oil', '2.28%'] 3
#
#
# ['', 'Healthcare Services', '1.65%'] 3
#
#
# ['', 'Cement & Cement Products', '1.50%'] 3
#
#
# ['', 'Capital Markets', '1.41%'] 3
#
#
# ['', 'Non - Ferrous Metals', '1.31%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 15
# table in page : 27
# ['This product is suitable for investors who are\nseeking*:\nWealth Creation in long term.\nInvestment primarily in equity and equity-\nrelated securities of upto 30 companies and the\nrest in debt securities & money market\ninstruments\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (Nifty 500 TRI): basis it’s constituents; as on June 30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Banks', '25.72%'] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Electrical Equipment', '1.30%'] 3
#
#
# ['', 'Financial Technology (Fintech)', '1.29%'] 3
#
#
# ['', 'IT - Services', '1.12%'] 3
#
#
# ['', 'Pharmaceuticals & Biotechnology', '7.95%'] 3
#
#
# ['', 'Leisure Services', '1.06%'] 3
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v696.66 Crores'] 2
# ['AUM## As on June 30, 2025', ': v717.79 Crores'] 2
#
#
# ['', 'TOTAL EQUITY HOLDING', '95.81%'] 3
#
#
# ['', 'Finance', '6.81%'] 3
#
#
# ['', 'Total Fixed Income Holdings', '', ''] 4
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'GRAND TOTAL', '', '100.00%'] 4
#
#
# ['', 'Petroleum Products', '6.10%'] 3
#
#
# ['', 'IT - Software', '6.05%'] 3
#
#
# ['', 'Telecom - Services', '5.60%'] 3
#
#
# ['', 'Insurance', '4.69%'] 3
#
#
# ['', 'Power', '4.52%'] 3
#
#
# ['', 'Healthcare Services', '4.44%'] 3
#
#
# ['', 'Textiles & Apparels', '3.44%'] 3
#
#
# ['', 'Transport Services', '2.71%'] 3
#
#
# ['', 'Retailing', '2.61%'] 3
#
#
# ['', 'Capital Markets', '2.49%'] 3
#
#
# ['', 'Automobiles', '2.44%'] 3
#
#
# ['', 'Construction', '2.05%'] 3
#
#
# ['', 'Oil', '1.81%'] 3
#
#
# ['', 'Aerospace & Defense', '1.61%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 16
# table in page : 32
# ['This product is suitable for investors who are\nseeking*:\nWealth Creation in long term.\nInvestments in diversified and actively\nmanaged portfolio of equity and equity\nrelated securities across market\ncapitalisation along with income tax rebate\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (Nifty 500 TRI): basis it’s constituents; as on June 30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Banks', '21.10%'] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Healthcare Services', '1.69%'] 3
#
#
# ['', 'Non - Ferrous Metals', '1.63%'] 3
#
#
# ['', 'Cement & Cement Products', '1.62%'] 3
#
#
# ['', 'Leisure Services', '1.47%'] 3
#
#
# ['', 'IT - Software', '7.14%'] 3
#
#
# ['', 'Capital Markets', '1.45%'] 3
#
#
# ['', 'Transport Services', '1.06%'] 3
#
#
# ['Monthly AAUM## As on June 30,\n2025', ': v918.04 Crores'] 2
# ['AUM## As on June 30, 2025', ': v933.84 Crores'] 2
#
#
# ['', 'Retailing', '5.58%'] 3
#
#
# ['', 'TOTAL EQUITY HOLDING', '96.98%'] 3
#
#
# ['', 'Total Fixed Income Holdings', '', ''] 4
#
#
# ['', 'Finance', '5.22%'] 3
#
#
# ['', 'GRAND TOTAL', '', '100.00%'] 4
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'Petroleum Products', '4.57%'] 3
#
#
# ['', 'Pharmaceuticals & Biotechnology', '4.29%'] 3
#
#
# ['', 'Electrical Equipment', '4.02%'] 3
#
#
# ['', 'Chemicals & Petrochemicals', '3.66%'] 3
#
#
# ['', 'Automobiles', '3.59%'] 3
#
#
# ['', 'Food Products', '3.34%'] 3
#
#
# ['', 'Telecom - Services', '3.28%'] 3
#
#
# ['', 'Financial Technology (Fintech)', '3.20%'] 3
#
#
# ['', 'Power', '3.06%'] 3
#
#
# ['', 'Beverages', '3.05%'] 3
#
#
# ['', 'Industrial Manufacturing', '2.97%'] 3
#
#
# ['', 'Consumer Durables', '2.16%'] 3
#
#
# ['', 'Insurance', '2.13%'] 3
#
#
# ['', 'IT - Services', '2.01%'] 3
#
#
# ['', 'Construction', '1.93%'] 3
#
#
# ['', 'Industrial Products', '1.76%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 17
# table in page : 21
# ['This product is suitable for investors who are\nseeking*:\nWealth Creation in long term.\nInvestment primarily in equity and equityrelated\nsecurities and the rest in debt securities &\nmoney market instruments to generate capital\nappreciation and provide long-term growth\nopportunities by investing in companies\nexpected to benefit by providing products and\nservices to the growing consumption needs of\nIndian consumers.\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (Nifty India Consumption TRI): basis it’s constituents; as on June 30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Automobiles', '19.12%'] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
#
#
# ['', 'Realty', '2.54%'] 3
#
#
# ['', 'Financial Technology (Fintech)', '1.85%'] 3
#
#
# ['', 'Healthcare Services', '1.73%'] 3
#
#
# ['', 'Consumer Durables', '12.27%'] 3
#
#
# ['', 'Textiles & Apparels', '1.17%'] 3
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v1,452.02 Crores'] 2
# ['AUM## As on June 30, 2025', ': v1,476.91 Crores'] 2
#
#
# ['', 'LESS THAN 0.75% EXPOSURE', '1.03%'] 3
# ['', 'TOTAL EQUITY HOLDING', '95.91%'] 3
#
#
# ['', 'FIXED INCOME HOLDINGS', 'Rating', '% of Net\nAssets'] 4
# ['', 'Treasury Bill', '', '0.59%'] 4
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'Total Fixed Income Holdings', '', '0.59%'] 4
#
#
# ['', 'Diversified FMCG', '10.13%'] 3
#
#
# ['', 'Telecom - Services', '9.19%'] 3
#
#
# ['', 'Retailing', '8.38%'] 3
#
#
# ['', 'Personal Products', '7.71%'] 3
#
#
# ['', 'Food Products', '6.68%'] 3
#
#
# ['', 'Leisure Services', '5.43%'] 3
#
#
# ['', 'Beverages', '4.93%'] 3
#
#
# ['', 'Agricultural Food & other Products', '3.75%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 18
# table in page : 36
# ['This product is suitable for investors who are\nseeking*:\nLong term wealth creation.\nInvestment predominantly in equity & equity\nrelated securities, including equity derivatives in\nIndian markets with focus on riding business\ncycles through dynamic allocation between\nvarious sectors & stocks at different stages of\nbusiness cycles in the economy.\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (BSE 500 TRI): basis it’s constituents; as on June 30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Banks', '21.43%'] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
#
#
# ['', 'Healthcare Services', '1.08%'] 3
#
#
# ['', 'Capital Markets', '1.01%'] 3
#
#
# ['', 'Pharmaceuticals & Biotechnology', '8.76%'] 3
#
#
# ['', 'Agricultural Food & other Products', '0.94%'] 3
#
#
# ['', 'LESS THAN 0.75% EXPOSURE', '2.93%'] 3
# ['', 'FUTURES LONG POSITION', '1.52%'] 3
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v586.04 Crores'] 2
# ['AUM## As on June 30, 2025', ': v595.46 Crores'] 2
#
#
# ['', 'TOTAL EQUITY HOLDING', '96.42%'] 3
#
#
# ['', 'FIXED INCOME HOLDINGS', 'Rating', '% of Net\nAssets'] 4
# ['', 'Treasury Bill', '', '0.98%'] 4
#
#
# ['', 'IT - Software', '8.54%'] 3
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'Total Fixed Income Holdings', '', '0.98%'] 4
#
#
# ['', 'GRAND TOTAL', '', '100.00%'] 4
#
#
# ['', 'Petroleum Products', '5.44%'] 3
#
#
# ['', 'Electrical Equipment', '5.33%'] 3
#
#
# ['', 'Automobiles', '5.05%'] 3
#
#
# ['', 'Auto Components', '3.95%'] 3
#
#
# ['', 'Construction', '3.88%'] 3
#
#
# ['', 'Beverages', '2.42%'] 3
#
#
# ['', 'Retailing', '2.35%'] 3
#
#
# ['', 'Power', '2.25%'] 3
#
#
# ['', 'Telecom - Services', '2.13%'] 3
#
#
# ['', 'Industrial Manufacturing', '1.95%'] 3
#
#
# ['', 'Food Products', '1.68%'] 3
#
#
# ['', 'Diversified FMCG', '1.38%'] 3
#
#
# ['', 'Financial Technology (Fintech)', '1.35%'] 3
#
#
# ['', 'Leisure Services', '1.32%'] 3
#
#
# ['', 'Chemicals & Petrochemicals', '1.31%'] 3
#
#
# ['', 'Cement & Cement Products', '1.30%'] 3
#
#
# ['', 'Aerospace & Defense', '1.27%'] 3
#
#
# ['', 'Consumer Durables', '1.27%'] 3
#
#
# ['', 'Finance', '1.24%'] 3
#
#
# ['', 'Realty', '1.23%'] 3
#
#
# ['', 'Insurance', '1.11%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 19
# table in page : 13
# ['This product is suitable for investors who are\nseeking*:\nCapital appreciation over long term.\nInvestment predominantly in equity and equity\nrelated securities of companies engaged in the\nBanking & Financial Services Sector.\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (Nifty Financial Services TRI): basis it’s constituents; as on\nJune 30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Banks', '65.76%'] 3
#
#
# ['', 'Treasury Bill', '', '0.24%'] 4
#
#
# ['', 'Total Fixed Income Holdings', '', '0.24%'] 4
#
#
# ['', 'GRAND TOTAL', '', '100.00%'] 4
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v280.31 Crores'] 2
# ['AUM## As on June 30, 2025', ': v290.05 Crores'] 2
#
#
# ['', 'Finance', '14.35%'] 3
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'Capital Markets', '8.48%'] 3
#
#
# ['', 'Insurance', '4.44%'] 3
#
#
# ['', 'Financial Technology (Fintech)', '3.17%'] 3
#
#
# ['', 'FUTURES LONG POSITION', '0.97%'] 3
#
#
# ['', 'TOTAL EQUITY HOLDING', '97.17%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 20
# table in page : 31
# ['This product is suitable for investors who are\nseeking*:\nLong term capital appreciation\nInvestment in equity & equity related securities\nof the companies that benefit from innovation\ntheme.\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (Nifty 500 TRI): basis it’s constituents; as on June 30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Retailing', '11.18%'] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Fertilizers & Agrochemicals', '1.08%'] 3
#
#
# ['', 'FUTURES LONG POSITION', '0.98%'] 3
#
#
# ['', 'TOTAL EQUITY HOLDING', '96.26%'] 3
#
#
# ['', 'Pharmaceuticals & Biotechnology', '10.41%'] 3
#
#
# ['', 'FIXED INCOME HOLDINGS', 'Rating', '% of Net\nAssets'] 4
# ['', 'Treasury Bill', '', '0.99%'] 4
#
#
# ['', 'Total Fixed Income Holdings', '', '0.99%'] 4
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v998.17 Crores'] 2
# ['AUM## As on June 30, 2025', ': v1,005.39 Crores'] 2
#
#
# ['', 'GRAND TOTAL', '', '100.00%'] 4
#
#
# ['', 'Chemicals & Petrochemicals', '7.62%'] 3
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'IT - Software', '7.23%'] 3
#
#
# ['', 'Capital Markets', '6.92%'] 3
#
#
# ['', 'Automobiles', '6.85%'] 3
#
#
# ['', 'Financial Technology (Fintech)', '5.83%'] 3
#
#
# ['', 'Industrial Manufacturing', '4.80%'] 3
#
#
# ['', 'Telecom - Services', '4.29%'] 3
#
#
# ['', 'Electrical Equipment', '3.79%'] 3
#
#
# ['', 'Banks', '3.67%'] 3
#
#
# ['', 'Industrial Products', '2.54%'] 3
#
#
# ['', 'Petroleum Products', '2.45%'] 3
#
#
# ['', 'Insurance', '2.35%'] 3
#
#
# ['', 'Auto Components', '2.35%'] 3
#
#
# ['', 'Food Products', '2.15%'] 3
#
#
# ['', 'Finance', '2.14%'] 3
#
#
# ['', 'Diversified', '1.97%'] 3
#
#
# ['', 'Transport Services', '1.58%'] 3
#
#
# ['', 'Consumer Durables', '1.48%'] 3
#
#
# ['', 'Leisure Services', '1.37%'] 3
#
#
# ['', 'IT - Services', '1.23%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 21
# table in page : 26
# ['This product is suitable for investors who are\nseeking*:\nLong term capital appreciation.\nInvesting in equity and equity related securities\nof companies engaged in manufacturing theme.\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (Nifty India Manufacturing TRI): basis it’s constituents; as\non June 30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Pharmaceuticals & Biotechnology', '20.45%'] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Power', '0.78%'] 3
#
#
# ['', 'LESS THAN 0.75% EXPOSURE', '1.40%'] 3
# ['', 'TOTAL EQUITY HOLDING', '93.6%'] 3
#
#
# ['', 'FIXED INCOME HOLDINGS', 'Rating', '% of Net\nAssets'] 4
# ['', 'Treasury Bill', '', '1.87%'] 4
#
#
# ['', 'Automobiles', '12.85%'] 3
#
#
# ['', 'Total Fixed Income Holdings', '', '1.87%'] 4
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v1,307.96 Crores'] 2
# ['AUM## As on June 30, 2025', ': v1,322.53 Crores'] 2
#
#
# ['', 'GRAND TOTAL', '', '100.00%'] 4
#
#
# ['', 'Petroleum Products', '11.26%'] 3
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'Electrical Equipment', '7.36%'] 3
#
#
# ['', 'Auto Components', '6.57%'] 3
#
#
# ['', 'Industrial Products', '6.24%'] 3
#
#
# ['', 'Chemicals & Petrochemicals', '5.40%'] 3
#
#
# ['', 'Industrial Manufacturing', '3.47%'] 3
#
#
# ['', 'Diversified Metals', '3.14%'] 3
#
#
# ['', 'Aerospace & Defense', '2.58%'] 3
#
#
# ['', 'Agricultural, Commercial &\nConstruction Vehicles', '2.04%'] 3
#
#
# ['', 'Fertilizers & Agrochemicals', '1.80%'] 3
#
#
# ['', 'Non - Ferrous Metals', '1.70%'] 3
#
#
# ['', 'Oil', '1.50%'] 3
#
#
# ['', 'Gas', '1.31%'] 3
#
#
# ['', 'Diversified', '1.26%'] 3
#
#
# ['', 'Beverages', '1.26%'] 3
#
#
# ['', 'Cement & Cement Products', '1.23%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 22
# table in page : 18
# ['This product is suitable for investors who are\nseeking*:\nLong term capital appreciation and growth.\nInvesting in predominantly in equity and equity\nrelated securities of energy companies\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (Nifty Energy TRI): basis it’s constituents; as on June 30,\n2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets'] 3
# ['', 'Power', '24.63%'] 3
#
#
# ['', 'FIXED INCOME HOLDINGS', 'Rating', '% of Net\nAssets'] 4
# ['', 'Treasury Bill', '', '2.57%'] 4
#
#
# ['', 'Total Fixed Income Holdings', '', '2.57%'] 4
#
#
# ['', 'GRAND TOTAL', '', '100.00%'] 4
#
#
# ['', 'Petroleum Products', '21.04%'] 3
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v753.74 Crores'] 2
# ['AUM## As on June 30, 2025', ': v762.58 Crores'] 2
#
#
# ['', 'Electrical Equipment', '11.56%'] 3
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['', 'Oil', '11.45%'] 3
#
#
# ['', 'Gas', '7.13%'] 3
#
#
# ['', 'Industrial Products', '6.16%'] 3
#
#
# ['', 'Consumable Fuels', '6.06%'] 3
#
#
# ['', 'Chemicals & Petrochemicals', '2.41%'] 3
#
#
# ['', 'Cement & Cement Products', '1.59%'] 3
#
#
# ['', 'Non - Ferrous Metals', '1.32%'] 3
#
#
# ['', 'Industrial Manufacturing', '1.27%'] 3
#
#
# ['', 'TOTAL EQUITY HOLDING', '94.62%'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 23
# table in page : 8
# ['This product is suitable for investors who are\nseeking*:\nWealth creation in long term.\nInvestments predominantly in units of BNP\nParibas Funds Aqua (Lux).\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at Very High\nrisk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (MSCI World Index (TRI)): basis it’s constituents; as on June 30, 2025', None, None] 3
#
#
# ['', 'NAME OF INSTRUMENT', '% of Net Assets'] 3
#
#
# ['', 'GRAND TOTAL', '100.00%'] 3
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v37.39 Crores'] 2
# ['AUM## As on June 30, 2025', ': v37.56 Crores'] 2
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# ['No. of Holdings in Portfolio', '44'] 2
#
#
# ['Total', '100.00'] 2
#
#
# ['Total', '100.00'] 2
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 24
# table in page : 5
# ['This product is suitable for investors who are\nseeking*:\nRegular income and capital appreciation\nInvestments in units of debt and arbitrage\nschemes\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Moderate risk', 'Benchmark riskometer is at Low To\nModerate risk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (Nifty Composite Debt Index 60% + Nifty Arbitrage Index 40% TRI): basis it’s\nconstituents; as on June 30, 2025', None, None] 3
#
#
# ['', 'NAME OF INSTRUMENT', '% of Net Assets'] 3
#
#
# ['', 'GRAND TOTAL', '100.00%'] 3
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v95.57 Crores'] 2
# ['AUM## As on June 30, 2025', ': v104.79 Crores'] 2
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 25
# table in page : 6
# ['This product is suitable for investors who are\nseeking*:\nRegular income and Capital Appreciation\nInvestments in units of debt, equity and gold\nschemes\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Moderately High\nrisk', 'Benchmark riskometer is at\nModerately High risk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (60% of Nifty Composite Debt Index + 20% Nifty 500 TRI+ 20% of INR Price of\nGold): basis it’s constituents; as on June 30, 2025', None, None] 3
#
#
# ['', 'NAME OF INSTRUMENT', '% of Net Assets'] 3
#
#
# ['', 'TOTAL MUTUAL FUND UNITS', '78.21%'] 3
#
#
# ['', 'GRAND TOTAL', '100.00%'] 3
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v126.04 Crores'] 2
# ['AUM## As on June 30, 2025', ': v126.25 Crores'] 2
#
#
# ['', 'Fund Manager', 'Managing fund since', 'Experience'] 4
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 26
# table in page : 32
# ['This product is suitable for investors who are\nseeking*:\nCapital appreciation over medium to long term.\nInvestments in equity and equity linked\nsecurities as well as debt and money market\ninstruments while managing risk through active\nasset allocation.\n*Investors should consult their financial advisers\nif in doubt about whether the product is suitable\nfor them.', 'Scheme Riskometer^^', 'Benchmark (Tier 1) Riskometer^'] 3
# [None, 'Investors understand that their\nprincipal will be at Very High risk', 'Benchmark riskometer is at High risk'] 3
# ['^^Riskometer For Scheme: basis it’s portfolio, ^Riskometer For Benchmark (NIFTY 50 Hybrid Composite debt 50:50 Index): basis it’s constituents; as on June\n30, 2025', None, None] 3
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets', ''] 4
# ['', 'Banks', '17.11%', ''] 4
#
#
# ['', 'EQUITY HOLDINGS', '% of Net\nAssets', ''] 4
#
#
# ['', 'Insurance', '1.62%', ''] 4
#
#
# ['', 'Aerospace & Defense', '1.58%', ''] 4
#
#
# ['', 'Cement & Cement Products', '1.37%', ''] 4
#
#
# ['', 'Pharmaceuticals &\nBiotechnology', '5.89%', ''] 4
#
#
# ['', 'Beverages', '1.36%', ''] 4
#
#
# ['', 'Transport Services', '1.35%', ''] 4
#
#
# ['Monthly AAUM## As on June 30, 2025', ': v4,347.10 Crores'] 2
# ['AUM## As on June 30, 2025', ': v4,413.02 Crores'] 2
#
#
# ['', 'Oil', '1.28%', ''] 4
#
#
# ['', 'IT - Software', '4.68%', ''] 4
#
#
# ['', 'Financial Technology (Fintech)', '1.08%', ''] 4
#
#
# ['Category', 'Fund Manager', 'Managing\nfund since', 'Experience'] 4
#
#
# ['', 'Personal Products', '1.07%', ''] 4
#
#
# ['', 'Petroleum Products', '4.63%', ''] 4
#
#
# ['', 'Healthcare Services', '0.89%', ''] 4
#
#
# ['', 'Electrical Equipment', '3.38%', ''] 4
#
#
# ['', 'Diversified FMCG', '0.78%', ''] 4
#
#
# ['', 'Power', '0.75%', ''] 4
#
#
# ['', 'Finance', '3.26%', ''] 4
#
#
# ['', 'LESS THAN 0.75% EXPOSURE', '3.42%', ''] 4
# ['', 'TOTAL EQUITY HOLDING', '72.78%', ''] 4
# ['', 'REITs/InvITs Holdings', '', '% of Net\nAssets'] 4
#
#
# ['', 'Telecom - Services', '2.96%', ''] 4
#
#
# ['', 'Capital Markets', '2.32%', ''] 4
#
#
# ['', 'Retailing', '2.27%', ''] 4
#
#
# ['', 'Auto Components', '2.20%', ''] 4
#
#
# ['', 'Construction', '2.16%', ''] 4
#
#
# ['', 'Textiles & Apparels', '2.02%', ''] 4
#
#
# ['', 'Consumer Durables', '1.68%', ''] 4
#
#
# ['', 'Industrial Manufacturing', '1.67%', ''] 4
#
#
# ['', 'Total REITs/InvITs Holdings', '', '6.93%'] 4
# ['', 'MUTUAL FUND UNITS', '', '% of Net\nAssets'] 4
#
#
# ['', 'Total MUTUAL FUND UNITS', '', '0.45%'] 4
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 27
# table in page : 9
# ...
# ['Hybrid Schemes', None, None] 3
# ['Baroda BNP Paribas Balanced Advantage Fund', 'Mr. Sanjay Chawla (Equity Portfolio)', 'November 14, 2018'] 3
# [None, 'Mr. Pratish Krishnan (Equity Portfolio)', 'August 05, 2021'] 3
# [None, 'Mr. Neeraj Saxena (Equity Portfolio)', 'October 21, 2024'] 3
# [None, 'Mr. Gurvinder Singh Wasan (Fixed Income Portfolio)', 'October 21, 2024'] 3
# ['Baroda BNP Paribas Aggressive Hybrid Fund', 'Mr. Jitendra Sriram (Equity Portfolio)', 'June 16, 2022'] 3
# [None, 'Mr. Pratish Krishnan (Equity Portfolio)', 'March 14, 2022'] 3
# [None, 'Mr. Gurvinder Singh Wasan (Fixed Income Portfolio)', 'October 21, 2024'] 3
# ['Baroda BNP Paribas Multi Asset Fund', 'Mr. Jitendra Sriram (Equity Portfolio)', 'December 19, 2022'] 3
# [None, 'Mr. Pratish Krishnan (Equity Portfolio)', 'October 21, 2024'] 3
# [None, 'Mr. Vikram Pamnani (Fixed Income Portfolio)', 'December 19, 2022'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 62
# table in page : 1
# ['Baroda BNP Paribas Equity Savings Fund', 'Mr. Pratish Krishnan (Equity Portfolio)', 'September 05, 2019'] 3
# [None, 'Mr. Neeraj Saxena (Equity Portfolio)', 'October 21, 2024'] 3
# [None, 'Mr. Ankeet Pandya (Equity Portfolio)', 'January 01, 2025'] 3
# [None, 'Mr. Gurvinder Singh Wasan (Fixed Income Portfolio)', 'October 21, 2024'] 3
# ['Baroda BNP Paribas Conservative Hybrid Fund', 'Mr. Pratish Krishnan (Equity Portfolio)', 'March 14, 2022'] 3
# [None, 'Mr. Gurvinder Singh Wasan (Fixed Income Portfolio)', 'October 21, 2024'] 3
# [None, 'Mr. Ankeet Pandya (Equity Portfolio)', 'January 01, 2025'] 3
# [None, 'Mr. Prashant Pimple (Fixed Income Portfolio)', 'October 21, 2022'] 3
# ['Baroda BNP Paribas Arbitrage Fund', 'Mr. Neeraj Saxena (Equity Portfolio)', 'March 14, 2022'] 3
# [None, 'Mr. Vikram Pamnani (Fixed Income Portfolio)', 'March 16, 2022'] 3
# ['Solution Oriented Fund', None, None] 3
# ['Baroda BNP Paribas Retirement Fund', 'Mr. Pratish Krishnan (Equity Portfolio)', 'May 28, 2024'] 3
# [None, 'Mr. Ankeet Pandya (Equity Portfolio)', 'January 01, 2025'] 3
# [None, 'Mr. Gurvinder Singh Wasan (Fixed Income Portfolio)', 'October 21, 2024'] 3
# ["Baroda BNP Paribas Children's Fund", 'Mr. Pratish Krishnan', 'December 27, 2024'] 3
# [None, 'Mr. Ankeet Pandya', 'January 01, 2025'] 3
# ['Debt Schemes', None, None] 3
# ['Baroda BNP Paribas Liquid Fund', 'Mr. Vikram Pamnani', 'March 14, 2022'] 3
# [None, 'Mr. Gurvinder Singh Wasan', 'October 21, 2024'] 3
# ['Baroda BNP Paribas Overnight Fund', 'Mr. Vikram Pamnani', 'March 14, 2022'] 3
# [None, 'Mr. Gurvinder Singh Wasan', 'October 21, 2024'] 3
# ['Baroda BNP Paribas Ultra Short Duration Fund', 'Mr. Vikram Pamnani', 'March 14, 2022'] 3
# [None, 'Mr. Gurvinder Singh Wasan', 'October 21, 2024'] 3
# ['Baroda BNP Paribas Low Duration Fund', 'Mr. Vikram Pamnani', 'December 27, 2017'] 3
# [None, 'Mr. Gurvinder Singh Wasan', 'October 21, 2024'] 3
# ['Baroda BNP Paribas Money Market Fund', 'Mr. Vikram Pamnani', 'March 14, 2022'] 3
# [None, 'Mr. Gurvinder Singh Wasan', 'October 21, 2024'] 3
# ['Baroda BNP Paribas Banking and PSU Bond Fund', 'Mr. Gurvinder Singh Wasan', 'October 21, 2024'] 3
# [None, 'Mr. Vikram Pamnani', 'July 11, 2024'] 3
# ['Baroda BNP Paribas Short Duration Fund', 'Mr. Gurvinder Singh Wasan', 'October 21, 2024'] 3
# [None, 'Mr. Vikram Pamnani', 'March 14, 2022'] 3
# ['Baroda BNP Paribas Credit Risk Fund\n(scheme has two segregated portfolios)', 'Mr. Gurvinder Singh Wasan', 'October 21, 2024'] 3
# [None, 'Mr. Vikram Pamnani', 'July 11, 2024'] 3
# ['Baroda BNP Paribas Corporate Bond Fund', 'Mr. Gurvinder Singh Wasan', 'October 21, 2024'] 3
# [None, 'Mr. Vikram Pamnani', 'July 11, 2024'] 3
# ['Baroda BNP Paribas Dynamic Bond Fund', 'Mr. Prashant Pimple', 'July 11, 2024'] 3
# [None, 'Mr. Gurvinder Singh Wasan', 'October 21, 2024'] 3
# ['Baroda BNP Paribas Gilt Fund', 'Mr. Prashant Pimple', 'July 11, 2024'] 3
# [None, 'Mr. Gurvinder Singh Wasan', 'October 21, 2024'] 3
# ['Other Schemes', None, None] 3
# ['Baroda BNP Paribas Nifty SDL December 2026 Index Fund', 'Mr. Gurvinder Singh Wasan', 'October 21, 2024'] 3
# [None, 'Mr. Vikram Pamnani', 'July 11, 2024'] 3
# ['Baroda BNP Paribas Nifty SDL December 2028 Index Fund', 'Mr. Gurvinder Singh Wasan', 'October 21, 2024'] 3
# [None, 'Mr. Vikram Pamnani', 'July 11, 2024'] 3
# ['Baroda BNP Paribas Nifty 50 Index Fund', 'Mr. Neeraj Saxena', 'January 29, 2024'] 3
# ['Baroda BNP Paribas Gold ETF', 'Mr. Gurvinder Singh Wasan', 'October 21, 2024'] 3
# [None, 'Mr. Madhav Vyas', 'January 01, 2025'] 3
# ['Baroda BNP Paribas NIFTY BANK ETF', 'Mr. Neeraj Saxena', 'June 18, 2024'] 3
# ['Baroda BNP Paribas Nifty 200 Momentum 30 Index Fund', 'Mr. Neeraj Saxena', 'October 15, 2024'] 3
# ['Baroda BNP Paribas Nifty Midcap 150 Index Fund', 'Mr. Neeraj Saxena', 'November 4, 2024'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 63
# table in page : 13
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/ Others', None] 3
# ['Regular Plan - Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/ Others', None] 3
# ['Regular Plan - Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/ Others', None] 3
# ['Regular Plan - Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Baroda BNP Paribas Large and Mid Cap Fund', None, None] 3
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/ Others', None] 3
# ['Regular Plan - Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/ Others', None] 3
# ['Regular Plan - Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/ Others', None] 3
# ['Regular Plan - Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/ Others', None] 3
# ['Regular Plan - Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/ Others', None] 3
# ['Regular Plan - Monthly Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/ Others', None] 3
# ['Regular Plan - Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/ Others', None] 3
# ['Regular Plan - Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/ Others', None] 3
# ['Regular Plan - Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/ Others', None] 3
# ['Regular Plan - Monthly Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/ Others', None] 3
# ['Regular Plan - Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 64
# table in page : 9
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/ Others', None] 3
# ['Regular Plan - Adhoc Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/Others', None] 3
# ['Regular Plan - Monthly Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/Others', None] 3
# ['Regular Plan - Monthly Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/Others', None] 3
# ['Regular Plan - Monthly Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/Others', None] 3
# ['Regular Plan - Monthly Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/Others', None] 3
# ['Regular Plan - Monthly Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Baroda BNP Paribas Credit Risk Fund\n(scheme has two segregated portfolios)', ''] 2
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/Others', None] 3
# ['Regular Plan - Monthly Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)', 'Cum-Distribution\nNAV (v)'] 3
# [None, 'Individual/Others', None] 3
# ['Regular Plan - Monthly Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 65
# table in page : 2
# ['Record Date', 'Distribution Rate Per Unit (v)\nIndividual/Others', 'Cum-Distribution\nNAV (v)'] 3
# ['Regular Plan - Aadhoc Income Distribution cum capital\nwithdrawal option (Last 3 Dividends)', None, None] 3
#
#
# ['Record Date', 'Distribution Rate Per Unit (v)\nIndividual/Others', 'Cum-Distribution\nNAV (v)'] 3
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 66
# table in page : 1
# ['Banking', ''] 2
# ['Currency in circulation (% YoY)', 'Measures cash in circulation and is an important indicator of economic activity particularly in the informal sector'] 2
# ['M3 (% YoY)', 'Measures money supply and is linked to real GDP growth and inflation'] 2
# ['Bank non-food credit growth (%YoY)', "Measures total non-food bank credit growth. The key sub components are personal credit growth (home loan, auto\nloans, personal loan, credit cards etc.), credit to industry (loans for infrastructure, large corporates and large projects)\nand credit to services (loans given to NBFCs and service related industry). These are reflective of consumption in\neconomy, industry's demand for credit and services' sector demand for credit respectively."] 2
# ['Personal credit (%YoY)', None] 2
# ['Credit to industry (%YoY)', None] 2
# ['Credit to services (%YoY)', None] 2
# ['Deposit growth (%YoY)', 'Measures total deposit growth in the banking system'] 2
# ['Credit to deposit ratio (%)', 'Total credit / Total deposits reflects credit demand vs. availability of funds in the banking system and hence scope for\ntransmission of rate cuts.'] 2
# ['10 year G-Sec yields (%)', "G-Secs are securities issued by Central Government to borrow from financial market to meet its fiscal deficit. Gsec\nyields are determinant of the government's ability to service its debt."] 2
# ['Weighted average lending rate of Banks (%)', 'Lending rate for all loans'] 2
# ['Weighted average deposit rate of banks (%)', 'Cost of deposits for banks'] 2
# ['Median MCLR (%)', 'Margin lending rate for new loans. Indicator of effectiveness of monetary transmission'] 2
# ['Commercial Paper issuance (%YoY)', 'Measures demand for short term funds of corporates via the market route. Also reflective of ease of access to funds.'] 2
# ['Industry', ''] 2
# ['Cement production (% YoY)', 'Measures volume of cement production and determines the construction component of GDP'] 2
# ['Steel production (% YoY)', 'Measures volume of steel production determines the construction component of GDP'] 2
# ['IIP (%YoY)', 'The Index of Industrial Production (IIP) measures volume of industrial output. It is an index which details out the\ngrowth of various sectors in an economy such as mineral mining, electricity and manufacturing.'] 2
# ['Mining (% YoY)', None] 2
# ['Manufacturing (%YoY)', None] 2
# ['Electricity (%YoY)', None] 2
# ['Capital goods production (%YoY)', 'These are part of IIP manufacturing. Measures volume of domestic capital goods production which is (1) reflective of\nthe capex cycle, (2) measures volume of consumer durable output including automobiles, and (3) measures volume of\nconsumer non-durable output particularly FMCG products.'] 2
# ['Consumer durable production (% YoY)', None] 2
# ['Consumer non-durable production (% YoY)', None] 2
# ['PMI Manufacturing Index', "The Purchasing Managers' Index (PMI) is an index of the prevailing direction of economic trends in the manufacturing\nand service sectors. A lead indicator of manufacturing sector performance takes into account business sentiment on\norder book, prices, employment etc."] 2
# ['PMI Services Index', None] 2
# ['PMI Composite Index', None] 2
# ['Consumer', ''] 2
# ['Rural wage (% YoY)', 'Measures average rural wages which determines rural propensity to consume'] 2
# ['Motorvehicle sales (%YoY)', 'Measures total number of wholesale motor vehicle sales (passenger vehicles, tractor, commercial and two wheelers)\ni.e. dispatches from manufacturers to dealers. Indicator of consumption activity.'] 2
# ['Passenger Vehicle (% YoY)', None] 2
# ['Commercial Vehicle (% YoY)', None] 2
# ['Two wheeler (% YoY)', None] 2
# ['Tractor sales', None] 2
# ['Petrol consumption (% YoY)', 'Measures volume of motor spirit consumption'] 2
# ['Diesel consumption (%YoY)', 'Measures volume of high speed diesel consumption which reflects industrial activity in the economy'] 2
# ['Air traffic (% YoY)', 'Domestic passengers flown, an important determinant of trade, hotels, transport storage and communication\ncomponent of GDP.'] 2
# ['Foreign tourist arrivals (%YoY)', 'Measures number of foreign tourist arrivals into the country, an important determinant of trade, hotels, transport\nstorage and communication component of GDP.'] 2
# ['Freight', ''] 2
# ['Major port tarffic (%YoY)', 'Volume of cargo traffic at ports, proxy for EXIM and Domestic activity in the country'] 2
# ['Rail freight traffic (% YoY)', 'Earnings from railway freight traffic and proxy for movement of goods in the country'] 2
# ['Foreign Trade', ''] 2
# ['Export growth (% YoY)', 'Measures value of exports'] 2
# ['Import growth (% YoY)', 'Measures value of imports'] 2
# ['Capital goods imports (%YoY)', 'Measures value of capital goods imports and is reflective of the domestic capex cycle.'] 2
# ['Fiscal', ''] 2
# ['Central Government expenditure (%YoY)', 'Measures total central government expenditure and is an important determinant of the public administration, defence\nand other services component of GDP.'] 2
# ['Indirect tax (%YoY)', 'Measures total growth in indirect taxes and hence consumption. Also determines the taxes component of GDP.'] 2
# ['Inflation', ''] 2
# ['CPI (%YoY)', 'Consumer price index (CPI) is defined as the change in the prices of a basket of goods and services that are typically\npurchased by specific groups of households. Whereas WPI measures change in wholesale prices for goods. Core CPI is\nconsumer price inflation excluding food and fuel.'] 2
# ['Core CPI (%YoY)', None] 2
# ['WPI (%YoY)', None] 2
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# page_num : 67
# table in page : 0
# page_num : 68
# table in page : 0
# page_num : 69
# table in page : 1
# ['', ''] 2
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
