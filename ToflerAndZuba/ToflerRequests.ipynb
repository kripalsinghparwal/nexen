# %%
###################### Code to fetch data using request wiht nonce and cname ###########################
from curl_cffi import requests
import hashlib
import pandas as pd
import time

def gen_nonce(cname: str) -> str:
    return hashlib.md5(("a" + cname).encode("utf-8")).hexdigest()

c_list = pd.read_excel(r"D:\Nexensus_Projects\ToflerAndZuba\input_folder\Book7.xlsx")[:30]['c_name'].tolist()
for c_name in c_list:
    # c_name =  "Compuage Infocom Limited"
    nonce = gen_nonce(c_name)

    url = "https://www.tofler.in/cnamesearch"  # <-- real endpoint

    payload = {
        "cname": c_name,   # space → tata+
        "nonce": nonce
    }

    headers = {
        "accept": "application/json, text/javascript, */*; q=0.01",
        "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
        "x-requested-with": "XMLHttpRequest",
        "origin": "https://www.tofler.in",
        "referer": "https://www.tofler.in/",
    }

    # cookies = {
    #     "ToflerSession": "ba9450cf69395a5c9ac47593abde13fd",
    #     # add other cookies if present
    # }

    resp = requests.post(
        url,
        impersonate="chrome",
        headers=headers,
        # cookies=cookies,
        data=payload,
    )
    print(c_name)
    print(resp.status_code)
    print(resp.json())
    print(type(resp.json()))
    print()
    time.sleep(0.5)
# Out:
# Devvrat Developers Private Limited
# 200
# [{'label': 'DEVVRAT DEVELOPERS PRIVATE LIMITED', 'status': 'Active', 'value': 'U70100MH1995PTC088764', 'subtype': 'companyinfo', 'url': '/devvrat-developers-private-limited/company/U70100MH1995PTC088764'}]
# <class 'list'>
#
# Omkara Assets Reconstruction Private Limited
# 200
# [{'label': 'OMKARA ASSETS RECONSTRUCTION PRIVATE LIMITED', 'status': 'Active', 'value': 'U67100TZ2014PTC020363', 'subtype': 'companyinfo', 'url': '/omkara-assets-reconstruction-private-limited/company/U67100TZ2014PTC020363'}, {'label': 'OMKARA ASSETS RECONSTRUCTION PRIVATE LIMITED (old name)', 'value': 'U67100TZ2014PTC020363', 'subtype': 'companyinfo', 'url': '/omkara-assets-reconstruction-private-limited/company/U67100TZ2014PTC020363'}]
# <class 'list'>
#
# Varma Steels Private Limited
# 200
# [{'label': 'VARMA STEELS PRIVATE LIMITED', 'status': 'Active', 'value': 'U51102TG2016PTC103003', 'subtype': 'companyinfo', 'url': '/varma-steels-private-limited/company/U51102TG2016PTC103003'}, {'label': 'VARMA STEELS CONSTRUCTIONS PRIVATE LIMITED', 'status': 'Active', 'value': 'U43900TS2023PTC176696', 'subtype': 'companyinfo', 'url': '/varma-steels-constructions-private-limited/company/U43900TS2023PTC176696'}]
# <class 'list'>
#
# Suraksha Realty Limited
# 200
# [{'label': 'SURAKSHA REALTY LIMITED', 'status': 'Active', 'value': 'U45201MH2008PLC180675', 'subtype': 'companyinfo', 'url': '/suraksha-realty-limited/company/U45201MH2008PLC180675'}, {'label': 'SURAKSHAPLUS REALTY INDIA LIMITED', 'status': 'Active', 'value': 'U45200MP2012PLC028478', 'subtype': 'companyinfo', 'url': '/surakshaplus-realty-india-limited/company/U45200MP2012PLC028478'}, {'label': 'SURAKSHA REALTY LIMITED (old name)', 'value': 'U45201MH2008PLC180675', 'subtype': 'companyinfo', 'url': '/suraksha-realty-limited/company/U45201MH2008PLC180675'}, {'label': 'SURAKSHAPLUS REALTY INDIA LIMITED (old name)', 'value': 'U45200MP2012PLC028478', 'subtype': 'companyinfo', 'url': '/surakshaplus-realty-india-limited/company/U45200MP2012PLC028478'}]
# <class 'list'>
#
# Hg Graphic Private Limited
# 200
# [{'label': 'H G GRAPHICS PRIVATE LIMITED', 'status': 'Active', 'value': 'U22219DL2013PTC247983', 'subtype': 'companyinfo', 'url': '/h-g-graphics-private-limited/company/U22219DL2013PTC247983'}]
# <class 'list'>
#
# Svc Co-Operative Bank Limited
# 200
# [{'label': 'No companies found', 'value': '', 'subtype': 'nomatch'}]
# <class 'list'>
#
# Kolon Investments Private Limited
# 200
# [{'label': 'KOLON INVESTMENTS PVT LTD', 'status': 'Under Liquidation', 'value': 'U70200GJ1993PTC113099', 'subtype': 'companyinfo', 'url': '/kolon-investments-pvt-ltd/company/U70200GJ1993PTC113099'}]
# <class 'list'>
#
# Kolon Investments Private Limited
# 200
# [{'label': 'KOLON INVESTMENTS PVT LTD', 'status': 'Under Liquidation', 'value': 'U70200GJ1993PTC113099', 'subtype': 'companyinfo', 'url': '/kolon-investments-pvt-ltd/company/U70200GJ1993PTC113099'}]
# <class 'list'>
#
# Omkara Assets Reconstruction Private Limited
# 200
# [{'label': 'OMKARA ASSETS RECONSTRUCTION PRIVATE LIMITED', 'status': 'Active', 'value': 'U67100TZ2014PTC020363', 'subtype': 'companyinfo', 'url': '/omkara-assets-reconstruction-private-limited/company/U67100TZ2014PTC020363'}, {'label': 'OMKARA ASSETS RECONSTRUCTION PRIVATE LIMITED (old name)', 'value': 'U67100TZ2014PTC020363', 'subtype': 'companyinfo', 'url': '/omkara-assets-reconstruction-private-limited/company/U67100TZ2014PTC020363'}]
# <class 'list'>
#
# Julabo Siskin Asea  Private Limited
# 200
# [{'label': 'JULABO SISKIN (ASEA) PRIVATE LIMITED', 'status': 'Active', 'value': 'U33127KA2001PTC029573', 'subtype': 'companyinfo', 'url': '/julabo-siskin-asea-private-limited/company/U33127KA2001PTC029573'}]
# <class 'list'>
#
# Aubergine Properties Private Limited
# 200
# [{'label': 'AUBERGINE PROPERTIES PRIVATE LIMITED', 'status': 'Active', 'value': 'U45201KA2006PTC038463', 'subtype': 'companyinfo', 'url': '/aubergine-properties-private-limited/company/U45201KA2006PTC038463'}]
# <class 'list'>
#
# Stbl Projects Limited
# 200
# [{'label': 'STBL PROJECTS LIMITED', 'status': 'Active', 'value': 'U45200AP2007PLC053028', 'subtype': 'companyinfo', 'url': '/stbl-projects-limited/company/U45200AP2007PLC053028'}, {'label': 'STBL PROJECTS LIMITED (old name)', 'value': 'U45200AP2007PLC053028', 'subtype': 'companyinfo', 'url': '/stbl-projects-limited/company/U45200AP2007PLC053028'}]
# <class 'list'>
#
# Punjab National Bank International Limited
# 200
# [{'label': 'No companies found', 'value': '', 'subtype': 'nomatch'}]
# <class 'list'>
#
# Julabo Siskin Asea Private Limited
# 200
# [{'label': 'JULABO SISKIN (ASEA) PRIVATE LIMITED', 'status': 'Active', 'value': 'U33127KA2001PTC029573', 'subtype': 'companyinfo', 'url': '/julabo-siskin-asea-private-limited/company/U33127KA2001PTC029573'}]
# <class 'list'>
#
# Narbada Gems And Jewellery Limited
# 200
# [{'label': 'NARBADA GEMS AND JEWELLERY LIMITED', 'status': 'Active', 'value': 'L01222TG1992PLC014173', 'subtype': 'companyinfo', 'url': '/narbada-gems-and-jewellery-limited/company/L01222TG1992PLC014173'}, {'label': 'NARBADA GEMS AND JEWELLERY LIMITED (old name)', 'value': 'L01222TG1992PLC014173', 'subtype': 'companyinfo', 'url': '/narbada-gems-and-jewellery-limited/company/L01222TG1992PLC014173'}]
# <class 'list'>
#
# Aman Ashiyana Makers Private Limited
# 200
# [{'label': 'AMAN ASHIYANA MAKERS PRIVATE LIMITED', 'status': 'Strike Off', 'value': 'U45203MP2002PTC015373', 'subtype': 'companyinfo', 'url': '/aman-ashiyana-makers-private-limited/company/U45203MP2002PTC015373'}]
# <class 'list'>
#
# Miku Polymers & Plastics Limited
# 200
# [{'label': 'MIKU POLYMERS & PLASTICS LIMITED', 'status': 'Under CIRP', 'value': 'U51902GJ2019PLC106891', 'subtype': 'companyinfo', 'url': '/miku-polymers-and-plastics-limited/company/U51902GJ2019PLC106891'}]
# <class 'list'>
#
# Gujarat Power Corporation Limited
# 200
# [{'label': 'GUJARAT POWERGEN ENERGY CORPORATION PRIVATE LIMITED (old name)', 'value': 'U40100GJ1992PTC018284', 'subtype': 'companyinfo', 'url': '/gujarat-powergen-energy-corporation-private-limited/company/U40100GJ1992PTC018284'}]
# <class 'list'>
#
# Strategic Bizcom Services Private Limited
# 200
# [{'label': 'STRATEGIC BIZCOM SERVICES PRIVATE LIMITED', 'status': 'Active', 'value': 'U72900GJ2015PTC082067', 'subtype': 'companyinfo', 'url': '/strategic-bizcom-services-private-limited/company/U72900GJ2015PTC082067'}, {'label': 'Strategic Bizcom Services Private Limited (old name)', 'value': 'U72900GJ2015PTC082067', 'subtype': 'companyinfo', 'url': '/strategic-bizcom-services-private-limited/company/U72900GJ2015PTC082067'}]
# <class 'list'>
#
# The Nasik Merchants Co -Operative Bank Limited
# 200
# [{'label': 'No companies found', 'value': '', 'subtype': 'nomatch'}]
# <class 'list'>
#
# Mascot Dynamics Private Limited
# 200
# [{'label': 'MASCOT DYNAMICS PRIVATE LIMITED', 'status': 'Active', 'value': 'U29199MH2011PTC221875', 'subtype': 'companyinfo', 'url': '/mascot-dynamics-private-limited/company/U29199MH2011PTC221875'}, {'label': 'MASCOT DYNAMICS PRIVATE LIMITED (old name)', 'value': 'U29199MH2011PTC221875', 'subtype': 'companyinfo', 'url': '/mascot-dynamics-private-limited/company/U29199MH2011PTC221875'}]
# <class 'list'>
#
# Koncept Nirmaan Private Limited
# 200
# [{'label': 'KONCEPT NIRMAAN PRIVATE LIMITED', 'status': 'Active', 'value': 'U45200TG2004PTC043098', 'subtype': 'companyinfo', 'url': '/koncept-nirmaan-private-limited/company/U45200TG2004PTC043098'}]
# <class 'list'>
#
# Vignette India Private Limited
# 200
# [{'label': 'VIGNETTE INDIA PRIVATE LIMITED', 'status': 'Active', 'value': 'U72200TG2000PTC095399', 'subtype': 'companyinfo', 'url': '/vignette-india-private-limited/company/U72200TG2000PTC095399'}, {'label': 'VIGNETTE SOFTWARE DEVELOPMENT INDIA PRIVATE LIMITED (old name)', 'value': 'U72200TG2005PTC045191', 'subtype': 'companyinfo', 'url': '/vignette-software-development-india-private-limited/company/U72200TG2005PTC045191'}]
# <class 'list'>
#
# Narayani Resources Private Limited
# 200
# [{'label': 'NARAYANI RESOURCES PRIVATE LIMITED', 'status': 'Active', 'value': 'U51909WB2011PTC164746', 'subtype': 'companyinfo', 'url': '/narayani-resources-private-limited/company/U51909WB2011PTC164746'}, {'label': 'NARAYANI MINERALS & RESOURCES PRIVATE LIMITED', 'status': 'Active', 'value': 'U14290AP2020PTC114343', 'subtype': 'companyinfo', 'url': '/narayani-minerals-and-resources-private-limited/company/U14290AP2020PTC114343'}, {'label': 'NARAYANI RESOURCES PRIVATE LIMITED (old name)', 'value': 'U51909WB2011PTC164746', 'subtype': 'companyinfo', 'url': '/narayani-resources-private-limited/company/U51909WB2011PTC164746'}]
# <class 'list'>
#
# Lanco Babandh Power Limited
# 200
# [{'label': 'LANCO BABANDH POWER LIMITED', 'status': 'Under Liquidation', 'value': 'U40104TG2007PLC054207', 'subtype': 'companyinfo', 'url': '/lanco-babandh-power-limited/company/U40104TG2007PLC054207'}, {'label': 'LANCO BABANDH POWER PRIVATE LIMITED (old name)', 'value': 'U40104TG2007PLC054207', 'subtype': 'companyinfo', 'url': '/lanco-babandh-power-private-limited/company/U40104TG2007PLC054207'}]
# <class 'list'>
#
# Fiora Online Limited
# 200
# [{'label': 'FIORA ONLINE LIMITED', 'status': 'Active', 'value': 'U74999MH2017PLC303402', 'subtype': 'companyinfo', 'url': '/fiora-online-limited/company/U74999MH2017PLC303402'}]
# <class 'list'>
#
# Sree Bajrang Infracon Private Limited
# 200
# [{'label': 'SREE BAJRANG INFRACON PRIVATE LIMITED (old name)', 'value': 'U45209AS2013PTC011550', 'subtype': 'companyinfo', 'url': '/sree-bajrang-infracon-private-limited/company/U45209AS2013PTC011550'}]
# <class 'list'>
#
# Allcheckdeals India Private Limited
# 200
# [{'label': 'ALLCHECKDEALS INDIA PRIVATE LIMITED', 'status': 'Active', 'value': 'U72400DL2008PTC181632', 'subtype': 'companyinfo', 'url': '/allcheckdeals-india-private-limited/company/U72400DL2008PTC181632'}, {'label': 'Allcheckdeals India Private Limited (old name)', 'value': 'U72400DL2008PTC181632', 'subtype': 'companyinfo', 'url': '/allcheckdeals-india-private-limited/company/U72400DL2008PTC181632'}]
# <class 'list'>
#
# Tidal Laboratories Private Limited
# 200
# [{'label': 'TIDAL LABORATORIES PRIVATE LIMITED', 'status': 'Active', 'value': 'U24230MH1994PTC084152', 'subtype': 'companyinfo', 'url': '/tidal-laboratories-private-limited/company/U24230MH1994PTC084152'}]
# <class 'list'>
#
# Jaidayal Packaging Private Limited
# 200
# [{'label': 'No companies found', 'value': '', 'subtype': 'nomatch'}]
# <class 'list'>

# %%
PRIVATE_LIMITED_LOOKUP = {
    # ===============================
    # Standard spaced forms
    # ===============================
    "PRIVATE LIMITED": "PRIVATE LIMITED",
    "PRIVATE LTD": "PRIVATE LIMITED",
    "PVT LIMITED": "PRIVATE LIMITED",
    "PVT LTD": "PRIVATE LIMITED",

    # ===============================
    # No-space / joined forms
    # ===============================
    "PRIVATELIMITED": "PRIVATE LIMITED",
    "PRIVATELTD": "PRIVATE LIMITED",
    "PVTLIMITED": "PRIVATE LIMITED",
    "PVTLTD": "PRIVATE LIMITED",

    # ===============================
    # Dot / comma separated
    # ===============================
    "PRIVATE.LIMITED": "PRIVATE LIMITED",
    "PRIVATE,LIMITED": "PRIVATE LIMITED",
    "PRIVATE.LTD": "PRIVATE LIMITED",
    "PRIVATE,LTD": "PRIVATE LIMITED",
    "PVT.LIMITED": "PRIVATE LIMITED",
    "PVT,LIMITED": "PRIVATE LIMITED",
    "PVT.LTD": "PRIVATE LIMITED",
    "PVT,LTD": "PRIVATE LIMITED",

    # ===============================
    # Trailing punctuation
    # ===============================
    "PVT. LTD." : "PRIVATE LIMITED",
    "PVT. LTD" : "PRIVATE LIMITED",
    "PVT LTD." : "PRIVATE LIMITED",
    "PVT.LTD.": "PRIVATE LIMITED",
    "PVT.LTD,": "PRIVATE LIMITED",
    "PVTLTD.": "PRIVATE LIMITED",
    "PVTLTD,": "PRIVATE LIMITED",

    # ===============================
    # Bracketed PRIVATE + LTD (NO space)
    # e.g. Integera Software Services(Pvt)Ltd
    # ===============================
    "(PVT)LTD": "PRIVATE LIMITED",
    "(PVT)LIMITED": "PRIVATE LIMITED",
    "(PRIVATE)LTD": "PRIVATE LIMITED",
    "(PRIVATE)LIMITED": "PRIVATE LIMITED",

    "(PVT).LTD.": "PRIVATE LIMITED",
    "(PVT).LTD": "PRIVATE LIMITED",
    "(PVT)LTD.": "PRIVATE LIMITED",
    "(PVT).LIMITED.": "PRIVATE LIMITED",
    "(PRIVATE).LTD.": "PRIVATE LIMITED",
    "(PRIVATE).LIMITED.": "PRIVATE LIMITED",

    # ===============================
    # Bracketed PRIVATE + LTD (WITH space)
    # ===============================
    "(PVT) LTD": "PRIVATE LIMITED",
    "(PRIVATE) LTD": "PRIVATE LIMITED",

    # ===============================
    # OCR / typo combinations
    # ===============================
    "PRIVATELIMTED": "PRIVATE LIMITED",
    "PRIVTELIMITED": "PRIVATE LIMITED",
    "PVTLIMTED": "PRIVATE LIMITED",
    "PVT LIMTED": "PRIVATE LIMITED",
    "P. LTD." : "PRIVATE LIMITED",
    "P. LTD" : "PRIVATE LIMITED",
    "P LTD." : "PRIVATE LIMITED",
    "P LTD" : "PRIVATE LIMITED"
}



PRIVATE_LOOKUP = {
    # Standard
    "PRIVATE,": "PRIVATE",
    "PRIVATE.": "PRIVATE",
    "PRIVATE": "PRIVATE",
    "PVT," : "PRIVATE",
    "PVT.": "PRIVATE",
    "PVT": "PRIVATE",

    # OCR / typos
    "PRIVTE": "PRIVATE",
    "PRVATE": "PRIVATE",
    "PRITVATE": "PRIVATE",

    # Joined / spacing issues
    "PRIV ATE": "PRIVATE",

    # Brackets / noise
    "(PRIVATE),": "PRIVATE",
    "(PRIVATE).": "PRIVATE",
    "(PRIVATE)": "PRIVATE",
    "(P)," : "PRIVATE",
    "(P)." : "PRIVATE",
    "(P)" : "PRIVATE",
}

LIMITED_LOOKUP = {
    # Standard
    "LIMITED," : "LIMITED",
    "LIMITED." : "LIMITED",
    "LIMITED": "LIMITED",
    "LTD.": "LIMITED",
    "LTD": "LIMITED",

    # OCR / typos
    "LIMTED,": "LIMITED",
    "LIMTED.": "LIMITED",
    "LIMTED": "LIMITED",
    "LIMTD": "LIMITED",
    "LMTD": "LIMITED",
    "L1TD": "LIMITED",
    "LT0": "LIMITED",

    # Joined / spacing issues
    "L T D": "LIMITED",
    "LTD ": "LIMITED",

    # Noise
    "(LTD),": "LIMITED",
    "(LTD).": "LIMITED",
    "(LTD)": "LIMITED",
}

LLP_LOOKUP = {
    # Standard
    "LLP" : "LLP",
    "LIMITED LIABILITY PARTNERSHIP": "LLP",
    "LIMITED LIABILITY PARTNERSHIP.": "LLP",
    "LIMITED LIABILITY PARTNERSHIP FIRM": "LLP",

    # Common abbreviations
    # "L L P": "LLP",
    # "L.L.P.": "LLP",
    # "L.L.P": "LLP",
    "LLP.": "LLP",
    "LLP," : "LLP",


    # Noise / brackets
    "(LLP).": "LLP",
    "(LLP),": "LLP",
    "(LLP)": "LLP",

}

INDIA_LOOKUP = {
    # Standard
    "INDIA": "INDIA",

    # Brackets / noise
    "(INDIA)." : "INDIA",
    "(INDIA)," : "INDIA",
    "(INDIA)": "INDIA",
    "(I)." : "INDIA",
    "(I)," : "INDIA",
    "(I)": "INDIA",
    }



def normalize_company_suffix(name: str) -> str:
    if not name:
        return name

    name_up = " ".join(name.upper().split())

    # Replace PRIVATE LIMITED first
    for key in sorted(PRIVATE_LIMITED_LOOKUP, key=len, reverse=True):
        name_up = name_up.replace(key, PRIVATE_LIMITED_LOOKUP[key])

    # Replace PRIVATE first
    for key in sorted(PRIVATE_LOOKUP, key=len, reverse=True):
        name_up = name_up.replace(key, PRIVATE_LOOKUP[key])

    # Replace LIMITED next
    for key in sorted(LIMITED_LOOKUP, key=len, reverse=True):
        name_up = name_up.replace(key, LIMITED_LOOKUP[key])

    # LLP
    for key in sorted(LLP_LOOKUP, key=len, reverse=True):
        name_up = name_up.replace(key, LLP_LOOKUP[key])

    # LLP
    for key in sorted(INDIA_LOOKUP, key=len, reverse=True):
        name_up = name_up.replace(key, INDIA_LOOKUP[key])

    return name_up

# %%
######################### Function wise processing for tofler ####################################################
import os
import time
import random
import pandas as pd
import re
from fuzzywuzzy import fuzz
from curl_cffi import requests
import hashlib


def human_delay(a=2, b=5):
    """Random sleep between a and b seconds."""
    time.sleep(random.uniform(a, b))


def extract_after_manager(simplified: str):
    # Split on "manager" (case-insensitive), only once
    parts = re.split(r'manager', simplified, flags=re.IGNORECASE)
    
    if len(parts) < 2:
        return simplified  # or return None if you prefer
    
    result = parts[1]

    # Remove leading spaces, commas, periods
    result = result.lstrip(" ,.")

    return result.strip()
# === Load Input Data ===
import pandas as pd
input_list = pd.read_excel(r"D:\Nexensus_Projects\ToflerAndZuba\input_folder\Book10.xlsx")['c_name'].drop_duplicates().to_list()[:]
output_path = 'testRequest.xlsx'
# === Resume if partial file exists ===
if os.path.exists(output_path):
    existing_df = pd.read_excel(output_path)
    processed_names = set(existing_df['input'])
    input_list = [name for name in input_list if name not in processed_names]
    all_data = existing_df.to_dict('records')
    print(f"🟡 Resuming — already processed {len(processed_names)} companies.")
else:
    print("🟢 Starting fresh extraction.")

# === Output File ===
all_data = []
batch_size = 5

# driver = start_driver()
def find_ratio(output_dict):
    input_name = output_dict['input']
    corrected_name = output_dict['corrected_name']
    if isinstance(corrected_name, float) or corrected_name is None:
        # ratio_list.append(0)
        output_dict['ratio'] = 0
        # output_dict = {"input": input_name, "cin": cin, "corrected_name": corrected_name, "status" : status, "ratio": 0}
    else:
        if fuzz.ratio(input_name.lower().strip(), corrected_name.lower().replace("(old name)", "").strip()) != 100:
            ratio = fuzz.ratio(normalize_company_suffix(input_name).strip(), normalize_company_suffix(corrected_name.replace("(old name)", "").strip()))
            # ratio_list.append(fuzz.ratio(normalize_company_suffix(row.input).strip(), normalize_company_suffix(row.corrected_name.replace("(old name)", "").strip())))
            output_dict['ratio'] = ratio
            # output_dict = {"input": input_name, "cin": cin, "corrected_name": corrected_name, "status" : status, "ratio": ratio}
        else:
            ratio = fuzz.ratio(input_name.lower().strip(), corrected_name.lower().replace("(old name)", "").strip())
            # ratio_list.append(fuzz.ratio(row.input.lower().strip(), row.corrected_name.lower().replace("(old name)", "").strip()))
            output_dict['ratio'] = ratio
            # output_dict = {"input": input_name, "cin": cin, "corrected_name": corrected_name, "status" : status, "ratio": ratio}
    return output_dict

def gen_nonce(cname: str) -> str:
    return hashlib.md5(("a" + cname).encode("utf-8")).hexdigest()

def process_company(input_name):
# for idx, input_name in enumerate(input_list, start=1):
    try:
        # driver = start_driver()
        nonce = gen_nonce(input_name)
    
        url = "https://www.tofler.in/cnamesearch"  # <-- real endpoint

        payload = {
            "cname": input_name,   # space → tata+
            "nonce": nonce
        }

        headers = {
            "accept": "application/json, text/javascript, */*; q=0.01",
            "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
            "x-requested-with": "XMLHttpRequest",
            "origin": "https://www.tofler.in",
            "referer": "https://www.tofler.in/",
        }

        # cookies = {
        #     "ToflerSession": "ba9450cf69395a5c9ac47593abde13fd",
        #     # add other cookies if present
        # }

        resp = requests.post(
            url,
            impersonate="chrome",
            headers=headers,
            # cookies=cookies,
            data=payload,
        )
        # print(input_name)
        # print(resp.status_code)
        resp_list = resp.json()
        # print()
        time.sleep(0.5)
        # print(resp_list)
        # [{'label': 'COMPUAGE INFOCOM LIMITED', 'status': 'Active', 'value': 'L99999MH1999PLC135914', 'subtype': 'companyinfo', 'url': '/compuage-infocom-limited/company/L99999MH1999PLC135914'}, {'label': 'COMPUAGE INFOCOM LIMITED', 'status': 'Not available for efiling', 'value': 'U30007TN1999PLC042926', 'subtype': 'companyinfo', 'url': '/compuage-infocom-limited/company/U30007TN1999PLC042926'}]
        if resp_list[0]['subtype'].strip() != 'nomatch':
            for elment in resp_list:
                try:
                    corrected_name = elment['label']
                    corrected_name = re.sub(r"\s+", " ", corrected_name).strip()
                except:
                    corrected_name = None
                try:
                    cin = elment['value']
                except:
                    cin = None
                # element_text = elment.text.strip()
                # element_text = re.sub(r"\s+", " ", element_text).strip()
                try:
                    status = elment['status']
                except:
                    status = None
                output_dict = {"input": input_name, "cin": cin, "corrected_name": corrected_name, "status" : status}
                output_dict = find_ratio(output_dict)
                if output_dict['ratio'] == 100 and output_dict['status'] == 'Active':
                    all_data.append(output_dict)
                    return output_dict
                else:
                    if output_dict not in all_data:
                        all_data.append(output_dict)
            # return all_data
            # return output_dict
            return {"input": input_name, "corrected_name": None, "cin": None, "status": None, 'ratio': None}
        else:
            print("❌ Failed — retrying with simplified name:", input_name)
            try:
                time.sleep(0.1)

                simplified = (
                    input_name.lower()
                    .replace("(p) limited.", "")
                    .replace("(p) limited", "")  
                    .replace("p limited.", "")  
                    .replace("p Limited", "")  
                    .replace("(p) ltd.", "")    
                    .replace("(p).ltd.", "")
                    .replace("p.Ltd.", "")  
                    .replace("p Ltd.", "")  
                    .replace("pLtd.", "")  
                    .replace("(p) Ltd", "")
                    .replace("(p)Ltd", "")
                    .replace("pLtd", "")  
                    .replace("p Ltd", "")          
                    .replace("limited.", "")
                    .replace("private.", "")
                    .replace("limited", "")
                    .replace("private", "")
                    .replace("pvt.", "")
                    .replace("ltd.", "")
                    .replace("pvt", "")
                    .replace("ltd", "")
                    .replace("llp.", "")
                    .replace("llp", "")
                    .replace("messers", "")
                    .replace("messars", "")
                    .replace("m/s", "")
                    .replace("()", "")
                    # .replace("A.O.,", "")
                    .strip()
                    .rstrip(',')
                    .lstrip(',')
                    .lstrip(".")
                )
                if len(simplified) == 3:
                    simplified = simplified + " "
                simplified = extract_after_manager(simplified)
                if "officer," in simplified:
                    simplified = simplified.split("officer,")[1].strip()
                elif "officer ," in simplified:
                    simplified = simplified.split("officer,")[1].strip()

                nonce = gen_nonce(simplified)
            
                url = "https://www.tofler.in/cnamesearch"  # <-- real endpoint

                payload = {
                    "cname": simplified,   # space → tata+
                    "nonce": nonce
                }

                headers = {
                    "accept": "application/json, text/javascript, */*; q=0.01",
                    "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
                    "x-requested-with": "XMLHttpRequest",
                    "origin": "https://www.tofler.in",
                    "referer": "https://www.tofler.in/",
                }

                # cookies = {
                #     "ToflerSession": "ba9450cf69395a5c9ac47593abde13fd",
                #     # add other cookies if present
                # }

                resp = requests.post(
                    url,
                    impersonate="chrome",
                    headers=headers,
                    # cookies=cookies,
                    data=payload,
                )
                # print(input_name)
                # print(resp.status_code)
                resp_list = resp.json()
                # print()
                time.sleep(0.5)
                print(len(resp_list))
                if resp_list[0]['subtype'].strip() != 'nomatch':
                    for elment in resp_list:
                        try:
                            corrected_name = elment['label']
                            corrected_name = re.sub(r"\s+", " ", corrected_name).strip()
                        except:
                            corrected_name = None
                        try:
                            cin = elment['value']
                        except:
                            cin = None
                        # element_text = elment.text.strip()
                        # element_text = re.sub(r"\s+", " ", element_text).strip()
                        try:
                            status = elment['status']
                        except:
                            status = None

                        output_dict = {"input": input_name, "cin": cin, "corrected_name": corrected_name, "status" : status}
                        output_dict = find_ratio(output_dict)
                        if output_dict['ratio'] == 100 and output_dict['status'] == 'Active':
                            all_data.append(output_dict)
                            return output_dict
                        else:
                            if output_dict not in all_data:
                                all_data.append(output_dict)
                    # return all_data
                    # return output_dict
                    return {"input": input_name, "corrected_name": None, "cin": None, "status": None, 'ratio': None}
                else:
                    output_dict = {"input": input_name, "corrected_name": None, "cin": None, "status": None, 'ratio': None}
                    all_data.append(output_dict)
                    return output_dict
            except Exception as e:
                # print("🚫 Not found:", input_name)
                print("exception 1: ", e)
                output_dict = {"input": input_name, "corrected_name": None, "cin": None, "status": None, 'ratio': None}
                if output_dict not in all_data:
                    all_data.append(output_dict)
                # return all_data
                return output_dict
    except Exception as e:
        # print("🚫 Not found:", input_name)
        print("exception 2: ", e)
        output_dict = {"input": input_name, "corrected_name": None, "cin": None, "status": None, 'ratio': None}
        if output_dict not in all_data:
            all_data.append(output_dict)
        # return all_data
        return output_dict
# # driver.quit()
# driver = start_driver()
idx = 1
# def check_restart_driver(driver):
#     # === Restart driver + Save progress after every 50 ===
#     if idx % batch_size == 0:
#         print(f"\n💾 Saving progress and restarting browser after {idx} companies...\n")
#         # pd.DataFrame(all_data).to_excel(output_path, index=False)
#         # print(f"✅ Progress saved to {output_path}")
#         driver.quit()
#         time.sleep(20)
#         driver = start_driver()
#     if idx % 200 == 0:
#         driver.quit()
#         print("sleeping for 1 minutes for recovery")
#         # time.sleep(300)
#         time.sleep(random.uniform(40, 60))
#         driver = start_driver()
#     return driver

# for input_name in input_list :
#     print("output :", process_company(input_name))
#     idx += 1
#     print("idx :", idx)
# Out:
# 🟡 Resuming — already processed 223 companies.

# %%
# === Final save ===
output_path = 'testRequest.xlsx'

if all_data:
    final_df = pd.DataFrame(all_data)
    # final_df = pd.read_excel(r"D:\Nexensus_Projects\ToflerAndZuba\Book7_data.xlsx")
    ratio_list = []

    # for row in final_df.itertuples():
    #     if isinstance(row.corrected_name, float) or row.corrected_name is None:
    #         ratio_list.append(0)
    #     else:
    #         ratio_list.append(fuzz.ratio(row.input.lower(), row.corrected_name.lower().replace("(old name)", "").strip()))

    # final_df['ratio'] = ratio_list
    
    for row in final_df.itertuples():
        if isinstance(row.corrected_name, float) or row.corrected_name is None:
            ratio_list.append(0)
        else:
            if fuzz.ratio(row.input.lower().strip(), row.corrected_name.lower().replace("(old name)", "").strip()) != 100:
                ratio_list.append(fuzz.ratio(normalize_company_suffix(row.input).strip(), normalize_company_suffix(row.corrected_name.replace("(old name)", "").strip())))
            else:
                ratio_list.append(fuzz.ratio(row.input.lower().strip(), row.corrected_name.lower().replace("(old name)", "").strip()))

    final_df['ratio'] = ratio_list

    # --- 1) Filter Active + ratio == 100 ---
    df_100_active = final_df[(final_df['status'] == 'Active') & (final_df['ratio'] == 100)]

    # --- 2) Remove rows from df_100_active based on input column ---
    df_remaining = final_df[~final_df['input'].isin(df_100_active['input'])]

    # --- 3) Filter 80Plus from remaining ---
    df_80_plus = df_remaining[df_remaining['ratio'] >= 80]

    # --- 4) Remaining after removing 80Plus ---
    df_remaining_final = df_remaining[~df_remaining['input'].isin(df_80_plus['input'])]

    # --- Save to Excel with multiple sheets ---
    with pd.ExcelWriter(output_path, engine='openpyxl') as writer:
        final_df.to_excel(writer, sheet_name='allData', index=False)
        df_100_active.to_excel(writer, sheet_name='100Active', index=False)
        df_80_plus.to_excel(writer, sheet_name='80Plus', index=False)
        df_remaining_final.to_excel(writer, sheet_name='remaining', index=False)

    print(f"🎉 All done! Final file saved to {output_path}")
# Out:
# 🎉 All done! Final file saved to testRequest.xlsx

# %%
process_company('SHIVALIK COTSYN PRIVATE LIMITED')
# Out:
# {'input': 'SHIVALIK COTSYN PRIVATE LIMITED',
#  'cin': 'U17111UP1993PTC015765',
#  'corrected_name': 'SHIVALIK COTSYN PRIVATE LIMITED',
#  'status': 'Active',
#  'ratio': 100}

# %%
######################### Block to get nonce from string  #########################################
import hashlib

def gen_nonce(cname: str) -> str:
    return hashlib.md5(("a" + cname).encode("utf-8")).hexdigest()

print(gen_nonce("tata"))
print(gen_nonce("tata moto"))
# Out:
# 5af9ecd6dde388230086089d06c79afd
# 1d037a85f0c187d5587a26e50a41ae15
