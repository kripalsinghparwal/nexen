# %%
PRIVATE_LIMITED_LOOKUP = {
    # ===============================
    # Standard spaced forms
    # ===============================
    "PRIVATE LIMITED": "PRIVATE LIMITED",
    "PRIVATE LTD": "PRIVATE LIMITED",
    "PVT LIMITED": "PRIVATE LIMITED",
    "PVT LTD": "PRIVATE LIMITED",

    # ===============================
    # No-space / joined forms
    # ===============================
    "PRIVATELIMITED": "PRIVATE LIMITED",
    "PRIVATELTD": "PRIVATE LIMITED",
    "PVTLIMITED": "PRIVATE LIMITED",
    "PVTLTD": "PRIVATE LIMITED",

    # ===============================
    # Dot / comma separated
    # ===============================
    "PRIVATE.LIMITED": "PRIVATE LIMITED",
    "PRIVATE,LIMITED": "PRIVATE LIMITED",
    "PRIVATE.LTD": "PRIVATE LIMITED",
    "PRIVATE,LTD": "PRIVATE LIMITED",
    "PVT.LIMITED": "PRIVATE LIMITED",
    "PVT,LIMITED": "PRIVATE LIMITED",
    "PVT.LTD": "PRIVATE LIMITED",
    "PVT,LTD": "PRIVATE LIMITED",

    # ===============================
    # Trailing punctuation
    # ===============================
    "PVT.LTD.": "PRIVATE LIMITED",
    "PVT.LTD,": "PRIVATE LIMITED",
    "PVTLTD.": "PRIVATE LIMITED",
    "PVTLTD,": "PRIVATE LIMITED",

    # ===============================
    # Bracketed PRIVATE + LTD (NO space)
    # e.g. Integera Software Services(Pvt)Ltd
    # ===============================
    "(PVT)LTD": "PRIVATE LIMITED",
    "(PVT)LIMITED": "PRIVATE LIMITED",
    "(PRIVATE)LTD": "PRIVATE LIMITED",
    "(PRIVATE)LIMITED": "PRIVATE LIMITED",

    "(PVT).LTD.": "PRIVATE LIMITED",
    "(PVT).LTD": "PRIVATE LIMITED",
    "(PVT)LTD.": "PRIVATE LIMITED",
    "(PVT).LIMITED.": "PRIVATE LIMITED",
    "(PRIVATE).LTD.": "PRIVATE LIMITED",
    "(PRIVATE).LIMITED.": "PRIVATE LIMITED",

    # ===============================
    # Bracketed PRIVATE + LTD (WITH space)
    # ===============================
    "(PVT) LTD": "PRIVATE LIMITED",
    "(PRIVATE) LTD": "PRIVATE LIMITED",

    # ===============================
    # OCR / typo combinations
    # ===============================
    "PRIVATELIMTED": "PRIVATE LIMITED",
    "PRIVTELIMITED": "PRIVATE LIMITED",
    "PVTLIMTED": "PRIVATE LIMITED",
    "PVT LIMTED": "PRIVATE LIMITED",
}



PRIVATE_LOOKUP = {
    # Standard
    "PRIVATE,": "PRIVATE",
    "PRIVATE.": "PRIVATE",
    "PRIVATE": "PRIVATE",
    "PVT," : "PRIVATE",
    "PVT.": "PRIVATE",
    "PVT": "PRIVATE",

    # OCR / typos
    "PRIVTE": "PRIVATE",
    "PRVATE": "PRIVATE",
    # " PRIATE": " PRIVATE",
    "PRITVATE": "PRIVATE",

    # Joined / spacing issues
    # " PV T": " PRIVATE",
    "PRIV ATE": "PRIVATE",

    # Brackets / noise
    "(PRIVATE),": "PRIVATE",
    "(PRIVATE).": "PRIVATE",
    "(PRIVATE)": "PRIVATE",
    "(P)," : "PRIVATE",
    "(P)." : "PRIVATE",
    "(P)" : "PRIVATE",
}

LIMITED_LOOKUP = {
    # Standard
    "LIMITED," : "LIMITED",
    "LIMITED." : "LIMITED",
    "LIMITED": "LIMITED",
    "LTD.": "LIMITED",
    "LTD": "LIMITED",

    # OCR / typos
    "LIMTED,": "LIMITED",
    "LIMTED.": "LIMITED",
    "LIMTED": "LIMITED",
    "LIMTD": "LIMITED",
    "LMTD": "LIMITED",
    "L1TD": "LIMITED",
    "LT0": "LIMITED",

    # Joined / spacing issues
    "L T D": "LIMITED",
    "LTD ": "LIMITED",

    # Noise
    "(LTD),": "LIMITED",
    "(LTD).": "LIMITED",
    "(LTD)": "LIMITED",
}

LLP_LOOKUP = {
    # Standard
    "LLP" : "LLP",
    "LIMITED LIABILITY PARTNERSHIP": "LLP",
    "LIMITED LIABILITY PARTNERSHIP.": "LLP",
    "LIMITED LIABILITY PARTNERSHIP FIRM": "LLP",

    # Common abbreviations
    # "L L P": "LLP",
    # "L.L.P.": "LLP",
    # "L.L.P": "LLP",
    "LLP.": "LLP",
    "LLP," : "LLP",

    # OCR / typo variants (very common in scanned orders)
    # "LL P": "LLP",
    # "LLR": "LLP",
    # "ILP": "LLP",
    # "LIP": "LLP",
    # "L L R": "LLP",

    # Noise / brackets
    "(LLP).": "LLP",
    "(LLP),": "LLP",
    "(LLP)": "LLP",

}

INDIA_LOOKUP = {
    # Standard
    "INDIA": "INDIA",

    # Abbreviations
    # "IND": "INDIA",
    # "IND.": "INDIA",

    # Common OCR / typo variants
    # "INDA": "INDIA",
    # "INDlA": "INDIA",   # lowercase L instead of I
    # "1NDIA": "INDIA",   # 1 instead of I
    # "IN DIA": "INDIA",

    # Joined / spacing issues
    # "I N D I A": "INDIA",

    # Brackets / noise
    "(INDIA)." : "INDIA",
    "(INDIA)," : "INDIA",
    "(INDIA)": "INDIA",
    "(I)." : "INDIA",
    "(I)," : "INDIA",
    "(I)": "INDIA",
    }



def normalize_company_suffix(name: str) -> str:
    if not name:
        return name

    name_up = " ".join(name.upper().split())

    # Replace PRIVATE LIMITED first
    for key in sorted(PRIVATE_LIMITED_LOOKUP, key=len, reverse=True):
        name_up = name_up.replace(key, PRIVATE_LIMITED_LOOKUP[key])

    # Replace PRIVATE first
    for key in sorted(PRIVATE_LOOKUP, key=len, reverse=True):
        name_up = name_up.replace(key, PRIVATE_LOOKUP[key])

    # Replace LIMITED next
    for key in sorted(LIMITED_LOOKUP, key=len, reverse=True):
        name_up = name_up.replace(key, LIMITED_LOOKUP[key])

    # LLP
    for key in sorted(LLP_LOOKUP, key=len, reverse=True):
        name_up = name_up.replace(key, LLP_LOOKUP[key])

    # LLP
    for key in sorted(INDIA_LOOKUP, key=len, reverse=True):
        name_up = name_up.replace(key, INDIA_LOOKUP[key])

    return name_up

# %%
######################### Batch wise processing for tofler using selenium ####################################################
import os
import time
import random
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import re
from fuzzywuzzy import fuzz

# === List of realistic user agents (desktop + mobile mix) ===
USER_AGENTS = [
    # Chrome (Windows)
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
    "(KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    # Edge
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
    "(KHTML, like Gecko) Chrome/118.0.5993.90 Safari/537.36 Edg/118.0.2088.61",
    # Firefox
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:120.0) Gecko/20100101 Firefox/120.0",
]

def human_delay(a=2, b=5):
    """Random sleep between a and b seconds."""
    time.sleep(random.uniform(a, b))

def start_driver():
    """Initialize and return a new Chrome WebDriver instance with random user-agent."""
    ua = random.choice(USER_AGENTS)
    print(f"🧠 Using User-Agent: {ua}\n")

    service = Service(ChromeDriverManager().install())
    options = Options()

    # --- Headless Mode ---
    options.add_argument("--headless=new")     # Recommended for Chrome 109+
    options.add_argument("--window-size=1920,1080")

    options.add_argument("--disable-notifications")
    options.add_argument("--start-maximized")
    options.add_argument(f"user-agent={ua}")
    options.add_argument("--disable-blink-features=AutomationControlled")
    options.add_experimental_option("excludeSwitches", ["enable-automation"])
    options.add_experimental_option("useAutomationExtension", False)
    driver = webdriver.Chrome(service=service, options=options)
    return driver

def extract_after_manager(simplified: str):
    # Split on "manager" (case-insensitive), only once
    parts = re.split(r'manager', simplified, flags=re.IGNORECASE)
    
    if len(parts) < 2:
        return simplified  # or return None if you prefer
    
    result = parts[1]

    # Remove leading spaces, commas, periods
    result = result.lstrip(" ,.")

    return result.strip()
# === Load Input Data ===
import pandas as pd
input_list = pd.read_excel(r"D:\Nexensus_Projects\ToflerAndZuba\input_folder\Highcourt.xlsx")['c_name'].drop_duplicates().to_list()[:]

# === Output File ===
output_path = "HC_data.xlsx"
all_data = []

# === Resume if partial file exists ===
if os.path.exists(output_path):
    existing_df = pd.read_excel(output_path)
    processed_names = set(existing_df['input'])
    input_list = [name for name in input_list if name not in processed_names]
    all_data = existing_df.to_dict('records')
    print(f"🟡 Resuming — already processed {len(processed_names)} companies.")
else:
    print("🟢 Starting fresh extraction.")

batch_size = 50
driver = start_driver()

for idx, input_name in enumerate(input_list, start=1):
    try:
        driver.get("https://www.tofler.in/")
        time.sleep(2)

        # Clean company name for first attempt
        clean_name = input_name.strip().rstrip(',')
        driver.find_element(By.ID, "searchbox").send_keys(clean_name)
        time.sleep(4)
        # driver.find_element(By.ID, "ui-id-1").click()
        # time.sleep(2)

        # cin = driver.current_url.split("/")[-1]
        # corrected_name = driver.find_element(
        #     By.CLASS_NAME, "company_title.items-center.nowrap.gap-16"
        # ).text.strip()
        ul = driver.find_element(By.ID, "ui-id-1")
        for elment in ul.find_elements(By.TAG_NAME, "li"):
            corrected_name = elment.find_element(By.TAG_NAME, "a").get_attribute('data-company')
            corrected_name = re.sub(r"\s+", " ", corrected_name).strip()
            cin = elment.find_element(By.TAG_NAME, "a").get_attribute('data-cin')
            element_text = elment.text.strip()
            element_text = re.sub(r"\s+", " ", element_text).strip()
            status = element_text.lower().replace(corrected_name.lower(), "").strip().capitalize()

            print({"input": input_name, "cin": cin, "corrected_name": corrected_name, "status" : status})
            all_data.append({"input": input_name, "corrected_name": corrected_name, "cin": cin, 'status' : status})
        # print()

    except Exception:
        print("❌ Failed — retrying with simplified name:", input_name)
        try:
            driver.get("https://www.tofler.in/")
            time.sleep(2)

            simplified = (
                input_name.lower()
                .replace("(p) limited.", "")
                .replace("(p) limited", "")  
                .replace("p limited.", "")  
                .replace("p Limited", "")  
                .replace("(p) ltd.", "")    
                .replace("(p).ltd.", "")
                .replace("p.Ltd.", "")  
                .replace("p Ltd.", "")  
                .replace("pLtd.", "")  
                .replace("(p) Ltd", "")
                .replace("(p)Ltd", "")
                .replace("pLtd", "")  
                .replace("p Ltd", "")          
                .replace("limited.", "")
                .replace("private.", "")
                .replace("limited", "")
                .replace("private", "")
                .replace("pvt.", "")
                .replace("ltd.", "")
                .replace("pvt", "")
                .replace("ltd", "")
                .replace("llp.", "")
                .replace("llp", "")
                .replace("messers", "")
                .replace("messars", "")
                .replace("m/s", "")
                .replace("()", "")
                # .replace("A.O.,", "")
                .strip()
                .rstrip(',')
                .lstrip(',')
                .lstrip(".")
            )
            if len(simplified) == 3:
                simplified = simplified + " "
            simplified = extract_after_manager(simplified)
            if "officer," in simplified:
                simplified = simplified.split("officer,")[1].strip()
            elif "officer ," in simplified:
                simplified = simplified.split("officer,")[1].strip()
            driver.find_element(By.ID, "searchbox").send_keys(simplified)
            time.sleep(4)
            # driver.find_element(By.ID, "ui-id-1").click()
            # time.sleep(2)

            # cin = driver.current_url.split("/")[-1]
            # corrected_name = driver.find_element(
            #     By.CLASS_NAME, "company_title.items-center.nowrap.gap-16"
            # ).text.strip()
            ul = driver.find_element(By.ID, "ui-id-1")
            for elment in ul.find_elements(By.TAG_NAME, "li"):
                corrected_name = elment.find_element(By.TAG_NAME, "a").get_attribute('data-company')
                corrected_name = re.sub(r"\s+", " ", corrected_name).strip()
                cin = elment.find_element(By.TAG_NAME, "a").get_attribute('data-cin')
                element_text = elment.text.strip()
                element_text = re.sub(r"\s+", " ", element_text).strip()
                status = element_text.lower().replace(corrected_name.lower(), "").strip().capitalize()

                print({"input": input_name, "cin": cin, "corrected_name": corrected_name, "status" : status})
                all_data.append({"input": input_name, "corrected_name": corrected_name, "cin": cin, 'status' : status})
            # print()

        except Exception as e:
            # print("🚫 Not found:", input_name)
            print("exception 2: ", e)
            all_data.append({"input": input_name, "corrected_name": None, "cin": None, "status": None})

    # === Restart driver + Save progress after every 50 ===
    if idx % batch_size == 0:
        print(f"\n💾 Saving progress and restarting browser after {idx} companies...\n")
        pd.DataFrame(all_data).to_excel(output_path, index=False)
        print(f"✅ Progress saved to {output_path}")

        driver.quit()
        time.sleep(20)
        driver = start_driver()
    if idx % 200 == 0:
        driver.quit()
        print("sleeping for 5 minutes for recovery")
        # time.sleep(300)
        time.sleep(random.uniform(80, 100))
        driver = start_driver()

# === Final save ===
driver.quit()
ratio_list = []
if all_data:
    final_df = pd.DataFrame(all_data)
    for row in final_df.itertuples():
        if type(row.corrected_name) == float or row.corrected_name == None:
            ratio_list.append(0)  
        else:
            ratio_list.append(fuzz.ratio(row.input.lower(), row.corrected_name.lower()))
    final_df['ratio'] = ratio_list
    final_df.to_excel(output_path, index=False)
    print(f"🎉 All done! Final file saved to {output_path}")

if all_data:
    final_df = pd.DataFrame(all_data)
    # final_df = pd.read_excel(r"D:\Nexensus_Projects\ToflerAndZuba\Book7_data.xlsx")
    ratio_list = []

    # for row in final_df.itertuples():
    #     if isinstance(row.corrected_name, float) or row.corrected_name is None:
    #         ratio_list.append(0)
    #     else:
    #         ratio_list.append(fuzz.ratio(row.input.lower(), row.corrected_name.lower().replace("(old name)", "").strip()))

    # final_df['ratio'] = ratio_list
    
    for row in final_df.itertuples():
        if isinstance(row.corrected_name, float) or row.corrected_name is None:
            ratio_list.append(0)
        else:
            if fuzz.ratio(row.input.lower().strip(), row.corrected_name.lower().replace("(old name)", "").strip()) != 100:
                ratio_list.append(fuzz.ratio(normalize_company_suffix(row.input).strip(), normalize_company_suffix(row.corrected_name.replace("(old name)", "").strip())))
            else:
                ratio_list.append(fuzz.ratio(row.input.lower().strip(), row.corrected_name.lower().replace("(old name)", "").strip()))

    final_df['ratio'] = ratio_list

    # --- 1) Filter Active + ratio == 100 ---
    df_100_active = final_df[(final_df['status'] == 'Active') & (final_df['ratio'] == 100)]

    # --- 2) Remove rows from df_100_active based on input column ---
    df_remaining = final_df[~final_df['input'].isin(df_100_active['input'])]

    # --- 3) Filter 80Plus from remaining ---
    df_80_plus = df_remaining[df_remaining['ratio'] >= 80]

    # --- 4) Remaining after removing 80Plus ---
    df_remaining_final = df_remaining[~df_remaining['input'].isin(df_80_plus['input'])]

    # --- Save to Excel with multiple sheets ---
    with pd.ExcelWriter(output_path, engine='openpyxl') as writer:
        final_df.to_excel(writer, sheet_name='allData', index=False)
        df_100_active.to_excel(writer, sheet_name='100Active', index=False)
        df_80_plus.to_excel(writer, sheet_name='80Plus', index=False)
        df_remaining_final.to_excel(writer, sheet_name='remaining', index=False)

    print(f"🎉 All done! Final file saved to {output_path}")
# Out:
# 🟡 Resuming — already processed 86850 companies.
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36
#
# ❌ Failed — retrying with simplified name: A1 Facility And Property Managers Pvt Limited
# ❌ Failed — retrying with simplified name: Addl. G.M. Manager Iti Ltd
# ❌ Failed — retrying with simplified name: Addl. General Manager, Iti Ltd
# ❌ Failed — retrying with simplified name: Aryavart Bank Branch Terakalan Barabanki Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Aryavart Bank Branch, Kamlabhari Shrawasti Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Aryavart Bank Presently U.P. Gramin Bank Kheri Thru. Authorized Officer / Regional Manager
# ❌ Failed — retrying with simplified name: Aryavart Bank Regional Office C930,931 Civil Lines Deva Road Barabanki Thru.Regional Manager
# ❌ Failed — retrying with simplified name: Aryavart Bank, Branch Office Fatehgarh, District Farrukhabad Through Branch Manager
# ❌ Failed — retrying with simplified name: Aryavart Bank, Chaubisi Branch, Barabanki Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Aryavart Bank, Mahewaganj, Lakhimpur Kheri Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Aryavart Gramin Bank , Branch Kothawan Hardoi Thru. Branch Manager
#
# 💾 Saving progress and restarting browser after 50 companies...
#
# ✅ Progress saved to HC_data.xlsx
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36
#
# ❌ Failed — retrying with simplified name: Assets Recovery Management (A.R.M.), Canara Bank, Branch Lucknow Through Its Senior Manager
# ❌ Failed — retrying with simplified name: Asst. General Manager, Iti Ltd
# ❌ Failed — retrying with simplified name: Atul Sharma. Bank Manager
# ❌ Failed — retrying with simplified name: Au Small Finance Bank Branch Manager
# ❌ Failed — retrying with simplified name: Au Small Finance Bank (Branch Ambabari) Through General Manager
# ❌ Failed — retrying with simplified name: Axis Bank , Notice To Be Served Upon Branch Manager
# ❌ Failed — retrying with simplified name: Axis Bank Branch Vibhuti Khand Lko. Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Axis Bank Represented By Its Manager
# ❌ Failed — retrying with simplified name: Axis Bank Thr Manager
# ❌ Failed — retrying with simplified name: Axis Bank Thro Branch Manager
# ❌ Failed — retrying with simplified name: Axis Bank Through Its Brach Manager
# ❌ Failed — retrying with simplified name: Axis Bank Through Its Manager
# ❌ Failed — retrying with simplified name: Axis Bank, Represented By Its Authorized Officer/Manager
# ❌ Failed — retrying with simplified name: Axis Bank,Mumbai, Thr. General Manager
# ❌ Failed — retrying with simplified name: Bandhan Bank Kolkata Thru. Its Chief Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Vaishali Branch, Ghaziabad Through Its Chief Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda , Mujaffara, Ayodhya Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda , Through Assistant General Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda , Through Deputy General Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda , Through General Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Bighapur, Unnao Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Branch At Chhawani Bazar Bahraich Thru. Authorized Officer And Chief Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Branch At Vikash Khand Jagdishpur Thru.Branch Head /Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Branch Barra Kanpur City Thru. Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Branch Hanuman Ganj Sultanpur Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Branch Hanumanganj Sultanpur Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Branch Hanumanganj Sultanpur Thru.Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Branch L.D.A. Colony Kanpur Road Lko. Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Branch Malwan, Post-Malwan, District-Fatehpur Through Its Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Branch Nirala Nagar Lko. Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Branch Pratapgarh Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Branch Ram Nagar Colony Shahjahanpur Thru. Seniour Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Branch Sarb Raibareli Thru. Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Card Vadodara, Thr. General Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Ikauna, Shravasti Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Jamunapur, Raebareli Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Lko. Thru. Regional Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Mahibullapur Branch Dd Thru. Senior Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Mohibullapur Lko Thru. Senior Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Represented By Its Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Service Through Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Shahganj, Ayodhya Thru. Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Thr. Its General Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Through Bank Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Through Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Through Its Authorised Officer And Chief Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Through Its Chief General Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Through Its Chief Manager,
#
# 💾 Saving progress and restarting browser after 100 companies...
#
# ✅ Progress saved to HC_data.xlsx
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36
#
# ❌ Failed — retrying with simplified name: Bank Of Baroda Through Its General Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Through Its Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Through The Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda Through The Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Ayodhya Thru. Its Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Branch Anpara Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Branch Bilsanda, Pilibhit District Pilibhit, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Branch- Hussainganj, Lko.Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Branch Koireepur Sultanpur Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Branch Laxmiganj, Kasganj Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Branch Sector-9, Lko. Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Branch-Golghar, Gorakhpur, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Branch-Hanumanganj, Sultanpur Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Directorate Of Animal Husbandry Lko Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Hanuman Ganj, Sultanpur Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Hanuman Ganj, Sultanpur, Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Hanumanganj, Sultanpur Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Hanumanganj, Sultanpur Thru. Ts Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Hanumanganj, Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Hanumanganj,Sultanpur Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Hanunamganj, Sultanpur, Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Hyderabad, Thr. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Lal Imli Branch, Shahjahanpur, Through Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Lalganj, Raebareli Thru. Its Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Lko. Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Main Branch Firozabad ,District Firozabad Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Main Branch Through Director / General Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Nagpur, Thr. Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Sangrampur, Amethi Thru. Its Branch Manager.
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Sultanpur Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Thootha Branch Rpr. By Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Through Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda, Through Its Manager
# ❌ Failed — retrying with simplified name: Bank Of Baroda,Jamunapur Chuarah, Unchahar, Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of India Represented By Its General Manager
# ❌ Failed — retrying with simplified name: Bank Of India (Boi) Through Manager
# ❌ Failed — retrying with simplified name: Bank Of India Branch Gandhi Park Gonda Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of India Branch Govindganj Shahjahanpur Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of India Centralised Pension Processing Centre Through Its General Manager
# ❌ Failed — retrying with simplified name: Bank Of India Kondhali Thr Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of India Thr, Its Zonal Manager
# ❌ Failed — retrying with simplified name: Bank Of India Thro Manager
# ❌ Failed — retrying with simplified name: Bank Of India Through Branch Manager,
# ❌ Failed — retrying with simplified name: Bank Of India Through General Manager
# ❌ Failed — retrying with simplified name: Bank Of India Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of India Through Its Manager
# ❌ Failed — retrying with simplified name: Bank Of India Through The General Manager
# ❌ Failed — retrying with simplified name: Bank Of India Through The Manager
# ❌ Failed — retrying with simplified name: Bank Of India, Asset Recovery Branch, Ranchi Zone Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of India, Budheshwar Branch, Lko. Thru. Its Manager
#
# 💾 Saving progress and restarting browser after 150 companies...
#
# ✅ Progress saved to HC_data.xlsx
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.5993.90 Safari/537.36 Edg/118.0.2088.61
#
# ❌ Failed — retrying with simplified name: Bank Of India, Chandrapur, Thr. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of India, Chief Manager
# ❌ Failed — retrying with simplified name: Bank Of India, Malkapur, Buldhana, Thr. Its Manager
# ❌ Failed — retrying with simplified name: Bank Of India, Mapusa Branch Thr Its Chief Manager
# ❌ Failed — retrying with simplified name: Bank Of India, Musafirkhana, Amethi Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of India, Through Its Chief General Manager, Hr
# ❌ Failed — retrying with simplified name: Bank Of India, Through Its Chief Manager
# ❌ Failed — retrying with simplified name: Bank Of India, Through Its Zonal Manager,
# ❌ Failed — retrying with simplified name: Bank Of India, Zonal Office, Thr. Its Zonal Manager
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra (Through Manager)
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra Disciplinary Authority And General Manager
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra Kozhikode Branch, Represented By Its Manager
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra Lko Thru. Authorized Officer/ Chief Manager
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra Main Branch, Nagpur, Thr. Zonal Manager
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra Rep By Its General Manager
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra Rep By Its Manager
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra Represented By Its Chief Manager
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra Thr Its Chief Manager
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra, Jagdishpur, Amethi Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra, Mumbai, Thr. Authorised Officer And Assistant General Manager
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra, Nagpur, Thr. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra, Through The General Manager,
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra, Wardhaman Nagar Br., Nagpur, Thr. Branch Manager
# ❌ Failed — retrying with simplified name: Bank Of Maharashtra, Zonal Office, Lucknow Thru. Its Chief Manager
# ❌ Failed — retrying with simplified name: Bank Of Maharasthra Represented By Manager
# ❌ Failed — retrying with simplified name: Baroda Gujarat Gramin Bank Thro Branch Manager
# ❌ Failed — retrying with simplified name: Baroda Gujarat Gramin Bank Through Regional Manager
# ❌ Failed — retrying with simplified name: Baroda U.P Gramin Bank, Hanumanganj, Sultanpur Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Bank Barara Buzurg Raebareli Thru. Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Bank Branch Chini Mill Gorakhpur Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Bank Branch Ghosi District Mau Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Bank Branch Hanuman Ganj Sultanpur Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Bank Branch Hanumanganj Sultanpur Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Bank Gandhinagar Raebareli Thru. Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Bank Through Its Regional Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Bank, Branch- Balrampur, District- Prayagraj Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Bank, Branch- Hanuman Ganj, Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Bank, Hanumanganj, Sultanpur Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Bank, Jaisinghpur, Sultanpur Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Gramin Bank Branch Dulhapur Sultanpur Thru.Branch Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Gramin Bank Branch Hanumanganj, Sultanpur Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Gramin Bank Kudwar Sultanpur Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Gramin Bank, Branch Bandipur, Ambedkar Nagar Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Baroda U.P. Gramin Bank, Hanumanganj. Sultanpur Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Baroda U.P.Bank, Ayodhya, Thru. Its Prescribed Officer/Regional Manager
# ❌ Failed — retrying with simplified name: Bharath Coperative Bank Rep By Its Manager
# ❌ Failed — retrying with simplified name: Bharti Axa Investment Managers Pvt Ltd
# ❌ Failed — retrying with simplified name: Bhumi Vikas Bank (Ldb) Bikapur Ayodhya Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Bhumi Vikas Bank Branch Nawabganj Gonda Thru. Branch Manager
#
# 💾 Saving progress and restarting browser after 200 companies...
#
# ✅ Progress saved to HC_data.xlsx
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:120.0) Gecko/20100101 Firefox/120.0
#
# sleeping for 5 minutes for recovery
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36
#
# ❌ Failed — retrying with simplified name: Bhumi Vikas Bank, Branch Nanauta, District Saharanpur Through Its Manager
# ❌ Failed — retrying with simplified name: Branch Manager Manager, The New India Insurance Co. Ltd
# ❌ Failed — retrying with simplified name: Branch Manager, Manager Magma General Insurance Company Limited
# ❌ Failed — retrying with simplified name: C/M Kisan Primary Pathsala Bankata Thru. Manager
# ❌ Failed — retrying with simplified name: Canara Bank Branch Alambagh Lko. Thru.Branch Manager
# ❌ Failed — retrying with simplified name: Canara Bank Thru. Its Authorised Officer Cum Chief Manager
# ❌ Failed — retrying with simplified name: Canara Bank (Rep Thorugh Its Branch Manager)
# ❌ Failed — retrying with simplified name: Canara Bank , Manga Talab Near Zaidpur Barabanki Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Canara Bank Arm Branch Agra Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Canara Bank Bengaluru, Thr. General Manager
# ❌ Failed — retrying with simplified name: Canara Bank E Syndicate Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Canara Bank Its Chief Manager
# ❌ Failed — retrying with simplified name: Canara Bank Jaipur House Agra U.P. Thru. Its Manager
# ❌ Failed — retrying with simplified name: Canara Bank Manga Talab Near Zaidpur Barabanki Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Canara Bank Rep By Manager,
# ❌ Failed — retrying with simplified name: Canara Bank Rep.By Branch Manager
# ❌ Failed — retrying with simplified name: Canara Bank Represented By Bank Manager
# ❌ Failed — retrying with simplified name: Canara Bank Represented By Its Manager
# ❌ Failed — retrying with simplified name: Canara Bank Represented By The Bank Manager,
# ❌ Failed — retrying with simplified name: Canara Bank Through Branch Manager,
# ❌ Failed — retrying with simplified name: Canara Bank Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Canara Bank Through Its Chief Manager
# ❌ Failed — retrying with simplified name: Canara Bank Through Its Regional Manager
# ❌ Failed — retrying with simplified name: Canara Bank, Rep By Its Senior Manager,
# ❌ Failed — retrying with simplified name: Canara Bank, Branch Atrauli, District Aligarh Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Canara Bank, Branch- Masauli, Barabanki Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Canara Bank, Branch, Kheri., Lakhimpur Kheri Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Canara Bank, Branch-Jalalabad, District-Ghaziabad Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Canara Bank, Jankipuram Lko. Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Canara Bank, Kheragarh, District Agra Through Its Branch Manager.
# ❌ Failed — retrying with simplified name: Canara Bank, Lakhimpur Kheri Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Canara Bank, Regional Office, Rdc Raj Nagar, Ghaziabad (201002), Through Its Regional Manager
# ❌ Failed — retrying with simplified name: Canara Bank, Regional Officer, Agra Through Its Regional Manager
# ❌ Failed — retrying with simplified name: Canara Bank, Represented By Its Manager,
# ❌ Failed — retrying with simplified name: Canara Bank, Through Its Assistant General Manager
# ❌ Failed — retrying with simplified name: Canara Bank, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Canara Bank, Through Its Branch Manager,
# ❌ Failed — retrying with simplified name: Canara Bank, Wandoor Branch,Represented By Its Manager,
# ❌ Failed — retrying with simplified name: Canra Bank Lakhimpur Kheri Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Canra Bank Through Its General Manager
# ❌ Failed — retrying with simplified name: Capital Small Finance Bank, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Cenara Bank Branch Jaidpur, Barabanki Thru. Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India , Lko Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India Branch Bindki, District Fatehpur Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India Branch Jhinjhak Kanpur Dehat Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India Branch Kosi Kala, District Mathura Through Its Branch Manager.
# ❌ Failed — retrying with simplified name: Central Bank Of India Civil Lines Thr Branch Manager
#
# 💾 Saving progress and restarting browser after 250 companies...
#
# ✅ Progress saved to HC_data.xlsx
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36
#
# ❌ Failed — retrying with simplified name: Central Bank Of India Head Office/Registered Office At Chander Mukhi Nariman Point Thru. Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India Thro Assistant General Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India Through Chief General Manager,
# ❌ Failed — retrying with simplified name: Central Bank Of India Through Chief Manager Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India Through Its Assistant General Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India Through Its Chief Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India Through Its General Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India Through Its Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India Through Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India Thru. Regional Manager Lko
# ❌ Failed — retrying with simplified name: Central Bank Of India, Branch Bara Bazar District Jhansi Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India, Branch, Favara, Agra Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India, Lko. Thru. Its Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India, Mumbai, Thr. General Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India, Rep By Its Genral Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Central Bank Of India, Through Its General Manager,
# ❌ Failed — retrying with simplified name: Central Bank Of India, Through Its Regional Manager
# ❌ Failed — retrying with simplified name: Central Bharath Copertive Bank Rep By Its General Manager
# ❌ Failed — retrying with simplified name: Chandrani Sen Maple Infra Inv It Manager Pvt Ltd
# ❌ Failed — retrying with simplified name: Chief General Manager,Mcl Ltd
# ❌ Failed — retrying with simplified name: Chief Manager, Iti Ltd
# ❌ Failed — retrying with simplified name: Citi Bank Sco 132-134 Sec 9C Madhya Marg Ut Chd Thr Branch Manager
# ❌ Failed — retrying with simplified name: City Union Bank Rep Its Manager,
# ❌ Failed — retrying with simplified name: City Union Bank Rep By Branch Manager
# ❌ Failed — retrying with simplified name: City Union Bank Rep By Its Manager,
# ❌ Failed — retrying with simplified name: City Union Bank, Represented By Branch Manager
# ❌ Failed — retrying with simplified name: Dcb Bank Lko. Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Dcb Bank Through Its Chief Manager
# ❌ Failed — retrying with simplified name: Dcb Bank, Through Its Banch Manager
# ❌ Failed — retrying with simplified name: Dena Bank (Now Bank Of Baroda), Deesa Branch, Through Its Manager
# ❌ Failed — retrying with simplified name: Dena Bank, Branch- 24/57, Birhana Raod, Kanpur Through Its Chief Manager
# ❌ Failed — retrying with simplified name: Deutsche Bank, Rep. By Its General Manager
# ❌ Failed — retrying with simplified name: Dillp
# ❌ Failed — retrying with simplified name: District Central Cooperative Bank, Hisar Through Its Manager
# ❌ Failed — retrying with simplified name: Dlllp
# ❌ Failed — retrying with simplified name: Esaf Small Finance Bank Represented By Its Manager.
# ❌ Failed — retrying with simplified name: Federal Bank Rep By Its General Manager
# ❌ Failed — retrying with simplified name: Federal Bank Rep By Its Manager
# ❌ Failed — retrying with simplified name: Federal Bank Represented By Bank Manager
# ❌ Failed — retrying with simplified name: Federal Bank Represented By Its General Manager
# ❌ Failed — retrying with simplified name: Federal Bank Represented By The Bank Manager
# ❌ Failed — retrying with simplified name: Federal Bank, Represented By The Bank Manager
# ❌ Failed — retrying with simplified name: Federal Bank, Malappuram Branch, Rep. By Its Branch Manager
# ❌ Failed — retrying with simplified name: Federal Bank, Rep. By Its Chief Manager
# ❌ Failed — retrying with simplified name: Fedral Bank Rep By The Generai Manager
#
# 💾 Saving progress and restarting browser after 300 companies...
#
# ✅ Progress saved to HC_data.xlsx
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36
#
# ❌ Failed — retrying with simplified name: Fedreal Bank Rep By Its Manager
# ❌ Failed — retrying with simplified name: Gadhingalaj Sahakari Bank, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: General Manager (Mining)- Cum-Project Officer, Mcl, Ltd
# ❌ Failed — retrying with simplified name: General Manager, Iti Ltd
# ❌ Failed — retrying with simplified name: General Manager,Mcl Ltd
# ❌ Failed — retrying with simplified name: General Manager.Mcl Ltd
# ❌ Failed — retrying with simplified name: Gollp
# ❌ Failed — retrying with simplified name: H.D.F.C. Bank Branch Khorhansa Gonda Thru. Branch Manager
# ❌ Failed — retrying with simplified name: H.D.F.C. Bank Branch, Masoodabad, District Aligarh Through Its Manager
# ❌ Failed — retrying with simplified name: H.D.F.C. Bank House, Through Its Manager
# ❌ Failed — retrying with simplified name: H.D.F.C. Bank Shahabad Hardoi Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Hdb Bank, Thr. Branch Manager
# ❌ Failed — retrying with simplified name: Hdfc Bank Repby Manager
# ❌ Failed — retrying with simplified name: Hdfc Bank The Branch Manager
# ❌ Failed — retrying with simplified name: Hdfc Bank Branch Padam Tower Kanpur Thru.Branch Manager
# ❌ Failed — retrying with simplified name: Hdfc Bank Mumbai, Thr. General Manager
# ❌ Failed — retrying with simplified name: Hdfc Bank Thr Manager
# ❌ Failed — retrying with simplified name: Hdfc Bank Thro Branch Manager
# ❌ Failed — retrying with simplified name: Hdfc Bank Through Branch Manager
# ❌ Failed — retrying with simplified name: Hdfc Bank Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Hdfc Bank Through Its General Manager
# ❌ Failed — retrying with simplified name: Hdfc Bank Through Manager
# ❌ Failed — retrying with simplified name: Hdfc Bank, Branch Tundla, District Firozabad, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Hdfc Bank, Sanjay Place, Agra Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Hdfc Bank, Through Branch Manager
# ❌ Failed — retrying with simplified name: I.C.I.C.I. Bank Gomti Nagar, Lko. Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: I.C.I.C.I. Bank Through Manager
# ❌ Failed — retrying with simplified name: Icici Bank , Nikol Branch Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Icici Bank Manager
# ❌ Failed — retrying with simplified name: Icici Bank Raebareli Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Icici Bank Rep By Branch Manager
# ❌ Failed — retrying with simplified name: Icici Bank Rep By It'S Manager,
# ❌ Failed — retrying with simplified name: Icici Bank Represeneted By Branch Manager
# ❌ Failed — retrying with simplified name: Icici Bank Represented By Bank Manager
# ❌ Failed — retrying with simplified name: Icici Bank Represented By The Bank Manager
# ❌ Failed — retrying with simplified name: Icici Bank Thr, Manager
# ❌ Failed — retrying with simplified name: Icici Bank Thro Branch Manager
# ❌ Failed — retrying with simplified name: Icici Bank Thro Manager
# ❌ Failed — retrying with simplified name: Icici Bank Through Brach Manager
# ❌ Failed — retrying with simplified name: Icici Bank Through Its Bank Manager
# ❌ Failed — retrying with simplified name: Icici Bank Through Its Manager
# ❌ Failed — retrying with simplified name: Icici Bank Through Manager
# ❌ Failed — retrying with simplified name: Icici Bank, Goregoan ( W) S.V Road Branch Represented By Its Branch Manager
# ❌ Failed — retrying with simplified name: Icici Bank, Through Branch Manager
# ❌ Failed — retrying with simplified name: Idbi Bank Thro Branch Manager
# ❌ Failed — retrying with simplified name: Idbi Bank Through Branch Manager
# ❌ Failed — retrying with simplified name: Idbi Bank Thru. Zonal Manager Lko
# ❌ Failed — retrying with simplified name: Idbi Bank, Represented By Bank Manager
# ❌ Failed — retrying with simplified name: Idfc Bank Through Branch Manager
#
# 💾 Saving progress and restarting browser after 350 companies...
#
# ✅ Progress saved to HC_data.xlsx
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:120.0) Gecko/20100101 Firefox/120.0
#
# ❌ Failed — retrying with simplified name: Idfc First Bank Thro Branch Manager
# ❌ Failed — retrying with simplified name: Idfc First Bank Through Manager
# ❌ Failed — retrying with simplified name: Idfc First Bank, Reperesented By Branch Manager
# ❌ Failed — retrying with simplified name: Idfc First Bank, Represented By Its Manager
# ❌ Failed — retrying with simplified name: Iifhl Bank Thru.Manager
# ❌ Failed — retrying with simplified name: Il And Fs Urban Infrastructure Managers Limited
# ❌ Failed — retrying with simplified name: Indian Bank Rep By Its Manager
# ❌ Failed — retrying with simplified name: Indian Bank ( Allahabad Bank ) Mewatipura, Bahraich Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank (Allahabad Bank) Branch Maigalganj Kheri Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank (Erstwhile Allahabad Bank ) A Body Corporate Thru.Authorized Officer /Chief Manager
# ❌ Failed — retrying with simplified name: Indian Bank (Erstwhile Allahabad Bank) Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank (Erstwhile Allahabad Bank) Through Its General Manager
# ❌ Failed — retrying with simplified name: Indian Bank (Erstwhile Bank Allahabad Bank), Thru. Chief Manager
# ❌ Failed — retrying with simplified name: Indian Bank (Ranchi Branch), Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank Branch Dharmshala Gorakhpur Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank Branch Sohanjani Tagan, District-Muzaffarnagar Through Its Branch Manager.
# ❌ Failed — retrying with simplified name: Indian Bank Branch Tavakkalpur Nagara Sultanpur Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank Branch Tulsipur Balrampur Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank Chief Manager
# ❌ Failed — retrying with simplified name: Indian Bank Estwhile Allahabad Bank, Gonda Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank Rep. By Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank Shrawasti Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank Thro Manager
# ❌ Failed — retrying with simplified name: Indian Bank Through Assistant General Manager
# ❌ Failed — retrying with simplified name: Indian Bank Through Authorized Officer / Chief Manager
# ❌ Failed — retrying with simplified name: Indian Bank Through Its Authorized Officer / Chief Manager
# ❌ Failed — retrying with simplified name: Indian Bank Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank Through Its Chief Manager
# ❌ Failed — retrying with simplified name: Indian Bank Through Its General Manager
# ❌ Failed — retrying with simplified name: Indian Bank Through Its Manager
# ❌ Failed — retrying with simplified name: Indian Bank, Branch Allahabad Katra Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank, Branch J.V.C. Badaut, District Bagpat, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank, Branch Naraini, District Banda, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank, Branch Tundla, District Firozabad, Through Manager
# ❌ Failed — retrying with simplified name: Indian Bank, Branch-Jasra, District-Prayagraj Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank, Branch-Kolana, Chunar, Mirzapur, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank, Prayagraj, Branch Katra Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank, Stressed Asset Management Large Branch, Kolkata, Through Its Chief Manager
# ❌ Failed — retrying with simplified name: Indian Bank, Swaroop Nagar Branch, In Front Of Motijheel, Kanpur Through Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank, Through Its Chief Manager
# ❌ Failed — retrying with simplified name: Indian Bank/Allahabad Bank Daulatpur Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Indian Bank/Allahabad Bank, Branch- Daulatpur (1480), Vabhanjot, Gonda Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Overseas Bank Santhome Branch By Its Manager
# ❌ Failed — retrying with simplified name: Indian Overseas Bank Represented By Its General Manager
# ❌ Failed — retrying with simplified name: Indian Overseas Bank Branch Bijnor Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Overseas Bank Represented By Its Assistant Manager
# ❌ Failed — retrying with simplified name: Indian Overseas Bank Represented By Its Manager
# ❌ Failed — retrying with simplified name: Indian Overseas Bank Represented By Its Senior Manager
# ❌ Failed — retrying with simplified name: Indian Overseas Bank Telibagh Branch Lko. Thru. Branch Manager
#
# 💾 Saving progress and restarting browser after 400 companies...
#
# ✅ Progress saved to HC_data.xlsx
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:120.0) Gecko/20100101 Firefox/120.0
#
# sleeping for 5 minutes for recovery
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:120.0) Gecko/20100101 Firefox/120.0
#
# ❌ Failed — retrying with simplified name: Indian Overseas Bank Thr The Assistant General Manager
# ❌ Failed — retrying with simplified name: Indian Overseas Bank Through Its Assistant Manager
# ❌ Failed — retrying with simplified name: Indian Overseas Bank Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Overseas Bank Through Its General Manager
# ❌ Failed — retrying with simplified name: Indian Overseas Bank, Branch Shahjahanpur , Through Its Authorized Officer (Manager)
# ❌ Failed — retrying with simplified name: Indian Overseas Bank, Branch Sikandra, District Agra, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indian Overseas Bank, Central Office 763, Anna Salai, Chennai-600002, Through Its Chief Manager
# ❌ Failed — retrying with simplified name: Indian Overseas Bank, Represented By Its Authorized Officer/Senior Manager,
# ❌ Failed — retrying with simplified name: Indian Overseas Bank, Represented Through Its General Manager
# ❌ Failed — retrying with simplified name: Indian Overseas Bank,Represented By Its Branch Manager,
# ❌ Failed — retrying with simplified name: Indusind Bank Mumbai, Thr. General Manager
# ❌ Failed — retrying with simplified name: Indusind Bank Represented By Bank Manager,
# ❌ Failed — retrying with simplified name: Indusind Bank Represented By Bank Manager
# ❌ Failed — retrying with simplified name: Indusind Bank Thr Manager
# ❌ Failed — retrying with simplified name: Indusind Bank Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Indusind Bank, Muvattupuzha Branch (Rep By Branch Manager)
# ❌ Failed — retrying with simplified name: Indusind Bank, Thodupuzha Branch (Rep By Branch Manager)
# ❌ Failed — retrying with simplified name: J And K Bank Th Its Branch Manager
# ❌ Failed — retrying with simplified name: Jana Small Finance Bank Thru Zonal Legal Manager
# ❌ Failed — retrying with simplified name: Kerala Bank, Puduppadi Branch, Represented By Its Manager
# ❌ Failed — retrying with simplified name: Kerala Bank, Taliparamba Branch (Rep By Branch Manager)
# ❌ Failed — retrying with simplified name: Kerala Gramin Bank Represented By Bank Manager
# ❌ Failed — retrying with simplified name: Kerala Gramin Bank Represented By Its Branch Manager
# ❌ Failed — retrying with simplified name: Kerala Gramin Bank Represented By Its General Manager
# ❌ Failed — retrying with simplified name: Kerala Gramin Bank Represented By Its Manager
# ❌ Failed — retrying with simplified name: Kerala Gramina Bank, Pulamanthole Branch, Rep. By Its Bank Manager
# ❌ Failed — retrying with simplified name: Kerala State Co-Operative Bank (Kerala Bank), Represented By Its Manager,
# ❌ Failed — retrying with simplified name: Kerala State Co-Operative Bank (Kerala Bank) Represented By Its General Manager.
# ❌ Failed — retrying with simplified name: Kerala State Co-Operative Bank (Kerala Bank), Rep.By Its Manager
# ❌ Failed — retrying with simplified name: Kerala State Co-Operative Bank Rep. By Its General Manager
# ❌ Failed — retrying with simplified name: Kerala State Cooperative Bank Represented By Its Branch Manager,
# ❌ Failed — retrying with simplified name: Kerala State Co-Operative Bank, Alanallur Branch Represented By Its Manager
# ❌ Failed — retrying with simplified name: Kerala State Co-Operative Bank, Erstwhile Mdc Bank, Perinthalmanna Main Branch Represented By Its Manager
# ❌ Failed — retrying with simplified name: Kerala State Co-Operative Bank, Koothattukulam Bank Rep. By Its Manager
# ❌ Failed — retrying with simplified name: Kerala State Co-Operative Bank, Rep. By Its Branch Manager,
# ❌ Failed — retrying with simplified name: Kerala State Co-Operative Bank, Rep. By Its Manager,
# ❌ Failed — retrying with simplified name: Kizhuvilam Service Co-Operative Bank, Kizhuvilam Branch, Represented By Its Manager
# ❌ Failed — retrying with simplified name: Kotak Mahindra Bank Mumbai, Thr. General Manager
# ❌ Failed — retrying with simplified name: Kotak Mahindra Bank Panjim Goa Branch, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Kotak Mahindra Bank Represented By Bank Manager
# ❌ Failed — retrying with simplified name: Kotak Mahindra Bank Thr. Its Branch Manager
# ❌ Failed — retrying with simplified name: Kotak Mahindra Bank Thro Manager
# ❌ Failed — retrying with simplified name: Kotak Mahindra Bank Through Its Branch Manager
#
# 💾 Saving progress and restarting browser after 450 companies...
#
# ✅ Progress saved to HC_data.xlsx
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:120.0) Gecko/20100101 Firefox/120.0
#
# ❌ Failed — retrying with simplified name: Kotak Mahindra Bank Through Its General Manager
# ❌ Failed — retrying with simplified name: Kotak Mahindra Bank Throuhg Branch Manager
# ❌ Failed — retrying with simplified name: Kotak Mahindra Bank, Branch Manager
# ❌ Failed — retrying with simplified name: Kotak Mahindra Bank, Thr. Its Manager
# ❌ Failed — retrying with simplified name: Land Sales Officer, U.P. Co-Operative Village Development Bank, Branch Amethi Thru. Branch Manager
# ❌ Failed — retrying with simplified name: A 1 Facility And Property Managers Private Ltd
# ❌ Failed — retrying with simplified name: Dena Gujarat Gramin Bank Through Branch Manager
# ❌ Failed — retrying with simplified name: Madarsa Ziyaul Islam Fatehpur Barabanki Thru. Manager
# ❌ Failed — retrying with simplified name: Maharashtra Gramin Bank Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Malwa Gramin Bank Through Its Manager
# ❌ Failed — retrying with simplified name: Manager Jct Limited
# ❌ Failed — retrying with simplified name: Marudhara Gramin Bank Through Branch Manager
# ❌ Failed — retrying with simplified name: Motilal Banoth, The United Commercial Bank, Through The Deputy Zonal Manager,
# ❌ Failed — retrying with simplified name: Mr. Rajiv Kumar Srivastava, Addl. General Manager, Iti Ltd
# ❌ Failed — retrying with simplified name: Ms National Highways Infra Investment Managers Private Limited
# ❌ Failed — retrying with simplified name: Nallp
# ❌ Failed — retrying with simplified name: National Bank For Agriculture And Rural Development Through Its Chief General Manager
# ❌ Failed — retrying with simplified name: National Bank For Agriculture And Rural Devpt. (Nabard), Thr. Chief General Manager
# ❌ Failed — retrying with simplified name: Ndian Overseas Bank, Branch Raj Bhawan,Lucknow, Through Its Assistant Manager
# ❌ Failed — retrying with simplified name: Nothern Arc Investment Managers Private Limited
# ❌ Failed — retrying with simplified name: Oriental Bank Of Commerce Branch Oc Urban Estate Patiala Thr Chief Manager
# ❌ Failed — retrying with simplified name: Oriental Bank Of Commerce Thru. Branch Manager Lko
# ❌ Failed — retrying with simplified name: Panjab National Bank, A Body Corporate, Nagpur, Thr. Its Manager
# ❌ Failed — retrying with simplified name: Panjab National Bank, Baraut, District-Baghpat, Uttar Pradesg-250611 Through Its Branch Manager.
# ❌ Failed — retrying with simplified name: Prathama Bank Thru. Chief Manager
# ❌ Failed — retrying with simplified name: Prathama Bank U.P. Gramin Bank Branch Mubarakpur, District Rampur Through It Branch Manager
# ❌ Failed — retrying with simplified name: Prathma U.P. Gramin Bank Head Office At Moradabad Branch Office Belsor Gonda Thru. Manager
# ❌ Failed — retrying with simplified name: Prathma U.P. Gramin Bank, Branch Biharigarh, District-Saharanpur Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Punjab & Sind Bank Branch-Gursandi, District Mirzapur (Through Its Branch Manager)
# ❌ Failed — retrying with simplified name: Punjab & Sind Bank, Through Branch Manager
# ❌ Failed — retrying with simplified name: Punjab And Sind Bank Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Punjab And Sind Bank Through Its Zonal Manager
# ❌ Failed — retrying with simplified name: Punjab And Sind Bank, Branch Bhunerheri Through Branch Manager
# ❌ Failed — retrying with simplified name: Punjab And Sind Bank, Branch Doraha Through Its Manager
#
# 💾 Saving progress and restarting browser after 500 companies...
#
# ✅ Progress saved to HC_data.xlsx
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36
#
# ❌ Failed — retrying with simplified name: Punjab And Sind Bank, Through Its Chief Manager
# ❌ Failed — retrying with simplified name: Punjab And Sind Bank, Zonal Office, Kolkata, Through Its Zonal Manager
# ❌ Failed — retrying with simplified name: Punjab And Sindh Bank, Barabanki Thru. Its Chief Manager
# ❌ Failed — retrying with simplified name: Punjab And Sindh Bank, Ladwa Branch Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Baraut Baghpat Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Branch 442300 Bijnor, Vikas Bhawan District-Bijnor Through Its Bank Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Branch Bawani Khera Through Its Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Branch Lakhimpur, Lakhimpur Kheri Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Branch Masigan Through Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Branch Sultanpur Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Hata, Manda, District Prayagraj Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Kalsana Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Main Branch Dhuri District Sangrur Thr Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Ram Ganga Vihar, Moradabad Through Its Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Represented Through Its Zonal Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Represented By Its Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Thou Its Wagholi Branch Thou Its Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Through Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Through Branch Manager,
# ❌ Failed — retrying with simplified name: Punjab National Bank Through Chief Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Through Its Authorized Officer / Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Through Its Chief Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Through Its Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank Thru Authorized Officer,Mr.Divyendu Gaurav (Chief Manager)
# ❌ Failed — retrying with simplified name: Punjab National Bank Thru. Authorized Officer,Smt. Kavita Kuchhal Agarwal Chief Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank, A Body Corporate, Nagpur, Thr. Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank, Branch Mohalla Ganj, District Firozabad, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank, Branch Ramnagar, District Bareilly Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank, Branch Sastripuram Sikandra, District Agra Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank, First Floor, Pnb Square, Sector 17 B, Chandigarh Through Its Zonal Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank, Ghaziabad Thru. Authorised Officer/ Chief Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank, Head Office Plot No. 4, Sector 10 Dwarka, New Delhi Through Its Chief Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank, Housing Finance Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank, Kanke Branch, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank, Lambi Through Branch Manager,
# ❌ Failed — retrying with simplified name: Punjab National Bank, Large Corporate Branch Through Its Bank Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank, Large Corporate Branch, Through Its Bank Manager,
# ❌ Failed — retrying with simplified name: Punjab National Bank, Nagpur, Thr. Manager
# ❌ Failed — retrying with simplified name: Punjab National Bank, Regional Office, Mathura, Through Its Regional Manager
# ...
# ❌ Failed — retrying with simplified name: State Bank Of India, Smec, Through Its Chief Manager,
# ❌ Failed — retrying with simplified name: State Bank Of India, State Industrial Branch, Aurangabad, Thr. Manager
#
# 💾 Saving progress and restarting browser after 650 companies...
#
# ✅ Progress saved to HC_data.xlsx
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36
#
# ❌ Failed — retrying with simplified name: State Bank Of India, Through Deputy General Manager
# ❌ Failed — retrying with simplified name: State Bank Of India, Through General Manager
# ❌ Failed — retrying with simplified name: State Bank Of India, Through Its Authorized Officer/Branch Manager
# ❌ Failed — retrying with simplified name: State Bank Of India, Through Its Authorized Officer/Chief Manager
# ❌ Failed — retrying with simplified name: State Bank Of India, Through Its General Manager
# ❌ Failed — retrying with simplified name: State Bank Of India, Through Its Regional Manager
# ❌ Failed — retrying with simplified name: State Bank Of India, Zonal Office, Gorakhpur Through Its Zonal Manager
# ❌ Failed — retrying with simplified name: State Bank Of India,Rep. By Its Branch Manager,
# ❌ Failed — retrying with simplified name: State Bank Of Inia Pathankot Thr Manager
# ❌ Failed — retrying with simplified name: State Bank Of Patiala Through Manager
# ❌ Failed — retrying with simplified name: State Bank Of Patiala, Branch Adb, Patiala Throughbranch Manager
# ❌ Failed — retrying with simplified name: State Of Bank Of India Sandila Branch, Hardoi Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Tarn Taran Central Cooperative Bank Through Its District Manager
# ❌ Failed — retrying with simplified name: Tavasya Ssf (C/O Tavasya Capital Managers Llp
# ❌ Failed — retrying with simplified name: Th Ebank Manager
# ❌ Failed — retrying with simplified name: Th General Manager Iti Limited
# ❌ Failed — retrying with simplified name: The Bank Manager
# ❌ Failed — retrying with simplified name: The Andhra Bank, Then Union Bank Of India Through Its Branch Manager
# ❌ Failed — retrying with simplified name: The Axis Bank, Branch-Iim Road, Lucknow, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: The Bank Manager,
# ❌ Failed — retrying with simplified name: The Bank Of Baroda General Manager,
# ❌ Failed — retrying with simplified name: The Bank Of Baroda Through Its Chief Manager
# ❌ Failed — retrying with simplified name: The Bank Of India, Branch-Gausganj, District-Hardoi, Through Its Branch Manager
# ❌ Failed — retrying with simplified name: The Bank Of Lndia Through Its Manager
# ❌ Failed — retrying with simplified name: The Bank Of Maharashtra Thr. Its Regional Manager
# ❌ Failed — retrying with simplified name: The Bihar State Cooperative Bank, Madhepura Through Its Branch Manager
# ❌ Failed — retrying with simplified name: The Canara Bank Rep. By Its Branch Manager,
# ❌ Failed — retrying with simplified name: The Canara Bank Through The General Manager,
# ❌ Failed — retrying with simplified name: The Canara Bank, Kadma Branch, Thro Its Branch Manager,
# ❌ Failed — retrying with simplified name: The Canara Bank, Through Its Regional Manager,
# ❌ Failed — retrying with simplified name: The Central Bank Of India Through Its Regional Manager
# ❌ Failed — retrying with simplified name: The Chief Bank Manager,
# ❌ Failed — retrying with simplified name: The Corporation Bank, Represented By Its Branch Manager
# ❌ Failed — retrying with simplified name: The District Lead Bank Manager
# ❌ Failed — retrying with simplified name: The Employers In Relation To The Management Of Bank Of India Through The Branch Manager,
# ❌ Failed — retrying with simplified name: The Federal Bank, Represented By Its Manager
# ❌ Failed — retrying with simplified name: The Ferozepur Primary Co-Op Development Bank Thr Assistant Manager
# ❌ Failed — retrying with simplified name: The Field Officer, Ioc Ltd
# ❌ Failed — retrying with simplified name: The Gdcc Bank Rep.By Its Manager,
# ❌ Failed — retrying with simplified name: The General Manager Iti Limited
# ❌ Failed — retrying with simplified name: The General Manager Iti Ltd
# ❌ Failed — retrying with simplified name: The General Manager, Ccl Ltd
# ❌ Failed — retrying with simplified name: The Hdfc Bank Cherthala Branch (Hdfc0001489), Represented By Its Manager
#
# 💾 Saving progress and restarting browser after 700 companies...
#
# ✅ Progress saved to HC_data.xlsx
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:120.0) Gecko/20100101 Firefox/120.0
#
# ❌ Failed — retrying with simplified name: The Hdfc Bank Represented By Bank Manager
# ❌ Failed — retrying with simplified name: The Hdfc Bank, Himatnagar Branch Through Manager
# ❌ Failed — retrying with simplified name: The Icici Bank, Devas Building, Represented By Its Branch Manager,
# ❌ Failed — retrying with simplified name: The Icici Bank, Represented By Its Manager,
# ❌ Failed — retrying with simplified name: The Idfc Bank, Rep By Its Branch Manager
# ❌ Failed — retrying with simplified name: The Indus Ind Bank Through Its Manager
# ❌ Failed — retrying with simplified name: The Induslnd Bank, Ramankulangara Branch, Represented By Its Manager
# ❌ Failed — retrying with simplified name: The Kerala Bank , Represented By Its General Manager,
# ❌ Failed — retrying with simplified name: The Kerala Gramin Bank, Rep By The Branch Manager,
# ❌ Failed — retrying with simplified name: The Kerala State Co-Operative Bank ( Kerala Bank) Aruvikkara Branch , Represented By Its Manager,
# ❌ Failed — retrying with simplified name: The Kerala State Co-Operative Bank Represented By Its General Manager
# ❌ Failed — retrying with simplified name: The Kerala State Co-Operative Bank Represented Its General Manager
# ❌ Failed — retrying with simplified name: The Kerala State Co-Operative Bank(Erstwhile Mdc Bank), Represented By Its Manager,
# ❌ Failed — retrying with simplified name: The Lead Bank Manager
# ❌ Failed — retrying with simplified name: The National Bank For Agriculture And Rural Development Through It Sgeneral Manager
# ❌ Failed — retrying with simplified name: The National Banking Zonal Manager
# ❌ Failed — retrying with simplified name: The Nodal Officer And Bank Manager,
# ❌ Failed — retrying with simplified name: The Punjab National Bank Through Its Zonal Manager,
# ❌ Failed — retrying with simplified name: The Punjab National Bank, Represented By Its Authorized Officer /Chief Manager,
# ❌ Failed — retrying with simplified name: The Punjab National Bank, Kanhan, Branch, Nagpur, Thr. Branch Manager
# ❌ Failed — retrying with simplified name: The Punjab National Bank, Mahatma Gandhi Avenue Branch Represented By Its Branch Manager
# ❌ Failed — retrying with simplified name: The Reginal Bank Manager
# ❌ Failed — retrying with simplified name: The Reserve Bank Of India Through Chief General Manager
# ❌ Failed — retrying with simplified name: The Reserve Bank Of India Through The Chief General Manager
# ❌ Failed — retrying with simplified name: The Reserve Bank Of India, Through Its General Manager
# ❌ Failed — retrying with simplified name: The Senior Bank Manager
# ❌ Failed — retrying with simplified name: The State Bank Of Idnai Through Its Manager
# ❌ Failed — retrying with simplified name: The State Bank Of India Thou Deputy General Manager
# ❌ Failed — retrying with simplified name: The State Bank Of India Through General Manager
# ❌ Failed — retrying with simplified name: The State Bank Of India Through Its Branch Manager
# ❌ Failed — retrying with simplified name: The State Bank Of India Through Its Manager
# ❌ Failed — retrying with simplified name: The State Bank Of India Through Shri Anurag Joshi, Chief General Manager
# ❌ Failed — retrying with simplified name: The State Bank Of India Through The Regional Manager
# ❌ Failed — retrying with simplified name: The State Bank Of India, Acting Thr. Its Deputy General Manager
# ❌ Failed — retrying with simplified name: The State Bank Of India, Amravati, Thr. Manager
# ❌ Failed — retrying with simplified name: The State Bank Of India, Cherthala Branch (Sbin0005046), Represented By Its Manager
# ❌ Failed — retrying with simplified name: The State Bank Of India, Small And Medium Enterprises, Thr. Its Branch Manager
# ❌ Failed — retrying with simplified name: The State Bank Of India, Through Branch Manager
# ❌ Failed — retrying with simplified name: The State Bank Of India, Through Its Chief General Manager
# ❌ Failed — retrying with simplified name: The State Bank Of Lndia Through Its Branch Manager
# ❌ Failed — retrying with simplified name: The State Bank Of Patiala Bank Now Sbi Through Its Manager
# ❌ Failed — retrying with simplified name: The State Of Bank Of India Through Its Branch Manager
# ❌ Failed — retrying with simplified name: The Vaibhav Nagar Co-Op Credit Societies Mumbai Through Its Bank Manager
#
# 💾 Saving progress and restarting browser after 750 companies...
#
# ✅ Progress saved to HC_data.xlsx
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.5993.90 Safari/537.36 Edg/118.0.2088.61
#
# ❌ Failed — retrying with simplified name: The Vaijpaur Merchant Cooperative Bank Through Its Manager
# ❌ Failed — retrying with simplified name: Through Legal Manager / Manager, Bajaj Allianz General Insurance Company Ltd
# ❌ Failed — retrying with simplified name: Trinity Investment Managers Ltd
# ❌ Failed — retrying with simplified name: U.C.O. Bank Zonal Office, Lko. Thru. Zonal Manager
# ❌ Failed — retrying with simplified name: U.P. Cooperative Village Development Bank Raniganj, Pratapgarh Thru. Branch Manager
# ❌ Failed — retrying with simplified name: U.P. Gram Vikas Bank Sultanpur Thru. Branch Manager
# ❌ Failed — retrying with simplified name: U.P. Gramin Bank Branch Mahadeva Kalan Gonda Thru. Branch Manager
# ❌ Failed — retrying with simplified name: U.P. Gramin Bank, Srinagar Babaganj, Gonda Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: U.P. Sahkari Gram Vikas Bank Lakhimpur Kheri Thru. Manager
# ❌ Failed — retrying with simplified name: U.P. Sahkari Gram Vikas Bank Through Its Manager
# ❌ Failed — retrying with simplified name: U.P. Sahkari Gramya Vikas Bank Gonda Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Uco Bank Ayodhya Zonal Office At Shiva Palace Deolali Bypass Ayodhya Thru. Zonal Branch Manager
# ❌ Failed — retrying with simplified name: Uco Bank Branch- Balangir, Odisha Thru Its Branch Manager
# ❌ Failed — retrying with simplified name: Uco Bank Branch Nandini Complex Civil Lines Sultanpur Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Uco Bank Itaunja Branch, Lucknow Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Uco Bank Represented By Its Manager,
# ❌ Failed — retrying with simplified name: Uco Bank Through Branch Manager
# ❌ Failed — retrying with simplified name: Uco Bank Through Chief Manager
# ❌ Failed — retrying with simplified name: Uco Bank Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Uco Bank, Branch Nakur District Saharanpur Through (Branch Manager)
# ❌ Failed — retrying with simplified name: Uco Bank, Nagpur, Thr. Manager
# ❌ Failed — retrying with simplified name: Uco Bank, Nagpur, Through Its Zonal Manager
# ❌ Failed — retrying with simplified name: Ujjivan Small Finance Bank Branch Zero Road Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India Barabanki Branch Thru. Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India Branch-Sarai Swami Airport Road Varanasi Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India Lucknow Main Branch Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India New Delhi Thru. Authorized Officr/ Chief Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India Raebareli Road Branch Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India Represented By Bank Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India Sham Branch Ii Floor Sharda Tower Kapoorthala Aliganj Lko Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India Through Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India Through Its Branch Manager,
# ❌ Failed — retrying with simplified name: Union Bank Of India Through Its Chief General Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India Through Its Deputy General Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India Through Its Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India, 341-G, Sadar Bazar, Cantonment, Jhansi Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India, Branch Basti-2, District-Basti Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India, Branch Chowk, Lko. Thru. Senior Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India, Branch Saraiya Nanhu, Gonda Thru. Its Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India, Branch Shahjahanpur Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India, Branch, Stb Hapur Branch Mandi Patia, District Hapur, Through Branch Manager/
# ❌ Failed — retrying with simplified name: Union Bank Of India, Lko. Thru. Its Deputy General Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India, Nagpur, Thr. Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India, Raj Nagar Branch, Uttar Pradesh Through Its Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India, Swaroop Nagar Branch, Kanpur Nagar Through Its Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Of India, Thoppumpady Branch, Represented By Its Branch Manager,
#
# 💾 Saving progress and restarting browser after 800 companies...
#
# ✅ Progress saved to HC_data.xlsx
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:120.0) Gecko/20100101 Firefox/120.0
#
# sleeping for 5 minutes for recovery
# 🧠 Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:120.0) Gecko/20100101 Firefox/120.0
#
# ❌ Failed — retrying with simplified name: Union Bank Of India, Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Of Indian, Branch Sukhipur, Phulvaria, Azamgarh Thru. Branch Manager
# ❌ Failed — retrying with simplified name: Union Bank Throu Manager
# ❌ Failed — retrying with simplified name: Urban Co-Operative Bank, Hadihall, Pratapgarh Thru. Its Secy. Manager
# ❌ Failed — retrying with simplified name: Yallp
# ❌ Failed — retrying with simplified name: Yes Bank Rep By Its General Manager
# ❌ Failed — retrying with simplified name: Yes Bank Represented By Bank Manager
# ❌ Failed — retrying with simplified name: Yes Bank Thr Its Branch Manager
# ❌ Failed — retrying with simplified name: Yes Bank, Represented By Its Manager,
# ❌ Failed — retrying with simplified name: Yes Bank, West Hill Brach, Represented By Its Branch Manager
# ❌ Failed — retrying with simplified name: Zonal Office Punjab & Sind Bank, Lucknow, U.P. Through Its Zonal Manager
# 🎉 All done! Final file saved to HC_data.xlsx
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 237
#     235 else:
#     236     if fuzz.ratio(row.input.lower().strip(), row.corrected_name.lower().replace("(old name)", "").strip()) != 100:
# --> 237         ratio_list.append(fuzz.ratio(normalize_company_suffix(row.input).strip(), normalize_company_suffix(row.corrected_name.replace("(old name)", "").strip())))
#     238     else:
#     239         ratio_list.append(fuzz.ratio(row.input.lower().strip(), row.corrected_name.lower().replace("(old name)", "").strip()))
#
# NameError: name 'normalize_company_suffix' is not defined
